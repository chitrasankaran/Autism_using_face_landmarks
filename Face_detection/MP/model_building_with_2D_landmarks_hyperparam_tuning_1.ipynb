# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ## Configure Project Path and other paths

# %%
import numpy as np
rstate = np.random.default_rng(seed=72)

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
proj_path = '/content/drive/MyDrive/Magnimind/Face_detection/MP'
os.chdir(proj_path)

# %%
train_csv_path = os.path.join(proj_path, 'train_2D.csv')
test_csv_path = os.path.join(proj_path, 'test_2D.csv')

# %% [markdown]
# ## Read data from csv to pandas dataframe

# %%
train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        839  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        825  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        817  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...        845  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        844  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_1_x  landmark_1_y  landmark_2_x  \
# 0      0.511593      0.709910      0.517181      0.670308      0.515403
# 1      0.566339      0.733220      0.575596      0.677747      0.568713
# 2      0.437217      0.744490      0.426740      0.685478      0.433244
# 3      0.533727      0.797597      0.549781      0.762331      0.540980
# 4      0.524054      0.774706      0.505436      0.710976      0.512779
#
#    landmark_2_y  landmark_3_x  ...  landmark_463_x  landmark_463_y  \
# 0      0.679123      0.500272  ...        0.614458        0.486299
# 1      0.697361      0.553947  ...        0.628819        0.549039
# 2      0.704711      0.405189  ...        0.517382        0.542334
# 3      0.772093      0.528068  ...        0.624055        0.614141
# 4      0.727149      0.466017  ...        0.550516        0.553379
#
#    landmark_464_x  landmark_464_y  landmark_465_x  landmark_465_y  \
# 0        0.597307        0.492995        0.587559        0.500262
# 1        0.615948        0.553194        0.609449        0.556148
# 2        0.499661        0.547696        0.488665        0.551752
# 3        0.608973        0.618901        0.601406        0.623819
# 4        0.536100        0.562195        0.528307        0.568924
#
#    landmark_466_x  landmark_466_y  landmark_467_x  landmark_467_y
# 0        0.768636        0.474503        0.784336        0.468965
# 1        0.738344        0.541875        0.751471        0.531839
# 2        0.656447        0.535078        0.674554        0.525373
# 3        0.766676        0.603243        0.782729        0.596054
# 4        0.683886        0.525732        0.697740        0.517121
#
# [5 rows x 939 columns]

# %%
test_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        100  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        108  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        106  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...          1  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        103  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_1_x  landmark_1_y  landmark_2_x  \
# 0      0.727391      0.710138      0.753489      0.581854      0.723864
# 1      0.457443      0.710929      0.437796      0.633989      0.445459
# 2      0.452099      0.779923      0.453784      0.726497      0.455887
# 3      0.457504      0.754957      0.470419      0.687706      0.467041
# 4      0.362426      0.740446      0.366750      0.668341      0.372543
#
#    landmark_2_y  landmark_3_x  ...  landmark_463_x  landmark_463_y  \
# 0      0.624057      0.699572  ...        0.749237        0.411756
# 1      0.658974      0.401915  ...        0.509359        0.460005
# 2      0.738631      0.441661  ...        0.577733        0.505678
# 3      0.708499      0.457171  ...        0.599581        0.529724
# 4      0.689162      0.377194  ...        0.525101        0.542058
#
#    landmark_464_x  landmark_464_y  landmark_465_x  landmark_465_y  \
# 0        0.737767        0.418196        0.737665        0.421433
# 1        0.492417        0.466946        0.482040        0.471925
# 2        0.558054        0.512911        0.546055        0.521134
# 3        0.578473        0.532598        0.565713        0.535771
# 4        0.504449        0.543285        0.491366        0.545638
#
#    landmark_466_x  landmark_466_y  landmark_467_x  landmark_467_y
# 0        0.890724        0.401811        0.903891        0.394724
# 1        0.660659        0.437236        0.679693        0.424461
# 2        0.749610        0.499630        0.771000        0.490222
# 3        0.783299        0.529403        0.804902        0.522787
# 4        0.686309        0.559731        0.705237        0.556214
#
# [5 rows x 939 columns]

# %%
train_df['label'].value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_1_x, landmark_1_y, landmark_2_x, landmark_2_y, landmark_3_x, landmark_3_y, landmark_4_x, landmark_4_y, landmark_5_x, landmark_5_y, landmark_6_x, landmark_6_y, landmark_7_x, landmark_7_y, landmark_8_x, landmark_8_y, landmark_9_x, landmark_9_y, landmark_10_x, landmark_10_y, landmark_11_x, landmark_11_y, landmark_12_x, landmark_12_y, landmark_13_x, landmark_13_y, landmark_14_x, landmark_14_y, landmark_15_x, landmark_15_y, landmark_16_x, landmark_16_y, landmark_17_x, landmark_17_y, landmark_18_x, landmark_18_y, landmark_19_x, landmark_19_y, landmark_20_x, landmark_20_y, landmark_21_x, landmark_21_y, landmark_22_x, landmark_22_y, landmark_23_x, landmark_23_y, landmark_24_x, landmark_24_y, landmark_25_x, landmark_25_y, landmark_26_x, landmark_26_y, landmark_27_x, landmark_27_y, landmark_28_x, landmark_28_y, landmark_29_x, landmark_29_y, landmark_30_x, landmark_30_y, landmark_31_x, landmark_31_y, landmark_32_x, landmark_32_y, landmark_33_x, landmark_33_y, landmark_34_x, landmark_34_y, landmark_35_x, landmark_35_y, landmark_36_x, landmark_36_y, landmark_37_x, landmark_37_y, landmark_38_x, landmark_38_y, landmark_39_x, landmark_39_y, landmark_40_x, landmark_40_y, landmark_41_x, landmark_41_y, landmark_42_x, landmark_42_y, landmark_43_x, landmark_43_y, landmark_44_x, landmark_44_y, landmark_45_x, landmark_45_y, landmark_46_x, landmark_46_y, landmark_47_x, landmark_47_y, landmark_48_x, ...]
# Index: []
#
# [0 rows x 939 columns]

# %%
test_df['label'].value_counts()
# Out:
# Autistic        150
# Non_Autistic    150
# Name: label, dtype: int64

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_1_x, landmark_1_y, landmark_2_x, landmark_2_y, landmark_3_x, landmark_3_y, landmark_4_x, landmark_4_y, landmark_5_x, landmark_5_y, landmark_6_x, landmark_6_y, landmark_7_x, landmark_7_y, landmark_8_x, landmark_8_y, landmark_9_x, landmark_9_y, landmark_10_x, landmark_10_y, landmark_11_x, landmark_11_y, landmark_12_x, landmark_12_y, landmark_13_x, landmark_13_y, landmark_14_x, landmark_14_y, landmark_15_x, landmark_15_y, landmark_16_x, landmark_16_y, landmark_17_x, landmark_17_y, landmark_18_x, landmark_18_y, landmark_19_x, landmark_19_y, landmark_20_x, landmark_20_y, landmark_21_x, landmark_21_y, landmark_22_x, landmark_22_y, landmark_23_x, landmark_23_y, landmark_24_x, landmark_24_y, landmark_25_x, landmark_25_y, landmark_26_x, landmark_26_y, landmark_27_x, landmark_27_y, landmark_28_x, landmark_28_y, landmark_29_x, landmark_29_y, landmark_30_x, landmark_30_y, landmark_31_x, landmark_31_y, landmark_32_x, landmark_32_y, landmark_33_x, landmark_33_y, landmark_34_x, landmark_34_y, landmark_35_x, landmark_35_y, landmark_36_x, landmark_36_y, landmark_37_x, landmark_37_y, landmark_38_x, landmark_38_y, landmark_39_x, landmark_39_y, landmark_40_x, landmark_40_y, landmark_41_x, landmark_41_y, landmark_42_x, landmark_42_y, landmark_43_x, landmark_43_y, landmark_44_x, landmark_44_y, landmark_45_x, landmark_45_y, landmark_46_x, landmark_46_y, landmark_47_x, landmark_47_y, landmark_48_x, ...]
# Index: []
#
# [0 rows x 939 columns]

# %% [markdown]
# ## Setting input features and output features

# %%
X = train_df.drop(columns=['img_path', 'image_num', 'label'])
y = train_df['label']

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
y = y.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
y.value_counts()
# Out:
# 1    1270
# 0     810
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, shuffle=True, random_state=72)

# %%
X_test = test_df.drop(columns=['img_path', 'image_num', 'label'])
y_test = test_df['label']
y_test = y_test.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
X_train.shape
# Out:
# (1560, 936)

# %%
X_val.shape
# Out:
# (520, 936)

# %%
X_test.shape
# Out:
# (300, 936)

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import precision_recall_curve
import numpy as np
from sklearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import hyperopt

# %%
# Initializing random_state
random_state = 72

# %%
from hyperopt.pyll.base import Apply

def hyperopt_indices_to_values(space, best):
    best_params = {}

    for key, val in best.items():
        print(f"Processing key: {key}, val: {val}")  # Debugging line
        #print(f"Type of space[key]: {type(space[key])}")  # Additional Debugging line
        #print(f"Name attribute of space[key] (if exists): {getattr(space[key], 'name', 'No name attribute')}")  # Additional Debugging line

        if key == 'penalty_solver':
            # Extract penalty and solver values directly from the tuple
            penalty, solver = space[key].pos_args[int(val) + 1].pos_args
            best_params['penalty'] = penalty.obj
            best_params['solver'] = solver.obj

        elif isinstance(space[key], Apply) and space[key].name == 'switch':
            # This means the parameter is defined using hp.choice
            selected_item = space[key].pos_args[val + 1]
            if key == 'hidden_layers':
                try:
                    # Attempt to unpack it as if it was a list
                    best_params[key] = [item.obj for item in selected_item.pos_args]
                except AttributeError:
                    # If there's an error, revert back to previous handling
                    best_params[key] = getattr(selected_item, 'obj', selected_item)

            else:
                # Handle the scenario where 'selected_item' might not have 'obj'
                best_params[key] = getattr(selected_item, 'obj', selected_item)

        else:
            # Otherwise, directly assign the value
            best_params[key] = val

    return best_params

# %%
def optimize_hyperparams(model_class, default_params, space,
                         X_train, y_train, enable_early_stopping=False,
                         max_evals=20, random_state=72):
    def objective(params):
        try:
            # If 'penalty_solver' is in params, get mapped 'penalty' and 'solver' params
            if 'penalty_solver' in params:
                params['penalty'], params['solver'] = params.pop('penalty_solver')

            # If the penalty is not 'elasticnet', remove the l1_ratio parameter
            if params.get('penalty') != 'elasticnet':
                params.pop('l1_ratio', None)


            all_params = {**default_params, **params}
            m = model_class(**all_params)

            cv_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

            if enable_early_stopping:
                # Set early_stopping_rounds
                m.set_params(early_stopping_rounds=3, eval_metric="logloss")
                scores = []

                for train_index, test_index in cv_folds.split(X_train, y_train):
                    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[test_index]

                    eval_set = [(X_val_fold, y_val_fold)]
                    m.fit(X_train_fold, y_train_fold,
                          eval_set=eval_set, verbose=True)

                    predictions = m.predict(X_val_fold)
                    score = f1_score(y_val_fold, predictions)
                    scores.append(score)

                return -np.mean(scores) # since we want to maximize F1 score

            else:
                loss = -cross_val_score(m, X_train, y_train, cv=cv_folds, scoring='f1').mean()
                return loss

        except Exception as e:
            print(f"Exception encountered: {e}")
            # Handle any other exception that arises during model training or evaluation
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest,
                max_evals=max_evals, trials=trials, rstate=rstate)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
# Evaluate the fitted pipeline
def evaluate(model, X, y):
    # Predict on given X
    y_pred = model.predict(X)

    # Calculate below evaluation metrics
    accuracy = round(accuracy_score(y, y_pred), 2)
    precision = round(precision_score(y, y_pred), 2)
    recall = round(recall_score(y, y_pred), 2)
    f1 = round(f1_score(y, y_pred), 2)

    # Return the values in a dictionary

    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
default_params = {
    'random_state': random_state,
    'max_iter': 3000,
    'class_weight': 'balanced',
}

lr_hyperparam_space = {
    # Combine penalty and solver
    'penalty_solver': hp.choice('penalty_solver', [
        ('l1', 'liblinear'),
        ('l2', 'liblinear'),
    ]),

    # Regularization strength
    'C': hp.loguniform('C', np.log(0.0001), np.log(1)),
}

# Using the function
best_params = optimize_hyperparams(LogisticRegression,
                                   default_params,
                                   lr_hyperparam_space,
                                   X_train, y_train,
                                   max_evals=30)
print(best_params)
# Out:
# 100%|██████████| 30/30 [00:34<00:00,  1.15s/trial, best loss: -0.7723447507133281]
# Processing key: C, val: 0.9584144891508987
# Processing key: penalty_solver, val: 1
# {'C': 0.9584144891508987, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
optimized_params = {**default_params, **best_params}
print(optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
lr = LogisticRegression(**optimized_params)
lr.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(lr, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(lr, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(lr, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'max_iter': 3000, 'class_weight': 'balanced', 'C': 0.9584144891508987, 'penalty': 'l2', 'solver': 'liblinear'}
# Training Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.81, 'Recall': 0.74, 'F1': 0.78}
#
# Validation Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.84, 'Recall': 0.74, 'F1': 0.79}
#
# Test Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.74, 'Recall': 0.78, 'F1': 0.76}

# %%
rf_default_params = {
    'random_state': random_state,
    'class_weight': 'balanced',
    'n_jobs': -1,
}

rf_hyperparam_space = {
    'n_estimators': hp.choice('n_estimators', list(range(50, 90, 10))),
    'max_depth': hp.choice('max_depth', list(range(2, 5))),  # Excluding None to prevent unlimited depth
    'min_samples_split': hp.uniform('min_samples_split', 0.01, 0.1),  # Increasing the lower bound to avoid tiny splits
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.005, 0.05),  # Increasing the lower bound to ensure larger leaves
    'max_features': hp.choice('max_features', [0.3, 0.4, 0.5, 'sqrt', 'log2']),  # Focusing on fewer feature options
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'bootstrap': hp.choice('bootstrap', [True]),
    'oob_score': hp.choice('oob_score', [True, False])
}

# Using the function
rf_best_params = optimize_hyperparams(RandomForestClassifier,
                                      rf_default_params,
                                      rf_hyperparam_space,
                                      X_train, y_train,
                                      max_evals=25)
print(rf_best_params)
# Out:
# 100%|██████████| 25/25 [08:11<00:00, 19.68s/trial, best loss: -0.7668196886720647]
# Processing key: bootstrap, val: 0
# Processing key: criterion, val: 1
# Processing key: max_depth, val: 2
# Processing key: max_features, val: 3
# Processing key: min_samples_leaf, val: 0.007672044168308856
# Processing key: min_samples_split, val: 0.09560597908843027
# Processing key: n_estimators, val: 2
# Processing key: oob_score, val: 1
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 0.007672044168308856, 'min_samples_split': 0.09560597908843027, 'n_estimators': 70, 'oob_score': False}

# %%
rf_optimized_params = {**rf_default_params, **rf_best_params}
print(rf_optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
rf = RandomForestClassifier(**rf_optimized_params)
rf.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(rf, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(rf, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(rf, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'class_weight': 'balanced', 'n_jobs': -1, 'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 0.007672044168308856, 'min_samples_split': 0.09560597908843027, 'n_estimators': 70, 'oob_score': False}
# Training Data Evaluation:
# {'Accuracy': 0.77, 'Precision': 0.82, 'Recall': 0.8, 'F1': 0.81}
#
# Validation Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.79, 'Recall': 0.77, 'F1': 0.78}
#
# Test Data Evaluation:
# {'Accuracy': 0.72, 'Precision': 0.68, 'Recall': 0.83, 'F1': 0.74}

# %%
adb_default_params = {
    'random_state': random_state,
}

adb_hyperparam_space = {
    # AdaBoost hyperparameters
    # Number of weak learners to train
    'n_estimators': hp.choice('n_estimators', list(range(10, 50, 3))),
    # Helps to shrink the contribution of each classifier
    'learning_rate': hp.loguniform('learning_rate', -7, 0), # Log uniform distribution between 1e-7 and 1
}

# Using the function
adb_best_params = optimize_hyperparams(AdaBoostClassifier,
                                       adb_default_params,
                                       adb_hyperparam_space,
                                       X_train, y_train,
                                       max_evals=20)
print(adb_best_params)
# Out:
# 100%|██████████| 20/20 [08:47<00:00, 26.36s/trial, best loss: -0.8018152320138]
# Processing key: learning_rate, val: 0.23576473845101711
# Processing key: n_estimators, val: 2
# {'learning_rate': 0.23576473845101711, 'n_estimators': 16}

# %%
# Merge default and best params
adb_optimized_params = {**adb_default_params, **adb_best_params}
print(adb_optimized_params)

# Train the model using the optimized parameters
adb = AdaBoostClassifier(**adb_optimized_params)
adb.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(adb, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(adb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(adb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'learning_rate': 0.23576473845101711, 'n_estimators': 16}
# Training Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.73, 'Recall': 0.92, 'F1': 0.81}
#
# Validation Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.73, 'Recall': 0.91, 'F1': 0.81}
#
# Test Data Evaluation:
# {'Accuracy': 0.66, 'Precision': 0.6, 'Recall': 0.94, 'F1': 0.73}

# %%
xgb_default_params = {
    'random_state': random_state,
    'n_jobs': -1,
}

# Hyperparams for XGB
xgb_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2.5), # smaller learning rates
    'n_estimators': hp.choice('n_estimators', [20, 30, 40, 50, 60, 70, 80]),
    'max_depth': hp.choice('max_depth', [1, 2, 3, 4]),
    'min_child_weight': hp.quniform('min_child_weight', 15, 50, 1), # increased min_child_weight range
    'gamma': hp.uniform('gamma', 0.2, 0.6), # increased lower bound
    'colsample_bytree': hp.uniform('colsample_bytree', 0.4, 0.7), # more conservative column sampling
    'alpha': hp.loguniform('alpha', -2, 3),
    'lambda': hp.loguniform('lambda', -2, 3),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 6)
}

# Using the function
xgb_best_params = optimize_hyperparams(XGBClassifier,
                                       xgb_default_params,
                                       xgb_hyperparam_space,
                                       X_train, y_train,
                                       enable_early_stopping=True,
                                       max_evals=25)
print(xgb_best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# [15]	validation_0-logloss:0.58762
# [16]	validation_0-logloss:0.58449
# [17]	validation_0-logloss:0.58096
# [18]	validation_0-logloss:0.57754
# [19]	validation_0-logloss:0.57480
# [20]	validation_0-logloss:0.57329
# [21]	validation_0-logloss:0.57139
# [22]	validation_0-logloss:0.56963
# [23]	validation_0-logloss:0.56856
# [24]	validation_0-logloss:0.56638
# [25]	validation_0-logloss:0.56400
# [26]	validation_0-logloss:0.56290
# [27]	validation_0-logloss:0.56118
# [28]	validation_0-logloss:0.56025
# [29]	validation_0-logloss:0.55865
# [30]	validation_0-logloss:0.55702
# [31]	validation_0-logloss:0.55569
# [32]	validation_0-logloss:0.55467
# [33]	validation_0-logloss:0.55370
# [34]	validation_0-logloss:0.55218
# [35]	validation_0-logloss:0.55079
# [36]	validation_0-logloss:0.54997
# [37]	validation_0-logloss:0.54921
# [38]	validation_0-logloss:0.54804
# [39]	validation_0-logloss:0.54752
# [40]	validation_0-logloss:0.54652
# [41]	validation_0-logloss:0.54612
# [42]	validation_0-logloss:0.54551
# [43]	validation_0-logloss:0.54459
# [44]	validation_0-logloss:0.54454
# [45]	validation_0-logloss:0.54402
# [46]	validation_0-logloss:0.54284
# [47]	validation_0-logloss:0.54270
# [48]	validation_0-logloss:0.54190
# [49]	validation_0-logloss:0.54083
# [50]	validation_0-logloss:0.54086
# [51]	validation_0-logloss:0.54047
# [52]	validation_0-logloss:0.53971
# [53]	validation_0-logloss:0.53940
# [54]	validation_0-logloss:0.53845
# [55]	validation_0-logloss:0.53785
# [56]	validation_0-logloss:0.53728
# [57]	validation_0-logloss:0.53739
# [58]	validation_0-logloss:0.53737
# [59]	validation_0-logloss:0.53683
# [60]	validation_0-logloss:0.53633
# [61]	validation_0-logloss:0.53598
# [62]	validation_0-logloss:0.53542
# [63]	validation_0-logloss:0.53486
# [64]	validation_0-logloss:0.53402
# [65]	validation_0-logloss:0.53419
# [66]	validation_0-logloss:0.53375
# [67]	validation_0-logloss:0.53366
# [68]	validation_0-logloss:0.53314
# [69]	validation_0-logloss:0.53319
# [70]	validation_0-logloss:0.53246
# [71]	validation_0-logloss:0.53198
# [72]	validation_0-logloss:0.53192
# [73]	validation_0-logloss:0.53132
# [74]	validation_0-logloss:0.53099
# [75]	validation_0-logloss:0.53074
# [76]	validation_0-logloss:0.53031
# [77]	validation_0-logloss:0.53025
# [78]	validation_0-logloss:0.52990
# [79]	validation_0-logloss:0.53003
# [0]	validation_0-logloss:0.67787
# [1]	validation_0-logloss:0.66711
# [2]	validation_0-logloss:0.65810
# [3]	validation_0-logloss:0.64922
# [4]	validation_0-logloss:0.64290
# [5]	validation_0-logloss:0.63674
# [6]	validation_0-logloss:0.63083
# [7]	validation_0-logloss:0.62743
# [8]	validation_0-logloss:0.62272
# [9]	validation_0-logloss:0.61881
# [10]	validation_0-logloss:0.61443
# [11]	validation_0-logloss:0.60996
# [12]	validation_0-logloss:0.60629
# [13]	validation_0-logloss:0.60354
# [14]	validation_0-logloss:0.60103
# [15]	validation_0-logloss:0.59831
# [16]	validation_0-logloss:0.59630
# [17]	validation_0-logloss:0.59361
# [18]	validation_0-logloss:0.59205
# [19]	validation_0-logloss:0.59016
# [20]	validation_0-logloss:0.58818
# [21]	validation_0-logloss:0.58727
# [22]	validation_0-logloss:0.58495
# [23]	validation_0-logloss:0.58362
# [24]	validation_0-logloss:0.58208
# [25]	validation_0-logloss:0.58082
# [26]	validation_0-logloss:0.58040
# [27]	validation_0-logloss:0.57900
# [28]	validation_0-logloss:0.57863
# [29]	validation_0-logloss:0.57794
# [30]	validation_0-logloss:0.57716
# [31]	validation_0-logloss:0.57661
# [32]	validation_0-logloss:0.57636
# [33]	validation_0-logloss:0.57570
# [34]	validation_0-logloss:0.57472
# [35]	validation_0-logloss:0.57368
# [36]	validation_0-logloss:0.57355
# [37]	validation_0-logloss:0.57267
# [38]	validation_0-logloss:0.57197
# [39]	validation_0-logloss:0.57113
# [40]	validation_0-logloss:0.57119
# [41]	validation_0-logloss:0.57092
# [42]	validation_0-logloss:0.57051
# [43]	validation_0-logloss:0.57032
# [44]	validation_0-logloss:0.56978
# [45]	validation_0-logloss:0.56923
# [46]	validation_0-logloss:0.56941
# [47]	validation_0-logloss:0.56922
# [48]	validation_0-logloss:0.56860
# [49]	validation_0-logloss:0.56805
# [50]	validation_0-logloss:0.56783
# [51]	validation_0-logloss:0.56731
# [52]	validation_0-logloss:0.56677
# [53]	validation_0-logloss:0.56686
# [54]	validation_0-logloss:0.56709
# [55]	validation_0-logloss:0.56644
# [56]	validation_0-logloss:0.56578
# [57]	validation_0-logloss:0.56544
# [58]	validation_0-logloss:0.56525
# [59]	validation_0-logloss:0.56501
# [60]	validation_0-logloss:0.56446
# [61]	validation_0-logloss:0.56410
# [62]	validation_0-logloss:0.56401
# [63]	validation_0-logloss:0.56402
# [64]	validation_0-logloss:0.56377
# [65]	validation_0-logloss:0.56339
# [66]	validation_0-logloss:0.56359
# [67]	validation_0-logloss:0.56331
# [68]	validation_0-logloss:0.56341
# [69]	validation_0-logloss:0.56297
# [70]	validation_0-logloss:0.56322
# [71]	validation_0-logloss:0.56272
# [72]	validation_0-logloss:0.56215
# [73]	validation_0-logloss:0.56198
# [74]	validation_0-logloss:0.56178
# [75]	validation_0-logloss:0.56210
# [76]	validation_0-logloss:0.56237
# [77]	validation_0-logloss:0.56181
# [0]	validation_0-logloss:0.67529
# [1]	validation_0-logloss:0.66595
# [2]	validation_0-logloss:0.65606
# [3]	validation_0-logloss:0.64733
# [4]	validation_0-logloss:0.64018
# [5]	validation_0-logloss:0.63325
# [6]	validation_0-logloss:0.62681
# [7]	validation_0-logloss:0.62044
# [8]	validation_0-logloss:0.61574
# [9]	validation_0-logloss:0.61259
# [10]	validation_0-logloss:0.60859
# [11]	validation_0-logloss:0.60607
# [12]	validation_0-logloss:0.60128
# [13]	validation_0-logloss:0.59854
# [14]	validation_0-logloss:0.59660
# [15]	validation_0-logloss:0.59545
# [16]	validation_0-logloss:0.59310
# [17]	validation_0-logloss:0.59092
# [18]	validation_0-logloss:0.58916
# [19]	validation_0-logloss:0.58712
# [20]	validation_0-logloss:0.58558
# [21]	validation_0-logloss:0.58360
# [22]	validation_0-logloss:0.58243
# [23]	validation_0-logloss:0.58108
# [24]	validation_0-logloss:0.57969
# [25]	validation_0-logloss:0.57831
# [26]	validation_0-logloss:0.57717
# [27]	validation_0-logloss:0.57506
# [28]	validation_0-logloss:0.57478
# [29]	validation_0-logloss:0.57389
# [30]	validation_0-logloss:0.57304
# [31]	validation_0-logloss:0.57171
# [32]	validation_0-logloss:0.57095
# [33]	validation_0-logloss:0.56938
# [34]	validation_0-logloss:0.56904
# [35]	validation_0-logloss:0.56825
# [36]	validation_0-logloss:0.56795
# [37]	validation_0-logloss:0.56775
# [38]	validation_0-logloss:0.56645
# [39]	validation_0-logloss:0.56595
# [40]	validation_0-logloss:0.56580
# [41]	validation_0-logloss:0.56484
# [42]	validation_0-logloss:0.56448
# [43]	validation_0-logloss:0.56376
# [44]	validation_0-logloss:0.56262
# [45]	validation_0-logloss:0.56231
# [46]	validation_0-logloss:0.56172
# [47]	validation_0-logloss:0.56149
# [48]	validation_0-logloss:0.56105
# [49]	validation_0-logloss:0.56133
# [50]	validation_0-logloss:0.56128
# [51]	validation_0-logloss:0.56045
# [52]	validation_0-logloss:0.56033
# [53]	validation_0-logloss:0.55925
# [54]	validation_0-logloss:0.55928
# [55]	validation_0-logloss:0.55862
# [56]	validation_0-logloss:0.55803
# [57]	validation_0-logloss:0.55845
# [58]	validation_0-logloss:0.55797
# [59]	validation_0-logloss:0.55762
# [60]	validation_0-logloss:0.55769
# [61]	validation_0-logloss:0.55750
# [62]	validation_0-logloss:0.55710
# [63]	validation_0-logloss:0.55678
# [64]	validation_0-logloss:0.55694
# [65]	validation_0-logloss:0.55732
# [66]	validation_0-logloss:0.55703
# [0]	validation_0-logloss:0.78735
# [1]	validation_0-logloss:0.78585
# [2]	validation_0-logloss:0.78424
# [3]	validation_0-logloss:0.78262
# [4]	validation_0-logloss:0.78115
# [5]	validation_0-logloss:0.77967
# [6]	validation_0-logloss:0.77829
# [7]	validation_0-logloss:0.77705
# [8]	validation_0-logloss:0.77570
# [9]	validation_0-logloss:0.77445
# [10]	validation_0-logloss:0.77248
# [11]	validation_0-logloss:0.77131
# [12]	validation_0-logloss:0.77017
# [13]	validation_0-logloss:0.76835
# [14]	validation_0-logloss:0.76728
# [15]	validation_0-logloss:0.76554
# [16]	validation_0-logloss:0.76453
# [17]	validation_0-logloss:0.76279
# [18]	validation_0-logloss:0.76183
# [19]	validation_0-logloss:0.76091
# [20]	validation_0-logloss:0.76002
# [21]	validation_0-logloss:0.75915
# [22]	validation_0-logloss:0.75767
# [23]	validation_0-logloss:0.75611
# [24]	validation_0-logloss:0.75453
# [25]	validation_0-logloss:0.75376
# [26]	validation_0-logloss:0.75258
# [27]	validation_0-logloss:0.75124
# [28]	validation_0-logloss:0.75006
# [29]	validation_0-logloss:0.74892
# [0]	validation_0-logloss:0.78712
# [1]	validation_0-logloss:0.78527
# [2]	validation_0-logloss:0.78349
# [3]	validation_0-logloss:0.78172
# [4]	validation_0-logloss:0.77958
# [5]	validation_0-logloss:0.77790
# [6]	validation_0-logloss:0.77596
# [7]	validation_0-logloss:0.77401
# [8]	validation_0-logloss:0.77246
# [9]	validation_0-logloss:0.77061
# [10]	validation_0-logloss:0.76915
# [11]	validation_0-logloss:0.76742
# [12]	validation_0-logloss:0.76575
# [13]	validation_0-logloss:0.76441
# [14]	validation_0-logloss:0.76283
# [15]	validation_0-logloss:0.76162
# [16]	validation_0-logloss:0.76012
# [17]	validation_0-logloss:0.75841
# [18]	validation_0-logloss:0.75699
# [19]	validation_0-logloss:0.75562
# [20]	validation_0-logloss:0.75429
# [21]	validation_0-logloss:0.75285
# [22]	validation_0-logloss:0.75132
# [23]	validation_0-logloss:0.75007
# [24]	validation_0-logloss:0.74875
# [25]	validation_0-logloss:0.74744
# [26]	validation_0-logloss:0.74604
# [27]	validation_0-logloss:0.74467
# [28]	validation_0-logloss:0.74335
# [29]	validation_0-logloss:0.74204
# [0]	validation_0-logloss:0.78166
# [1]	validation_0-logloss:0.77936
# [2]	validation_0-logloss:0.77737
# [3]	validation_0-logloss:0.77508
# [4]	validation_0-logloss:0.77297
# [5]	validation_0-logloss:0.77095
# [6]	validation_0-logloss:0.76895
# [7]	validation_0-logloss:0.76698
# [8]	validation_0-logloss:0.76502
# [9]	validation_0-logloss:0.76316
# [10]	validation_0-logloss:0.76154
# [11]	validation_0-logloss:0.75979
# [12]	validation_0-logloss:0.75800
# [13]	validation_0-logloss:0.75621
# [14]	validation_0-logloss:0.75452
# [15]	validation_0-logloss:0.75297
# [16]	validation_0-logloss:0.75144
# [17]	validation_0-logloss:0.75005
# [18]	validation_0-logloss:0.74855
# [19]	validation_0-logloss:0.74707
# [20]	validation_0-logloss:0.74566
# [21]	validation_0-logloss:0.74439
# [22]	validation_0-logloss:0.74313
# [23]	validation_0-logloss:0.74193
# [24]	validation_0-logloss:0.74031
# [25]	validation_0-logloss:0.73912
# [26]	validation_0-logloss:0.73756
# [27]	validation_0-logloss:0.73625
# [28]	validation_0-logloss:0.73476
# [29]	validation_0-logloss:0.73341
# [0]	validation_0-logloss:0.78163
# [1]	validation_0-logloss:0.77969
# [2]	validation_0-logloss:0.77810
# [3]	validation_0-logloss:0.77600
# [4]	validation_0-logloss:0.77404
# [5]	validation_0-logloss:0.77205
# [6]	validation_0-logloss:0.77012
# [7]	validation_0-logloss:0.76839
# [8]	validation_0-logloss:0.76671
# [9]	validation_0-logloss:0.76505
# [10]	validation_0-logloss:0.76336
# [11]	validation_0-logloss:0.76177
# [12]	validation_0-logloss:0.76019
# [13]	validation_0-logloss:0.75869
# [14]	validation_0-logloss:0.75755
# [15]	validation_0-logloss:0.75648
# [16]	validation_0-logloss:0.75509
# [17]	validation_0-logloss:0.75370
# [18]	validation_0-logloss:0.75243
# [19]	validation_0-logloss:0.75066
# [20]	validation_0-logloss:0.74940
# [21]	validation_0-logloss:0.74773
# [22]	validation_0-logloss:0.74626
# [23]	validation_0-logloss:0.74484
# [24]	validation_0-logloss:0.74350
# [25]	validation_0-logloss:0.74262
# [26]	validation_0-logloss:0.74135
# [27]	validation_0-logloss:0.73986
# [28]	validation_0-logloss:0.73841
# [29]	validation_0-logloss:0.73743
# [0]	validation_0-logloss:0.78212
# [1]	validation_0-logloss:0.78020
# [2]	validation_0-logloss:0.77834
# [3]	validation_0-logloss:0.77649
# [4]	validation_0-logloss:0.77475
# [5]	validation_0-logloss:0.77315
# [6]	validation_0-logloss:0.77149
# [7]	validation_0-logloss:0.76983
# [8]	validation_0-logloss:0.76770
# [9]	validation_0-logloss:0.76620
# [10]	validation_0-logloss:0.76405
# [11]	validation_0-logloss:0.76250
# [12]	validation_0-logloss:0.76115
# [13]	validation_0-logloss:0.75919
# [14]	validation_0-logloss:0.75790
# [15]	validation_0-logloss:0.75624
# [16]	validation_0-logloss:0.75453
# [17]	validation_0-logloss:0.75286
# [18]	validation_0-logloss:0.75122
# [19]	validation_0-logloss:0.74961
# [20]	validation_0-logloss:0.74808
# [21]	validation_0-logloss:0.74659
# [22]	validation_0-logloss:0.74514
# [23]	validation_0-logloss:0.74409
# [24]	validation_0-logloss:0.74273
# [25]	validation_0-logloss:0.74160
# [26]	validation_0-logloss:0.74031
# [27]	validation_0-logloss:0.73901
# [28]	validation_0-logloss:0.73778
# [29]	validation_0-logloss:0.73700
# [0]	validation_0-logloss:0.80620
# [1]	validation_0-logloss:0.80233
# [2]	validation_0-logloss:0.79984
# [3]	validation_0-logloss:0.79651
# [4]	validation_0-logloss:0.79349
# [5]	validation_0-logloss:0.79069
# [6]	validation_0-logloss:0.78845
# [7]	validation_0-logloss:0.78618
# [8]	validation_0-logloss:0.78469
# [9]	validation_0-logloss:0.78248
# [10]	validation_0-logloss:0.78162
# [11]	validation_0-logloss:0.78036
# [12]	validation_0-logloss:0.77845
# [13]	validation_0-logloss:0.77742
# [14]	validation_0-logloss:0.77648
# [15]	validation_0-logloss:0.77567
# [16]	validation_0-logloss:0.77419
# [17]	validation_0-logloss:0.77402
# [18]	validation_0-logloss:0.77266
# [19]	validation_0-logloss:0.76957
# [0]	validation_0-logloss:0.80669
# [1]	validation_0-logloss:0.80278
# [2]	validation_0-logloss:0.79989
# [3]	validation_0-logloss:0.79667
# [4]	validation_0-logloss:0.79308
# [5]	validation_0-logloss:0.79055
# [6]	validation_0-logloss:0.78754
# [7]	validation_0-logloss:0.78526
# [8]	validation_0-logloss:0.78325
# [9]	validation_0-logloss:0.78082
# [10]	validation_0-logloss:0.77939
# [11]	validation_0-logloss:0.77732
# [12]	validation_0-logloss:0.77544
# [13]	validation_0-logloss:0.77411
# [14]	validation_0-logloss:0.77291
# [15]	validation_0-logloss:0.77207
# [16]	validation_0-logloss:0.76860
# [17]	validation_0-logloss:0.76615
# [18]	validation_0-logloss:0.76471
# [19]	validation_0-logloss:0.76146
# [0]	validation_0-logloss:0.80056
# [1]	validation_0-logloss:0.79614
# [2]	validation_0-logloss:0.79284
# [3]	validation_0-logloss:0.78851
# [4]	validation_0-logloss:0.78499
# [5]	validation_0-logloss:0.78179
# [6]	validation_0-logloss:0.77805
# [7]	validation_0-logloss:0.77565
# [8]	validation_0-logloss:0.77274
# [9]	validation_0-logloss:0.77095
# [10]	validation_0-logloss:0.76899
# [11]	validation_0-logloss:0.76675
# [12]	validation_0-logloss:0.76454
# [13]	validation_0-logloss:0.76298
# [14]	validation_0-logloss:0.75906
# [15]	validation_0-logloss:0.75863
# [16]	validation_0-logloss:0.75656
# [17]	validation_0-logloss:0.75319
# [18]	validation_0-logloss:0.75031
# [19]	validation_0-logloss:0.74802
# [0]	validation_0-logloss:0.80195
# [1]	validation_0-logloss:0.79867
# [2]	validation_0-logloss:0.79630
# [3]	validation_0-logloss:0.79408
# [4]	validation_0-logloss:0.79170
# [5]	validation_0-logloss:0.78981
# [6]	validation_0-logloss:0.78793
# [7]	validation_0-logloss:0.78610
# [8]	validation_0-logloss:0.78446
# [9]	validation_0-logloss:0.78301
# [10]	validation_0-logloss:0.78186
# [11]	validation_0-logloss:0.77900
# [12]	validation_0-logloss:0.77570
# [13]	validation_0-logloss:0.77306
# [14]	validation_0-logloss:0.76961
# [15]	validation_0-logloss:0.76905
# [16]	validation_0-logloss:0.76603
# [17]	validation_0-logloss:0.76321
# [18]	validation_0-logloss:0.76085
# [19]	validation_0-logloss:0.75850
# [0]	validation_0-logloss:0.80070
# [1]	validation_0-logloss:0.79660
# [2]	validation_0-logloss:0.79355
# [3]	validation_0-logloss:0.79069
# [4]	validation_0-logloss:0.78795
# [5]	validation_0-logloss:0.78550
# [6]	validation_0-logloss:0.78326
# [7]	validation_0-logloss:0.78126
# [8]	validation_0-logloss:0.77915
# [9]	validation_0-logloss:0.77774
# [10]	validation_0-logloss:0.77652
# [11]	validation_0-logloss:0.77507
# [12]	validation_0-logloss:0.77392
# [13]	validation_0-logloss:0.77227
# [14]	validation_0-logloss:0.77136
# [15]	validation_0-logloss:0.77109
# [16]	validation_0-logloss:0.76793
# [17]	validation_0-logloss:0.76692
# [18]	validation_0-logloss:0.76547
# [19]	validation_0-logloss:0.76420
# [0]	validation_0-logloss:0.69500
# [1]	validation_0-logloss:0.69349
# [2]	validation_0-logloss:0.69194
# [3]	validation_0-logloss:0.69039
# [4]	validation_0-logloss:0.68904
# [5]	validation_0-logloss:0.68756
# [6]	validation_0-logloss:0.68618
# [7]	validation_0-logloss:0.68483
# [8]	validation_0-logloss:0.68341
# [9]	validation_0-logloss:0.68217
# [10]	validation_0-logloss:0.68082
# [11]	validation_0-logloss:0.67948
# [12]	validation_0-logloss:0.67818
# [13]	validation_0-logloss:0.67693
# [14]	validation_0-logloss:0.67566
# [15]	validation_0-logloss:0.67451
# [16]	validation_0-logloss:0.67328
# [17]	validation_0-logloss:0.67215
# [18]	validation_0-logloss:0.67107
# [19]	validation_0-logloss:0.66994
# [20]	validation_0-logloss:0.66868
# [21]	validation_0-logloss:0.66760
# [22]	validation_0-logloss:0.66638
# [23]	validation_0-logloss:0.66521
# [24]	validation_0-logloss:0.66401
# [25]	validation_0-logloss:0.66303
# [26]	validation_0-logloss:0.66188
# [27]	validation_0-logloss:0.66097
# [28]	validation_0-logloss:0.65986
# [29]	validation_0-logloss:0.65875
# [0]	validation_0-logloss:0.69494
# [1]	validation_0-logloss:0.69329
# [2]	validation_0-logloss:0.69166
# [3]	validation_0-logloss:0.69007
# [4]	validation_0-logloss:0.68839
# [5]	validation_0-logloss:0.68685
# [6]	validation_0-logloss:0.68534
# [7]	validation_0-logloss:0.68390
# [8]	validation_0-logloss:0.68244
# [9]	validation_0-logloss:0.68107
# [10]	validation_0-logloss:0.67968
# [11]	validation_0-logloss:0.67829
# [12]	validation_0-logloss:0.67693
# [13]	validation_0-logloss:0.67557
# [14]	validation_0-logloss:0.67426
# [15]	validation_0-logloss:0.67299
# [16]	validation_0-logloss:0.67174
# [17]	validation_0-logloss:0.67050
# [18]	validation_0-logloss:0.66920
# [19]	validation_0-logloss:0.66782
# [20]	validation_0-logloss:0.66662
# [21]	validation_0-logloss:0.66541
# [22]	validation_0-logloss:0.66423
# [23]	validation_0-logloss:0.66292
# [24]	validation_0-logloss:0.66158
# [25]	validation_0-logloss:0.66029
# [26]	validation_0-logloss:0.65911
# [27]	validation_0-logloss:0.65782
# [28]	validation_0-logloss:0.65669
# [29]	validation_0-logloss:0.65545
# [0]	validation_0-logloss:0.69173
# [1]	validation_0-logloss:0.69013
# [2]	validation_0-logloss:0.68828
# [3]	validation_0-logloss:0.68648
# [4]	validation_0-logloss:0.68498
# [5]	validation_0-logloss:0.68339
# [6]	validation_0-logloss:0.68193
# [7]	validation_0-logloss:0.68037
# [8]	validation_0-logloss:0.67900
# [9]	validation_0-logloss:0.67740
# [10]	validation_0-logloss:0.67576
# [11]	validation_0-logloss:0.67442
# [12]	validation_0-logloss:0.67286
# [13]	validation_0-logloss:0.67146
# [14]	validation_0-logloss:0.66996
# [15]	validation_0-logloss:0.66857
# [16]	validation_0-logloss:0.66722
# [17]	validation_0-logloss:0.66579
# [18]	validation_0-logloss:0.66451
# [19]	validation_0-logloss:0.66313
# [20]	validation_0-logloss:0.66177
# [21]	validation_0-logloss:0.66044
# [22]	validation_0-logloss:0.65924
# [23]	validation_0-logloss:0.65796
# [24]	validation_0-logloss:0.65669
# [25]	validation_0-logloss:0.65563
# [26]	validation_0-logloss:0.65451
# [27]	validation_0-logloss:0.65331
# [28]	validation_0-logloss:0.65210
# [29]	validation_0-logloss:0.65092
# [0]	validation_0-logloss:0.69175
# [1]	validation_0-logloss:0.69019
# [2]	validation_0-logloss:0.68865
# [3]	validation_0-logloss:0.68721
# [4]	validation_0-logloss:0.68566
# [5]	validation_0-logloss:0.68422
# [6]	validation_0-logloss:0.68277
# [7]	validation_0-logloss:0.68136
# [8]	validation_0-logloss:0.67996
# [9]	validation_0-logloss:0.67860
# [10]	validation_0-logloss:0.67730
# [11]	validation_0-logloss:0.67603
# [12]	validation_0-logloss:0.67475
# [13]	validation_0-logloss:0.67348
# [14]	validation_0-logloss:0.67224
# [15]	validation_0-logloss:0.67108
# [16]	validation_0-logloss:0.66993
# [17]	validation_0-logloss:0.66875
# [18]	validation_0-logloss:0.66761
# [19]	validation_0-logloss:0.66647
# [20]	validation_0-logloss:0.66530
# [21]	validation_0-logloss:0.66421
# [22]	validation_0-logloss:0.66290
# [23]	validation_0-logloss:0.66172
# [24]	validation_0-logloss:0.66046
# [25]	validation_0-logloss:0.65931
# [26]	validation_0-logloss:0.65807
# [27]	validation_0-logloss:0.65695
# [28]	validation_0-logloss:0.65590
# [29]	validation_0-logloss:0.65471
# [0]	validation_0-logloss:0.69197
# [1]	validation_0-logloss:0.69065
# [2]	validation_0-logloss:0.68896
# [3]	validation_0-logloss:0.68733
# [4]	validation_0-logloss:0.68607
# [5]	validation_0-logloss:0.68447
# [6]	validation_0-logloss:0.68279
# [7]	validation_0-logloss:0.68132
# [8]	validation_0-logloss:0.67971
# [9]	validation_0-logloss:0.67859
# [10]	validation_0-logloss:0.67716
# [11]	validation_0-logloss:0.67604
# [12]	validation_0-logloss:0.67463
# [13]	validation_0-logloss:0.67329
# [14]	validation_0-logloss:0.67192
# [15]	validation_0-logloss:0.67070
# [16]	validation_0-logloss:0.66947
# [17]	validation_0-logloss:0.66821
# [18]	validation_0-logloss:0.66702
# [19]	validation_0-logloss:0.66575
# [20]	validation_0-logloss:0.66451
# [21]	validation_0-logloss:0.66329
# [22]	validation_0-logloss:0.66215
# [23]	validation_0-logloss:0.66094
# [24]	validation_0-logloss:0.65977
# [25]	validation_0-logloss:0.65888
# [26]	validation_0-logloss:0.65780
# [27]	validation_0-logloss:0.65668
# [28]	validation_0-logloss:0.65556
# [29]	validation_0-logloss:0.65453
# [0]	validation_0-logloss:0.72150
# [1]	validation_0-logloss:0.71883
# [2]	validation_0-logloss:0.71547
# [3]	validation_0-logloss:0.71257
# [4]	validation_0-logloss:0.71019
# [5]	validation_0-logloss:0.70753
# [6]	validation_0-logloss:0.70516
# [7]	validation_0-logloss:0.70288
# [8]	validation_0-logloss:0.70024
# [9]	validation_0-logloss:0.69813
# [10]	validation_0-logloss:0.69558
# [11]	validation_0-logloss:0.69285
# [12]	validation_0-logloss:0.69095
# [13]	validation_0-logloss:0.68864
# [14]	validation_0-logloss:0.68625
# [15]	validation_0-logloss:0.68454
# [16]	validation_0-logloss:0.68227
# [17]	validation_0-logloss:0.68008
# [18]	validation_0-logloss:0.67798
# [19]	validation_0-logloss:0.67617
# [20]	validation_0-logloss:0.67408
# [21]	validation_0-logloss:0.67204
# [22]	validation_0-logloss:0.67028
# [23]	validation_0-logloss:0.66864
# [24]	validation_0-logloss:0.66663
# [25]	validation_0-logloss:0.66488
# [26]	validation_0-logloss:0.66331
# [27]	validation_0-logloss:0.66150
# [28]	validation_0-logloss:0.65984
# [29]	validation_0-logloss:0.65870
# [30]	validation_0-logloss:0.65721
# [31]	validation_0-logloss:0.65544
# [32]	validation_0-logloss:0.65413
# [33]	validation_0-logloss:0.65274
# [34]	validation_0-logloss:0.65129
# [35]	validation_0-logloss:0.64985
# [36]	validation_0-logloss:0.64860
# [37]	validation_0-logloss:0.64727
# [38]	validation_0-logloss:0.64585
# [39]	validation_0-logloss:0.64479
# [40]	validation_0-logloss:0.64377
# [41]	validation_0-logloss:0.64252
# [42]	validation_0-logloss:0.64111
# [43]	validation_0-logloss:0.63985
# [44]	validation_0-logloss:0.63891
# [45]	validation_0-logloss:0.63821
# [46]	validation_0-logloss:0.63721
# [47]	validation_0-logloss:0.63599
# [48]	validation_0-logloss:0.63502
# [49]	validation_0-logloss:0.63409
# [50]	validation_0-logloss:0.63320
# [51]	validation_0-logloss:0.63195
# [52]	validation_0-logloss:0.63072
# [53]	validation_0-logloss:0.62987
# [54]	validation_0-logloss:0.62921
# [55]	validation_0-logloss:0.62825
# [56]	validation_0-logloss:0.62744
# [57]	validation_0-logloss:0.62650
# [58]	validation_0-logloss:0.62569
# [59]	validation_0-logloss:0.62511
# [60]	validation_0-logloss:0.62433
# [61]	validation_0-logloss:0.62361
# [62]	validation_0-logloss:0.62275
# [63]	validation_0-logloss:0.62215
# [64]	validation_0-logloss:0.62147
# [65]	validation_0-logloss:0.62047
# [66]	validation_0-logloss:0.61992
# [67]	validation_0-logloss:0.61922
# [68]	validation_0-logloss:0.61852
# [69]	validation_0-logloss:0.61804
# [70]	validation_0-logloss:0.61739
# [71]	validation_0-logloss:0.61665
# [72]	validation_0-logloss:0.61610
# [73]	validation_0-logloss:0.61549
# [74]	validation_0-logloss:0.61497
# [75]	validation_0-logloss:0.61426
# [76]	validation_0-logloss:0.61357
# [77]	validation_0-logloss:0.61308
# [78]	validation_0-logloss:0.61264
# [79]	validation_0-logloss:0.61208
# [0]	validation_0-logloss:0.72148
# [1]	validation_0-logloss:0.71826
# [2]	validation_0-logloss:0.71571
# [3]	validation_0-logloss:0.71221
# [4]	validation_0-logloss:0.70931
# [5]	validation_0-logloss:0.70608
# [6]	validation_0-logloss:0.70339
# [7]	validation_0-logloss:0.70081
# [8]	validation_0-logloss:0.69793
# [9]	validation_0-logloss:0.69553
# [10]	validation_0-logloss:0.69280
# [11]	validation_0-logloss:0.69056
# [12]	validation_0-logloss:0.68805
# [13]	validation_0-logloss:0.68561
# [14]	validation_0-logloss:0.68329
# [15]	validation_0-logloss:0.68130
# [16]	validation_0-logloss:0.67890
# [17]	validation_0-logloss:0.67668
# [18]	validation_0-logloss:0.67464
# [19]	validation_0-logloss:0.67277
# [20]	validation_0-logloss:0.67057
# [21]	validation_0-logloss:0.66843
# [22]	validation_0-logloss:0.66672
# [23]	validation_0-logloss:0.66485
# [24]	validation_0-logloss:0.66313
# [25]	validation_0-logloss:0.66167
# [26]	validation_0-logloss:0.66006
# [27]	validation_0-logloss:0.65822
# [28]	validation_0-logloss:0.65639
# [29]	validation_0-logloss:0.65500
# [30]	validation_0-logloss:0.65359
# [31]	validation_0-logloss:0.65232
# [32]	validation_0-logloss:0.65095
# [33]	validation_0-logloss:0.64956
# [34]	validation_0-logloss:0.64826
# [35]	validation_0-logloss:0.64698
# [36]	validation_0-logloss:0.64566
# [37]	validation_0-logloss:0.64448
# [38]	validation_0-logloss:0.64327
# [39]	validation_0-logloss:0.64186
# [40]	validation_0-logloss:0.64069
# [41]	validation_0-logloss:0.63933
# [42]	validation_0-logloss:0.63835
# [43]	validation_0-logloss:0.63730
# [44]	validation_0-logloss:0.63636
# [45]	validation_0-logloss:0.63520
# [46]	validation_0-logloss:0.63431
# [47]	validation_0-logloss:0.63344
# [48]	validation_0-logloss:0.63247
# [49]	validation_0-logloss:0.63163
# [50]	validation_0-logloss:0.63082
# [51]	validation_0-logloss:0.62992
# [52]	validation_0-logloss:0.62905
# [53]	validation_0-logloss:0.62808
# [54]	validation_0-logloss:0.62727
# [55]	validation_0-logloss:0.62648
# [56]	validation_0-logloss:0.62577
# [57]	validation_0-logloss:0.62471
# [58]	validation_0-logloss:0.62402
# [59]	validation_0-logloss:0.62317
# [60]	validation_0-logloss:0.62225
# [61]	validation_0-logloss:0.62135
# [62]	validation_0-logloss:0.62039
# [63]	validation_0-logloss:0.61983
# [64]	validation_0-logloss:0.61893
# [65]	validation_0-logloss:0.61818
# [66]	validation_0-logloss:0.61756
# [67]	validation_0-logloss:0.61681
# [68]	validation_0-logloss:0.61605
# [69]	validation_0-logloss:0.61531
# [70]	validation_0-logloss:0.61467
# [71]	validation_0-logloss:0.61395
# [72]	validation_0-logloss:0.61320
# [73]	validation_0-logloss:0.61255
# [74]	validation_0-logloss:0.61179
# [75]	validation_0-logloss:0.61112
# [76]	validation_0-logloss:0.61073
# [77]	validation_0-logloss:0.61011
# [78]	validation_0-logloss:0.60961
# [79]	validation_0-logloss:0.60909
# [0]	validation_0-logloss:0.71716
# [1]	validation_0-logloss:0.71390
# [2]	validation_0-logloss:0.71073
# [3]	validation_0-logloss:0.70743
# [4]	validation_0-logloss:0.70449
# [5]	validation_0-logloss:0.70166
# [6]	validation_0-logloss:0.69855
# [7]	validation_0-logloss:0.69568
# [8]	validation_0-logloss:0.69274
# [9]	validation_0-logloss:0.69015
# [10]	validation_0-logloss:0.68787
# [11]	validation_0-logloss:0.68523
# [12]	validation_0-logloss:0.68226
# [13]	validation_0-logloss:0.67957
# [14]	validation_0-logloss:0.67688
# [15]	validation_0-logloss:0.67475
# [16]	validation_0-logloss:0.67220
# [17]	validation_0-logloss:0.66972
# [18]	validation_0-logloss:0.66743
# [19]	validation_0-logloss:0.66499
# [20]	validation_0-logloss:0.66282
# [21]	validation_0-logloss:0.66072
# [22]	validation_0-logloss:0.65879
# [23]	validation_0-logloss:0.65676
# [24]	validation_0-logloss:0.65451
# [25]	validation_0-logloss:0.65277
# [26]	validation_0-logloss:0.65090
# [27]	validation_0-logloss:0.64907
# [28]	validation_0-logloss:0.64723
# [29]	validation_0-logloss:0.64550
# [30]	validation_0-logloss:0.64387
# [31]	validation_0-logloss:0.64199
# [32]	validation_0-logloss:0.64043
# [33]	validation_0-logloss:0.63894
# [34]	validation_0-logloss:0.63742
# [35]	validation_0-logloss:0.63609
# [36]	validation_0-logloss:0.63460
# [37]	validation_0-logloss:0.63334
# [38]	validation_0-logloss:0.63189
# [39]	validation_0-logloss:0.63046
# [40]	validation_0-logloss:0.62924
# [41]	validation_0-logloss:0.62802
# [42]	validation_0-logloss:0.62681
# [43]	validation_0-logloss:0.62505
# [44]	validation_0-logloss:0.62362
# [45]	validation_0-logloss:0.62251
# [46]	validation_0-logloss:0.62132
# [47]	validation_0-logloss:0.62021
# [48]	validation_0-logloss:0.61915
# [49]	validation_0-logloss:0.61807
# [50]	validation_0-logloss:0.61699
# [51]	validation_0-logloss:0.61609
# [52]	validation_0-logloss:0.61523
# [53]	validation_0-logloss:0.61419
# [54]	validation_0-logloss:0.61326
# [55]	validation_0-logloss:0.61207
# [56]	validation_0-logloss:0.61076
# [57]	validation_0-logloss:0.60992
# [58]	validation_0-logloss:0.60907
# [59]	validation_0-logloss:0.60821
# [60]	validation_0-logloss:0.60724
# [61]	validation_0-logloss:0.60634
# [62]	validation_0-logloss:0.60555
# [63]	validation_0-logloss:0.60478
# [64]	validation_0-logloss:0.60389
# [65]	validation_0-logloss:0.60316
# [66]	validation_0-logloss:0.60243
# [67]	validation_0-logloss:0.60167
# [68]	validation_0-logloss:0.60101
# [69]	validation_0-logloss:0.60025
# [70]	validation_0-logloss:0.59945
# [71]	validation_0-logloss:0.59884
# [72]	validation_0-logloss:0.59813
# [73]	validation_0-logloss:0.59749
# [74]	validation_0-logloss:0.59697
# [75]	validation_0-logloss:0.59629
# [76]	validation_0-logloss:0.59574
# [77]	validation_0-logloss:0.59507
# [78]	validation_0-logloss:0.59452
# [79]	validation_0-logloss:0.59356
# [0]	validation_0-logloss:0.71782
# [1]	validation_0-logloss:0.71502
# [2]	validation_0-logloss:0.71268
# [3]	validation_0-logloss:0.71022
# [4]	validation_0-logloss:0.70771
# [5]	validation_0-logloss:0.70543
# [6]	validation_0-logloss:0.70323
# [7]	validation_0-logloss:0.70107
# [8]	validation_0-logloss:0.69831
# [9]	validation_0-logloss:0.69623
# [10]	validation_0-logloss:0.69355
# [11]	validation_0-logloss:0.69091
# [12]	validation_0-logloss:0.68819
# [13]	validation_0-logloss:0.68598
# [14]	validation_0-logloss:0.68334
# [15]	validation_0-logloss:0.68159
# [16]	validation_0-logloss:0.67904
# [17]	validation_0-logloss:0.67649
# [18]	validation_0-logloss:0.67410
# [19]	validation_0-logloss:0.67188
# [20]	validation_0-logloss:0.66971
# [21]	validation_0-logloss:0.66777
# [22]	validation_0-logloss:0.66615
# [23]	validation_0-logloss:0.66426
# [24]	validation_0-logloss:0.66250
# [25]	validation_0-logloss:0.66123
# [26]	validation_0-logloss:0.65973
# [27]	validation_0-logloss:0.65786
# [28]	validation_0-logloss:0.65637
# [29]	validation_0-logloss:0.65500
# [30]	validation_0-logloss:0.65373
# [31]	validation_0-logloss:0.65224
# [32]	validation_0-logloss:0.65093
# [33]	validation_0-logloss:0.64982
# [34]	validation_0-logloss:0.64880
# [35]	validation_0-logloss:0.64756
# [36]	validation_0-logloss:0.64614
# [37]	validation_0-logloss:0.64496
# [38]	validation_0-logloss:0.64382
# [39]	validation_0-logloss:0.64278
# [40]	validation_0-logloss:0.64164
# [41]	validation_0-logloss:0.64070
# [42]	validation_0-logloss:0.63960
# [43]	validation_0-logloss:0.63849
# [44]	validation_0-logloss:0.63727
# [45]	validation_0-logloss:0.63624
# [46]	validation_0-logloss:0.63542
# [47]	validation_0-logloss:0.63437
# [48]	validation_0-logloss:0.63355
# [49]	validation_0-logloss:0.63280
# [50]	validation_0-logloss:0.63183
# [51]	validation_0-logloss:0.63092
# [52]	validation_0-logloss:0.63015
# [53]	validation_0-logloss:0.62937
# [54]	validation_0-logloss:0.62876
# [55]	validation_0-logloss:0.62791
# [56]	validation_0-logloss:0.62708
# [57]	validation_0-logloss:0.62655
# [58]	validation_0-logloss:0.62583
# [59]	validation_0-logloss:0.62524
# [60]	validation_0-logloss:0.62458
# [61]	validation_0-logloss:0.62380
# [62]	validation_0-logloss:0.62304
# [63]	validation_0-logloss:0.62257
# [64]	validation_0-logloss:0.62183
# [65]	validation_0-logloss:0.62119
# [66]	validation_0-logloss:0.62052
# [67]	validation_0-logloss:0.61997
# [68]	validation_0-logloss:0.61933
# [69]	validation_0-logloss:0.61872
# [70]	validation_0-logloss:0.61811
# [71]	validation_0-logloss:0.61756
# [72]	validation_0-logloss:0.61714
# [73]	validation_0-logloss:0.61646
# [74]	validation_0-logloss:0.61590
# [75]	validation_0-logloss:0.61536
# [76]	validation_0-logloss:0.61490
# [77]	validation_0-logloss:0.61438
# [78]	validation_0-logloss:0.61403
# [79]	validation_0-logloss:0.61346
# [0]	validation_0-logloss:0.71728
# [1]	validation_0-logloss:0.71402
# [2]	validation_0-logloss:0.71125
# [3]	validation_0-logloss:0.70776
# [4]	validation_0-logloss:0.70485
# [5]	validation_0-logloss:0.70149
# [6]	validation_0-logloss:0.69883
# [7]	validation_0-logloss:0.69631
# [8]	validation_0-logloss:0.69384
# [9]	validation_0-logloss:0.69126
# [10]	validation_0-logloss:0.68900
# [11]	validation_0-logloss:0.68675
# [12]	validation_0-logloss:0.68406
# [13]	validation_0-logloss:0.68202
# [14]	validation_0-logloss:0.67971
# [15]	validation_0-logloss:0.67811
# [16]	validation_0-logloss:0.67582
# [17]	validation_0-logloss:0.67366
# [18]	validation_0-logloss:0.67136
# [19]	validation_0-logloss:0.66965
# [20]	validation_0-logloss:0.66743
# [21]	validation_0-logloss:0.66537
# [22]	validation_0-logloss:0.66382
# [23]	validation_0-logloss:0.66191
# [24]	validation_0-logloss:0.66007
# [25]	validation_0-logloss:0.65861
# [26]	validation_0-logloss:0.65722
# [27]	validation_0-logloss:0.65544
# [28]	validation_0-logloss:0.65407
# [29]	validation_0-logloss:0.65270
# [30]	validation_0-logloss:0.65138
# [31]	validation_0-logloss:0.64985
# [32]	validation_0-logloss:0.64865
# [33]	validation_0-logloss:0.64747
# [34]	validation_0-logloss:0.64646
# [35]	validation_0-logloss:0.64516
# [36]	validation_0-logloss:0.64383
# [37]	validation_0-logloss:0.64259
# [38]	validation_0-logloss:0.64139
# [39]	validation_0-logloss:0.64043
# [40]	validation_0-logloss:0.63942
# [41]	validation_0-logloss:0.63850
# [42]	validation_0-logloss:0.63736
# [43]	validation_0-logloss:0.63639
# [44]	validation_0-logloss:0.63488
# [45]	validation_0-logloss:0.63406
# [46]	validation_0-logloss:0.63322
# [47]	validation_0-logloss:0.63221
# [48]	validation_0-logloss:0.63145
# [49]	validation_0-logloss:0.63067
# [50]	validation_0-logloss:0.62990
# [51]	validation_0-logloss:0.62892
# [52]	validation_0-logloss:0.62800
# [53]	validation_0-logloss:0.62720
# [54]	validation_0-logloss:0.62657
# [55]	validation_0-logloss:0.62546
# [56]	validation_0-logloss:0.62486
# [57]	validation_0-logloss:0.62393
# [58]	validation_0-logloss:0.62353
# [59]	validation_0-logloss:0.62281
# [60]	validation_0-logloss:0.62212
# [61]	validation_0-logloss:0.62155
# [62]	validation_0-logloss:0.62062
# [63]	validation_0-logloss:0.62018
# [64]	validation_0-logloss:0.61951
# [65]	validation_0-logloss:0.61872
# [66]	validation_0-logloss:0.61833
# [67]	validation_0-logloss:0.61788
# [68]	validation_0-logloss:0.61753
# [69]	validation_0-logloss:0.61683
# [70]	validation_0-logloss:0.61649
# [71]	validation_0-logloss:0.61579
# [72]	validation_0-logloss:0.61516
# [73]	validation_0-logloss:0.61435
# [74]	validation_0-logloss:0.61353
# [75]	validation_0-logloss:0.61280
# [76]	validation_0-logloss:0.61247
# [77]	validation_0-logloss:0.61212
# [78]	validation_0-logloss:0.61163
# [79]	validation_0-logloss:0.61091
# [0]	validation_0-logloss:0.72369
# [1]	validation_0-logloss:0.72096
# [2]	validation_0-logloss:0.71810
# [3]	validation_0-logloss:0.71542
# [4]	validation_0-logloss:0.71350
# [5]	validation_0-logloss:0.71121
# [6]	validation_0-logloss:0.70905
# [7]	validation_0-logloss:0.70712
# [8]	validation_0-logloss:0.70516
# [9]	validation_0-logloss:0.70324
# [10]	validation_0-logloss:0.70146
# [11]	validation_0-logloss:0.69903
# [12]	validation_0-logloss:0.69752
# [13]	validation_0-logloss:0.69520
# [14]	validation_0-logloss:0.69364
# [15]	validation_0-logloss:0.69253
# [16]	validation_0-logloss:0.69033
# [17]	validation_0-logloss:0.68931
# [18]	validation_0-logloss:0.68721
# [19]	validation_0-logloss:0.68586
# [20]	validation_0-logloss:0.68385
# [21]	validation_0-logloss:0.68260
# [22]	validation_0-logloss:0.68068
# [23]	validation_0-logloss:0.67920
# [24]	validation_0-logloss:0.67832
# [25]	validation_0-logloss:0.67650
# [26]	validation_0-logloss:0.67569
# [27]	validation_0-logloss:0.67395
# [28]	validation_0-logloss:0.67264
# [29]	validation_0-logloss:0.67098
# [30]	validation_0-logloss:0.67033
# [31]	validation_0-logloss:0.66965
# [32]	validation_0-logloss:0.66807
# [33]	validation_0-logloss:0.66655
# [34]	validation_0-logloss:0.66593
# [35]	validation_0-logloss:0.66483
# [36]	validation_0-logloss:0.66432
# [37]	validation_0-logloss:0.66288
# [38]	validation_0-logloss:0.66149
# [39]	validation_0-logloss:0.66074
# [40]	validation_0-logloss:0.65941
# [41]	validation_0-logloss:0.65895
# [42]	validation_0-logloss:0.65802
# [43]	validation_0-logloss:0.65675
# [44]	validation_0-logloss:0.65637
# [45]	validation_0-logloss:0.65516
# [46]	validation_0-logloss:0.65453
# [47]	validation_0-logloss:0.65337
# [48]	validation_0-logloss:0.65304
# [49]	validation_0-logloss:0.65269
# [50]	validation_0-logloss:0.65159
# [51]	validation_0-logloss:0.65103
# [52]	validation_0-logloss:0.65028
# [53]	validation_0-logloss:0.64999
# [54]	validation_0-logloss:0.64949
# [55]	validation_0-logloss:0.64845
# [56]	validation_0-logloss:0.64746
# [57]	validation_0-logloss:0.64696
# [58]	validation_0-logloss:0.64600
# [59]	validation_0-logloss:0.64580
# [60]	validation_0-logloss:0.64501
# [61]	validation_0-logloss:0.64409
# [62]	validation_0-logloss:0.64386
# [63]	validation_0-logloss:0.64320
# [64]	validation_0-logloss:0.64281
# [65]	validation_0-logloss:0.64194
# [66]	validation_0-logloss:0.64153
# [67]	validation_0-logloss:0.64081
# [68]	validation_0-logloss:0.63998
# [69]	validation_0-logloss:0.63928
# [0]	validation_0-logloss:0.72380
# [1]	validation_0-logloss:0.72058
# [2]	validation_0-logloss:0.71778
# [3]	validation_0-logloss:0.71513
# [4]	validation_0-logloss:0.71240
# [5]	validation_0-logloss:0.71001
# [6]	validation_0-logloss:0.70756
# [7]	validation_0-logloss:0.70526
# [8]	validation_0-logloss:0.70321
# [9]	validation_0-logloss:0.70114
# [10]	validation_0-logloss:0.69874
# [11]	validation_0-logloss:0.69644
# [12]	validation_0-logloss:0.69455
# [13]	validation_0-logloss:0.69237
# [14]	validation_0-logloss:0.69067
# [15]	validation_0-logloss:0.68883
# [16]	validation_0-logloss:0.68677
# [17]	validation_0-logloss:0.68496
# [18]	validation_0-logloss:0.68341
# [19]	validation_0-logloss:0.68152
# [20]	validation_0-logloss:0.68027
# [21]	validation_0-logloss:0.67847
# [22]	validation_0-logloss:0.67694
# [23]	validation_0-logloss:0.67538
# [24]	validation_0-logloss:0.67373
# [25]	validation_0-logloss:0.67246
# [26]	validation_0-logloss:0.67142
# [27]	validation_0-logloss:0.66993
# [28]	validation_0-logloss:0.66896
# [29]	validation_0-logloss:0.66754
# [30]	validation_0-logloss:0.66610
# [31]	validation_0-logloss:0.66521
# [32]	validation_0-logloss:0.66385
# [33]	validation_0-logloss:0.66302
# [34]	validation_0-logloss:0.66204
# [35]	validation_0-logloss:0.66115
# [36]	validation_0-logloss:0.65988
# [37]	validation_0-logloss:0.65870
# [38]	validation_0-logloss:0.65757
# [39]	validation_0-logloss:0.65676
# [40]	validation_0-logloss:0.65561
# [41]	validation_0-logloss:0.65466
# [42]	validation_0-logloss:0.65375
# [43]	validation_0-logloss:0.65266
# [44]	validation_0-logloss:0.65206
# [45]	validation_0-logloss:0.65108
# [46]	validation_0-logloss:0.65017
# [47]	validation_0-logloss:0.64918
# [48]	validation_0-logloss:0.64819
# [49]	validation_0-logloss:0.64740
# [50]	validation_0-logloss:0.64664
# [51]	validation_0-logloss:0.64570
# [52]	validation_0-logloss:0.64488
# [53]	validation_0-logloss:0.64398
# [54]	validation_0-logloss:0.64320
# [55]	validation_0-logloss:0.64252
# [56]	validation_0-logloss:0.64192
# [57]	validation_0-logloss:0.64107
# [58]	validation_0-logloss:0.64037
# [59]	validation_0-logloss:0.63973
# [60]	validation_0-logloss:0.63893
# [61]	validation_0-logloss:0.63825
# [62]	validation_0-logloss:0.63766
# [63]	validation_0-logloss:0.63689
# [64]	validation_0-logloss:0.63639
# [65]	validation_0-logloss:0.63571
# [66]	validation_0-logloss:0.63509
# [67]	validation_0-logloss:0.63446
# [68]	validation_0-logloss:0.63393
# [69]	validation_0-logloss:0.63369
# [0]	validation_0-logloss:0.71920
# [1]	validation_0-logloss:0.71577
# [2]	validation_0-logloss:0.71186
# [3]	validation_0-logloss:0.70827
# [4]	validation_0-logloss:0.70533
# [5]	validation_0-logloss:0.70305
# [6]	validation_0-logloss:0.70087
# [7]	validation_0-logloss:0.69770
# [8]	validation_0-logloss:0.69564
# [9]	validation_0-logloss:0.69310
# [10]	validation_0-logloss:0.69116
# [11]	validation_0-logloss:0.68833
# [12]	validation_0-logloss:0.68650
# [13]	validation_0-logloss:0.68372
# [14]	validation_0-logloss:0.68200
# [15]	validation_0-logloss:0.67938
# [16]	validation_0-logloss:0.67770
# [17]	validation_0-logloss:0.67614
# [18]	validation_0-logloss:0.67396
# [19]	validation_0-logloss:0.67235
# [20]	validation_0-logloss:0.67090
# [21]	validation_0-logloss:0.66939
# [22]	validation_0-logloss:0.66797
# [23]	validation_0-logloss:0.66609
# [24]	validation_0-logloss:0.66479
# [25]	validation_0-logloss:0.66342
# [26]	validation_0-logloss:0.66152
# [27]	validation_0-logloss:0.66031
# [28]	validation_0-logloss:0.65904
# [29]	validation_0-logloss:0.65735
# [30]	validation_0-logloss:0.65615
# [31]	validation_0-logloss:0.65446
# [32]	validation_0-logloss:0.65285
# [33]	validation_0-logloss:0.65106
# [34]	validation_0-logloss:0.65001
# [35]	validation_0-logloss:0.64900
# [36]	validation_0-logloss:0.64805
# [37]	validation_0-logloss:0.64710
# [38]	validation_0-logloss:0.64569
# [39]	validation_0-logloss:0.64450
# [40]	validation_0-logloss:0.64362
# [41]	validation_0-logloss:0.64223
# [42]	validation_0-logloss:0.64091
# [43]	validation_0-logloss:0.63944
# [44]	validation_0-logloss:0.63817
# [45]	validation_0-logloss:0.63739
# [46]	validation_0-logloss:0.63653
# [47]	validation_0-logloss:0.63533
# [48]	validation_0-logloss:0.63442
# [49]	validation_0-logloss:0.63322
# [50]	validation_0-logloss:0.63251
# [51]	validation_0-logloss:0.63165
# [52]	validation_0-logloss:0.63082
# [53]	validation_0-logloss:0.62970
# [54]	validation_0-logloss:0.62905
# [55]	validation_0-logloss:0.62799
# [56]	validation_0-logloss:0.62731
# [57]	validation_0-logloss:0.62654
# [58]	validation_0-logloss:0.62541
# [59]	validation_0-logloss:0.62489
# [60]	validation_0-logloss:0.62432
# [61]	validation_0-logloss:0.62337
# [62]	validation_0-logloss:0.62244
# [63]	validation_0-logloss:0.62176
# [64]	validation_0-logloss:0.62125
# [65]	validation_0-logloss:0.62036
# [66]	validation_0-logloss:0.61989
# [67]	validation_0-logloss:0.61930
# [68]	validation_0-logloss:0.61870
# [69]	validation_0-logloss:0.61808
# [0]	validation_0-logloss:0.71996
# [1]	validation_0-logloss:0.71723
# [2]	validation_0-logloss:0.71432
# [3]	validation_0-logloss:0.71187
# [4]	validation_0-logloss:0.70936
# [5]	validation_0-logloss:0.70681
# [6]	validation_0-logloss:0.70454
# [7]	validation_0-logloss:0.70230
# [8]	validation_0-logloss:0.70017
# [9]	validation_0-logloss:0.69828
# [10]	validation_0-logloss:0.69616
# [11]	validation_0-logloss:0.69438
# [12]	validation_0-logloss:0.69238
# [13]	validation_0-logloss:0.69069
# [14]	validation_0-logloss:0.68882
# [15]	validation_0-logloss:0.68704
# [16]	validation_0-logloss:0.68546
# [17]	validation_0-logloss:0.68379
# [18]	validation_0-logloss:0.68229
# [19]	validation_0-logloss:0.68086
# [20]	validation_0-logloss:0.67949
# [21]	validation_0-logloss:0.67806
# [22]	validation_0-logloss:0.67677
# [23]	validation_0-logloss:0.67530
# [24]	validation_0-logloss:0.67408
# [25]	validation_0-logloss:0.67255
# [26]	validation_0-logloss:0.67140
# [27]	validation_0-logloss:0.67004
# [28]	validation_0-logloss:0.66875
# [29]	validation_0-logloss:0.66767
# [30]	validation_0-logloss:0.66664
# [31]	validation_0-logloss:0.66544
# [32]	validation_0-logloss:0.66447
# [33]	validation_0-logloss:0.66331
# [34]	validation_0-logloss:0.66253
# [35]	validation_0-logloss:0.66144
# [36]	validation_0-logloss:0.66052
# [37]	validation_0-logloss:0.65947
# [38]	validation_0-logloss:0.65863
# [39]	validation_0-logloss:0.65779
# [40]	validation_0-logloss:0.65686
# [41]	validation_0-logloss:0.65590
# [42]	validation_0-logloss:0.65501
# [43]	validation_0-logloss:0.65439
# [44]	validation_0-logloss:0.65355
# [45]	validation_0-logloss:0.65283
# [46]	validation_0-logloss:0.65203
# [47]	validation_0-logloss:0.65124
# [48]	validation_0-logloss:0.65053
# [49]	validation_0-logloss:0.64985
# [50]	validation_0-logloss:0.64894
# [51]	validation_0-logloss:0.64835
# [52]	validation_0-logloss:0.64757
# [53]	validation_0-logloss:0.64701
# [54]	validation_0-logloss:0.64633
# [55]	validation_0-logloss:0.64565
# [56]	validation_0-logloss:0.64486
# [57]	validation_0-logloss:0.64433
# [58]	validation_0-logloss:0.64373
# [59]	validation_0-logloss:0.64307
# [60]	validation_0-logloss:0.64258
# [61]	validation_0-logloss:0.64208
# [62]	validation_0-logloss:0.64129
# [63]	validation_0-logloss:0.64082
# [64]	validation_0-logloss:0.64027
# [65]	validation_0-logloss:0.63993
# [66]	validation_0-logloss:0.63938
# [67]	validation_0-logloss:0.63894
# [68]	validation_0-logloss:0.63853
# [69]	validation_0-logloss:0.63788
# [0]	validation_0-logloss:0.71922
# [1]	validation_0-logloss:0.71579
# [2]	validation_0-logloss:0.71284
# [3]	validation_0-logloss:0.71006
# [4]	validation_0-logloss:0.70737
# [5]	validation_0-logloss:0.70485
# [6]	validation_0-logloss:0.70218
# [7]	validation_0-logloss:0.69987
# [8]	validation_0-logloss:0.69835
# [9]	validation_0-logloss:0.69639
# [10]	validation_0-logloss:0.69435
# [11]	validation_0-logloss:0.69272
# [12]	validation_0-logloss:0.69080
# [13]	validation_0-logloss:0.68876
# [14]	validation_0-logloss:0.68701
# [15]	validation_0-logloss:0.68529
# [16]	validation_0-logloss:0.68337
# [17]	validation_0-logloss:0.68153
# [18]	validation_0-logloss:0.67975
# [19]	validation_0-logloss:0.67817
# [20]	validation_0-logloss:0.67649
# [21]	validation_0-logloss:0.67552
# [22]	validation_0-logloss:0.67369
# [23]	validation_0-logloss:0.67232
# [24]	validation_0-logloss:0.67078
# [25]	validation_0-logloss:0.66951
# [26]	validation_0-logloss:0.66807
# [27]	validation_0-logloss:0.66680
# [28]	validation_0-logloss:0.66583
# [29]	validation_0-logloss:0.66463
# [30]	validation_0-logloss:0.66373
# [31]	validation_0-logloss:0.66244
# [32]	validation_0-logloss:0.66091
# [33]	validation_0-logloss:0.65981
# [34]	validation_0-logloss:0.65862
# [35]	validation_0-logloss:0.65782
# [36]	validation_0-logloss:0.65679
# [37]	validation_0-logloss:0.65542
# [38]	validation_0-logloss:0.65469
# [39]	validation_0-logloss:0.65374
# [40]	validation_0-logloss:0.65313
# [41]	validation_0-logloss:0.65209
# [42]	validation_0-logloss:0.65125
# [43]	validation_0-logloss:0.65005
# [44]	validation_0-logloss:0.64946
# [45]	validation_0-logloss:0.64892
# [46]	validation_0-logloss:0.64816
# [47]	validation_0-logloss:0.64734
# [48]	validation_0-logloss:0.64656
# [49]	validation_0-logloss:0.64569
# [50]	validation_0-logloss:0.64485
# [51]	validation_0-logloss:0.64412
# [52]	validation_0-logloss:0.64310
# [53]	validation_0-logloss:0.64267
# [54]	validation_0-logloss:0.64221
# [55]	validation_0-logloss:0.64146
# [56]	validation_0-logloss:0.64104
# [57]	validation_0-logloss:0.64039
# [58]	validation_0-logloss:0.63977
# [59]	validation_0-logloss:0.63920
# [60]	validation_0-logloss:0.63884
# [61]	validation_0-logloss:0.63826
# [62]	validation_0-logloss:0.63793
# [63]	validation_0-logloss:0.63730
# [64]	validation_0-logloss:0.63696
# [65]	validation_0-logloss:0.63612
# [66]	validation_0-logloss:0.63560
# [67]	validation_0-logloss:0.63532
# [68]	validation_0-logloss:0.63483
# [69]	validation_0-logloss:0.63426
# [0]	validation_0-logloss:0.77261
# [1]	validation_0-logloss:0.76981
# [2]	validation_0-logloss:0.76748
# [3]	validation_0-logloss:0.76477
# [4]	validation_0-logloss:0.76272
# [5]	validation_0-logloss:0.76022
# [6]	validation_0-logloss:0.75790
# [7]	validation_0-logloss:0.75597
# [8]	validation_0-logloss:0.75366
# [9]	validation_0-logloss:0.75136
# [10]	validation_0-logloss:0.74922
# [11]	validation_0-logloss:0.74706
# [12]	validation_0-logloss:0.74491
# [13]	validation_0-logloss:0.74280
# [14]	validation_0-logloss:0.74080
# [15]	validation_0-logloss:0.73887
# [16]	validation_0-logloss:0.73727
# [17]	validation_0-logloss:0.73544
# [18]	validation_0-logloss:0.73372
# [19]	validation_0-logloss:0.73238
# [20]	validation_0-logloss:0.73112
# [21]	validation_0-logloss:0.72936
# [22]	validation_0-logloss:0.72823
# [23]	validation_0-logloss:0.72694
# [24]	validation_0-logloss:0.72550
# [25]	validation_0-logloss:0.72392
# [26]	validation_0-logloss:0.72254
# [27]	validation_0-logloss:0.72143
# [28]	validation_0-logloss:0.72059
# [29]	validation_0-logloss:0.71913
# [30]	validation_0-logloss:0.71799
# [31]	validation_0-logloss:0.71652
# [32]	validation_0-logloss:0.71565
# [33]	validation_0-logloss:0.71459
# [34]	validation_0-logloss:0.71343
# [35]	validation_0-logloss:0.71233
# [36]	validation_0-logloss:0.71128
# [37]	validation_0-logloss:0.71003
# [38]	validation_0-logloss:0.70911
# [39]	validation_0-logloss:0.70809
# [40]	validation_0-logloss:0.70754
# [41]	validation_0-logloss:0.70689
# [42]	validation_0-logloss:0.70585
# [43]	validation_0-logloss:0.70506
# [44]	validation_0-logloss:0.70447
# [45]	validation_0-logloss:0.70334
# [46]	validation_0-logloss:0.70245
# [47]	validation_0-logloss:0.70161
# [48]	validation_0-logloss:0.70091
# [49]	validation_0-logloss:0.70031
# [50]	validation_0-logloss:0.69923
# [51]	validation_0-logloss:0.69825
# [52]	validation_0-logloss:0.69744
# [53]	validation_0-logloss:0.69627
# [54]	validation_0-logloss:0.69544
# [55]	validation_0-logloss:0.69458
# [56]	validation_0-logloss:0.69386
# [57]	validation_0-logloss:0.69284
# ...
# [30]	validation_0-logloss:0.61449
# [31]	validation_0-logloss:0.61390
# [32]	validation_0-logloss:0.61363
# [33]	validation_0-logloss:0.61237
# [34]	validation_0-logloss:0.61210
# [35]	validation_0-logloss:0.61112
# [36]	validation_0-logloss:0.60934
# [37]	validation_0-logloss:0.60957
# [38]	validation_0-logloss:0.60908
# [39]	validation_0-logloss:0.60808
# [0]	validation_0-logloss:0.73591
# [1]	validation_0-logloss:0.72288
# [2]	validation_0-logloss:0.70892
# [3]	validation_0-logloss:0.69748
# [4]	validation_0-logloss:0.68878
# [5]	validation_0-logloss:0.68247
# [6]	validation_0-logloss:0.67655
# [7]	validation_0-logloss:0.67037
# [8]	validation_0-logloss:0.66659
# [9]	validation_0-logloss:0.66255
# [10]	validation_0-logloss:0.65786
# [11]	validation_0-logloss:0.65459
# [12]	validation_0-logloss:0.65187
# [13]	validation_0-logloss:0.64823
# [14]	validation_0-logloss:0.64593
# [15]	validation_0-logloss:0.64368
# [16]	validation_0-logloss:0.64134
# [17]	validation_0-logloss:0.63944
# [18]	validation_0-logloss:0.63724
# [19]	validation_0-logloss:0.63547
# [20]	validation_0-logloss:0.63357
# [21]	validation_0-logloss:0.63233
# [22]	validation_0-logloss:0.63119
# [23]	validation_0-logloss:0.63081
# [24]	validation_0-logloss:0.62886
# [25]	validation_0-logloss:0.62574
# [26]	validation_0-logloss:0.62528
# [27]	validation_0-logloss:0.62402
# [28]	validation_0-logloss:0.62265
# [29]	validation_0-logloss:0.62021
# [30]	validation_0-logloss:0.61960
# [31]	validation_0-logloss:0.61904
# [32]	validation_0-logloss:0.61805
# [33]	validation_0-logloss:0.61798
# [34]	validation_0-logloss:0.61706
# [35]	validation_0-logloss:0.61482
# [36]	validation_0-logloss:0.61279
# [37]	validation_0-logloss:0.61249
# [38]	validation_0-logloss:0.61250
# [39]	validation_0-logloss:0.61152
# [0]	validation_0-logloss:0.74052
# [1]	validation_0-logloss:0.72827
# [2]	validation_0-logloss:0.71664
# [3]	validation_0-logloss:0.70617
# [4]	validation_0-logloss:0.69872
# [5]	validation_0-logloss:0.69127
# [6]	validation_0-logloss:0.68473
# [7]	validation_0-logloss:0.67913
# [8]	validation_0-logloss:0.67380
# [9]	validation_0-logloss:0.66765
# [10]	validation_0-logloss:0.66376
# [11]	validation_0-logloss:0.66007
# [12]	validation_0-logloss:0.65498
# [13]	validation_0-logloss:0.65052
# [14]	validation_0-logloss:0.64633
# [15]	validation_0-logloss:0.64222
# [16]	validation_0-logloss:0.63906
# [17]	validation_0-logloss:0.63559
# [18]	validation_0-logloss:0.63398
# [19]	validation_0-logloss:0.63089
# [20]	validation_0-logloss:0.62858
# [21]	validation_0-logloss:0.62660
# [22]	validation_0-logloss:0.62379
# [23]	validation_0-logloss:0.62228
# [24]	validation_0-logloss:0.62005
# [25]	validation_0-logloss:0.61711
# [26]	validation_0-logloss:0.61383
# [27]	validation_0-logloss:0.61250
# [28]	validation_0-logloss:0.61177
# [29]	validation_0-logloss:0.60934
# [30]	validation_0-logloss:0.60781
# [31]	validation_0-logloss:0.60626
# [32]	validation_0-logloss:0.60438
# [33]	validation_0-logloss:0.60140
# [34]	validation_0-logloss:0.59810
# [35]	validation_0-logloss:0.59811
# [36]	validation_0-logloss:0.59621
# [37]	validation_0-logloss:0.59555
# [38]	validation_0-logloss:0.59466
# [39]	validation_0-logloss:0.59321
# [0]	validation_0-logloss:0.73996
# [1]	validation_0-logloss:0.72631
# [2]	validation_0-logloss:0.71282
# [3]	validation_0-logloss:0.70211
# [4]	validation_0-logloss:0.69291
# [5]	validation_0-logloss:0.68497
# [6]	validation_0-logloss:0.67765
# [7]	validation_0-logloss:0.67008
# [8]	validation_0-logloss:0.66403
# [9]	validation_0-logloss:0.65922
# [10]	validation_0-logloss:0.65368
# [11]	validation_0-logloss:0.64869
# [12]	validation_0-logloss:0.64448
# [13]	validation_0-logloss:0.64113
# [14]	validation_0-logloss:0.63709
# [15]	validation_0-logloss:0.63416
# [16]	validation_0-logloss:0.63286
# [17]	validation_0-logloss:0.63011
# [18]	validation_0-logloss:0.62729
# [19]	validation_0-logloss:0.62438
# [20]	validation_0-logloss:0.62163
# [21]	validation_0-logloss:0.61939
# [22]	validation_0-logloss:0.61793
# [23]	validation_0-logloss:0.61558
# [24]	validation_0-logloss:0.61561
# [25]	validation_0-logloss:0.61424
# [26]	validation_0-logloss:0.61263
# [27]	validation_0-logloss:0.61175
# [28]	validation_0-logloss:0.60917
# [29]	validation_0-logloss:0.60692
# [30]	validation_0-logloss:0.60512
# [31]	validation_0-logloss:0.60406
# [32]	validation_0-logloss:0.60216
# [33]	validation_0-logloss:0.60138
# [34]	validation_0-logloss:0.60069
# [35]	validation_0-logloss:0.59957
# [36]	validation_0-logloss:0.59828
# [37]	validation_0-logloss:0.59789
# [38]	validation_0-logloss:0.59637
# [39]	validation_0-logloss:0.59628
# [0]	validation_0-logloss:0.73366
# [1]	validation_0-logloss:0.72024
# [2]	validation_0-logloss:0.70612
# [3]	validation_0-logloss:0.69368
# [4]	validation_0-logloss:0.68307
# [5]	validation_0-logloss:0.67381
# [6]	validation_0-logloss:0.66486
# [7]	validation_0-logloss:0.65634
# [8]	validation_0-logloss:0.64930
# [9]	validation_0-logloss:0.64162
# [10]	validation_0-logloss:0.63589
# [11]	validation_0-logloss:0.63024
# [12]	validation_0-logloss:0.62486
# [13]	validation_0-logloss:0.61883
# [14]	validation_0-logloss:0.61389
# [15]	validation_0-logloss:0.61017
# [16]	validation_0-logloss:0.60700
# [17]	validation_0-logloss:0.60371
# [18]	validation_0-logloss:0.60131
# [19]	validation_0-logloss:0.59732
# [20]	validation_0-logloss:0.59369
# [21]	validation_0-logloss:0.59029
# [22]	validation_0-logloss:0.58786
# [23]	validation_0-logloss:0.58492
# [24]	validation_0-logloss:0.58348
# [25]	validation_0-logloss:0.58177
# [26]	validation_0-logloss:0.57986
# [27]	validation_0-logloss:0.57688
# [28]	validation_0-logloss:0.57440
# [29]	validation_0-logloss:0.57324
# [30]	validation_0-logloss:0.57113
# [31]	validation_0-logloss:0.56987
# [32]	validation_0-logloss:0.56791
# [33]	validation_0-logloss:0.56701
# [34]	validation_0-logloss:0.56518
# [35]	validation_0-logloss:0.56542
# [36]	validation_0-logloss:0.56488
# [37]	validation_0-logloss:0.56291
# [38]	validation_0-logloss:0.56258
# [39]	validation_0-logloss:0.56231
# [0]	validation_0-logloss:0.73486
# [1]	validation_0-logloss:0.72052
# [2]	validation_0-logloss:0.70874
# [3]	validation_0-logloss:0.69883
# [4]	validation_0-logloss:0.69201
# [5]	validation_0-logloss:0.68421
# [6]	validation_0-logloss:0.67703
# [7]	validation_0-logloss:0.67059
# [8]	validation_0-logloss:0.66623
# [9]	validation_0-logloss:0.66254
# [10]	validation_0-logloss:0.65836
# [11]	validation_0-logloss:0.65458
# [12]	validation_0-logloss:0.64994
# [13]	validation_0-logloss:0.64624
# [14]	validation_0-logloss:0.64427
# [15]	validation_0-logloss:0.64190
# [16]	validation_0-logloss:0.64034
# [17]	validation_0-logloss:0.63813
# [18]	validation_0-logloss:0.63569
# [19]	validation_0-logloss:0.63387
# [20]	validation_0-logloss:0.63326
# [21]	validation_0-logloss:0.63195
# [22]	validation_0-logloss:0.62957
# [23]	validation_0-logloss:0.62845
# [24]	validation_0-logloss:0.62599
# [25]	validation_0-logloss:0.62458
# [26]	validation_0-logloss:0.62319
# [27]	validation_0-logloss:0.62228
# [28]	validation_0-logloss:0.61967
# [29]	validation_0-logloss:0.61778
# [30]	validation_0-logloss:0.61657
# [31]	validation_0-logloss:0.61530
# [32]	validation_0-logloss:0.61468
# [33]	validation_0-logloss:0.61392
# [34]	validation_0-logloss:0.61307
# [35]	validation_0-logloss:0.61210
# [36]	validation_0-logloss:0.61146
# [37]	validation_0-logloss:0.61153
# [38]	validation_0-logloss:0.61086
# [39]	validation_0-logloss:0.61030
# [0]	validation_0-logloss:0.73500
# [1]	validation_0-logloss:0.72197
# [2]	validation_0-logloss:0.70836
# [3]	validation_0-logloss:0.69711
# [4]	validation_0-logloss:0.68854
# [5]	validation_0-logloss:0.68224
# [6]	validation_0-logloss:0.67636
# [7]	validation_0-logloss:0.67218
# [8]	validation_0-logloss:0.66712
# [9]	validation_0-logloss:0.66283
# [10]	validation_0-logloss:0.65878
# [11]	validation_0-logloss:0.65516
# [12]	validation_0-logloss:0.65139
# [13]	validation_0-logloss:0.64938
# [14]	validation_0-logloss:0.64699
# [15]	validation_0-logloss:0.64529
# [16]	validation_0-logloss:0.64235
# [17]	validation_0-logloss:0.64048
# [18]	validation_0-logloss:0.63864
# [19]	validation_0-logloss:0.63757
# [20]	validation_0-logloss:0.63605
# [21]	validation_0-logloss:0.63487
# [22]	validation_0-logloss:0.63498
# [23]	validation_0-logloss:0.63439
# [24]	validation_0-logloss:0.63108
# [25]	validation_0-logloss:0.62772
# [26]	validation_0-logloss:0.62661
# [27]	validation_0-logloss:0.62595
# [28]	validation_0-logloss:0.62407
# [29]	validation_0-logloss:0.62418
# [30]	validation_0-logloss:0.62146
# [31]	validation_0-logloss:0.61963
# [32]	validation_0-logloss:0.61681
# [33]	validation_0-logloss:0.61704
# [34]	validation_0-logloss:0.61594
# [35]	validation_0-logloss:0.61568
# [36]	validation_0-logloss:0.61423
# [37]	validation_0-logloss:0.61433
# [38]	validation_0-logloss:0.61403
# [39]	validation_0-logloss:0.61379
# [0]	validation_0-logloss:0.73961
# [1]	validation_0-logloss:0.73201
# [2]	validation_0-logloss:0.72452
# [3]	validation_0-logloss:0.71791
# [4]	validation_0-logloss:0.71193
# [5]	validation_0-logloss:0.70611
# [6]	validation_0-logloss:0.70111
# [7]	validation_0-logloss:0.69579
# [8]	validation_0-logloss:0.69172
# [9]	validation_0-logloss:0.68780
# [10]	validation_0-logloss:0.68372
# [11]	validation_0-logloss:0.67955
# [12]	validation_0-logloss:0.67516
# [13]	validation_0-logloss:0.67138
# [14]	validation_0-logloss:0.66751
# [15]	validation_0-logloss:0.66462
# [16]	validation_0-logloss:0.66142
# [17]	validation_0-logloss:0.65894
# [18]	validation_0-logloss:0.65561
# [19]	validation_0-logloss:0.65294
# [20]	validation_0-logloss:0.65032
# [21]	validation_0-logloss:0.64872
# [22]	validation_0-logloss:0.64666
# [23]	validation_0-logloss:0.64468
# [24]	validation_0-logloss:0.64228
# [25]	validation_0-logloss:0.64091
# [26]	validation_0-logloss:0.63855
# [27]	validation_0-logloss:0.63577
# [28]	validation_0-logloss:0.63402
# [29]	validation_0-logloss:0.63228
# [30]	validation_0-logloss:0.63067
# [31]	validation_0-logloss:0.62895
# [32]	validation_0-logloss:0.62687
# [33]	validation_0-logloss:0.62536
# [34]	validation_0-logloss:0.62378
# [35]	validation_0-logloss:0.62220
# [36]	validation_0-logloss:0.62110
# [37]	validation_0-logloss:0.61931
# [38]	validation_0-logloss:0.61730
# [39]	validation_0-logloss:0.61644
# [0]	validation_0-logloss:0.73892
# [1]	validation_0-logloss:0.73017
# [2]	validation_0-logloss:0.72436
# [3]	validation_0-logloss:0.71710
# [4]	validation_0-logloss:0.71053
# [5]	validation_0-logloss:0.70446
# [6]	validation_0-logloss:0.69809
# [7]	validation_0-logloss:0.69239
# [8]	validation_0-logloss:0.68744
# [9]	validation_0-logloss:0.68314
# [10]	validation_0-logloss:0.67818
# [11]	validation_0-logloss:0.67446
# [12]	validation_0-logloss:0.66954
# [13]	validation_0-logloss:0.66552
# [14]	validation_0-logloss:0.66126
# [15]	validation_0-logloss:0.65758
# [16]	validation_0-logloss:0.65510
# [17]	validation_0-logloss:0.65205
# [18]	validation_0-logloss:0.64851
# [19]	validation_0-logloss:0.64612
# [20]	validation_0-logloss:0.64411
# [21]	validation_0-logloss:0.64168
# [22]	validation_0-logloss:0.63990
# [23]	validation_0-logloss:0.63792
# [24]	validation_0-logloss:0.63522
# [25]	validation_0-logloss:0.63307
# [26]	validation_0-logloss:0.63132
# [27]	validation_0-logloss:0.62944
# [28]	validation_0-logloss:0.62742
# [29]	validation_0-logloss:0.62589
# [30]	validation_0-logloss:0.62436
# [31]	validation_0-logloss:0.62308
# [32]	validation_0-logloss:0.62145
# [33]	validation_0-logloss:0.61998
# [34]	validation_0-logloss:0.61887
# [35]	validation_0-logloss:0.61724
# [36]	validation_0-logloss:0.61647
# [37]	validation_0-logloss:0.61554
# [38]	validation_0-logloss:0.61486
# [39]	validation_0-logloss:0.61340
# [0]	validation_0-logloss:0.73372
# [1]	validation_0-logloss:0.72518
# [2]	validation_0-logloss:0.71617
# [3]	validation_0-logloss:0.70778
# [4]	validation_0-logloss:0.70101
# [5]	validation_0-logloss:0.69413
# [6]	validation_0-logloss:0.68747
# [7]	validation_0-logloss:0.68105
# [8]	validation_0-logloss:0.67566
# [9]	validation_0-logloss:0.67120
# [10]	validation_0-logloss:0.66677
# [11]	validation_0-logloss:0.66221
# [12]	validation_0-logloss:0.65654
# [13]	validation_0-logloss:0.65196
# [14]	validation_0-logloss:0.64738
# [15]	validation_0-logloss:0.64328
# [16]	validation_0-logloss:0.63936
# [17]	validation_0-logloss:0.63612
# [18]	validation_0-logloss:0.63196
# [19]	validation_0-logloss:0.62792
# [20]	validation_0-logloss:0.62484
# [21]	validation_0-logloss:0.62207
# [22]	validation_0-logloss:0.62019
# [23]	validation_0-logloss:0.61778
# [24]	validation_0-logloss:0.61501
# [25]	validation_0-logloss:0.61211
# [26]	validation_0-logloss:0.60934
# [27]	validation_0-logloss:0.60696
# [28]	validation_0-logloss:0.60474
# [29]	validation_0-logloss:0.60221
# [30]	validation_0-logloss:0.60044
# [31]	validation_0-logloss:0.59892
# [32]	validation_0-logloss:0.59722
# [33]	validation_0-logloss:0.59512
# [34]	validation_0-logloss:0.59280
# [35]	validation_0-logloss:0.59097
# [36]	validation_0-logloss:0.58982
# [37]	validation_0-logloss:0.58821
# [38]	validation_0-logloss:0.58623
# [39]	validation_0-logloss:0.58458
# [0]	validation_0-logloss:0.73526
# [1]	validation_0-logloss:0.72625
# [2]	validation_0-logloss:0.72076
# [3]	validation_0-logloss:0.71311
# [4]	validation_0-logloss:0.70751
# [5]	validation_0-logloss:0.70077
# [6]	validation_0-logloss:0.69444
# [7]	validation_0-logloss:0.68942
# [8]	validation_0-logloss:0.68432
# [9]	validation_0-logloss:0.68016
# [10]	validation_0-logloss:0.67604
# [11]	validation_0-logloss:0.67203
# [12]	validation_0-logloss:0.66818
# [13]	validation_0-logloss:0.66538
# [14]	validation_0-logloss:0.66114
# [15]	validation_0-logloss:0.65815
# [16]	validation_0-logloss:0.65475
# [17]	validation_0-logloss:0.65140
# [18]	validation_0-logloss:0.64876
# [19]	validation_0-logloss:0.64652
# [20]	validation_0-logloss:0.64431
# [21]	validation_0-logloss:0.64192
# [22]	validation_0-logloss:0.64014
# [23]	validation_0-logloss:0.63780
# [24]	validation_0-logloss:0.63622
# [25]	validation_0-logloss:0.63452
# [26]	validation_0-logloss:0.63296
# [27]	validation_0-logloss:0.63147
# [28]	validation_0-logloss:0.63021
# [29]	validation_0-logloss:0.62908
# [30]	validation_0-logloss:0.62789
# [31]	validation_0-logloss:0.62674
# [32]	validation_0-logloss:0.62593
# [33]	validation_0-logloss:0.62467
# [34]	validation_0-logloss:0.62401
# [35]	validation_0-logloss:0.62308
# [36]	validation_0-logloss:0.62241
# [37]	validation_0-logloss:0.62185
# [38]	validation_0-logloss:0.62062
# [39]	validation_0-logloss:0.62012
# [0]	validation_0-logloss:0.73446
# [1]	validation_0-logloss:0.72655
# [2]	validation_0-logloss:0.71750
# [3]	validation_0-logloss:0.71055
# [4]	validation_0-logloss:0.70421
# [5]	validation_0-logloss:0.69820
# [6]	validation_0-logloss:0.69359
# [7]	validation_0-logloss:0.68893
# [8]	validation_0-logloss:0.68452
# [9]	validation_0-logloss:0.68039
# [10]	validation_0-logloss:0.67699
# [11]	validation_0-logloss:0.67355
# [12]	validation_0-logloss:0.66931
# [13]	validation_0-logloss:0.66659
# [14]	validation_0-logloss:0.66281
# [15]	validation_0-logloss:0.66015
# [16]	validation_0-logloss:0.65700
# [17]	validation_0-logloss:0.65450
# [18]	validation_0-logloss:0.65138
# [19]	validation_0-logloss:0.64895
# [20]	validation_0-logloss:0.64656
# [21]	validation_0-logloss:0.64466
# [22]	validation_0-logloss:0.64293
# [23]	validation_0-logloss:0.64121
# [24]	validation_0-logloss:0.63940
# [25]	validation_0-logloss:0.63785
# [26]	validation_0-logloss:0.63649
# [27]	validation_0-logloss:0.63478
# [28]	validation_0-logloss:0.63366
# [29]	validation_0-logloss:0.63248
# [30]	validation_0-logloss:0.63169
# [31]	validation_0-logloss:0.63018
# [32]	validation_0-logloss:0.62922
# [33]	validation_0-logloss:0.62814
# [34]	validation_0-logloss:0.62716
# [35]	validation_0-logloss:0.62674
# [36]	validation_0-logloss:0.62584
# [37]	validation_0-logloss:0.62532
# [38]	validation_0-logloss:0.62505
# [39]	validation_0-logloss:0.62381
# 100%|██████████| 25/25 [11:26<00:00, 27.47s/trial, best loss: -0.8104278284582456]
# Processing key: alpha, val: 3.0939960004164857
# Processing key: colsample_bytree, val: 0.5719825376938534
# Processing key: gamma, val: 0.41482329149626224
# Processing key: lambda, val: 19.559714661785666
# Processing key: learning_rate, val: 0.0792949920725799
# Processing key: max_depth, val: 3
# Processing key: min_child_weight, val: 26.0
# Processing key: n_estimators, val: 2
# Processing key: scale_pos_weight, val: 3.151709869434891
# {'alpha': 3.0939960004164857, 'colsample_bytree': 0.5719825376938534, 'gamma': 0.41482329149626224, 'lambda': 19.559714661785666, 'learning_rate': 0.0792949920725799, 'max_depth': 4, 'min_child_weight': 26.0, 'n_estimators': 40, 'scale_pos_weight': 3.151709869434891}

# %%
# Merge default and best params
xgb_optimized_params = {**xgb_default_params, **xgb_best_params}
print(xgb_optimized_params)

# Train the model using the optimized parameters
xgb = XGBClassifier(**xgb_optimized_params)
xgb.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(xgb, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(xgb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(xgb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'n_jobs': -1, 'alpha': 3.0939960004164857, 'colsample_bytree': 0.5719825376938534, 'gamma': 0.41482329149626224, 'lambda': 19.559714661785666, 'learning_rate': 0.0792949920725799, 'max_depth': 4, 'min_child_weight': 26.0, 'n_estimators': 40, 'scale_pos_weight': 3.151709869434891}
# Training Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.7, 'Recall': 1.0, 'F1': 0.82}
#
# Validation Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.71, 'Recall': 0.98, 'F1': 0.82}
#
# Test Data Evaluation:
# {'Accuracy': 0.63, 'Precision': 0.57, 'Recall': 0.99, 'F1': 0.73}

# %%
# Import necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.metrics import Metric, Precision, Recall

class F1Score(Metric):
    def __init__(self, name="f1_score", **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
        p = self.precision.result()
        r = self.recall.result()
        # Compute F1 Score
        self.f1.assign(2 * ((p * r) / (p + r + K.epsilon())))

    def result(self):
        return self.f1

    def reset_state(self):
        self.f1.assign(0.)
        self.precision.reset_state()
        self.recall.reset_state()


def optimize_hyperparams_mlp(space, X_train, y_train, X_val, y_val, enable_early_stopping=True, max_evals=25, random_state=72):

    def objective(params):
        try:
            # Build the model
            model = Sequential()
            model.add(Dense(params['hidden_layers'][0],
                            activation='relu',
                            input_dim=X_train.shape[1]))

            model.add(Dropout(params['dropout']))
            for units in params['hidden_layers'][1:]:
                model.add(Dense(units, activation='relu'))
                model.add(Dropout(params['dropout']))
            model.add(Dense(1, activation='sigmoid'))  # for binary classification

            if params['optimizer'] == 'adam':
                opt = Adam(learning_rate=params['learning_rate'])
            else:
                opt = SGD(learning_rate=params['learning_rate'])

            model.compile(optimizer=opt, loss='binary_crossentropy',
                          metrics=['accuracy', Precision(), Recall(), F1Score()])

            # Set early stopping
            if enable_early_stopping:
                callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
            else:
                callbacks = None

            # Train the model
            model.fit(X_train, y_train, epochs=35,
                      batch_size=int(params['batch_size']),
                      verbose=0, validation_data=(X_val, y_val),
                      callbacks=callbacks)

            # Evaluate the model
            _, accuracy, precision, recall, f1_val = model.evaluate(X_val, y_val, verbose=0)

            return -f1_val  # we want to maximize accuracy, hence the negative sign

        except Exception as e:
            print(f"Exception encountered: {e}")
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest,
                max_evals=max_evals, trials=trials)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
from hyperopt import hp
from hyperopt import Trials, fmin, tpe

# Define the space
mlp_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2),
    'batch_size': hp.choice('batch_size', [32, 64, 128, 256]),
    'hidden_layers': hp.choice('hidden_layers', [
        [16],
        [32],
        [64],
        [128],
        [16, 16],
        [32, 32],
        [64, 64],
        [128, 128],
        [128, 64],
        [64, 32],
        [32, 16],
        [128, 64, 32, 16],
        [128, 64, 32]
    ]),
    'optimizer': hp.choice('optimizer', ['adam', 'sgd']),
    'dropout': hp.uniform('dropout', 0, 0.5)
}

# Use the function
mlp_best_params = optimize_hyperparams_mlp(space=mlp_hyperparam_space,
                                           X_train=X_train,
                                           y_train=y_train,
                                           X_val=X_val, y_val=y_val,
                                           enable_early_stopping=True,
                                           max_evals=35)
print(mlp_best_params)
# Out:
# 100%|██████████| 35/35 [04:03<00:00,  6.94s/trial, best loss: -0.7950480580329895]
# Processing key: batch_size, val: 0
# Processing key: dropout, val: 0.005490552202813068
# Processing key: hidden_layers, val: 3
# Processing key: learning_rate, val: 0.017613117894663157
# Processing key: optimizer, val: 1
# {'batch_size': 32, 'dropout': 0.005490552202813068, 'hidden_layers': [128], 'learning_rate': 0.017613117894663157, 'optimizer': 'sgd'}

# %%
# Evaluate the fitted pipeline
def evaluate_mlp(model, X, y):
    # Evaluate on given X
    _, accuracy, precision, recall, f1 = model.evaluate(X, y)

    # Return the values in a dictionary
    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD

model = Sequential()

hidden_layers = mlp_best_params['hidden_layers']

print(hidden_layers)
for units in hidden_layers:
    model.add(Dense(units, activation='relu'))
    model.add(Dropout(mlp_best_params['dropout']))


# Output layer
model.add(Dense(1, activation='sigmoid'))

# Determine optimizer based on the optimized parameters
if mlp_best_params['optimizer'] == 'adam':
    optimizer = Adam(learning_rate=mlp_best_params['learning_rate'])
elif mlp_best_params['optimizer'] == 'sgd':
    optimizer = SGD(learning_rate=mlp_best_params['learning_rate'])

callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall(), F1Score()])
model.fit(X_train, y_train,
          validation_data=(X_val, y_val),
          epochs=mlp_best_params.get('epochs', 35),
          batch_size=mlp_best_params['batch_size'],
          callbacks=callbacks, verbose=0)


# 5. Evaluate the trained model
train_results = {}
train_results = evaluate_mlp(model, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

validation_results = evaluate_mlp(model, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

test_results = evaluate_mlp(model, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# [128]
# 49/49 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6788 - precision_70: 0.7890 - recall_70: 0.6474 - f1_score: 0.7112
# Training Data Evaluation:
# {'Accuracy': 0.6788461804389954, 'Precision': 0.789002537727356, 'Recall': 0.6474291682243347, 'F1': 0.7112390995025635}
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5799 - accuracy: 0.6981 - precision_70: 0.8361 - recall_70: 0.6278 - f1_score: 0.7171
#
# Validation Data Evaluation:
# {'Accuracy': 0.6980769038200378, 'Precision': 0.8361344337463379, 'Recall': 0.6277602314949036, 'F1': 0.7171170711517334}
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5867 - accuracy: 0.7067 - precision_70: 0.7279 - recall_70: 0.6600 - f1_score: 0.6923
#
# Test Data Evaluation:
# {'Accuracy': 0.7066666483879089, 'Precision': 0.7279411554336548, 'Recall': 0.6600000262260437, 'F1': 0.6923075914382935}
