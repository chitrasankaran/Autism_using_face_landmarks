# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ## Configure Project Path and other paths

# %%
import numpy as np
np.random.seed(72)

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
proj_path = '/content/drive/MyDrive/Magnimind/Face_detection/MP'
os.chdir(proj_path)

# %%
train_csv_path = os.path.join(proj_path, 'train_3D.csv')
test_csv_path = os.path.join(proj_path, 'test_3D.csv')

# %% [markdown]
# ## Read data from csv to pandas dataframe

# %%
train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        839  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        825  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        817  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...        845  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        844  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.511593      0.709910     -0.040127      0.517181      0.670308
# 1      0.566339      0.733220     -0.065258      0.575596      0.677747
# 2      0.437217      0.744490     -0.077209      0.426740      0.685478
# 3      0.533727      0.797597     -0.053682      0.549781      0.762331
# 4      0.524054      0.774706     -0.052582      0.505436      0.710976
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.168715      0.515403  ...       -0.057532        0.587559
# 1     -0.127426      0.568713  ...        0.001300        0.609449
# 2     -0.165941      0.433244  ...       -0.018598        0.488665
# 3     -0.169223      0.540980  ...       -0.035548        0.601406
# 4     -0.152662      0.512779  ...       -0.039194        0.528307
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.500262       -0.077599        0.768636        0.474503
# 1        0.556148       -0.015839        0.738344        0.541875
# 2        0.551752       -0.038808        0.656447        0.535078
# 3        0.623819       -0.057016        0.766676        0.603243
# 4        0.568924       -0.058087        0.683886        0.525732
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0       -0.021161        0.784336        0.468965       -0.021392
# 1        0.039996        0.751471        0.531839        0.042270
# 2        0.003090        0.674554        0.525373        0.003349
# 3        0.013871        0.782729        0.596054        0.015662
# 4       -0.016595        0.697740        0.517121       -0.017281
#
# [5 rows x 1407 columns]

# %%
test_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        100  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        108  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        106  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...          1  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        103  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.727391      0.710138     -0.117875      0.753489      0.581854
# 1      0.457443      0.710929     -0.091133      0.437796      0.633989
# 2      0.452099      0.779923     -0.042830      0.453784      0.726497
# 3      0.457504      0.754957     -0.085740      0.470419      0.687706
# 4      0.362426      0.740446     -0.046425      0.366750      0.668341
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.193980      0.723864  ...        0.048919        0.737665
# 1     -0.193647      0.445459  ...       -0.020685        0.482040
# 2     -0.181251      0.455887  ...       -0.063696        0.546055
# 3     -0.211908      0.467041  ...       -0.034361        0.565713
# 4     -0.156865      0.372543  ...       -0.048113        0.491366
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.421433        0.016144        0.890724        0.401811
# 1        0.471925       -0.044690        0.660659        0.437236
# 2        0.521134       -0.084867        0.749610        0.499630
# 3        0.535771       -0.059295        0.783299        0.529403
# 4        0.545638       -0.066218        0.686309        0.559731
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0        0.169311        0.903891        0.394724        0.177334
# 1        0.013672        0.679693        0.424461        0.015152
# 2       -0.035831        0.771000        0.490222       -0.036383
# 3        0.008190        0.804902        0.522787        0.009052
# 4       -0.032427        0.705237        0.556214       -0.034047
#
# [5 rows x 1407 columns]

# %%
train_df['label'].value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %%
test_df['label'].value_counts()
# Out:
# Autistic        150
# Non_Autistic    150
# Name: label, dtype: int64

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %% [markdown]
# ## Setting input features and output features

# %%
X = train_df.drop(columns=['img_path', 'image_num', 'label'])
y = train_df['label']

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
y = y.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
y.value_counts()
# Out:
# 1    1270
# 0     810
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, shuffle=True, random_state=72)

# %%
X_test = test_df.drop(columns=['img_path', 'image_num', 'label'])
y_test = test_df['label']
y_test = y_test.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
X_train.shape
# Out:
# (1560, 1404)

# %%
X_val.shape
# Out:
# (520, 1404)

# %%
X_test.shape
# Out:
# (300, 1404)

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import precision_recall_curve
import numpy as np
from sklearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import hyperopt

# %%
# Initializing random_state
random_state = 72

# %%
from hyperopt.pyll.base import Apply

def hyperopt_indices_to_values(space, best):
    best_params = {}

    for key, val in best.items():
        print(f"Processing key: {key}, val: {val}")  # Debugging line
        #print(f"Type of space[key]: {type(space[key])}")  # Additional Debugging line
        #print(f"Name attribute of space[key] (if exists): {getattr(space[key], 'name', 'No name attribute')}")  # Additional Debugging line

        if key == 'penalty_solver':
            # Extract penalty and solver values directly from the tuple
            penalty, solver = space[key].pos_args[int(val) + 1].pos_args
            best_params['penalty'] = penalty.obj
            best_params['solver'] = solver.obj

        elif isinstance(space[key], Apply) and space[key].name == 'switch':
            # This means the parameter is defined using hp.choice
            selected_item = space[key].pos_args[val + 1]
            if key == 'hidden_layers':
                try:
                    # Attempt to unpack it as if it was a list
                    best_params[key] = [item.obj for item in selected_item.pos_args]
                except AttributeError:
                    # If there's an error, revert back to previous handling
                    best_params[key] = getattr(selected_item, 'obj', selected_item)

            else:
                # Handle the scenario where 'selected_item' might not have 'obj'
                best_params[key] = getattr(selected_item, 'obj', selected_item)

        else:
            # Otherwise, directly assign the value
            best_params[key] = val

    return best_params

# %%
def optimize_hyperparams(model_class, default_params, space,
                         X_train, y_train, enable_early_stopping=False,
                         max_evals=20, random_state=72):
    def objective(params):
        try:
            # If 'penalty_solver' is in params, get mapped 'penalty' and 'solver' params
            if 'penalty_solver' in params:
                params['penalty'], params['solver'] = params.pop('penalty_solver')

            # If the penalty is not 'elasticnet', remove the l1_ratio parameter
            if params.get('penalty') != 'elasticnet':
                params.pop('l1_ratio', None)


            all_params = {**default_params, **params}
            m = model_class(**all_params)

            cv_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

            if enable_early_stopping:
                # Set early_stopping_rounds
                m.set_params(early_stopping_rounds=3, eval_metric="logloss")
                scores = []

                for train_index, test_index in cv_folds.split(X_train, y_train):
                    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[test_index]

                    eval_set = [(X_val_fold, y_val_fold)]
                    m.fit(X_train_fold, y_train_fold,
                          eval_set=eval_set, verbose=True)

                    predictions = m.predict(X_val_fold)
                    score = f1_score(y_val_fold, predictions)
                    scores.append(score)

                return -np.mean(scores) # since we want to maximize F1 score

            else:
                loss = -cross_val_score(m, X_train, y_train, cv=cv_folds, scoring='f1').mean()
                return loss

        except Exception as e:
            print(f"Exception encountered: {e}")
            # Handle any other exception that arises during model training or evaluation
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=max_evals, trials=trials)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
# Evaluate the fitted pipeline
def evaluate(model, X, y):
    # Predict on given X
    y_pred = model.predict(X)

    # Calculate below evaluation metrics
    accuracy = round(accuracy_score(y, y_pred), 2)
    precision = round(precision_score(y, y_pred), 2)
    recall = round(recall_score(y, y_pred), 2)
    f1 = round(f1_score(y, y_pred), 2)

    # Return the values in a dictionary

    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
default_params = {
    'random_state': random_state,
    'max_iter': 6000,
    'class_weight': 'balanced',
}

lr_hyperparam_space = {
    # Combine penalty and solver
    'penalty_solver': hp.choice('penalty_solver', [
        ('l1', 'liblinear'),
        ('l2', 'lbfgs'),
        ('l2', 'liblinear'),
        ('elasticnet', 'saga')
    ]),

    # Regularization strength
    'C': hp.loguniform('C', np.log(0.0001), np.log(100)),
    'l1_ratio': hp.uniform('l1_ratio', 0, 1),

}

# Using the function
best_params = optimize_hyperparams(LogisticRegression,
                                   default_params,
                                   lr_hyperparam_space,
                                   X_train, y_train,
                                   max_evals=25)
print(best_params)
# Out:
#   4%|▍         | 1/25 [00:27<10:58, 27.45s/trial, best loss: -0.7620594014598542]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-971746b29ee0> in <cell line: 23>()
#      21
#      22 # Using the function
# ---> 23 best_params = optimize_hyperparams(LogisticRegression,
#      24                                    default_params,
#      25                                    lr_hyperparam_space,
#
# <ipython-input-25-380908a2a8de> in optimize_hyperparams(model_class, default_params, space, X_train, y_train, enable_early_stopping, max_evals, random_state)
#      47
#      48     trials = Trials()
# ---> 49     best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=max_evals, trials=trials)
#      50     best_params = hyperopt_indices_to_values(space, best)
#      51
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-25-380908a2a8de> in objective(params)
#      38
#      39             else:
# ---> 40                 loss = -cross_val_score(m, X_train, y_train, cv=cv_folds, scoring='f1').mean()
#      41                 return loss
#      42
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     513     scorer = check_scoring(estimator, scoring=scoring)
#     514
# --> 515     cv_results = cross_validate(
#     516         estimator=estimator,
#     517         X=X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264     # independent, and that it is pickle-able.
#     265     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266     results = parallel(
#     267         delayed(_fit_and_score)(
#     268             clone(estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1289             n_threads = 1
#    1290
# -> 1291         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1292             path_func(
#    1293                 X,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     522                 beta = (1.0 / C) * l1_ratio
#     523
# --> 524             w0, n_iter_i, warm_start_sag = sag_solver(
#     525                 X,
#     526                 target,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py in sag_solver(X, y, sample_weight, loss, alpha, beta, max_iter, tol, verbose, random_state, check_input, max_squared_sum, warm_start_mem, is_saga)
#     323
#     324     sag = sag64 if X.dtype == np.float64 else sag32
# --> 325     num_seen, n_iter_ = sag(
#     326         dataset,
#     327         coef_init,
#
# KeyboardInterrupt:

# %%
optimized_params = {**default_params, **best_params}
print(optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
lr = LogisticRegression(**optimized_params)
lr.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(lr, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(lr, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(lr, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'max_iter': 6000, 'class_weight': 'balanced', 'C': 59.653066982091595, 'l1_ratio': 0.0029340014712199713, 'penalty': 'l1', 'solver': 'liblinear'}
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# Training Data Evaluation:
# {'Accuracy': 0.78, 'Precision': 0.84, 'Recall': 0.78, 'F1': 0.81}
#
# Validation Data Evaluation:
# {'Accuracy': 0.77, 'Precision': 0.84, 'Recall': 0.76, 'F1': 0.8}
#
# Test Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.74, 'Recall': 0.78, 'F1': 0.76}

# %%
rf_default_params = {
    'random_state': random_state,
    'class_weight': 'balanced',
    'n_jobs': -1,
}

rf_hyperparam_space = {
    'n_estimators': hp.choice('n_estimators', list(range(50, 90, 10))),
    'max_depth': hp.choice('max_depth', list(range(2, 5))),  # Excluding None to prevent unlimited depth
    'min_samples_split': hp.uniform('min_samples_split', 0.01, 0.1),  # Increasing the lower bound to avoid tiny splits
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.005, 0.05),  # Increasing the lower bound to ensure larger leaves
    'max_features': hp.choice('max_features', [0.3, 0.4, 0.5, 'sqrt', 'log2']),  # Focusing on fewer feature options
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'bootstrap': hp.choice('bootstrap', [True]),
    'oob_score': hp.choice('oob_score', [True, False])
}

# Using the function
rf_best_params = optimize_hyperparams(RandomForestClassifier,
                                      rf_default_params,
                                      rf_hyperparam_space,
                                      X_train, y_train,
                                      max_evals=35)
print(rf_best_params)
# Out:
# 100%|██████████| 35/35 [13:06<00:00, 22.48s/trial, best loss: -0.7681112976890422]
# Processing key: bootstrap, val: 0
# Processing key: criterion, val: 0
# Processing key: max_depth, val: 0
# Processing key: max_features, val: 3
# Processing key: min_samples_leaf, val: 0.04759948385359268
# Processing key: min_samples_split, val: 0.09925362264002896
# Processing key: n_estimators, val: 3
# Processing key: oob_score, val: 0
# {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 0.04759948385359268, 'min_samples_split': 0.09925362264002896, 'n_estimators': 80, 'oob_score': True}

# %%
rf_optimized_params = {**rf_default_params, **rf_best_params}
print(rf_optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
rf = RandomForestClassifier(**rf_optimized_params)
rf.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(rf, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(rf, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(rf, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'class_weight': 'balanced', 'n_jobs': -1, 'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 0.04759948385359268, 'min_samples_split': 0.09925362264002896, 'n_estimators': 80, 'oob_score': True}
# Training Data Evaluation:
# {'Accuracy': 0.72, 'Precision': 0.8, 'Recall': 0.73, 'F1': 0.76}
#
# Validation Data Evaluation:
# {'Accuracy': 0.71, 'Precision': 0.79, 'Recall': 0.7, 'F1': 0.74}
#
# Test Data Evaluation:
# {'Accuracy': 0.73, 'Precision': 0.71, 'Recall': 0.78, 'F1': 0.74}

# %%
adb_default_params = {
    'random_state': random_state,
}

adb_hyperparam_space = {
    # AdaBoost hyperparameters
    # Number of weak learners to train
    'n_estimators': hp.choice('n_estimators', list(range(30, 150, 10))),
    # Helps to shrink the contribution of each classifier
    'learning_rate': hp.loguniform('learning_rate', -7, 0), # Log uniform distribution between 1e-7 and 1
}

# Using the function
adb_best_params = optimize_hyperparams(AdaBoostClassifier,
                                       adb_default_params,
                                       adb_hyperparam_space,
                                       X_train, y_train,
                                       max_evals=30)
print(adb_best_params)
# Out:
# 100%|██████████| 30/30 [1:01:06<00:00, 122.21s/trial, best loss: -0.8052813630665003]
# Processing key: learning_rate, val: 0.07649154602527411
# Processing key: n_estimators, val: 6
# {'learning_rate': 0.07649154602527411, 'n_estimators': 90}

# %%
# Merge default and best params
adb_optimized_params = {**adb_default_params, **adb_best_params}
print(adb_optimized_params)

# Train the model using the optimized parameters
adb = AdaBoostClassifier(**adb_optimized_params)
adb.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(adb, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(adb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(adb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'learning_rate': 0.07649154602527411, 'n_estimators': 90}
# Training Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.75, 'Recall': 0.91, 'F1': 0.82}
#
# Validation Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.75, 'Recall': 0.89, 'F1': 0.81}
#
# Test Data Evaluation:
# {'Accuracy': 0.66, 'Precision': 0.61, 'Recall': 0.92, 'F1': 0.73}

# %%
xgb_default_params = {
    'random_state': random_state,
    'n_jobs': -1,
}

# Hyperparams for XGB
xgb_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2.5), # smaller learning rates
    'n_estimators': hp.choice('n_estimators', [20, 30, 40, 50, 60, 70, 80]), # slightly reduced choices
    'max_depth': hp.choice('max_depth', [1, 2, 3, 4]), # further reduced depth
    'min_child_weight': hp.quniform('min_child_weight', 15, 50, 1), # increased min_child_weight range
    'gamma': hp.uniform('gamma', 0.2, 0.6), # increased lower bound
    'colsample_bytree': hp.uniform('colsample_bytree', 0.4, 0.7), # more conservative column sampling
    'alpha': hp.loguniform('alpha', -2, 3),
    'lambda': hp.loguniform('lambda', -2, 3),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 6)
}

# Using the function
xgb_best_params = optimize_hyperparams(XGBClassifier,
                                       xgb_default_params,
                                       xgb_hyperparam_space,
                                       X_train, y_train,
                                       enable_early_stopping=True,
                                       max_evals=25)
print(xgb_best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# [18]	validation_0-logloss:0.71281
# [19]	validation_0-logloss:0.71054
# [20]	validation_0-logloss:0.70847
# [21]	validation_0-logloss:0.70666
# [22]	validation_0-logloss:0.70475
# [23]	validation_0-logloss:0.70296
# [24]	validation_0-logloss:0.70133
# [25]	validation_0-logloss:0.69980
# [26]	validation_0-logloss:0.69889
# [27]	validation_0-logloss:0.69803
# [28]	validation_0-logloss:0.69660
# [29]	validation_0-logloss:0.69516
# [30]	validation_0-logloss:0.69376
# [31]	validation_0-logloss:0.69257
# [32]	validation_0-logloss:0.69113
# [33]	validation_0-logloss:0.69047
# [34]	validation_0-logloss:0.68954
# [35]	validation_0-logloss:0.68895
# [36]	validation_0-logloss:0.68764
# [37]	validation_0-logloss:0.68673
# [38]	validation_0-logloss:0.68558
# [39]	validation_0-logloss:0.68461
# [40]	validation_0-logloss:0.68347
# [41]	validation_0-logloss:0.68250
# [42]	validation_0-logloss:0.68159
# [43]	validation_0-logloss:0.68067
# [44]	validation_0-logloss:0.67973
# [45]	validation_0-logloss:0.67910
# [46]	validation_0-logloss:0.67834
# [47]	validation_0-logloss:0.67761
# [48]	validation_0-logloss:0.67703
# [49]	validation_0-logloss:0.67625
# [50]	validation_0-logloss:0.67597
# [51]	validation_0-logloss:0.67512
# [52]	validation_0-logloss:0.67491
# [53]	validation_0-logloss:0.67411
# [54]	validation_0-logloss:0.67381
# [55]	validation_0-logloss:0.67311
# [56]	validation_0-logloss:0.67235
# [57]	validation_0-logloss:0.67168
# [58]	validation_0-logloss:0.67125
# [59]	validation_0-logloss:0.67076
# [0]	validation_0-logloss:0.77218
# [1]	validation_0-logloss:0.76735
# [2]	validation_0-logloss:0.76255
# [3]	validation_0-logloss:0.75801
# [4]	validation_0-logloss:0.75380
# [5]	validation_0-logloss:0.74966
# [6]	validation_0-logloss:0.74534
# [7]	validation_0-logloss:0.74140
# [8]	validation_0-logloss:0.73783
# [9]	validation_0-logloss:0.73415
# [10]	validation_0-logloss:0.73133
# [11]	validation_0-logloss:0.72793
# [12]	validation_0-logloss:0.72507
# [13]	validation_0-logloss:0.72198
# [14]	validation_0-logloss:0.71922
# [15]	validation_0-logloss:0.71616
# [16]	validation_0-logloss:0.71337
# [17]	validation_0-logloss:0.71028
# [18]	validation_0-logloss:0.70769
# [19]	validation_0-logloss:0.70525
# [20]	validation_0-logloss:0.70293
# [21]	validation_0-logloss:0.70025
# [22]	validation_0-logloss:0.69728
# [23]	validation_0-logloss:0.69487
# [24]	validation_0-logloss:0.69285
# [25]	validation_0-logloss:0.69097
# [26]	validation_0-logloss:0.68909
# [27]	validation_0-logloss:0.68767
# [28]	validation_0-logloss:0.68575
# [29]	validation_0-logloss:0.68421
# [30]	validation_0-logloss:0.68249
# [31]	validation_0-logloss:0.68089
# [32]	validation_0-logloss:0.67952
# [33]	validation_0-logloss:0.67726
# [34]	validation_0-logloss:0.67587
# [35]	validation_0-logloss:0.67481
# [36]	validation_0-logloss:0.67366
# [37]	validation_0-logloss:0.67220
# [38]	validation_0-logloss:0.67077
# [39]	validation_0-logloss:0.66918
# [40]	validation_0-logloss:0.66801
# [41]	validation_0-logloss:0.66655
# [42]	validation_0-logloss:0.66546
# [43]	validation_0-logloss:0.66439
# [44]	validation_0-logloss:0.66300
# [45]	validation_0-logloss:0.66202
# [46]	validation_0-logloss:0.66097
# [47]	validation_0-logloss:0.65999
# [48]	validation_0-logloss:0.65885
# [49]	validation_0-logloss:0.65806
# [50]	validation_0-logloss:0.65740
# [51]	validation_0-logloss:0.65633
# [52]	validation_0-logloss:0.65602
# [53]	validation_0-logloss:0.65537
# [54]	validation_0-logloss:0.65465
# [55]	validation_0-logloss:0.65388
# [56]	validation_0-logloss:0.65368
# [57]	validation_0-logloss:0.65307
# [58]	validation_0-logloss:0.65242
# [59]	validation_0-logloss:0.65156
# [0]	validation_0-logloss:0.76609
# [1]	validation_0-logloss:0.76034
# [2]	validation_0-logloss:0.75521
# [3]	validation_0-logloss:0.75021
# [4]	validation_0-logloss:0.74568
# [5]	validation_0-logloss:0.74126
# [6]	validation_0-logloss:0.73621
# [7]	validation_0-logloss:0.73192
# [8]	validation_0-logloss:0.72820
# [9]	validation_0-logloss:0.72419
# [10]	validation_0-logloss:0.72087
# [11]	validation_0-logloss:0.71773
# [12]	validation_0-logloss:0.71418
# [13]	validation_0-logloss:0.71111
# [14]	validation_0-logloss:0.70816
# [15]	validation_0-logloss:0.70458
# [16]	validation_0-logloss:0.70136
# [17]	validation_0-logloss:0.69815
# [18]	validation_0-logloss:0.69495
# [19]	validation_0-logloss:0.69218
# [20]	validation_0-logloss:0.68920
# [21]	validation_0-logloss:0.68664
# [22]	validation_0-logloss:0.68448
# [23]	validation_0-logloss:0.68196
# [24]	validation_0-logloss:0.67934
# [25]	validation_0-logloss:0.67745
# [26]	validation_0-logloss:0.67528
# [27]	validation_0-logloss:0.67221
# [28]	validation_0-logloss:0.67004
# [29]	validation_0-logloss:0.66719
# [30]	validation_0-logloss:0.66512
# [31]	validation_0-logloss:0.66264
# [32]	validation_0-logloss:0.66162
# [33]	validation_0-logloss:0.66021
# [34]	validation_0-logloss:0.65850
# [35]	validation_0-logloss:0.65622
# [36]	validation_0-logloss:0.65378
# [37]	validation_0-logloss:0.65207
# [38]	validation_0-logloss:0.65053
# [39]	validation_0-logloss:0.64907
# [40]	validation_0-logloss:0.64733
# [41]	validation_0-logloss:0.64631
# [42]	validation_0-logloss:0.64438
# [43]	validation_0-logloss:0.64288
# [44]	validation_0-logloss:0.64173
# [45]	validation_0-logloss:0.64009
# [46]	validation_0-logloss:0.63910
# [47]	validation_0-logloss:0.63815
# [48]	validation_0-logloss:0.63668
# [49]	validation_0-logloss:0.63551
# [50]	validation_0-logloss:0.63382
# [51]	validation_0-logloss:0.63287
# [52]	validation_0-logloss:0.63129
# [53]	validation_0-logloss:0.62963
# [54]	validation_0-logloss:0.62871
# [55]	validation_0-logloss:0.62751
# [56]	validation_0-logloss:0.62624
# [57]	validation_0-logloss:0.62535
# [58]	validation_0-logloss:0.62465
# [59]	validation_0-logloss:0.62382
# [0]	validation_0-logloss:0.76793
# [1]	validation_0-logloss:0.76372
# [2]	validation_0-logloss:0.75931
# [3]	validation_0-logloss:0.75502
# [4]	validation_0-logloss:0.75150
# [5]	validation_0-logloss:0.74792
# [6]	validation_0-logloss:0.74462
# [7]	validation_0-logloss:0.74180
# [8]	validation_0-logloss:0.73903
# [9]	validation_0-logloss:0.73548
# [10]	validation_0-logloss:0.73284
# [11]	validation_0-logloss:0.73032
# [12]	validation_0-logloss:0.72730
# [13]	validation_0-logloss:0.72418
# [14]	validation_0-logloss:0.72192
# [15]	validation_0-logloss:0.71919
# [16]	validation_0-logloss:0.71667
# [17]	validation_0-logloss:0.71411
# [18]	validation_0-logloss:0.71165
# [19]	validation_0-logloss:0.70925
# [20]	validation_0-logloss:0.70617
# [21]	validation_0-logloss:0.70346
# [22]	validation_0-logloss:0.70081
# [23]	validation_0-logloss:0.69916
# [24]	validation_0-logloss:0.69738
# [25]	validation_0-logloss:0.69583
# [26]	validation_0-logloss:0.69460
# [27]	validation_0-logloss:0.69281
# [28]	validation_0-logloss:0.69130
# [29]	validation_0-logloss:0.68979
# [30]	validation_0-logloss:0.68846
# [31]	validation_0-logloss:0.68732
# [32]	validation_0-logloss:0.68605
# [33]	validation_0-logloss:0.68431
# [34]	validation_0-logloss:0.68307
# [35]	validation_0-logloss:0.68231
# [36]	validation_0-logloss:0.68150
# [37]	validation_0-logloss:0.68094
# [38]	validation_0-logloss:0.68013
# [39]	validation_0-logloss:0.67891
# [40]	validation_0-logloss:0.67813
# [41]	validation_0-logloss:0.67666
# [42]	validation_0-logloss:0.67550
# [43]	validation_0-logloss:0.67480
# [44]	validation_0-logloss:0.67388
# [45]	validation_0-logloss:0.67359
# [46]	validation_0-logloss:0.67311
# [47]	validation_0-logloss:0.67170
# [48]	validation_0-logloss:0.67087
# [49]	validation_0-logloss:0.66998
# [50]	validation_0-logloss:0.66907
# [51]	validation_0-logloss:0.66873
# [52]	validation_0-logloss:0.66783
# [53]	validation_0-logloss:0.66707
# [54]	validation_0-logloss:0.66703
# [55]	validation_0-logloss:0.66656
# [56]	validation_0-logloss:0.66624
# [57]	validation_0-logloss:0.66586
# [58]	validation_0-logloss:0.66500
# [59]	validation_0-logloss:0.66439
# [0]	validation_0-logloss:0.76773
# [1]	validation_0-logloss:0.76277
# [2]	validation_0-logloss:0.75806
# [3]	validation_0-logloss:0.75391
# [4]	validation_0-logloss:0.75017
# [5]	validation_0-logloss:0.74694
# [6]	validation_0-logloss:0.74362
# [7]	validation_0-logloss:0.74071
# [8]	validation_0-logloss:0.73804
# [9]	validation_0-logloss:0.73513
# [10]	validation_0-logloss:0.73226
# [11]	validation_0-logloss:0.72971
# [12]	validation_0-logloss:0.72717
# [13]	validation_0-logloss:0.72499
# [14]	validation_0-logloss:0.72245
# [15]	validation_0-logloss:0.71991
# [16]	validation_0-logloss:0.71787
# [17]	validation_0-logloss:0.71549
# [18]	validation_0-logloss:0.71328
# [19]	validation_0-logloss:0.71152
# [20]	validation_0-logloss:0.70946
# [21]	validation_0-logloss:0.70723
# [22]	validation_0-logloss:0.70563
# [23]	validation_0-logloss:0.70414
# [24]	validation_0-logloss:0.70253
# [25]	validation_0-logloss:0.70123
# [26]	validation_0-logloss:0.69976
# [27]	validation_0-logloss:0.69869
# [28]	validation_0-logloss:0.69715
# [29]	validation_0-logloss:0.69560
# [30]	validation_0-logloss:0.69431
# [31]	validation_0-logloss:0.69278
# [32]	validation_0-logloss:0.69133
# [33]	validation_0-logloss:0.69033
# [34]	validation_0-logloss:0.68958
# [35]	validation_0-logloss:0.68884
# [36]	validation_0-logloss:0.68760
# [37]	validation_0-logloss:0.68704
# [38]	validation_0-logloss:0.68587
# [39]	validation_0-logloss:0.68453
# [40]	validation_0-logloss:0.68376
# [41]	validation_0-logloss:0.68241
# [42]	validation_0-logloss:0.68185
# [43]	validation_0-logloss:0.68126
# [44]	validation_0-logloss:0.68114
# [45]	validation_0-logloss:0.68036
# [46]	validation_0-logloss:0.67981
# [47]	validation_0-logloss:0.67932
# [48]	validation_0-logloss:0.67890
# [49]	validation_0-logloss:0.67837
# [50]	validation_0-logloss:0.67728
# [51]	validation_0-logloss:0.67690
# [52]	validation_0-logloss:0.67668
# [53]	validation_0-logloss:0.67624
# [54]	validation_0-logloss:0.67594
# [55]	validation_0-logloss:0.67576
# [56]	validation_0-logloss:0.67481
# [57]	validation_0-logloss:0.67486
# [58]	validation_0-logloss:0.67398
# [59]	validation_0-logloss:0.67367
# [0]	validation_0-logloss:0.78772
# [1]	validation_0-logloss:0.78659
# [2]	validation_0-logloss:0.78550
# [3]	validation_0-logloss:0.78445
# [4]	validation_0-logloss:0.78343
# [5]	validation_0-logloss:0.78284
# [6]	validation_0-logloss:0.78189
# [7]	validation_0-logloss:0.78097
# [8]	validation_0-logloss:0.78029
# [9]	validation_0-logloss:0.77954
# [10]	validation_0-logloss:0.77869
# [11]	validation_0-logloss:0.77798
# [12]	validation_0-logloss:0.77717
# [13]	validation_0-logloss:0.77650
# [14]	validation_0-logloss:0.77586
# [15]	validation_0-logloss:0.77543
# [16]	validation_0-logloss:0.77487
# [17]	validation_0-logloss:0.77423
# [18]	validation_0-logloss:0.77372
# [19]	validation_0-logloss:0.77314
# [20]	validation_0-logloss:0.77257
# [21]	validation_0-logloss:0.77204
# [22]	validation_0-logloss:0.77151
# [23]	validation_0-logloss:0.77093
# [24]	validation_0-logloss:0.77039
# [25]	validation_0-logloss:0.76988
# [26]	validation_0-logloss:0.76941
# [27]	validation_0-logloss:0.76891
# [28]	validation_0-logloss:0.76862
# [29]	validation_0-logloss:0.76817
# [30]	validation_0-logloss:0.76774
# [31]	validation_0-logloss:0.76729
# [32]	validation_0-logloss:0.76690
# [33]	validation_0-logloss:0.76668
# [34]	validation_0-logloss:0.76631
# [35]	validation_0-logloss:0.76591
# [36]	validation_0-logloss:0.76552
# [37]	validation_0-logloss:0.76519
# [38]	validation_0-logloss:0.76484
# [39]	validation_0-logloss:0.76448
# [40]	validation_0-logloss:0.76421
# [41]	validation_0-logloss:0.76363
# [42]	validation_0-logloss:0.76327
# [43]	validation_0-logloss:0.76292
# [44]	validation_0-logloss:0.76274
# [45]	validation_0-logloss:0.76243
# [46]	validation_0-logloss:0.76176
# [47]	validation_0-logloss:0.76146
# [48]	validation_0-logloss:0.76124
# [49]	validation_0-logloss:0.76111
# [50]	validation_0-logloss:0.76045
# [51]	validation_0-logloss:0.76019
# [52]	validation_0-logloss:0.75955
# [53]	validation_0-logloss:0.75931
# [54]	validation_0-logloss:0.75885
# [55]	validation_0-logloss:0.75839
# [56]	validation_0-logloss:0.75777
# [57]	validation_0-logloss:0.75749
# [58]	validation_0-logloss:0.75742
# [59]	validation_0-logloss:0.75717
# [60]	validation_0-logloss:0.75693
# [61]	validation_0-logloss:0.75671
# [62]	validation_0-logloss:0.75650
# [63]	validation_0-logloss:0.75647
# [64]	validation_0-logloss:0.75606
# [65]	validation_0-logloss:0.75585
# [66]	validation_0-logloss:0.75566
# [67]	validation_0-logloss:0.75549
# [68]	validation_0-logloss:0.75533
# [69]	validation_0-logloss:0.75491
# [0]	validation_0-logloss:0.78777
# [1]	validation_0-logloss:0.78668
# [2]	validation_0-logloss:0.78564
# [3]	validation_0-logloss:0.78463
# [4]	validation_0-logloss:0.78368
# [5]	validation_0-logloss:0.78277
# [6]	validation_0-logloss:0.78185
# [7]	validation_0-logloss:0.78097
# [8]	validation_0-logloss:0.77997
# [9]	validation_0-logloss:0.77900
# [10]	validation_0-logloss:0.77807
# [11]	validation_0-logloss:0.77717
# [12]	validation_0-logloss:0.77640
# [13]	validation_0-logloss:0.77566
# [14]	validation_0-logloss:0.77484
# [15]	validation_0-logloss:0.77405
# [16]	validation_0-logloss:0.77309
# [17]	validation_0-logloss:0.77242
# [18]	validation_0-logloss:0.77170
# [19]	validation_0-logloss:0.77100
# [20]	validation_0-logloss:0.77033
# [21]	validation_0-logloss:0.76968
# [22]	validation_0-logloss:0.76906
# [23]	validation_0-logloss:0.76849
# [24]	validation_0-logloss:0.76773
# [25]	validation_0-logloss:0.76701
# [26]	validation_0-logloss:0.76648
# [27]	validation_0-logloss:0.76597
# [28]	validation_0-logloss:0.76542
# [29]	validation_0-logloss:0.76475
# [30]	validation_0-logloss:0.76411
# [31]	validation_0-logloss:0.76349
# [32]	validation_0-logloss:0.76289
# [33]	validation_0-logloss:0.76226
# [34]	validation_0-logloss:0.76182
# [35]	validation_0-logloss:0.76139
# [36]	validation_0-logloss:0.76071
# [37]	validation_0-logloss:0.76003
# [38]	validation_0-logloss:0.75960
# [39]	validation_0-logloss:0.75895
# [40]	validation_0-logloss:0.75828
# [41]	validation_0-logloss:0.75773
# [42]	validation_0-logloss:0.75711
# [43]	validation_0-logloss:0.75651
# [44]	validation_0-logloss:0.75587
# [45]	validation_0-logloss:0.75529
# [46]	validation_0-logloss:0.75466
# [47]	validation_0-logloss:0.75411
# [48]	validation_0-logloss:0.75375
# [49]	validation_0-logloss:0.75342
# [50]	validation_0-logloss:0.75280
# [51]	validation_0-logloss:0.75224
# [52]	validation_0-logloss:0.75163
# [53]	validation_0-logloss:0.75109
# [54]	validation_0-logloss:0.75055
# [55]	validation_0-logloss:0.75005
# [56]	validation_0-logloss:0.74947
# [57]	validation_0-logloss:0.74896
# [58]	validation_0-logloss:0.74844
# [59]	validation_0-logloss:0.74795
# [60]	validation_0-logloss:0.74738
# [61]	validation_0-logloss:0.74683
# [62]	validation_0-logloss:0.74636
# [63]	validation_0-logloss:0.74608
# [64]	validation_0-logloss:0.74559
# [65]	validation_0-logloss:0.74513
# [66]	validation_0-logloss:0.74493
# [67]	validation_0-logloss:0.74449
# [68]	validation_0-logloss:0.74406
# [69]	validation_0-logloss:0.74356
# [0]	validation_0-logloss:0.78239
# [1]	validation_0-logloss:0.78077
# [2]	validation_0-logloss:0.77946
# [3]	validation_0-logloss:0.77819
# [4]	validation_0-logloss:0.77696
# [5]	validation_0-logloss:0.77576
# [6]	validation_0-logloss:0.77428
# [7]	validation_0-logloss:0.77284
# [8]	validation_0-logloss:0.77173
# [9]	validation_0-logloss:0.77038
# [10]	validation_0-logloss:0.76907
# [11]	validation_0-logloss:0.76805
# [12]	validation_0-logloss:0.76680
# [13]	validation_0-logloss:0.76558
# [14]	validation_0-logloss:0.76464
# [15]	validation_0-logloss:0.76359
# [16]	validation_0-logloss:0.76270
# [17]	validation_0-logloss:0.76170
# [18]	validation_0-logloss:0.76085
# [19]	validation_0-logloss:0.76003
# [20]	validation_0-logloss:0.75942
# [21]	validation_0-logloss:0.75882
# [22]	validation_0-logloss:0.75789
# [23]	validation_0-logloss:0.75716
# [24]	validation_0-logloss:0.75658
# [25]	validation_0-logloss:0.75569
# [26]	validation_0-logloss:0.75494
# [27]	validation_0-logloss:0.75407
# [28]	validation_0-logloss:0.75351
# [29]	validation_0-logloss:0.75285
# [30]	validation_0-logloss:0.75227
# [31]	validation_0-logloss:0.75173
# [32]	validation_0-logloss:0.75110
# [33]	validation_0-logloss:0.75053
# [34]	validation_0-logloss:0.75001
# [35]	validation_0-logloss:0.74940
# [36]	validation_0-logloss:0.74887
# [37]	validation_0-logloss:0.74837
# [38]	validation_0-logloss:0.74788
# [39]	validation_0-logloss:0.74702
# [40]	validation_0-logloss:0.74650
# [41]	validation_0-logloss:0.74571
# [42]	validation_0-logloss:0.74489
# [43]	validation_0-logloss:0.74442
# [44]	validation_0-logloss:0.74387
# [45]	validation_0-logloss:0.74341
# [46]	validation_0-logloss:0.74285
# [47]	validation_0-logloss:0.74212
# [48]	validation_0-logloss:0.74168
# [49]	validation_0-logloss:0.74121
# [50]	validation_0-logloss:0.74079
# [51]	validation_0-logloss:0.73988
# [52]	validation_0-logloss:0.73923
# [53]	validation_0-logloss:0.73836
# [54]	validation_0-logloss:0.73795
# [55]	validation_0-logloss:0.73717
# [56]	validation_0-logloss:0.73677
# [57]	validation_0-logloss:0.73594
# [58]	validation_0-logloss:0.73549
# [59]	validation_0-logloss:0.73469
# [60]	validation_0-logloss:0.73390
# [61]	validation_0-logloss:0.73318
# [62]	validation_0-logloss:0.73247
# [63]	validation_0-logloss:0.73215
# [64]	validation_0-logloss:0.73170
# [65]	validation_0-logloss:0.73132
# [66]	validation_0-logloss:0.73095
# [67]	validation_0-logloss:0.73028
# [68]	validation_0-logloss:0.72989
# [69]	validation_0-logloss:0.72945
# [0]	validation_0-logloss:0.78281
# [1]	validation_0-logloss:0.78176
# [2]	validation_0-logloss:0.78076
# [3]	validation_0-logloss:0.77989
# [4]	validation_0-logloss:0.77905
# [5]	validation_0-logloss:0.77812
# [6]	validation_0-logloss:0.77723
# [7]	validation_0-logloss:0.77637
# [8]	validation_0-logloss:0.77554
# [9]	validation_0-logloss:0.77483
# [10]	validation_0-logloss:0.77415
# [11]	validation_0-logloss:0.77349
# [12]	validation_0-logloss:0.77286
# [13]	validation_0-logloss:0.77225
# [14]	validation_0-logloss:0.77157
# [15]	validation_0-logloss:0.77092
# [16]	validation_0-logloss:0.77018
# [17]	validation_0-logloss:0.76945
# [18]	validation_0-logloss:0.76876
# [19]	validation_0-logloss:0.76817
# [20]	validation_0-logloss:0.76751
# [21]	validation_0-logloss:0.76687
# [22]	validation_0-logloss:0.76608
# [23]	validation_0-logloss:0.76525
# [24]	validation_0-logloss:0.76445
# [25]	validation_0-logloss:0.76367
# [26]	validation_0-logloss:0.76326
# [27]	validation_0-logloss:0.76273
# [28]	validation_0-logloss:0.76216
# [29]	validation_0-logloss:0.76144
# [30]	validation_0-logloss:0.76075
# [31]	validation_0-logloss:0.75999
# [32]	validation_0-logloss:0.75926
# [33]	validation_0-logloss:0.75867
# [34]	validation_0-logloss:0.75797
# [35]	validation_0-logloss:0.75751
# [36]	validation_0-logloss:0.75713
# [37]	validation_0-logloss:0.75646
# [38]	validation_0-logloss:0.75598
# [39]	validation_0-logloss:0.75561
# [40]	validation_0-logloss:0.75525
# [41]	validation_0-logloss:0.75478
# [42]	validation_0-logloss:0.75416
# [43]	validation_0-logloss:0.75357
# [44]	validation_0-logloss:0.75322
# [45]	validation_0-logloss:0.75288
# [46]	validation_0-logloss:0.75255
# [47]	validation_0-logloss:0.75199
# [48]	validation_0-logloss:0.75155
# [49]	validation_0-logloss:0.75118
# [50]	validation_0-logloss:0.75087
# [51]	validation_0-logloss:0.75056
# [52]	validation_0-logloss:0.75026
# [53]	validation_0-logloss:0.74974
# [54]	validation_0-logloss:0.74945
# [55]	validation_0-logloss:0.74894
# [56]	validation_0-logloss:0.74865
# [57]	validation_0-logloss:0.74826
# [58]	validation_0-logloss:0.74777
# [59]	validation_0-logloss:0.74728
# [60]	validation_0-logloss:0.74701
# [61]	validation_0-logloss:0.74674
# [62]	validation_0-logloss:0.74648
# [63]	validation_0-logloss:0.74632
# [64]	validation_0-logloss:0.74601
# [65]	validation_0-logloss:0.74566
# [66]	validation_0-logloss:0.74532
# [67]	validation_0-logloss:0.74485
# [68]	validation_0-logloss:0.74452
# [69]	validation_0-logloss:0.74425
# [0]	validation_0-logloss:0.78241
# [1]	validation_0-logloss:0.78110
# [2]	validation_0-logloss:0.77983
# [3]	validation_0-logloss:0.77859
# [4]	validation_0-logloss:0.77759
# [5]	validation_0-logloss:0.77661
# [6]	validation_0-logloss:0.77563
# [7]	validation_0-logloss:0.77470
# [8]	validation_0-logloss:0.77391
# [9]	validation_0-logloss:0.77316
# [10]	validation_0-logloss:0.77211
# [11]	validation_0-logloss:0.77140
# [12]	validation_0-logloss:0.77041
# [13]	validation_0-logloss:0.76974
# [14]	validation_0-logloss:0.76905
# [15]	validation_0-logloss:0.76841
# [16]	validation_0-logloss:0.76778
# [17]	validation_0-logloss:0.76717
# [18]	validation_0-logloss:0.76641
# [19]	validation_0-logloss:0.76568
# [20]	validation_0-logloss:0.76512
# [21]	validation_0-logloss:0.76442
# [22]	validation_0-logloss:0.76391
# [23]	validation_0-logloss:0.76330
# [24]	validation_0-logloss:0.76271
# [25]	validation_0-logloss:0.76215
# [26]	validation_0-logloss:0.76158
# [27]	validation_0-logloss:0.76123
# [28]	validation_0-logloss:0.76062
# [29]	validation_0-logloss:0.76011
# [30]	validation_0-logloss:0.75962
# [31]	validation_0-logloss:0.75915
# [32]	validation_0-logloss:0.75884
# [33]	validation_0-logloss:0.75836
# [34]	validation_0-logloss:0.75799
# [35]	validation_0-logloss:0.75764
# [36]	validation_0-logloss:0.75711
# [37]	validation_0-logloss:0.75660
# [38]	validation_0-logloss:0.75634
# [39]	validation_0-logloss:0.75586
# [40]	validation_0-logloss:0.75555
# [41]	validation_0-logloss:0.75506
# [42]	validation_0-logloss:0.75461
# [43]	validation_0-logloss:0.75418
# [44]	validation_0-logloss:0.75397
# [45]	validation_0-logloss:0.75357
# [46]	validation_0-logloss:0.75337
# [47]	validation_0-logloss:0.75299
# [48]	validation_0-logloss:0.75274
# [49]	validation_0-logloss:0.75239
# [50]	validation_0-logloss:0.75215
# [51]	validation_0-logloss:0.75181
# [52]	validation_0-logloss:0.75133
# [53]	validation_0-logloss:0.75100
# [54]	validation_0-logloss:0.75079
# [55]	validation_0-logloss:0.75058
# [56]	validation_0-logloss:0.75020
# [57]	validation_0-logloss:0.74991
# [58]	validation_0-logloss:0.74972
# [59]	validation_0-logloss:0.74945
# [60]	validation_0-logloss:0.74919
# [61]	validation_0-logloss:0.74873
# [62]	validation_0-logloss:0.74857
# [63]	validation_0-logloss:0.74843
# [64]	validation_0-logloss:0.74819
# [65]	validation_0-logloss:0.74774
# [66]	validation_0-logloss:0.74731
# [67]	validation_0-logloss:0.74709
# [68]	validation_0-logloss:0.74664
# [69]	validation_0-logloss:0.74652
# [0]	validation_0-logloss:0.79841
# [1]	validation_0-logloss:0.79403
# [2]	validation_0-logloss:0.78942
# [3]	validation_0-logloss:0.78545
# [4]	validation_0-logloss:0.78079
# [5]	validation_0-logloss:0.77719
# [6]	validation_0-logloss:0.77359
# [7]	validation_0-logloss:0.76960
# [8]	validation_0-logloss:0.76610
# [9]	validation_0-logloss:0.76281
# [10]	validation_0-logloss:0.75993
# [11]	validation_0-logloss:0.75740
# [12]	validation_0-logloss:0.75501
# [13]	validation_0-logloss:0.75242
# [14]	validation_0-logloss:0.75011
# [15]	validation_0-logloss:0.74793
# [16]	validation_0-logloss:0.74564
# [17]	validation_0-logloss:0.74283
# [18]	validation_0-logloss:0.74075
# [19]	validation_0-logloss:0.73889
# [20]	validation_0-logloss:0.73716
# [21]	validation_0-logloss:0.73572
# [22]	validation_0-logloss:0.73385
# [23]	validation_0-logloss:0.73192
# [24]	validation_0-logloss:0.73076
# [25]	validation_0-logloss:0.72933
# [26]	validation_0-logloss:0.72850
# [27]	validation_0-logloss:0.72698
# [28]	validation_0-logloss:0.72578
# [29]	validation_0-logloss:0.72472
# [30]	validation_0-logloss:0.72365
# [31]	validation_0-logloss:0.72235
# [32]	validation_0-logloss:0.72136
# [33]	validation_0-logloss:0.71953
# [34]	validation_0-logloss:0.71838
# [35]	validation_0-logloss:0.71692
# [36]	validation_0-logloss:0.71548
# [37]	validation_0-logloss:0.71421
# [38]	validation_0-logloss:0.71343
# [39]	validation_0-logloss:0.71269
# [40]	validation_0-logloss:0.71195
# [41]	validation_0-logloss:0.71062
# [42]	validation_0-logloss:0.70966
# [43]	validation_0-logloss:0.70918
# [44]	validation_0-logloss:0.70848
# [45]	validation_0-logloss:0.70761
# [46]	validation_0-logloss:0.70639
# [47]	validation_0-logloss:0.70502
# [48]	validation_0-logloss:0.70368
# [49]	validation_0-logloss:0.70312
# [50]	validation_0-logloss:0.70230
# [51]	validation_0-logloss:0.70138
# [52]	validation_0-logloss:0.70081
# [53]	validation_0-logloss:0.70024
# [54]	validation_0-logloss:0.69946
# [55]	validation_0-logloss:0.69883
# [56]	validation_0-logloss:0.69848
# [57]	validation_0-logloss:0.69745
# [58]	validation_0-logloss:0.69677
# [59]	validation_0-logloss:0.69625
# [60]	validation_0-logloss:0.69560
# [61]	validation_0-logloss:0.69535
# [62]	validation_0-logloss:0.69503
# [63]	validation_0-logloss:0.69461
# [64]	validation_0-logloss:0.69385
# [65]	validation_0-logloss:0.69333
# [66]	validation_0-logloss:0.69256
# [67]	validation_0-logloss:0.69221
# [68]	validation_0-logloss:0.69188
# [69]	validation_0-logloss:0.69118
# [70]	validation_0-logloss:0.69043
# [71]	validation_0-logloss:0.68999
# [72]	validation_0-logloss:0.68977
# [73]	validation_0-logloss:0.68951
# [74]	validation_0-logloss:0.68933
# [75]	validation_0-logloss:0.68915
# [76]	validation_0-logloss:0.68864
# [77]	validation_0-logloss:0.68849
# [78]	validation_0-logloss:0.68863
# [79]	validation_0-logloss:0.68835
# [0]	validation_0-logloss:0.79845
# [1]	validation_0-logloss:0.79308
# [2]	validation_0-logloss:0.78806
# [3]	validation_0-logloss:0.78296
# [4]	validation_0-logloss:0.77828
# [5]	validation_0-logloss:0.77402
# [6]	validation_0-logloss:0.77017
# [7]	validation_0-logloss:0.76608
# [8]	validation_0-logloss:0.76216
# [9]	validation_0-logloss:0.75855
# [10]	validation_0-logloss:0.75525
# [11]	validation_0-logloss:0.75228
# [12]	validation_0-logloss:0.74918
# [13]	validation_0-logloss:0.74620
# [14]	validation_0-logloss:0.74322
# [15]	validation_0-logloss:0.74036
# [16]	validation_0-logloss:0.73774
# [17]	validation_0-logloss:0.73470
# [18]	validation_0-logloss:0.73215
# [19]	validation_0-logloss:0.72969
# [20]	validation_0-logloss:0.72685
# [21]	validation_0-logloss:0.72514
# [22]	validation_0-logloss:0.72261
# [23]	validation_0-logloss:0.72000
# [24]	validation_0-logloss:0.71781
# [25]	validation_0-logloss:0.71591
# [26]	validation_0-logloss:0.71460
# [27]	validation_0-logloss:0.71229
# [28]	validation_0-logloss:0.71076
# [29]	validation_0-logloss:0.70957
# [30]	validation_0-logloss:0.70753
# [31]	validation_0-logloss:0.70576
# [32]	validation_0-logloss:0.70428
# [33]	validation_0-logloss:0.70265
# [34]	validation_0-logloss:0.70014
# [35]	validation_0-logloss:0.69893
# [36]	validation_0-logloss:0.69683
# [37]	validation_0-logloss:0.69568
# [38]	validation_0-logloss:0.69370
# [39]	validation_0-logloss:0.69209
# [40]	validation_0-logloss:0.69087
# [41]	validation_0-logloss:0.68974
# [42]	validation_0-logloss:0.68843
# [43]	validation_0-logloss:0.68725
# [44]	validation_0-logloss:0.68605
# [45]	validation_0-logloss:0.68529
# [46]	validation_0-logloss:0.68453
# [47]	validation_0-logloss:0.68410
# [48]	validation_0-logloss:0.68321
# [49]	validation_0-logloss:0.68273
# [50]	validation_0-logloss:0.68234
# [51]	validation_0-logloss:0.68157
# [52]	validation_0-logloss:0.68110
# [53]	validation_0-logloss:0.68027
# [54]	validation_0-logloss:0.67956
# [55]	validation_0-logloss:0.67893
# [56]	validation_0-logloss:0.67846
# [57]	validation_0-logloss:0.67801
# [58]	validation_0-logloss:0.67745
# [59]	validation_0-logloss:0.67714
# [60]	validation_0-logloss:0.67617
# [61]	validation_0-logloss:0.67522
# [62]	validation_0-logloss:0.67484
# [63]	validation_0-logloss:0.67435
# [64]	validation_0-logloss:0.67371
# [65]	validation_0-logloss:0.67322
# [66]	validation_0-logloss:0.67270
# [67]	validation_0-logloss:0.67257
# [68]	validation_0-logloss:0.67174
# [69]	validation_0-logloss:0.67148
# [70]	validation_0-logloss:0.67089
# [71]	validation_0-logloss:0.67031
# [72]	validation_0-logloss:0.67021
# [73]	validation_0-logloss:0.66970
# [74]	validation_0-logloss:0.66917
# [75]	validation_0-logloss:0.66861
# [76]	validation_0-logloss:0.66824
# [77]	validation_0-logloss:0.66793
# [78]	validation_0-logloss:0.66796
# [79]	validation_0-logloss:0.66735
# [0]	validation_0-logloss:0.79277
# [1]	validation_0-logloss:0.78640
# [2]	validation_0-logloss:0.78128
# [3]	validation_0-logloss:0.77589
# [4]	validation_0-logloss:0.77094
# [5]	validation_0-logloss:0.76593
# [6]	validation_0-logloss:0.76105
# [7]	validation_0-logloss:0.75662
# [8]	validation_0-logloss:0.75252
# [9]	validation_0-logloss:0.74818
# [10]	validation_0-logloss:0.74438
# [11]	validation_0-logloss:0.74079
# [12]	validation_0-logloss:0.73687
# [13]	validation_0-logloss:0.73364
# [14]	validation_0-logloss:0.72980
# [15]	validation_0-logloss:0.72616
# [16]	validation_0-logloss:0.72341
# [17]	validation_0-logloss:0.72048
# [18]	validation_0-logloss:0.71742
# [19]	validation_0-logloss:0.71458
# [20]	validation_0-logloss:0.71187
# [21]	validation_0-logloss:0.70907
# [22]	validation_0-logloss:0.70660
# [23]	validation_0-logloss:0.70415
# [24]	validation_0-logloss:0.70207
# [25]	validation_0-logloss:0.69969
# [26]	validation_0-logloss:0.69763
# [27]	validation_0-logloss:0.69623
# [28]	validation_0-logloss:0.69443
# [29]	validation_0-logloss:0.69278
# [30]	validation_0-logloss:0.69109
# [31]	validation_0-logloss:0.68892
# [32]	validation_0-logloss:0.68679
# [33]	validation_0-logloss:0.68449
# [34]	validation_0-logloss:0.68239
# [35]	validation_0-logloss:0.68086
# [36]	validation_0-logloss:0.67888
# [37]	validation_0-logloss:0.67712
# [38]	validation_0-logloss:0.67532
# [39]	validation_0-logloss:0.67356
# [40]	validation_0-logloss:0.67217
# [41]	validation_0-logloss:0.67069
# [42]	validation_0-logloss:0.66955
# [43]	validation_0-logloss:0.66810
# [44]	validation_0-logloss:0.66671
# [45]	validation_0-logloss:0.66566
# [46]	validation_0-logloss:0.66472
# [47]	validation_0-logloss:0.66360
# [48]	validation_0-logloss:0.66258
# [49]	validation_0-logloss:0.66161
# [50]	validation_0-logloss:0.66033
# [51]	validation_0-logloss:0.65967
# [52]	validation_0-logloss:0.65823
# [53]	validation_0-logloss:0.65617
# [54]	validation_0-logloss:0.65470
# [55]	validation_0-logloss:0.65334
# [56]	validation_0-logloss:0.65243
# [57]	validation_0-logloss:0.65158
# [58]	validation_0-logloss:0.65004
# [59]	validation_0-logloss:0.64865
# [60]	validation_0-logloss:0.64682
# [61]	validation_0-logloss:0.64564
# [62]	validation_0-logloss:0.64441
# [63]	validation_0-logloss:0.64380
# [64]	validation_0-logloss:0.64298
# [65]	validation_0-logloss:0.64201
# [66]	validation_0-logloss:0.64071
# [67]	validation_0-logloss:0.63965
# [68]	validation_0-logloss:0.63877
# [69]	validation_0-logloss:0.63794
# [70]	validation_0-logloss:0.63655
# [71]	validation_0-logloss:0.63577
# [72]	validation_0-logloss:0.63519
# [73]	validation_0-logloss:0.63412
# [74]	validation_0-logloss:0.63324
# [75]	validation_0-logloss:0.63260
# [76]	validation_0-logloss:0.63195
# [77]	validation_0-logloss:0.63094
# [78]	validation_0-logloss:0.63004
# [79]	validation_0-logloss:0.62961
# [0]	validation_0-logloss:0.79388
# [1]	validation_0-logloss:0.78910
# [2]	validation_0-logloss:0.78448
# [3]	validation_0-logloss:0.78078
# [4]	validation_0-logloss:0.77779
# [5]	validation_0-logloss:0.77370
# [6]	validation_0-logloss:0.76974
# [7]	validation_0-logloss:0.76651
# [8]	validation_0-logloss:0.76288
# [9]	validation_0-logloss:0.75995
# [10]	validation_0-logloss:0.75730
# [11]	validation_0-logloss:0.75439
# [12]	validation_0-logloss:0.75145
# [13]	validation_0-logloss:0.74837
# [14]	validation_0-logloss:0.74594
# [15]	validation_0-logloss:0.74323
# [16]	validation_0-logloss:0.74053
# [17]	validation_0-logloss:0.73866
# [18]	validation_0-logloss:0.73610
# [19]	validation_0-logloss:0.73447
# [20]	validation_0-logloss:0.73214
# [21]	validation_0-logloss:0.72970
# [22]	validation_0-logloss:0.72713
# [23]	validation_0-logloss:0.72566
# [24]	validation_0-logloss:0.72285
# [25]	validation_0-logloss:0.72185
# [26]	validation_0-logloss:0.72067
# [27]	validation_0-logloss:0.71966
# [28]	validation_0-logloss:0.71825
# [29]	validation_0-logloss:0.71671
# [30]	validation_0-logloss:0.71430
# [31]	validation_0-logloss:0.71189
# [32]	validation_0-logloss:0.71020
# [33]	validation_0-logloss:0.70904
# [34]	validation_0-logloss:0.70720
# [35]	validation_0-logloss:0.70645
# [36]	validation_0-logloss:0.70495
# [37]	validation_0-logloss:0.70431
# [38]	validation_0-logloss:0.70277
# [39]	validation_0-logloss:0.70191
# [40]	validation_0-logloss:0.70102
# [41]	validation_0-logloss:0.69976
# [42]	validation_0-logloss:0.69923
# [43]	validation_0-logloss:0.69835
# [44]	validation_0-logloss:0.69772
# [45]	validation_0-logloss:0.69688
# [46]	validation_0-logloss:0.69634
# [47]	validation_0-logloss:0.69592
# [48]	validation_0-logloss:0.69536
# [49]	validation_0-logloss:0.69475
# [50]	validation_0-logloss:0.69382
# [51]	validation_0-logloss:0.69332
# [52]	validation_0-logloss:0.69248
# [53]	validation_0-logloss:0.69190
# [54]	validation_0-logloss:0.69187
# [55]	validation_0-logloss:0.69130
# [56]	validation_0-logloss:0.69106
# [57]	validation_0-logloss:0.69067
# [58]	validation_0-logloss:0.68997
# [59]	validation_0-logloss:0.68937
# [60]	validation_0-logloss:0.68887
# [61]	validation_0-logloss:0.68872
# [62]	validation_0-logloss:0.68837
# [63]	validation_0-logloss:0.68841
# [64]	validation_0-logloss:0.68822
# [65]	validation_0-logloss:0.68817
# [66]	validation_0-logloss:0.68755
# [67]	validation_0-logloss:0.68753
# [68]	validation_0-logloss:0.68754
# [69]	validation_0-logloss:0.68740
# [70]	validation_0-logloss:0.68740
# [71]	validation_0-logloss:0.68741
# [0]	validation_0-logloss:0.79372
# [1]	validation_0-logloss:0.78973
# [2]	validation_0-logloss:0.78495
# [3]	validation_0-logloss:0.78082
# [4]	validation_0-logloss:0.77694
# [5]	validation_0-logloss:0.77321
# [6]	validation_0-logloss:0.76969
# [7]	validation_0-logloss:0.76640
# [8]	validation_0-logloss:0.76341
# [9]	validation_0-logloss:0.76055
# [10]	validation_0-logloss:0.75827
# [11]	validation_0-logloss:0.75524
# [12]	validation_0-logloss:0.75248
# [13]	validation_0-logloss:0.74987
# [14]	validation_0-logloss:0.74798
# [15]	validation_0-logloss:0.74540
# [16]	validation_0-logloss:0.74361
# [17]	validation_0-logloss:0.74140
# [18]	validation_0-logloss:0.73950
# [19]	validation_0-logloss:0.73699
# [20]	validation_0-logloss:0.73540
# [21]	validation_0-logloss:0.73338
# [22]	validation_0-logloss:0.73119
# [23]	validation_0-logloss:0.72964
# [24]	validation_0-logloss:0.72755
# [25]	validation_0-logloss:0.72589
# [26]	validation_0-logloss:0.72402
# [27]	validation_0-logloss:0.72220
# [28]	validation_0-logloss:0.72021
# [29]	validation_0-logloss:0.71926
# [30]	validation_0-logloss:0.71793
# [31]	validation_0-logloss:0.71633
# [32]	validation_0-logloss:0.71490
# [33]	validation_0-logloss:0.71371
# [34]	validation_0-logloss:0.71272
# [35]	validation_0-logloss:0.71210
# [36]	validation_0-logloss:0.71132
# [37]	validation_0-logloss:0.71035
# [38]	validation_0-logloss:0.70929
# [39]	validation_0-logloss:0.70859
# [40]	validation_0-logloss:0.70780
# [41]	validation_0-logloss:0.70661
# [42]	validation_0-logloss:0.70624
# [43]	validation_0-logloss:0.70589
# [44]	validation_0-logloss:0.70532
# [45]	validation_0-logloss:0.70499
# [46]	validation_0-logloss:0.70447
# [47]	validation_0-logloss:0.70376
# [48]	validation_0-logloss:0.70295
# [49]	validation_0-logloss:0.70290
# [50]	validation_0-logloss:0.70244
# [51]	validation_0-logloss:0.70221
# [52]	validation_0-logloss:0.70171
# [53]	validation_0-logloss:0.70128
# [54]	validation_0-logloss:0.70094
# [55]	validation_0-logloss:0.70060
# [56]	validation_0-logloss:0.70080
# [57]	validation_0-logloss:0.70098
# [58]	validation_0-logloss:0.70090
# [0]	validation_0-logloss:0.80710
# [1]	validation_0-logloss:0.80527
# [2]	validation_0-logloss:0.80352
# [3]	validation_0-logloss:0.80224
# [4]	validation_0-logloss:0.80060
# [5]	validation_0-logloss:0.79932
# [6]	validation_0-logloss:0.79747
# [7]	validation_0-logloss:0.79570
# [8]	validation_0-logloss:0.79457
# [9]	validation_0-logloss:0.79289
# [10]	validation_0-logloss:0.79136
# [11]	validation_0-logloss:0.78971
# [12]	validation_0-logloss:0.78823
# [13]	validation_0-logloss:0.78699
# [14]	validation_0-logloss:0.78538
# [15]	validation_0-logloss:0.78393
# [16]	validation_0-logloss:0.78246
# [17]	validation_0-logloss:0.78113
# [18]	validation_0-logloss:0.77992
# [19]	validation_0-logloss:0.77876
# [20]	validation_0-logloss:0.77759
# [21]	validation_0-logloss:0.77626
# [22]	validation_0-logloss:0.77529
# [23]	validation_0-logloss:0.77437
# [24]	validation_0-logloss:0.77312
# [25]	validation_0-logloss:0.77197
# [26]	validation_0-logloss:0.77099
# [27]	validation_0-logloss:0.76975
# [28]	validation_0-logloss:0.76915
# [29]	validation_0-logloss:0.76817
# [30]	validation_0-logloss:0.76726
# [31]	validation_0-logloss:0.76637
# [32]	validation_0-logloss:0.76539
# [33]	validation_0-logloss:0.76454
# [34]	validation_0-logloss:0.76365
# [35]	validation_0-logloss:0.76281
# [36]	validation_0-logloss:0.76182
# [37]	validation_0-logloss:0.76094
# [38]	validation_0-logloss:0.76003
# [39]	validation_0-logloss:0.75919
# [40]	validation_0-logloss:0.75858
# [41]	validation_0-logloss:0.75774
# [42]	validation_0-logloss:0.75719
# [43]	validation_0-logloss:0.75633
# [44]	validation_0-logloss:0.75577
# [45]	validation_0-logloss:0.75549
# [46]	validation_0-logloss:0.75474
# [47]	validation_0-logloss:0.75401
# [48]	validation_0-logloss:0.75334
# [49]	validation_0-logloss:0.75294
# [0]	validation_0-logloss:0.80687
# [1]	validation_0-logloss:0.80493
# [2]	validation_0-logloss:0.80307
# [3]	validation_0-logloss:0.80110
# [4]	validation_0-logloss:0.79913
# [5]	validation_0-logloss:0.79733
# [6]	validation_0-logloss:0.79548
# [7]	validation_0-logloss:0.79372
# [8]	validation_0-logloss:0.79203
# [9]	validation_0-logloss:0.79030
# [10]	validation_0-logloss:0.78856
# [11]	validation_0-logloss:0.78718
# [12]	validation_0-logloss:0.78581
# [13]	validation_0-logloss:0.78445
# [14]	validation_0-logloss:0.78307
# [15]	validation_0-logloss:0.78157
# [16]	validation_0-logloss:0.78011
# [17]	validation_0-logloss:0.77900
# [18]	validation_0-logloss:0.77771
# [19]	validation_0-logloss:0.77625
# [20]	validation_0-logloss:0.77495
# [21]	validation_0-logloss:0.77364
# [22]	validation_0-logloss:0.77224
# [23]	validation_0-logloss:0.77119
# [24]	validation_0-logloss:0.76978
# [25]	validation_0-logloss:0.76851
# [26]	validation_0-logloss:0.76761
# [27]	validation_0-logloss:0.76637
# [28]	validation_0-logloss:0.76551
# [29]	validation_0-logloss:0.76430
# [30]	validation_0-logloss:0.76313
# [31]	validation_0-logloss:0.76200
# [32]	validation_0-logloss:0.76104
# [33]	validation_0-logloss:0.76007
# [34]	validation_0-logloss:0.75884
# [35]	validation_0-logloss:0.75818
# [36]	validation_0-logloss:0.75724
# [37]	validation_0-logloss:0.75632
# [38]	validation_0-logloss:0.75533
# [39]	validation_0-logloss:0.75439
# [40]	validation_0-logloss:0.75366
# [41]	validation_0-logloss:0.75253
# [42]	validation_0-logloss:0.75171
# [43]	validation_0-logloss:0.75091
# [44]	validation_0-logloss:0.75032
# [45]	validation_0-logloss:0.74957
# [46]	validation_0-logloss:0.74891
# [47]	validation_0-logloss:0.74807
# [48]	validation_0-logloss:0.74731
# [49]	validation_0-logloss:0.74669
# [0]	validation_0-logloss:0.80114
# [1]	validation_0-logloss:0.79885
# [2]	validation_0-logloss:0.79663
# [3]	validation_0-logloss:0.79448
# [4]	validation_0-logloss:0.79226
# [5]	validation_0-logloss:0.79013
# [6]	validation_0-logloss:0.78807
# [7]	validation_0-logloss:0.78620
# [8]	validation_0-logloss:0.78429
# [9]	validation_0-logloss:0.78210
# [10]	validation_0-logloss:0.77984
# [11]	validation_0-logloss:0.77822
# [12]	validation_0-logloss:0.77608
# [13]	validation_0-logloss:0.77418
# [14]	validation_0-logloss:0.77261
# [15]	validation_0-logloss:0.77069
# [16]	validation_0-logloss:0.76923
# [17]	validation_0-logloss:0.76767
# [18]	validation_0-logloss:0.76607
# [19]	validation_0-logloss:0.76476
# [20]	validation_0-logloss:0.76325
# [21]	validation_0-logloss:0.76190
# [22]	validation_0-logloss:0.76063
# [23]	validation_0-logloss:0.75948
# [24]	validation_0-logloss:0.75806
# [25]	validation_0-logloss:0.75685
# [26]	validation_0-logloss:0.75577
# [27]	validation_0-logloss:0.75444
# [28]	validation_0-logloss:0.75322
# [29]	validation_0-logloss:0.75206
# [30]	validation_0-logloss:0.75083
# [31]	validation_0-logloss:0.74952
# [32]	validation_0-logloss:0.74838
# [33]	validation_0-logloss:0.74737
# [34]	validation_0-logloss:0.74599
# [35]	validation_0-logloss:0.74515
# [36]	validation_0-logloss:0.74414
# [37]	validation_0-logloss:0.74296
# [38]	validation_0-logloss:0.74179
# [39]	validation_0-logloss:0.74068
# [40]	validation_0-logloss:0.73982
# [41]	validation_0-logloss:0.73870
# [42]	validation_0-logloss:0.73769
# [43]	validation_0-logloss:0.73669
# [44]	validation_0-logloss:0.73563
# [45]	validation_0-logloss:0.73479
# [46]	validation_0-logloss:0.73383
# [47]	validation_0-logloss:0.73246
# [48]	validation_0-logloss:0.73143
# [49]	validation_0-logloss:0.73058
# [0]	validation_0-logloss:0.80193
# [1]	validation_0-logloss:0.80029
# [2]	validation_0-logloss:0.79863
# [3]	validation_0-logloss:0.79684
# [4]	validation_0-logloss:0.79527
# [5]	validation_0-logloss:0.79395
# [6]	validation_0-logloss:0.79247
# [7]	validation_0-logloss:0.79104
# [8]	validation_0-logloss:0.78970
# [9]	validation_0-logloss:0.78825
# [10]	validation_0-logloss:0.78679
# [11]	validation_0-logloss:0.78568
# [12]	validation_0-logloss:0.78441
# [13]	validation_0-logloss:0.78326
# [14]	validation_0-logloss:0.78188
# [15]	validation_0-logloss:0.78063
# [16]	validation_0-logloss:0.77928
# [17]	validation_0-logloss:0.77830
# [18]	validation_0-logloss:0.77720
# [19]	validation_0-logloss:0.77620
# [20]	validation_0-logloss:0.77524
# [21]	validation_0-logloss:0.77432
# [22]	validation_0-logloss:0.77315
# [23]	validation_0-logloss:0.77192
# [24]	validation_0-logloss:0.77097
# [25]	validation_0-logloss:0.77005
# [26]	validation_0-logloss:0.76927
# [27]	validation_0-logloss:0.76826
# [28]	validation_0-logloss:0.76745
# [29]	validation_0-logloss:0.76637
# [30]	validation_0-logloss:0.76547
# [31]	validation_0-logloss:0.76440
# [32]	validation_0-logloss:0.76357
# [33]	validation_0-logloss:0.76261
# [34]	validation_0-logloss:0.76165
# [35]	validation_0-logloss:0.76138
# [36]	validation_0-logloss:0.76055
# [37]	validation_0-logloss:0.75962
# [38]	validation_0-logloss:0.75868
# [39]	validation_0-logloss:0.75778
# [40]	validation_0-logloss:0.75670
# [41]	validation_0-logloss:0.75542
# [42]	validation_0-logloss:0.75452
# [43]	validation_0-logloss:0.75362
# [44]	validation_0-logloss:0.75247
# [45]	validation_0-logloss:0.75167
# [46]	validation_0-logloss:0.75119
# [47]	validation_0-logloss:0.75044
# [48]	validation_0-logloss:0.74932
# [49]	validation_0-logloss:0.74887
# [0]	validation_0-logloss:0.80172
# [1]	validation_0-logloss:0.79986
# [2]	validation_0-logloss:0.79807
# [3]	validation_0-logloss:0.79621
# [4]	validation_0-logloss:0.79471
# [5]	validation_0-logloss:0.79318
# [6]	validation_0-logloss:0.79162
# [7]	validation_0-logloss:0.79027
# [8]	validation_0-logloss:0.78898
# [9]	validation_0-logloss:0.78733
# [10]	validation_0-logloss:0.78575
# [11]	validation_0-logloss:0.78427
# [12]	validation_0-logloss:0.78275
# [13]	validation_0-logloss:0.78163
# [14]	validation_0-logloss:0.78064
# [15]	validation_0-logloss:0.77962
# [16]	validation_0-logloss:0.77828
# [17]	validation_0-logloss:0.77701
# [18]	validation_0-logloss:0.77599
# [19]	validation_0-logloss:0.77496
# [20]	validation_0-logloss:0.77371
# [21]	validation_0-logloss:0.77289
# [22]	validation_0-logloss:0.77192
# [23]	validation_0-logloss:0.77097
# [24]	validation_0-logloss:0.76992
# [25]	validation_0-logloss:0.76906
# [26]	validation_0-logloss:0.76804
# [27]	validation_0-logloss:0.76710
# [28]	validation_0-logloss:0.76621
# [29]	validation_0-logloss:0.76534
# [30]	validation_0-logloss:0.76458
# [31]	validation_0-logloss:0.76384
# [32]	validation_0-logloss:0.76311
# [33]	validation_0-logloss:0.76246
# [34]	validation_0-logloss:0.76176
# [35]	validation_0-logloss:0.76130
# [36]	validation_0-logloss:0.76074
# [37]	validation_0-logloss:0.76005
# [38]	validation_0-logloss:0.75936
# [39]	validation_0-logloss:0.75888
# [40]	validation_0-logloss:0.75815
# [41]	validation_0-logloss:0.75754
# [42]	validation_0-logloss:0.75696
# [43]	validation_0-logloss:0.75637
# [44]	validation_0-logloss:0.75600
# [45]	validation_0-logloss:0.75524
# [46]	validation_0-logloss:0.75473
# [47]	validation_0-logloss:0.75392
# [48]	validation_0-logloss:0.75343
# [49]	validation_0-logloss:0.75295
# [0]	validation_0-logloss:0.74429
# [1]	validation_0-logloss:0.74046
# [2]	validation_0-logloss:0.73578
# [3]	validation_0-logloss:0.73282
# [4]	validation_0-logloss:0.72906
# [5]	validation_0-logloss:0.72675
# [6]	validation_0-logloss:0.72415
# [7]	validation_0-logloss:0.72128
# [8]	validation_0-logloss:0.71946
# [9]	validation_0-logloss:0.71704
# [10]	validation_0-logloss:0.71563
# [11]	validation_0-logloss:0.71355
# [12]	validation_0-logloss:0.71041
# [13]	validation_0-logloss:0.70868
# [14]	validation_0-logloss:0.70614
# [15]	validation_0-logloss:0.70504
# [16]	validation_0-logloss:0.70220
# [17]	validation_0-logloss:0.70096
# [18]	validation_0-logloss:0.69832
# [19]	validation_0-logloss:0.69584
# [20]	validation_0-logloss:0.69498
# [21]	validation_0-logloss:0.69420
# [22]	validation_0-logloss:0.69236
# [23]	validation_0-logloss:0.69174
# [24]	validation_0-logloss:0.68950
# [25]	validation_0-logloss:0.68888
# [26]	validation_0-logloss:0.68678
# [27]	validation_0-logloss:0.68514
# [28]	validation_0-logloss:0.68458
# [29]	validation_0-logloss:0.68264
# [30]	validation_0-logloss:0.68083
# [31]	validation_0-logloss:0.68004
# [32]	validation_0-logloss:0.67961
# [33]	validation_0-logloss:0.67922
# [34]	validation_0-logloss:0.67859
# [35]	validation_0-logloss:0.67826
# [36]	validation_0-logloss:0.67659
# [37]	validation_0-logloss:0.67503
# [38]	validation_0-logloss:0.67448
# [39]	validation_0-logloss:0.67373
# [40]	validation_0-logloss:0.67227
# [41]	validation_0-logloss:0.67179
# [42]	validation_0-logloss:0.67158
# [43]	validation_0-logloss:0.67094
# [44]	validation_0-logloss:0.66959
# [45]	validation_0-logloss:0.66943
# [46]	validation_0-logloss:0.66817
# [47]	validation_0-logloss:0.66742
# [48]	validation_0-logloss:0.66703
# [49]	validation_0-logloss:0.66669
# [50]	validation_0-logloss:0.66552
# [51]	validation_0-logloss:0.66542
# [52]	validation_0-logloss:0.66513
# [53]	validation_0-logloss:0.66508
# [54]	validation_0-logloss:0.66506
# [55]	validation_0-logloss:0.66464
# [56]	validation_0-logloss:0.66355
# [57]	validation_0-logloss:0.66348
# [58]	validation_0-logloss:0.66233
# [59]	validation_0-logloss:0.66192
# [60]	validation_0-logloss:0.66093
# [61]	validation_0-logloss:0.66001
# [62]	validation_0-logloss:0.65963
# [63]	validation_0-logloss:0.65929
# [64]	validation_0-logloss:0.65855
# [65]	validation_0-logloss:0.65786
# [66]	validation_0-logloss:0.65765
# [67]	validation_0-logloss:0.65736
# [68]	validation_0-logloss:0.65612
# [69]	validation_0-logloss:0.65599
# [70]	validation_0-logloss:0.65516
# [71]	validation_0-logloss:0.65498
# [72]	validation_0-logloss:0.65496
# [73]	validation_0-logloss:0.65434
# [74]	validation_0-logloss:0.65434
# [75]	validation_0-logloss:0.65410
# [76]	validation_0-logloss:0.65333
# [77]	validation_0-logloss:0.65260
# [78]	validation_0-logloss:0.65150
# [79]	validation_0-logloss:0.65126
# [0]	validation_0-logloss:0.74440
# [1]	validation_0-logloss:0.73970
# [2]	validation_0-logloss:0.73402
# [3]	validation_0-logloss:0.72969
# [4]	validation_0-logloss:0.72501
# [5]	validation_0-logloss:0.72143
# [6]	validation_0-logloss:0.71824
# [7]	validation_0-logloss:0.71458
# [8]	validation_0-logloss:0.71202
# [9]	validation_0-logloss:0.70952
# [10]	validation_0-logloss:0.70668
# [11]	validation_0-logloss:0.70364
# [12]	validation_0-logloss:0.70148
# [13]	validation_0-logloss:0.69886
# [14]	validation_0-logloss:0.69645
# [15]	validation_0-logloss:0.69432
# [16]	validation_0-logloss:0.69174
# [17]	validation_0-logloss:0.69029
# [18]	validation_0-logloss:0.68791
# [19]	validation_0-logloss:0.68568
# [20]	validation_0-logloss:0.68347
# [21]	validation_0-logloss:0.68216
# [22]	validation_0-logloss:0.68104
# [23]	validation_0-logloss:0.67901
# [24]	validation_0-logloss:0.67702
# [25]	validation_0-logloss:0.67540
# [26]	validation_0-logloss:0.67355
# [27]	validation_0-logloss:0.67218
# [28]	validation_0-logloss:0.67058
# [29]	validation_0-logloss:0.66902
# [30]	validation_0-logloss:0.66745
# [31]	validation_0-logloss:0.66659
# [32]	validation_0-logloss:0.66590
# [33]	validation_0-logloss:0.66448
# [34]	validation_0-logloss:0.66309
# [35]	validation_0-logloss:0.66238
# [36]	validation_0-logloss:0.66126
# [37]	validation_0-logloss:0.65997
# [38]	validation_0-logloss:0.65947
# [39]	validation_0-logloss:0.65834
# [40]	validation_0-logloss:0.65718
# [41]	validation_0-logloss:0.65604
# [42]	validation_0-logloss:0.65550
# [43]	validation_0-logloss:0.65471
# [44]	validation_0-logloss:0.65366
# [45]	validation_0-logloss:0.65266
# [46]	validation_0-logloss:0.65221
# [47]	validation_0-logloss:0.65130
# [48]	validation_0-logloss:0.64995
# [49]	validation_0-logloss:0.64918
# [50]	validation_0-logloss:0.64879
# [51]	validation_0-logloss:0.64803
# [52]	validation_0-logloss:0.64677
# [53]	validation_0-logloss:0.64624
# [54]	validation_0-logloss:0.64538
# [55]	validation_0-logloss:0.64477
# [56]	validation_0-logloss:0.64445
# [57]	validation_0-logloss:0.64331
# [58]	validation_0-logloss:0.64266
# [59]	validation_0-logloss:0.64203
# [60]	validation_0-logloss:0.64139
# [61]	validation_0-logloss:0.64113
# [62]	validation_0-logloss:0.64005
# [63]	validation_0-logloss:0.63903
# [64]	validation_0-logloss:0.63857
# [65]	validation_0-logloss:0.63798
# [66]	validation_0-logloss:0.63755
# [67]	validation_0-logloss:0.63702
# [68]	validation_0-logloss:0.63681
# [69]	validation_0-logloss:0.63594
# [70]	validation_0-logloss:0.63540
# [71]	validation_0-logloss:0.63491
# [72]	validation_0-logloss:0.63472
# [73]	validation_0-logloss:0.63407
# [74]	validation_0-logloss:0.63318
# [75]	validation_0-logloss:0.63272
# [76]	validation_0-logloss:0.63241
# [77]	validation_0-logloss:0.63189
# [78]	validation_0-logloss:0.63147
# [79]	validation_0-logloss:0.63102
# [0]	validation_0-logloss:0.73818
# [1]	validation_0-logloss:0.73157
# [2]	validation_0-logloss:0.72636
# ...
# [46]	validation_0-logloss:0.52668
# [47]	validation_0-logloss:0.52649
# [48]	validation_0-logloss:0.52703
# [49]	validation_0-logloss:0.52662
# [0]	validation_0-logloss:0.67738
# [1]	validation_0-logloss:0.66522
# [2]	validation_0-logloss:0.65287
# [3]	validation_0-logloss:0.64290
# [4]	validation_0-logloss:0.63315
# [5]	validation_0-logloss:0.62539
# [6]	validation_0-logloss:0.61657
# [7]	validation_0-logloss:0.60910
# [8]	validation_0-logloss:0.60236
# [9]	validation_0-logloss:0.59552
# [10]	validation_0-logloss:0.59016
# [11]	validation_0-logloss:0.58567
# [12]	validation_0-logloss:0.58051
# [13]	validation_0-logloss:0.57602
# [14]	validation_0-logloss:0.57231
# [15]	validation_0-logloss:0.56874
# [16]	validation_0-logloss:0.56571
# [17]	validation_0-logloss:0.56310
# [18]	validation_0-logloss:0.56012
# [19]	validation_0-logloss:0.55661
# [20]	validation_0-logloss:0.55426
# [21]	validation_0-logloss:0.55230
# [22]	validation_0-logloss:0.55092
# [23]	validation_0-logloss:0.54854
# [24]	validation_0-logloss:0.54636
# [25]	validation_0-logloss:0.54495
# [26]	validation_0-logloss:0.54303
# [27]	validation_0-logloss:0.54209
# [28]	validation_0-logloss:0.54017
# [29]	validation_0-logloss:0.53883
# [30]	validation_0-logloss:0.53747
# [31]	validation_0-logloss:0.53648
# [32]	validation_0-logloss:0.53548
# [33]	validation_0-logloss:0.53446
# [34]	validation_0-logloss:0.53292
# [35]	validation_0-logloss:0.53172
# [36]	validation_0-logloss:0.53087
# [37]	validation_0-logloss:0.52972
# [38]	validation_0-logloss:0.52924
# [39]	validation_0-logloss:0.52863
# [40]	validation_0-logloss:0.52749
# [41]	validation_0-logloss:0.52633
# [42]	validation_0-logloss:0.52584
# [43]	validation_0-logloss:0.52520
# [44]	validation_0-logloss:0.52378
# [45]	validation_0-logloss:0.52326
# [46]	validation_0-logloss:0.52227
# [47]	validation_0-logloss:0.52158
# [48]	validation_0-logloss:0.52039
# [49]	validation_0-logloss:0.51870
# [0]	validation_0-logloss:0.67413
# [1]	validation_0-logloss:0.65859
# [2]	validation_0-logloss:0.64677
# [3]	validation_0-logloss:0.63509
# [4]	validation_0-logloss:0.62553
# [5]	validation_0-logloss:0.61600
# [6]	validation_0-logloss:0.60772
# [7]	validation_0-logloss:0.59904
# [8]	validation_0-logloss:0.59143
# [9]	validation_0-logloss:0.58396
# [10]	validation_0-logloss:0.57821
# [11]	validation_0-logloss:0.57237
# [12]	validation_0-logloss:0.56675
# [13]	validation_0-logloss:0.56182
# [14]	validation_0-logloss:0.55664
# [15]	validation_0-logloss:0.55288
# [16]	validation_0-logloss:0.54955
# [17]	validation_0-logloss:0.54623
# [18]	validation_0-logloss:0.54189
# [19]	validation_0-logloss:0.53782
# [20]	validation_0-logloss:0.53472
# [21]	validation_0-logloss:0.53225
# [22]	validation_0-logloss:0.53002
# [23]	validation_0-logloss:0.52797
# [24]	validation_0-logloss:0.52558
# [25]	validation_0-logloss:0.52298
# [26]	validation_0-logloss:0.52115
# [27]	validation_0-logloss:0.51916
# [28]	validation_0-logloss:0.51735
# [29]	validation_0-logloss:0.51514
# [30]	validation_0-logloss:0.51374
# [31]	validation_0-logloss:0.51193
# [32]	validation_0-logloss:0.51080
# [33]	validation_0-logloss:0.50931
# [34]	validation_0-logloss:0.50747
# [35]	validation_0-logloss:0.50568
# [36]	validation_0-logloss:0.50396
# [37]	validation_0-logloss:0.50300
# [38]	validation_0-logloss:0.50175
# [39]	validation_0-logloss:0.49978
# [40]	validation_0-logloss:0.49863
# [41]	validation_0-logloss:0.49745
# [42]	validation_0-logloss:0.49665
# [43]	validation_0-logloss:0.49506
# [44]	validation_0-logloss:0.49384
# [45]	validation_0-logloss:0.49288
# [46]	validation_0-logloss:0.49132
# [47]	validation_0-logloss:0.48986
# [48]	validation_0-logloss:0.48871
# [49]	validation_0-logloss:0.48877
# [0]	validation_0-logloss:0.67408
# [1]	validation_0-logloss:0.66182
# [2]	validation_0-logloss:0.65229
# [3]	validation_0-logloss:0.64233
# [4]	validation_0-logloss:0.63425
# [5]	validation_0-logloss:0.62599
# [6]	validation_0-logloss:0.61978
# [7]	validation_0-logloss:0.61335
# [8]	validation_0-logloss:0.60735
# [9]	validation_0-logloss:0.60189
# [10]	validation_0-logloss:0.59656
# [11]	validation_0-logloss:0.59239
# [12]	validation_0-logloss:0.58797
# [13]	validation_0-logloss:0.58435
# [14]	validation_0-logloss:0.58150
# [15]	validation_0-logloss:0.57847
# [16]	validation_0-logloss:0.57535
# [17]	validation_0-logloss:0.57228
# [18]	validation_0-logloss:0.56893
# [19]	validation_0-logloss:0.56637
# [20]	validation_0-logloss:0.56338
# [21]	validation_0-logloss:0.56096
# [22]	validation_0-logloss:0.55882
# [23]	validation_0-logloss:0.55682
# [24]	validation_0-logloss:0.55488
# [25]	validation_0-logloss:0.55382
# [26]	validation_0-logloss:0.55243
# [27]	validation_0-logloss:0.55148
# [28]	validation_0-logloss:0.55051
# [29]	validation_0-logloss:0.54915
# [30]	validation_0-logloss:0.54755
# [31]	validation_0-logloss:0.54659
# [32]	validation_0-logloss:0.54518
# [33]	validation_0-logloss:0.54483
# [34]	validation_0-logloss:0.54391
# [35]	validation_0-logloss:0.54294
# [36]	validation_0-logloss:0.54227
# [37]	validation_0-logloss:0.54173
# [38]	validation_0-logloss:0.54105
# [39]	validation_0-logloss:0.54021
# [40]	validation_0-logloss:0.53972
# [41]	validation_0-logloss:0.53865
# [42]	validation_0-logloss:0.53744
# [43]	validation_0-logloss:0.53656
# [44]	validation_0-logloss:0.53587
# [45]	validation_0-logloss:0.53553
# [46]	validation_0-logloss:0.53484
# [47]	validation_0-logloss:0.53420
# [48]	validation_0-logloss:0.53376
# [49]	validation_0-logloss:0.53396
# [0]	validation_0-logloss:0.67545
# [1]	validation_0-logloss:0.66388
# [2]	validation_0-logloss:0.65399
# [3]	validation_0-logloss:0.64488
# [4]	validation_0-logloss:0.63696
# [5]	validation_0-logloss:0.62935
# [6]	validation_0-logloss:0.62182
# [7]	validation_0-logloss:0.61615
# [8]	validation_0-logloss:0.61088
# [9]	validation_0-logloss:0.60549
# [10]	validation_0-logloss:0.60115
# [11]	validation_0-logloss:0.59586
# [12]	validation_0-logloss:0.59278
# [13]	validation_0-logloss:0.59065
# [14]	validation_0-logloss:0.58786
# [15]	validation_0-logloss:0.58344
# [16]	validation_0-logloss:0.58035
# [17]	validation_0-logloss:0.57785
# [18]	validation_0-logloss:0.57456
# [19]	validation_0-logloss:0.57246
# [20]	validation_0-logloss:0.57098
# [21]	validation_0-logloss:0.56935
# [22]	validation_0-logloss:0.56843
# [23]	validation_0-logloss:0.56778
# [24]	validation_0-logloss:0.56514
# [25]	validation_0-logloss:0.56279
# [26]	validation_0-logloss:0.56229
# [27]	validation_0-logloss:0.56211
# [28]	validation_0-logloss:0.56045
# [29]	validation_0-logloss:0.56007
# [30]	validation_0-logloss:0.55889
# [31]	validation_0-logloss:0.55849
# [32]	validation_0-logloss:0.55836
# [33]	validation_0-logloss:0.55773
# [34]	validation_0-logloss:0.55709
# [35]	validation_0-logloss:0.55600
# [36]	validation_0-logloss:0.55602
# [37]	validation_0-logloss:0.55541
# [38]	validation_0-logloss:0.55468
# [39]	validation_0-logloss:0.55432
# [40]	validation_0-logloss:0.55359
# [41]	validation_0-logloss:0.55299
# [42]	validation_0-logloss:0.55260
# [43]	validation_0-logloss:0.55298
# [44]	validation_0-logloss:0.55244
# [45]	validation_0-logloss:0.55278
# [46]	validation_0-logloss:0.55229
# [47]	validation_0-logloss:0.55243
# [48]	validation_0-logloss:0.55307
# [49]	validation_0-logloss:0.55254
# [0]	validation_0-logloss:0.66582
# [1]	validation_0-logloss:0.65332
# [2]	validation_0-logloss:0.64270
# [3]	validation_0-logloss:0.63340
# [4]	validation_0-logloss:0.62462
# [5]	validation_0-logloss:0.61690
# [6]	validation_0-logloss:0.60915
# [7]	validation_0-logloss:0.60267
# [8]	validation_0-logloss:0.59718
# [9]	validation_0-logloss:0.59165
# [10]	validation_0-logloss:0.58579
# [11]	validation_0-logloss:0.58109
# [12]	validation_0-logloss:0.57809
# [13]	validation_0-logloss:0.57441
# [14]	validation_0-logloss:0.57042
# [15]	validation_0-logloss:0.56745
# [16]	validation_0-logloss:0.56454
# [17]	validation_0-logloss:0.56224
# [18]	validation_0-logloss:0.55928
# [19]	validation_0-logloss:0.55668
# [20]	validation_0-logloss:0.55547
# [21]	validation_0-logloss:0.55463
# [22]	validation_0-logloss:0.55160
# [23]	validation_0-logloss:0.54882
# [24]	validation_0-logloss:0.54704
# [25]	validation_0-logloss:0.54440
# [26]	validation_0-logloss:0.54189
# [27]	validation_0-logloss:0.54000
# [28]	validation_0-logloss:0.53842
# [29]	validation_0-logloss:0.53702
# [30]	validation_0-logloss:0.53445
# [31]	validation_0-logloss:0.53319
# [32]	validation_0-logloss:0.53218
# [33]	validation_0-logloss:0.53086
# [34]	validation_0-logloss:0.52942
# [35]	validation_0-logloss:0.52803
# [36]	validation_0-logloss:0.52696
# [37]	validation_0-logloss:0.52510
# [38]	validation_0-logloss:0.52504
# [39]	validation_0-logloss:0.52453
# [40]	validation_0-logloss:0.52312
# [41]	validation_0-logloss:0.52263
# [42]	validation_0-logloss:0.52179
# [43]	validation_0-logloss:0.52157
# [44]	validation_0-logloss:0.52106
# [45]	validation_0-logloss:0.52011
# [46]	validation_0-logloss:0.51956
# [47]	validation_0-logloss:0.51852
# [48]	validation_0-logloss:0.51780
# [49]	validation_0-logloss:0.51689
# [0]	validation_0-logloss:0.66563
# [1]	validation_0-logloss:0.65338
# [2]	validation_0-logloss:0.64222
# [3]	validation_0-logloss:0.63147
# [4]	validation_0-logloss:0.62269
# [5]	validation_0-logloss:0.61477
# [6]	validation_0-logloss:0.60758
# [7]	validation_0-logloss:0.59977
# [8]	validation_0-logloss:0.59315
# [9]	validation_0-logloss:0.58783
# [10]	validation_0-logloss:0.58216
# [11]	validation_0-logloss:0.57693
# [12]	validation_0-logloss:0.57167
# [13]	validation_0-logloss:0.56801
# [14]	validation_0-logloss:0.56333
# [15]	validation_0-logloss:0.55898
# [16]	validation_0-logloss:0.55529
# [17]	validation_0-logloss:0.55163
# [18]	validation_0-logloss:0.54787
# [19]	validation_0-logloss:0.54452
# [20]	validation_0-logloss:0.54171
# [21]	validation_0-logloss:0.53971
# [22]	validation_0-logloss:0.53817
# [23]	validation_0-logloss:0.53573
# [24]	validation_0-logloss:0.53354
# [25]	validation_0-logloss:0.53197
# [26]	validation_0-logloss:0.53029
# [27]	validation_0-logloss:0.52893
# [28]	validation_0-logloss:0.52760
# [29]	validation_0-logloss:0.52632
# [30]	validation_0-logloss:0.52542
# [31]	validation_0-logloss:0.52447
# [32]	validation_0-logloss:0.52416
# [33]	validation_0-logloss:0.52333
# [34]	validation_0-logloss:0.52186
# [35]	validation_0-logloss:0.52112
# [36]	validation_0-logloss:0.51970
# [37]	validation_0-logloss:0.51890
# [38]	validation_0-logloss:0.51722
# [39]	validation_0-logloss:0.51691
# [40]	validation_0-logloss:0.51715
# [41]	validation_0-logloss:0.51514
# [42]	validation_0-logloss:0.51394
# [43]	validation_0-logloss:0.51250
# [44]	validation_0-logloss:0.51169
# [45]	validation_0-logloss:0.51103
# [46]	validation_0-logloss:0.51008
# [47]	validation_0-logloss:0.51026
# [48]	validation_0-logloss:0.50903
# [49]	validation_0-logloss:0.50906
# [0]	validation_0-logloss:0.66139
# [1]	validation_0-logloss:0.64736
# [2]	validation_0-logloss:0.63558
# [3]	validation_0-logloss:0.62430
# [4]	validation_0-logloss:0.61479
# [5]	validation_0-logloss:0.60585
# [6]	validation_0-logloss:0.59789
# [7]	validation_0-logloss:0.59062
# [8]	validation_0-logloss:0.58268
# [9]	validation_0-logloss:0.57618
# [10]	validation_0-logloss:0.57159
# [11]	validation_0-logloss:0.56628
# [12]	validation_0-logloss:0.56178
# [13]	validation_0-logloss:0.55741
# [14]	validation_0-logloss:0.55318
# [15]	validation_0-logloss:0.54897
# [16]	validation_0-logloss:0.54506
# [17]	validation_0-logloss:0.54087
# [18]	validation_0-logloss:0.53689
# [19]	validation_0-logloss:0.53434
# [20]	validation_0-logloss:0.53042
# [21]	validation_0-logloss:0.52705
# [22]	validation_0-logloss:0.52399
# [23]	validation_0-logloss:0.52159
# [24]	validation_0-logloss:0.51898
# [25]	validation_0-logloss:0.51607
# [26]	validation_0-logloss:0.51435
# [27]	validation_0-logloss:0.51349
# [28]	validation_0-logloss:0.51188
# [29]	validation_0-logloss:0.50980
# [30]	validation_0-logloss:0.50770
# [31]	validation_0-logloss:0.50621
# [32]	validation_0-logloss:0.50397
# [33]	validation_0-logloss:0.50146
# [34]	validation_0-logloss:0.49963
# [35]	validation_0-logloss:0.49835
# [36]	validation_0-logloss:0.49668
# [37]	validation_0-logloss:0.49507
# [38]	validation_0-logloss:0.49396
# [39]	validation_0-logloss:0.49399
# [40]	validation_0-logloss:0.49289
# [41]	validation_0-logloss:0.49144
# [42]	validation_0-logloss:0.49044
# [43]	validation_0-logloss:0.49018
# [44]	validation_0-logloss:0.48935
# [45]	validation_0-logloss:0.48808
# [46]	validation_0-logloss:0.48797
# [47]	validation_0-logloss:0.48783
# [48]	validation_0-logloss:0.48667
# [49]	validation_0-logloss:0.48662
# [0]	validation_0-logloss:0.66373
# [1]	validation_0-logloss:0.65179
# [2]	validation_0-logloss:0.64220
# [3]	validation_0-logloss:0.63322
# [4]	validation_0-logloss:0.62524
# [5]	validation_0-logloss:0.61777
# [6]	validation_0-logloss:0.61182
# [7]	validation_0-logloss:0.60599
# [8]	validation_0-logloss:0.60048
# [9]	validation_0-logloss:0.59570
# [10]	validation_0-logloss:0.59103
# [11]	validation_0-logloss:0.58598
# [12]	validation_0-logloss:0.58162
# [13]	validation_0-logloss:0.57785
# [14]	validation_0-logloss:0.57465
# [15]	validation_0-logloss:0.57112
# [16]	validation_0-logloss:0.56791
# [17]	validation_0-logloss:0.56482
# [18]	validation_0-logloss:0.56142
# [19]	validation_0-logloss:0.55868
# [20]	validation_0-logloss:0.55647
# [21]	validation_0-logloss:0.55380
# [22]	validation_0-logloss:0.55213
# [23]	validation_0-logloss:0.54964
# [24]	validation_0-logloss:0.54875
# [25]	validation_0-logloss:0.54719
# [26]	validation_0-logloss:0.54520
# [27]	validation_0-logloss:0.54406
# [28]	validation_0-logloss:0.54321
# [29]	validation_0-logloss:0.54263
# [30]	validation_0-logloss:0.54105
# [31]	validation_0-logloss:0.53972
# [32]	validation_0-logloss:0.53791
# [33]	validation_0-logloss:0.53785
# [34]	validation_0-logloss:0.53661
# [35]	validation_0-logloss:0.53537
# [36]	validation_0-logloss:0.53476
# [37]	validation_0-logloss:0.53377
# [38]	validation_0-logloss:0.53343
# [39]	validation_0-logloss:0.53261
# [40]	validation_0-logloss:0.53205
# [41]	validation_0-logloss:0.53092
# [42]	validation_0-logloss:0.53013
# [43]	validation_0-logloss:0.53025
# [44]	validation_0-logloss:0.53023
# [45]	validation_0-logloss:0.52916
# [46]	validation_0-logloss:0.52897
# [47]	validation_0-logloss:0.52792
# [48]	validation_0-logloss:0.52752
# [49]	validation_0-logloss:0.52699
# [0]	validation_0-logloss:0.66340
# [1]	validation_0-logloss:0.65171
# [2]	validation_0-logloss:0.64177
# [3]	validation_0-logloss:0.63233
# [4]	validation_0-logloss:0.62399
# [5]	validation_0-logloss:0.61628
# [6]	validation_0-logloss:0.60881
# [7]	validation_0-logloss:0.60335
# [8]	validation_0-logloss:0.59788
# [9]	validation_0-logloss:0.59295
# [10]	validation_0-logloss:0.58898
# [11]	validation_0-logloss:0.58467
# [12]	validation_0-logloss:0.58075
# [13]	validation_0-logloss:0.57816
# [14]	validation_0-logloss:0.57451
# [15]	validation_0-logloss:0.56963
# [16]	validation_0-logloss:0.56650
# [17]	validation_0-logloss:0.56395
# [18]	validation_0-logloss:0.56115
# [19]	validation_0-logloss:0.55813
# [20]	validation_0-logloss:0.55600
# [21]	validation_0-logloss:0.55454
# [22]	validation_0-logloss:0.55380
# [23]	validation_0-logloss:0.55356
# [24]	validation_0-logloss:0.55071
# [25]	validation_0-logloss:0.54838
# [26]	validation_0-logloss:0.54751
# [27]	validation_0-logloss:0.54666
# [28]	validation_0-logloss:0.54582
# [29]	validation_0-logloss:0.54455
# [30]	validation_0-logloss:0.54441
# [31]	validation_0-logloss:0.54332
# [32]	validation_0-logloss:0.54165
# [33]	validation_0-logloss:0.54136
# [34]	validation_0-logloss:0.54079
# [35]	validation_0-logloss:0.54110
# [36]	validation_0-logloss:0.54011
# [37]	validation_0-logloss:0.53963
# [38]	validation_0-logloss:0.53894
# [39]	validation_0-logloss:0.53857
# [40]	validation_0-logloss:0.53791
# [41]	validation_0-logloss:0.53760
# [42]	validation_0-logloss:0.53755
# [43]	validation_0-logloss:0.53801
# [44]	validation_0-logloss:0.53784
# [45]	validation_0-logloss:0.53760
# 100%|██████████| 25/25 [16:01<00:00, 38.45s/trial, best loss: -0.8099723041274594]
# Processing key: alpha, val: 3.9228071431934324
# Processing key: colsample_bytree, val: 0.4082346357207089
# Processing key: gamma, val: 0.2048441004277867
# Processing key: lambda, val: 0.14443735949503822
# Processing key: learning_rate, val: 0.051761596984344835
# Processing key: max_depth, val: 3
# Processing key: min_child_weight, val: 15.0
# Processing key: n_estimators, val: 3
# Processing key: scale_pos_weight, val: 1.6324973019822813
# {'alpha': 3.9228071431934324, 'colsample_bytree': 0.4082346357207089, 'gamma': 0.2048441004277867, 'lambda': 0.14443735949503822, 'learning_rate': 0.051761596984344835, 'max_depth': 4, 'min_child_weight': 15.0, 'n_estimators': 50, 'scale_pos_weight': 1.6324973019822813}

# %%
# Merge default and best params
xgb_optimized_params = {**xgb_default_params, **xgb_best_params}
print(xgb_optimized_params)

# Train the model using the optimized parameters
xgb = XGBClassifier(**xgb_optimized_params)
xgb.fit(X_train, y_train)

# Evaluate on the training data
train_results = evaluate(xgb, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(xgb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(xgb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'n_jobs': -1, 'alpha': 3.9228071431934324, 'colsample_bytree': 0.4082346357207089, 'gamma': 0.2048441004277867, 'lambda': 0.14443735949503822, 'learning_rate': 0.051761596984344835, 'max_depth': 4, 'min_child_weight': 15.0, 'n_estimators': 50, 'scale_pos_weight': 1.6324973019822813}
# Training Data Evaluation:
# {'Accuracy': 0.77, 'Precision': 0.73, 'Recall': 0.98, 'F1': 0.84}
#
# Validation Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.72, 'Recall': 0.95, 'F1': 0.82}
#
# Test Data Evaluation:
# {'Accuracy': 0.64, 'Precision': 0.59, 'Recall': 0.97, 'F1': 0.73}

# %%
# Import necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.metrics import Metric, Precision, Recall

class F1Score(Metric):
    def __init__(self, name="f1_score", **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
        p = self.precision.result()
        r = self.recall.result()
        # Compute F1 Score
        self.f1.assign(2 * ((p * r) / (p + r + K.epsilon())))

    def result(self):
        return self.f1

    def reset_state(self):
        self.f1.assign(0.)
        self.precision.reset_state()
        self.recall.reset_state()


def optimize_hyperparams_mlp(space, X_train, y_train, X_val, y_val, enable_early_stopping=True, max_evals=25, random_state=72):

    def objective(params):
        try:
            # Build the model
            model = Sequential()
            model.add(Dense(params['hidden_layers'][0],
                            activation='relu',
                            input_dim=X_train.shape[1]))

            model.add(Dropout(params['dropout']))
            for units in params['hidden_layers'][1:]:
                model.add(Dense(units, activation='relu'))
                model.add(Dropout(params['dropout']))
            model.add(Dense(1, activation='sigmoid'))  # for binary classification

            if params['optimizer'] == 'adam':
                opt = Adam(learning_rate=params['learning_rate'])
            else:
                opt = SGD(learning_rate=params['learning_rate'])

            model.compile(optimizer=opt, loss='binary_crossentropy',
                          metrics=['accuracy', Precision(), Recall(), F1Score()])

            # Set early stopping
            if enable_early_stopping:
                callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
            else:
                callbacks = None

            # Train the model
            model.fit(X_train, y_train, epochs=35,
                      batch_size=int(params['batch_size']),
                      verbose=0, validation_data=(X_val, y_val),
                      callbacks=callbacks)

            # Evaluate the model
            _, accuracy, precision, recall, f1_val = model.evaluate(X_val, y_val, verbose=0)

            return -f1_val  # we want to maximize accuracy, hence the negative sign

        except Exception as e:
            print(f"Exception encountered: {e}")
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest,
                max_evals=max_evals, trials=trials)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
from hyperopt import hp
from hyperopt import Trials, fmin, tpe

# Define the space
mlp_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2),
    'batch_size': hp.choice('batch_size', [32, 64, 128, 256]),
    'hidden_layers': hp.choice('hidden_layers', [
        [16],
        [32],
        [64],
        [128],
        [16, 16],
        [32, 32],
        [64, 64],
        [128, 128],
        [128, 64],
        [64, 32],
        [32, 16],
        [128, 64, 32, 16],
        [128, 64, 32]
    ]),
    'optimizer': hp.choice('optimizer', ['adam', 'sgd']),
    'dropout': hp.uniform('dropout', 0, 0.5)
}

# Use the function
mlp_best_params = optimize_hyperparams_mlp(space=mlp_hyperparam_space,
                                           X_train=X_train,
                                           y_train=y_train,
                                           X_val=X_val, y_val=y_val,
                                           enable_early_stopping=True,
                                           max_evals=35)
print(mlp_best_params)
# Out:
# 100%|██████████| 35/35 [04:25<00:00,  7.58s/trial, best loss: -0.8038942217826843]
# Processing key: batch_size, val: 1
# Processing key: dropout, val: 0.04168423066802934
# Processing key: hidden_layers, val: 9
# Processing key: learning_rate, val: 0.016545615668333468
# Processing key: optimizer, val: 0
# {'batch_size': 64, 'dropout': 0.04168423066802934, 'hidden_layers': [64, 32], 'learning_rate': 0.016545615668333468, 'optimizer': 'adam'}

# %%
# Evaluate the fitted pipeline
def evaluate_mlp(model, X, y):
    # Evaluate on given X
    _, accuracy, precision, recall, f1 = model.evaluate(X, y)

    # Return the values in a dictionary
    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD

model = Sequential()

hidden_layers = mlp_best_params['hidden_layers']

print(hidden_layers)
for units in hidden_layers:
    model.add(Dense(units, activation='relu'))
    model.add(Dropout(mlp_best_params['dropout']))


# Output layer
model.add(Dense(1, activation='sigmoid'))

# Determine optimizer based on the optimized parameters
if mlp_best_params['optimizer'] == 'adam':
    optimizer = Adam(learning_rate=mlp_best_params['learning_rate'])
elif mlp_best_params['optimizer'] == 'sgd':
    optimizer = SGD(learning_rate=mlp_best_params['learning_rate'])

callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall(), F1Score()])
model.fit(X_train, y_train,
          validation_data=(X_val, y_val),
          epochs=mlp_best_params.get('epochs', 35),
          batch_size=mlp_best_params['batch_size'],
          callbacks=callbacks, verbose=0)


# 5. Evaluate the trained model
train_results = {}
train_results = evaluate_mlp(model, X_train, y_train)
print("Training Data Evaluation:")
print(train_results)

validation_results = evaluate_mlp(model, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

test_results = evaluate_mlp(model, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# [64, 32]
# 49/49 [==============================] - 0s 3ms/step - loss: 0.5297 - accuracy: 0.7205 - precision_473: 0.7498 - recall_473: 0.8143 - f1_score: 0.7807
# Training Data Evaluation:
# {'Accuracy': 0.7205128073692322, 'Precision': 0.7497584819793701, 'Recall': 0.8142707347869873, 'F1': 0.7806841135025024}
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.7385 - precision_473: 0.7718 - recall_473: 0.8107 - f1_score: 0.7908
#
# Validation Data Evaluation:
# {'Accuracy': 0.7384615540504456, 'Precision': 0.7717717885971069, 'Recall': 0.8107255697250366, 'F1': 0.7907691597938538}
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.7033 - precision_473: 0.6564 - recall_473: 0.8533 - f1_score: 0.7420
#
# Test Data Evaluation:
# {'Accuracy': 0.70333331823349, 'Precision': 0.656410276889801, 'Recall': 0.8533333539962769, 'F1': 0.7420290112495422}
