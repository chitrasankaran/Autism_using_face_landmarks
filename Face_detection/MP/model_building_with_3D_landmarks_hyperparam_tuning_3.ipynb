# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ## Configure Project Path and other paths

# %%
import numpy as np
rstate = np.random.default_rng(seed=72)

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
proj_path = '/content/drive/MyDrive/Magnimind/Face_detection/MP'
os.chdir(proj_path)

# %%
train_csv_path = os.path.join(proj_path, 'train_3D.csv')
test_csv_path = os.path.join(proj_path, 'test_3D.csv')

# %% [markdown]
# ## Read data from csv to pandas dataframe

# %%
train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        839  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        825  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        817  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...        845  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        844  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.511593      0.709910     -0.040127      0.517181      0.670308
# 1      0.566339      0.733220     -0.065258      0.575596      0.677747
# 2      0.437217      0.744490     -0.077209      0.426740      0.685478
# 3      0.533727      0.797597     -0.053682      0.549781      0.762331
# 4      0.524054      0.774706     -0.052582      0.505436      0.710976
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.168715      0.515403  ...       -0.057532        0.587559
# 1     -0.127426      0.568713  ...        0.001300        0.609449
# 2     -0.165941      0.433244  ...       -0.018598        0.488665
# 3     -0.169223      0.540980  ...       -0.035548        0.601406
# 4     -0.152662      0.512779  ...       -0.039194        0.528307
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.500262       -0.077599        0.768636        0.474503
# 1        0.556148       -0.015839        0.738344        0.541875
# 2        0.551752       -0.038808        0.656447        0.535078
# 3        0.623819       -0.057016        0.766676        0.603243
# 4        0.568924       -0.058087        0.683886        0.525732
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0       -0.021161        0.784336        0.468965       -0.021392
# 1        0.039996        0.751471        0.531839        0.042270
# 2        0.003090        0.674554        0.525373        0.003349
# 3        0.013871        0.782729        0.596054        0.015662
# 4       -0.016595        0.697740        0.517121       -0.017281
#
# [5 rows x 1407 columns]

# %%
test_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        100  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        108  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        106  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...          1  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        103  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.727391      0.710138     -0.117875      0.753489      0.581854
# 1      0.457443      0.710929     -0.091133      0.437796      0.633989
# 2      0.452099      0.779923     -0.042830      0.453784      0.726497
# 3      0.457504      0.754957     -0.085740      0.470419      0.687706
# 4      0.362426      0.740446     -0.046425      0.366750      0.668341
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.193980      0.723864  ...        0.048919        0.737665
# 1     -0.193647      0.445459  ...       -0.020685        0.482040
# 2     -0.181251      0.455887  ...       -0.063696        0.546055
# 3     -0.211908      0.467041  ...       -0.034361        0.565713
# 4     -0.156865      0.372543  ...       -0.048113        0.491366
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.421433        0.016144        0.890724        0.401811
# 1        0.471925       -0.044690        0.660659        0.437236
# 2        0.521134       -0.084867        0.749610        0.499630
# 3        0.535771       -0.059295        0.783299        0.529403
# 4        0.545638       -0.066218        0.686309        0.559731
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0        0.169311        0.903891        0.394724        0.177334
# 1        0.013672        0.679693        0.424461        0.015152
# 2       -0.035831        0.771000        0.490222       -0.036383
# 3        0.008190        0.804902        0.522787        0.009052
# 4       -0.032427        0.705237        0.556214       -0.034047
#
# [5 rows x 1407 columns]

# %%
train_df['label'].value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %%
test_df['label'].value_counts()
# Out:
# Autistic        150
# Non_Autistic    150
# Name: label, dtype: int64

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %% [markdown]
# ## Setting input features and output features

# %%
X = train_df.drop(columns=['img_path', 'image_num', 'label'])
y = train_df['label']

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
y = y.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
y.value_counts()
# Out:
# 1    1270
# 0     810
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, shuffle=True, random_state=72)

# %%
X_test = test_df.drop(columns=['img_path', 'image_num', 'label'])
y_test = test_df['label']
y_test = y_test.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
X_train.shape
# Out:
# (1560, 1404)

# %%
X_val.shape
# Out:
# (520, 1404)

# %%
X_test.shape
# Out:
# (300, 1404)

# %% [markdown]
# ## SMOTE

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=72)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# 0    953
# 1    953
# Name: label, dtype: int64

# %%
y_val.value_counts()
# Out:
# 1    317
# 0    203
# Name: label, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    150
# 0    150
# Name: label, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import precision_recall_curve
import numpy as np
from sklearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import hyperopt

# %%
# Initializing random_state
random_state = 72

# %%
from hyperopt.pyll.base import Apply

def hyperopt_indices_to_values(space, best):
    best_params = {}

    for key, val in best.items():
        print(f"Processing key: {key}, val: {val}")  # Debugging line
        #print(f"Type of space[key]: {type(space[key])}")  # Additional Debugging line
        #print(f"Name attribute of space[key] (if exists): {getattr(space[key], 'name', 'No name attribute')}")  # Additional Debugging line

        if key == 'penalty_solver':
            # Extract penalty and solver values directly from the tuple
            penalty, solver = space[key].pos_args[int(val) + 1].pos_args
            best_params['penalty'] = penalty.obj
            best_params['solver'] = solver.obj

        elif isinstance(space[key], Apply) and space[key].name == 'switch':
            # This means the parameter is defined using hp.choice
            selected_item = space[key].pos_args[val + 1]
            if key == 'hidden_layers':
                try:
                    # Attempt to unpack it as if it was a list
                    best_params[key] = [item.obj for item in selected_item.pos_args]
                except AttributeError:
                    # If there's an error, revert back to previous handling
                    best_params[key] = getattr(selected_item, 'obj', selected_item)

            else:
                # Handle the scenario where 'selected_item' might not have 'obj'
                best_params[key] = getattr(selected_item, 'obj', selected_item)

        else:
            # Otherwise, directly assign the value
            best_params[key] = val

    return best_params

# %%
def optimize_hyperparams(model_class, default_params, space,
                         X_train, y_train, enable_early_stopping=False,
                         max_evals=20, random_state=72):

        # Convert numpy arrays to pandas DataFrame or Series
    if isinstance(X_train, np.ndarray):
        X_train = pd.DataFrame(X_train)
    if isinstance(y_train, np.ndarray):
        y_train = pd.Series(y_train)

    def objective(params):
        try:
            # If 'penalty_solver' is in params, get mapped 'penalty' and 'solver' params
            if 'penalty_solver' in params:
                params['penalty'], params['solver'] = params.pop('penalty_solver')

            # If the penalty is not 'elasticnet', remove the l1_ratio parameter
            if params.get('penalty') != 'elasticnet':
                params.pop('l1_ratio', None)


            all_params = {**default_params, **params}
            m = model_class(**all_params)

            cv_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

            if enable_early_stopping:
                # Set early_stopping_rounds
                m.set_params(early_stopping_rounds=3, eval_metric="logloss")
                scores = []

                for train_index, test_index in cv_folds.split(X_train, y_train):
                    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[test_index]

                    eval_set = [(X_val_fold, y_val_fold)]
                    m.fit(X_train_fold, y_train_fold,
                          eval_set=eval_set, verbose=True)

                    predictions = m.predict(X_val_fold)
                    score = f1_score(y_val_fold, predictions)
                    scores.append(score)

                return -np.mean(scores) # since we want to maximize F1 score

            else:
                loss = -cross_val_score(m, X_train, y_train, cv=cv_folds, scoring='f1').mean()
                return loss

        except Exception as e:
            print(f"Exception encountered: {e}")
            # Handle any other exception that arises during model training or evaluation
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=max_evals,
                trials=trials, rstate=rstate)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
# Evaluate the fitted pipeline
def evaluate(model, X, y):
    # Predict on given X
    y_pred = model.predict(X)

    # Calculate below evaluation metrics
    accuracy = round(accuracy_score(y, y_pred), 2)
    precision = round(precision_score(y, y_pred), 2)
    recall = round(recall_score(y, y_pred), 2)
    f1 = round(f1_score(y, y_pred), 2)

    # Return the values in a dictionary

    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
default_params = {
    'random_state': random_state,
    'max_iter': 3000,
}

lr_hyperparam_space = {
    # Combine penalty and solver
    'penalty_solver': hp.choice('penalty_solver', [
        ('l1', 'liblinear'),
        ('l2', 'liblinear'),
    ]),

    # Regularization strength
    'C': hp.loguniform('C', np.log(0.0001), np.log(10)),
}

# Using the function
best_params = optimize_hyperparams(LogisticRegression,
                                   default_params,
                                   lr_hyperparam_space,
                                   X_train_smote, y_train_smote,
                                   max_evals=25)
print(best_params)
# Out:
# 100%|██████████| 25/25 [02:44<00:00,  6.56s/trial, best loss: -0.7604815966799269]
# Processing key: C, val: 7.865059935022496
# Processing key: penalty_solver, val: 1
# {'C': 7.865059935022496, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
optimized_params = {**default_params, **best_params}
print(optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
lr = LogisticRegression(**optimized_params)
lr.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(lr, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(lr, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(lr, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'max_iter': 3000, 'C': 7.865059935022496, 'penalty': 'l2', 'solver': 'liblinear'}
# Training Data Evaluation:
# {'Accuracy': 0.77, 'Precision': 0.77, 'Recall': 0.77, 'F1': 0.77}
#
# Validation Data Evaluation:
# {'Accuracy': 0.78, 'Precision': 0.86, 'Recall': 0.77, 'F1': 0.81}
#
# Test Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.73, 'Recall': 0.79, 'F1': 0.76}

# %%
rf_default_params = {
    'random_state': random_state,
    'class_weight': 'balanced',
    'n_jobs': -1,
}

rf_hyperparam_space = {
    'n_estimators': hp.choice('n_estimators', list(range(30, 70, 10))),
    'max_depth': hp.choice('max_depth', list(range(2, 4))),  # Excluding None to prevent unlimited depth
    'min_samples_split': hp.uniform('min_samples_split', 0.05, 0.2),  # Increasing the lower bound to avoid tiny splits
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.01, 0.1),  # Increasing the lower bound to ensure larger leaves
    'max_features': hp.choice('max_features', [0.4, 0.5, 0.6, 'sqrt', 'log2']),  # Focusing on fewer feature options
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'bootstrap': hp.choice('bootstrap', [True]),
    'oob_score': hp.choice('oob_score', [True, False])
}

# Using the function
rf_best_params = optimize_hyperparams(RandomForestClassifier,
                                      rf_default_params,
                                      rf_hyperparam_space,
                                      X_train_smote, y_train_smote,
                                      max_evals=35)
print(rf_best_params)
# Out:
# 100%|██████████| 35/35 [12:22<00:00, 21.22s/trial, best loss: -0.7364566642017619]
# Processing key: bootstrap, val: 0
# Processing key: criterion, val: 1
# Processing key: max_depth, val: 1
# Processing key: max_features, val: 4
# Processing key: min_samples_leaf, val: 0.08074060392066772
# Processing key: min_samples_split, val: 0.10346109107325333
# Processing key: n_estimators, val: 3
# Processing key: oob_score, val: 1
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 0.08074060392066772, 'min_samples_split': 0.10346109107325333, 'n_estimators': 60, 'oob_score': False}

# %%
rf_optimized_params = {**rf_default_params, **rf_best_params}
print(rf_optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
rf = RandomForestClassifier(**rf_optimized_params)
rf.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(rf, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(rf, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(rf, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'class_weight': 'balanced', 'n_jobs': -1, 'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 0.08074060392066772, 'min_samples_split': 0.10346109107325333, 'n_estimators': 60, 'oob_score': False}
# Training Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.74, 'Recall': 0.78, 'F1': 0.76}
#
# Validation Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.81, 'Recall': 0.75, 'F1': 0.78}
#
# Test Data Evaluation:
# {'Accuracy': 0.71, 'Precision': 0.68, 'Recall': 0.79, 'F1': 0.73}

# %%
adb_default_params = {
    'random_state': random_state,
}

adb_hyperparam_space = {
    # AdaBoost hyperparameters
    # Number of weak learners to train
    'n_estimators': hp.choice('n_estimators', list(range(30, 80, 10))),
    # Helps to shrink the contribution of each classifier
    'learning_rate': hp.loguniform('learning_rate', -7, 0), # Log uniform distribution between 1e-7 and 1
}

# Using the function
adb_best_params = optimize_hyperparams(AdaBoostClassifier,
                                       adb_default_params,
                                       adb_hyperparam_space,
                                       X_train_smote, y_train_smote,
                                       max_evals=30)
print(adb_best_params)
# Out:
# 100%|██████████| 30/30 [44:58<00:00, 89.94s/trial, best loss: -0.7465634543502966]
# Processing key: learning_rate, val: 0.12902472347860655
# Processing key: n_estimators, val: 4
# {'learning_rate': 0.12902472347860655, 'n_estimators': 70}

# %%
# Merge default and best params
adb_optimized_params = {**adb_default_params, **adb_best_params}
print(adb_optimized_params)

# Train the model using the optimized parameters
adb = AdaBoostClassifier(**adb_optimized_params)
adb.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(adb, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(adb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(adb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'learning_rate': 0.12902472347860655, 'n_estimators': 70}
# Training Data Evaluation:
# {'Accuracy': 0.76, 'Precision': 0.75, 'Recall': 0.79, 'F1': 0.77}
#
# Validation Data Evaluation:
# {'Accuracy': 0.76, 'Precision': 0.82, 'Recall': 0.77, 'F1': 0.79}
#
# Test Data Evaluation:
# {'Accuracy': 0.72, 'Precision': 0.68, 'Recall': 0.84, 'F1': 0.75}

# %%
xgb_default_params = {
    'random_state': random_state,
    'n_jobs': -1,
}

# Hyperparams for XGB
xgb_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -3),  # remain the same
    'n_estimators': hp.choice('n_estimators', [10, 20, 30]),  # even more reduced choices
    'max_depth': hp.choice('max_depth', [1, 2]),  # remain the same
    'min_child_weight': hp.quniform('min_child_weight', 16, 20, 1),  # remain the same
    'gamma': hp.uniform('gamma', 0.7, 1),  # remain the same
    'colsample_bytree': hp.uniform('colsample_bytree', 0.2, 0.5),  # remain the same
    'alpha': hp.loguniform('alpha', 0, 4),  # more aggressive L1 regularization
    'lambda': hp.loguniform('lambda', 0, 4),  # more aggressive L2 regularization
    'subsample': hp.uniform('subsample', 0.3, 0.7),  # remain the same
    'scale_pos_weight': hp.uniform('scale_pos_weight', 0.5, 1.5)  # reducing the influence of positive class
}


# Using the function
xgb_best_params = optimize_hyperparams(XGBClassifier,
                                       xgb_default_params,
                                       xgb_hyperparam_space,
                                       X_train_smote, y_train_smote,
                                       enable_early_stopping=True,
                                       max_evals=35)
print(xgb_best_params)
# Out:
# [0]	validation_0-logloss:0.70301
# [1]	validation_0-logloss:0.70038
# [2]	validation_0-logloss:0.69813
# [3]	validation_0-logloss:0.69568
# [4]	validation_0-logloss:0.69376
# [5]	validation_0-logloss:0.69148
# [6]	validation_0-logloss:0.68923
# [7]	validation_0-logloss:0.68783
# [8]	validation_0-logloss:0.68540
# [9]	validation_0-logloss:0.68299
# [10]	validation_0-logloss:0.68171
# [11]	validation_0-logloss:0.67945
# [12]	validation_0-logloss:0.67760
# [13]	validation_0-logloss:0.67540
# [14]	validation_0-logloss:0.67402
# [15]	validation_0-logloss:0.67302
# [16]	validation_0-logloss:0.67079
# [17]	validation_0-logloss:0.66882
# [18]	validation_0-logloss:0.66717
# [19]	validation_0-logloss:0.66614
# [20]	validation_0-logloss:0.66415
# [21]	validation_0-logloss:0.66254
# [22]	validation_0-logloss:0.66102
# [23]	validation_0-logloss:0.65992
# [24]	validation_0-logloss:0.65817
# [25]	validation_0-logloss:0.65747
# [26]	validation_0-logloss:0.65550
# [27]	validation_0-logloss:0.65404
# [28]	validation_0-logloss:0.65241
# [29]	validation_0-logloss:0.65128
# [0]	validation_0-logloss:0.70333
# [1]	validation_0-logloss:0.70045
# [2]	validation_0-logloss:0.69746
# [3]	validation_0-logloss:0.69464
# [4]	validation_0-logloss:0.69199
# [5]	validation_0-logloss:0.68943
# [6]	validation_0-logloss:0.68715
# [7]	validation_0-logloss:0.68510
# [8]	validation_0-logloss:0.68261
# [9]	validation_0-logloss:0.68026
# [10]	validation_0-logloss:0.67758
# [11]	validation_0-logloss:0.67515
# [12]	validation_0-logloss:0.67323
# [13]	validation_0-logloss:0.67116
# [14]	validation_0-logloss:0.66920
# [15]	validation_0-logloss:0.66707
# [16]	validation_0-logloss:0.66518
# [17]	validation_0-logloss:0.66315
# [18]	validation_0-logloss:0.66156
# [19]	validation_0-logloss:0.65968
# [20]	validation_0-logloss:0.65781
# [21]	validation_0-logloss:0.65614
# [22]	validation_0-logloss:0.65470
# [23]	validation_0-logloss:0.65321
# [24]	validation_0-logloss:0.65135
# [25]	validation_0-logloss:0.64906
# [26]	validation_0-logloss:0.64764
# [27]	validation_0-logloss:0.64603
# [28]	validation_0-logloss:0.64491
# [29]	validation_0-logloss:0.64330
# [0]	validation_0-logloss:0.70337
# [1]	validation_0-logloss:0.70057
# [2]	validation_0-logloss:0.69801
# [3]	validation_0-logloss:0.69537
# [4]	validation_0-logloss:0.69215
# [5]	validation_0-logloss:0.68934
# [6]	validation_0-logloss:0.68695
# [7]	validation_0-logloss:0.68560
# [8]	validation_0-logloss:0.68370
# [9]	validation_0-logloss:0.68132
# [10]	validation_0-logloss:0.67931
# [11]	validation_0-logloss:0.67687
# [12]	validation_0-logloss:0.67455
# [13]	validation_0-logloss:0.67216
# [14]	validation_0-logloss:0.67036
# [15]	validation_0-logloss:0.66828
# [16]	validation_0-logloss:0.66671
# [17]	validation_0-logloss:0.66466
# [18]	validation_0-logloss:0.66230
# [19]	validation_0-logloss:0.66061
# [20]	validation_0-logloss:0.65854
# [21]	validation_0-logloss:0.65676
# [22]	validation_0-logloss:0.65553
# [23]	validation_0-logloss:0.65388
# [24]	validation_0-logloss:0.65171
# [25]	validation_0-logloss:0.64965
# [26]	validation_0-logloss:0.64797
# [27]	validation_0-logloss:0.64668
# [28]	validation_0-logloss:0.64495
# [29]	validation_0-logloss:0.64309
# [0]	validation_0-logloss:0.70221
# [1]	validation_0-logloss:0.69993
# [2]	validation_0-logloss:0.69691
# [3]	validation_0-logloss:0.69412
# [4]	validation_0-logloss:0.69203
# [5]	validation_0-logloss:0.68976
# [6]	validation_0-logloss:0.68749
# [7]	validation_0-logloss:0.68539
# [8]	validation_0-logloss:0.68365
# [9]	validation_0-logloss:0.68124
# [10]	validation_0-logloss:0.67878
# [11]	validation_0-logloss:0.67673
# [12]	validation_0-logloss:0.67457
# [13]	validation_0-logloss:0.67237
# [14]	validation_0-logloss:0.67058
# [15]	validation_0-logloss:0.66903
# [16]	validation_0-logloss:0.66753
# [17]	validation_0-logloss:0.66573
# [18]	validation_0-logloss:0.66391
# [19]	validation_0-logloss:0.66266
# [20]	validation_0-logloss:0.66055
# [21]	validation_0-logloss:0.65900
# [22]	validation_0-logloss:0.65772
# [23]	validation_0-logloss:0.65611
# [24]	validation_0-logloss:0.65486
# [25]	validation_0-logloss:0.65332
# [26]	validation_0-logloss:0.65093
# [27]	validation_0-logloss:0.65002
# [28]	validation_0-logloss:0.64752
# [29]	validation_0-logloss:0.64550
# [0]	validation_0-logloss:0.70223
# [1]	validation_0-logloss:0.69889
# [2]	validation_0-logloss:0.69597
# [3]	validation_0-logloss:0.69336
# [4]	validation_0-logloss:0.69030
# [5]	validation_0-logloss:0.68762
# [6]	validation_0-logloss:0.68534
# [7]	validation_0-logloss:0.68312
# [8]	validation_0-logloss:0.68050
# [9]	validation_0-logloss:0.67844
# [10]	validation_0-logloss:0.67575
# [11]	validation_0-logloss:0.67348
# [12]	validation_0-logloss:0.67085
# [13]	validation_0-logloss:0.66924
# [14]	validation_0-logloss:0.66744
# [15]	validation_0-logloss:0.66512
# [16]	validation_0-logloss:0.66307
# [17]	validation_0-logloss:0.66145
# [18]	validation_0-logloss:0.65881
# [19]	validation_0-logloss:0.65697
# [20]	validation_0-logloss:0.65534
# [21]	validation_0-logloss:0.65310
# [22]	validation_0-logloss:0.65142
# [23]	validation_0-logloss:0.64991
# [24]	validation_0-logloss:0.64835
# [25]	validation_0-logloss:0.64651
# [26]	validation_0-logloss:0.64477
# [27]	validation_0-logloss:0.64318
# [28]	validation_0-logloss:0.64131
# [29]	validation_0-logloss:0.63965
# [0]	validation_0-logloss:0.72795
# [1]	validation_0-logloss:0.72190
# [2]	validation_0-logloss:0.71640
# [3]	validation_0-logloss:0.71194
# [4]	validation_0-logloss:0.70748
# [5]	validation_0-logloss:0.70338
# [6]	validation_0-logloss:0.69930
# [7]	validation_0-logloss:0.69512
# [8]	validation_0-logloss:0.69157
# [9]	validation_0-logloss:0.68844
# [0]	validation_0-logloss:0.72691
# [1]	validation_0-logloss:0.72068
# [2]	validation_0-logloss:0.71563
# [3]	validation_0-logloss:0.71031
# [4]	validation_0-logloss:0.70534
# [5]	validation_0-logloss:0.70068
# [6]	validation_0-logloss:0.69586
# [7]	validation_0-logloss:0.69121
# [8]	validation_0-logloss:0.68663
# [9]	validation_0-logloss:0.68273
# [0]	validation_0-logloss:0.72710
# [1]	validation_0-logloss:0.72141
# [2]	validation_0-logloss:0.71579
# [3]	validation_0-logloss:0.71151
# [4]	validation_0-logloss:0.70524
# [5]	validation_0-logloss:0.70028
# [6]	validation_0-logloss:0.69613
# [7]	validation_0-logloss:0.69222
# [8]	validation_0-logloss:0.68772
# [9]	validation_0-logloss:0.68274
# [0]	validation_0-logloss:0.72873
# [1]	validation_0-logloss:0.72342
# [2]	validation_0-logloss:0.71861
# [3]	validation_0-logloss:0.71400
# [4]	validation_0-logloss:0.70884
# [5]	validation_0-logloss:0.70477
# [6]	validation_0-logloss:0.70155
# [7]	validation_0-logloss:0.69673
# [8]	validation_0-logloss:0.69189
# [9]	validation_0-logloss:0.68772
# [0]	validation_0-logloss:0.72778
# [1]	validation_0-logloss:0.72212
# [2]	validation_0-logloss:0.71645
# [3]	validation_0-logloss:0.71106
# [4]	validation_0-logloss:0.70686
# [5]	validation_0-logloss:0.70226
# [6]	validation_0-logloss:0.69734
# [7]	validation_0-logloss:0.69312
# [8]	validation_0-logloss:0.68883
# [9]	validation_0-logloss:0.68481
# [0]	validation_0-logloss:0.70175
# [1]	validation_0-logloss:0.70061
# [2]	validation_0-logloss:0.69964
# [3]	validation_0-logloss:0.69863
# [4]	validation_0-logloss:0.69762
# [5]	validation_0-logloss:0.69685
# [6]	validation_0-logloss:0.69575
# [7]	validation_0-logloss:0.69499
# [8]	validation_0-logloss:0.69377
# [9]	validation_0-logloss:0.69265
# [10]	validation_0-logloss:0.69201
# [11]	validation_0-logloss:0.69084
# [12]	validation_0-logloss:0.68976
# [13]	validation_0-logloss:0.68865
# [14]	validation_0-logloss:0.68800
# [15]	validation_0-logloss:0.68726
# [16]	validation_0-logloss:0.68620
# [17]	validation_0-logloss:0.68521
# [18]	validation_0-logloss:0.68447
# [19]	validation_0-logloss:0.68367
# [0]	validation_0-logloss:0.70228
# [1]	validation_0-logloss:0.70100
# [2]	validation_0-logloss:0.69962
# [3]	validation_0-logloss:0.69848
# [4]	validation_0-logloss:0.69709
# [5]	validation_0-logloss:0.69602
# [6]	validation_0-logloss:0.69505
# [7]	validation_0-logloss:0.69395
# [8]	validation_0-logloss:0.69285
# [9]	validation_0-logloss:0.69171
# [10]	validation_0-logloss:0.69038
# [11]	validation_0-logloss:0.68939
# [12]	validation_0-logloss:0.68835
# [13]	validation_0-logloss:0.68720
# [14]	validation_0-logloss:0.68591
# [15]	validation_0-logloss:0.68497
# [16]	validation_0-logloss:0.68392
# [17]	validation_0-logloss:0.68287
# [18]	validation_0-logloss:0.68193
# [19]	validation_0-logloss:0.68097
# [0]	validation_0-logloss:0.70226
# [1]	validation_0-logloss:0.70111
# [2]	validation_0-logloss:0.69993
# [3]	validation_0-logloss:0.69865
# [4]	validation_0-logloss:0.69735
# [5]	validation_0-logloss:0.69601
# [6]	validation_0-logloss:0.69501
# [7]	validation_0-logloss:0.69439
# [8]	validation_0-logloss:0.69320
# [9]	validation_0-logloss:0.69194
# [10]	validation_0-logloss:0.69084
# [11]	validation_0-logloss:0.68992
# [12]	validation_0-logloss:0.68890
# [13]	validation_0-logloss:0.68750
# [14]	validation_0-logloss:0.68625
# [15]	validation_0-logloss:0.68524
# [16]	validation_0-logloss:0.68418
# [17]	validation_0-logloss:0.68334
# [18]	validation_0-logloss:0.68246
# [19]	validation_0-logloss:0.68161
# [0]	validation_0-logloss:0.70141
# [1]	validation_0-logloss:0.70036
# [2]	validation_0-logloss:0.69905
# [3]	validation_0-logloss:0.69784
# [4]	validation_0-logloss:0.69688
# [5]	validation_0-logloss:0.69599
# [6]	validation_0-logloss:0.69496
# [7]	validation_0-logloss:0.69388
# [8]	validation_0-logloss:0.69302
# [9]	validation_0-logloss:0.69191
# [10]	validation_0-logloss:0.69096
# [11]	validation_0-logloss:0.69000
# [12]	validation_0-logloss:0.68873
# [13]	validation_0-logloss:0.68750
# [14]	validation_0-logloss:0.68657
# [15]	validation_0-logloss:0.68578
# [16]	validation_0-logloss:0.68494
# [17]	validation_0-logloss:0.68394
# [18]	validation_0-logloss:0.68290
# [19]	validation_0-logloss:0.68211
# [0]	validation_0-logloss:0.70130
# [1]	validation_0-logloss:0.69977
# [2]	validation_0-logloss:0.69854
# [3]	validation_0-logloss:0.69748
# [4]	validation_0-logloss:0.69624
# [5]	validation_0-logloss:0.69517
# [6]	validation_0-logloss:0.69421
# [7]	validation_0-logloss:0.69307
# [8]	validation_0-logloss:0.69178
# [9]	validation_0-logloss:0.69076
# [10]	validation_0-logloss:0.68949
# [11]	validation_0-logloss:0.68832
# [12]	validation_0-logloss:0.68711
# [13]	validation_0-logloss:0.68609
# [14]	validation_0-logloss:0.68525
# [15]	validation_0-logloss:0.68416
# [16]	validation_0-logloss:0.68313
# [17]	validation_0-logloss:0.68229
# [18]	validation_0-logloss:0.68099
# [19]	validation_0-logloss:0.67990
# [0]	validation_0-logloss:0.70293
# [1]	validation_0-logloss:0.70142
# [2]	validation_0-logloss:0.69995
# [3]	validation_0-logloss:0.69845
# [4]	validation_0-logloss:0.69713
# [5]	validation_0-logloss:0.69588
# [6]	validation_0-logloss:0.69464
# [7]	validation_0-logloss:0.69339
# [8]	validation_0-logloss:0.69204
# [9]	validation_0-logloss:0.69095
# [10]	validation_0-logloss:0.68979
# [11]	validation_0-logloss:0.68845
# [12]	validation_0-logloss:0.68723
# [13]	validation_0-logloss:0.68606
# [14]	validation_0-logloss:0.68513
# [15]	validation_0-logloss:0.68402
# [16]	validation_0-logloss:0.68277
# [17]	validation_0-logloss:0.68168
# [18]	validation_0-logloss:0.68069
# [19]	validation_0-logloss:0.67975
# [20]	validation_0-logloss:0.67866
# [21]	validation_0-logloss:0.67743
# [22]	validation_0-logloss:0.67635
# [23]	validation_0-logloss:0.67538
# [24]	validation_0-logloss:0.67433
# [25]	validation_0-logloss:0.67345
# [26]	validation_0-logloss:0.67234
# [27]	validation_0-logloss:0.67122
# [28]	validation_0-logloss:0.67013
# [29]	validation_0-logloss:0.66927
# [0]	validation_0-logloss:0.70223
# [1]	validation_0-logloss:0.70068
# [2]	validation_0-logloss:0.69911
# [3]	validation_0-logloss:0.69768
# [4]	validation_0-logloss:0.69626
# [5]	validation_0-logloss:0.69478
# [6]	validation_0-logloss:0.69329
# [7]	validation_0-logloss:0.69192
# [8]	validation_0-logloss:0.69051
# [9]	validation_0-logloss:0.68921
# [10]	validation_0-logloss:0.68782
# [11]	validation_0-logloss:0.68665
# [12]	validation_0-logloss:0.68546
# [13]	validation_0-logloss:0.68440
# [14]	validation_0-logloss:0.68343
# [15]	validation_0-logloss:0.68219
# [16]	validation_0-logloss:0.68113
# [17]	validation_0-logloss:0.68021
# [18]	validation_0-logloss:0.67879
# [19]	validation_0-logloss:0.67721
# [20]	validation_0-logloss:0.67613
# [21]	validation_0-logloss:0.67512
# [22]	validation_0-logloss:0.67386
# [23]	validation_0-logloss:0.67282
# [24]	validation_0-logloss:0.67152
# [25]	validation_0-logloss:0.67079
# [26]	validation_0-logloss:0.66962
# [27]	validation_0-logloss:0.66859
# [28]	validation_0-logloss:0.66751
# [29]	validation_0-logloss:0.66632
# [0]	validation_0-logloss:0.70234
# [1]	validation_0-logloss:0.70091
# [2]	validation_0-logloss:0.69944
# [3]	validation_0-logloss:0.69810
# [4]	validation_0-logloss:0.69653
# [5]	validation_0-logloss:0.69511
# [6]	validation_0-logloss:0.69389
# [7]	validation_0-logloss:0.69273
# [8]	validation_0-logloss:0.69134
# [9]	validation_0-logloss:0.68974
# [10]	validation_0-logloss:0.68847
# [11]	validation_0-logloss:0.68708
# [12]	validation_0-logloss:0.68580
# [13]	validation_0-logloss:0.68456
# [14]	validation_0-logloss:0.68315
# [15]	validation_0-logloss:0.68177
# [16]	validation_0-logloss:0.68052
# [17]	validation_0-logloss:0.67970
# [18]	validation_0-logloss:0.67848
# [19]	validation_0-logloss:0.67731
# [20]	validation_0-logloss:0.67607
# [21]	validation_0-logloss:0.67493
# [22]	validation_0-logloss:0.67382
# [23]	validation_0-logloss:0.67267
# [24]	validation_0-logloss:0.67141
# [25]	validation_0-logloss:0.67023
# [26]	validation_0-logloss:0.66913
# [27]	validation_0-logloss:0.66809
# [28]	validation_0-logloss:0.66694
# [29]	validation_0-logloss:0.66565
# [0]	validation_0-logloss:0.70337
# [1]	validation_0-logloss:0.70198
# [2]	validation_0-logloss:0.70062
# [3]	validation_0-logloss:0.69920
# [4]	validation_0-logloss:0.69771
# [5]	validation_0-logloss:0.69649
# [6]	validation_0-logloss:0.69516
# [7]	validation_0-logloss:0.69389
# [8]	validation_0-logloss:0.69270
# [9]	validation_0-logloss:0.69143
# [10]	validation_0-logloss:0.69020
# [11]	validation_0-logloss:0.68903
# [12]	validation_0-logloss:0.68761
# [13]	validation_0-logloss:0.68619
# [14]	validation_0-logloss:0.68492
# [15]	validation_0-logloss:0.68364
# [16]	validation_0-logloss:0.68230
# [17]	validation_0-logloss:0.68124
# [18]	validation_0-logloss:0.67994
# [19]	validation_0-logloss:0.67879
# [20]	validation_0-logloss:0.67758
# [21]	validation_0-logloss:0.67646
# [22]	validation_0-logloss:0.67539
# [23]	validation_0-logloss:0.67435
# [24]	validation_0-logloss:0.67324
# [25]	validation_0-logloss:0.67207
# [26]	validation_0-logloss:0.67107
# [27]	validation_0-logloss:0.67021
# [28]	validation_0-logloss:0.66921
# [29]	validation_0-logloss:0.66821
# [0]	validation_0-logloss:0.70323
# [1]	validation_0-logloss:0.70168
# [2]	validation_0-logloss:0.70024
# [3]	validation_0-logloss:0.69881
# [4]	validation_0-logloss:0.69753
# [5]	validation_0-logloss:0.69620
# [6]	validation_0-logloss:0.69476
# [7]	validation_0-logloss:0.69333
# [8]	validation_0-logloss:0.69198
# [9]	validation_0-logloss:0.69064
# [10]	validation_0-logloss:0.68925
# [11]	validation_0-logloss:0.68773
# [12]	validation_0-logloss:0.68627
# [13]	validation_0-logloss:0.68508
# [14]	validation_0-logloss:0.68381
# [15]	validation_0-logloss:0.68262
# [16]	validation_0-logloss:0.68132
# [17]	validation_0-logloss:0.68015
# [18]	validation_0-logloss:0.67886
# [19]	validation_0-logloss:0.67743
# [20]	validation_0-logloss:0.67620
# [21]	validation_0-logloss:0.67477
# [22]	validation_0-logloss:0.67363
# [23]	validation_0-logloss:0.67249
# [24]	validation_0-logloss:0.67124
# [25]	validation_0-logloss:0.67029
# [26]	validation_0-logloss:0.66930
# [27]	validation_0-logloss:0.66815
# [28]	validation_0-logloss:0.66690
# [29]	validation_0-logloss:0.66577
# [0]	validation_0-logloss:0.68912
# [1]	validation_0-logloss:0.68426
# [2]	validation_0-logloss:0.68034
# [3]	validation_0-logloss:0.67702
# [4]	validation_0-logloss:0.67342
# [5]	validation_0-logloss:0.66959
# [6]	validation_0-logloss:0.66576
# [7]	validation_0-logloss:0.66297
# [8]	validation_0-logloss:0.65995
# [9]	validation_0-logloss:0.65710
# [10]	validation_0-logloss:0.65477
# [11]	validation_0-logloss:0.65168
# [12]	validation_0-logloss:0.64872
# [13]	validation_0-logloss:0.64618
# [14]	validation_0-logloss:0.64376
# [15]	validation_0-logloss:0.64137
# [16]	validation_0-logloss:0.63833
# [17]	validation_0-logloss:0.63583
# [18]	validation_0-logloss:0.63405
# [19]	validation_0-logloss:0.63210
# [0]	validation_0-logloss:0.68937
# [1]	validation_0-logloss:0.68444
# [2]	validation_0-logloss:0.67967
# [3]	validation_0-logloss:0.67522
# [4]	validation_0-logloss:0.67107
# [5]	validation_0-logloss:0.66693
# [6]	validation_0-logloss:0.66280
# [7]	validation_0-logloss:0.65890
# [8]	validation_0-logloss:0.65507
# [9]	validation_0-logloss:0.65138
# [10]	validation_0-logloss:0.64766
# [11]	validation_0-logloss:0.64437
# [12]	validation_0-logloss:0.64167
# [13]	validation_0-logloss:0.63873
# [14]	validation_0-logloss:0.63552
# [15]	validation_0-logloss:0.63255
# [16]	validation_0-logloss:0.62976
# [17]	validation_0-logloss:0.62697
# [18]	validation_0-logloss:0.62395
# [19]	validation_0-logloss:0.62091
# [0]	validation_0-logloss:0.68932
# [1]	validation_0-logloss:0.68461
# [2]	validation_0-logloss:0.67949
# [3]	validation_0-logloss:0.67566
# [4]	validation_0-logloss:0.67078
# [5]	validation_0-logloss:0.66677
# [6]	validation_0-logloss:0.66348
# [7]	validation_0-logloss:0.65998
# [8]	validation_0-logloss:0.65596
# [9]	validation_0-logloss:0.65279
# [10]	validation_0-logloss:0.64951
# [11]	validation_0-logloss:0.64659
# [12]	validation_0-logloss:0.64321
# [13]	validation_0-logloss:0.64055
# [14]	validation_0-logloss:0.63760
# [15]	validation_0-logloss:0.63455
# [16]	validation_0-logloss:0.63205
# [17]	validation_0-logloss:0.62967
# [18]	validation_0-logloss:0.62715
# [19]	validation_0-logloss:0.62468
# [0]	validation_0-logloss:0.68954
# [1]	validation_0-logloss:0.68443
# [2]	validation_0-logloss:0.67958
# [3]	validation_0-logloss:0.67538
# [4]	validation_0-logloss:0.67057
# [5]	validation_0-logloss:0.66661
# [6]	validation_0-logloss:0.66303
# [7]	validation_0-logloss:0.65965
# [8]	validation_0-logloss:0.65526
# [9]	validation_0-logloss:0.65187
# [10]	validation_0-logloss:0.64862
# [11]	validation_0-logloss:0.64547
# [12]	validation_0-logloss:0.64209
# [13]	validation_0-logloss:0.63902
# [14]	validation_0-logloss:0.63697
# [15]	validation_0-logloss:0.63365
# [16]	validation_0-logloss:0.63095
# [17]	validation_0-logloss:0.62846
# [18]	validation_0-logloss:0.62522
# [19]	validation_0-logloss:0.62289
# [0]	validation_0-logloss:0.68884
# [1]	validation_0-logloss:0.68389
# [2]	validation_0-logloss:0.67902
# [3]	validation_0-logloss:0.67386
# [4]	validation_0-logloss:0.66952
# [5]	validation_0-logloss:0.66533
# [6]	validation_0-logloss:0.66104
# [7]	validation_0-logloss:0.65719
# [8]	validation_0-logloss:0.65362
# [9]	validation_0-logloss:0.64989
# [10]	validation_0-logloss:0.64648
# [11]	validation_0-logloss:0.64279
# [12]	validation_0-logloss:0.63917
# [13]	validation_0-logloss:0.63610
# [14]	validation_0-logloss:0.63285
# [15]	validation_0-logloss:0.62975
# [16]	validation_0-logloss:0.62681
# [17]	validation_0-logloss:0.62386
# [18]	validation_0-logloss:0.62063
# [19]	validation_0-logloss:0.61772
# [0]	validation_0-logloss:0.70358
# [1]	validation_0-logloss:0.70002
# [2]	validation_0-logloss:0.69706
# [3]	validation_0-logloss:0.69447
# [4]	validation_0-logloss:0.69152
# [5]	validation_0-logloss:0.68841
# [6]	validation_0-logloss:0.68591
# [7]	validation_0-logloss:0.68327
# [8]	validation_0-logloss:0.68058
# [9]	validation_0-logloss:0.67816
# [10]	validation_0-logloss:0.67576
# [11]	validation_0-logloss:0.67283
# [12]	validation_0-logloss:0.67039
# [13]	validation_0-logloss:0.66840
# [14]	validation_0-logloss:0.66610
# [15]	validation_0-logloss:0.66430
# [16]	validation_0-logloss:0.66171
# [17]	validation_0-logloss:0.65951
# [18]	validation_0-logloss:0.65784
# [19]	validation_0-logloss:0.65624
# [0]	validation_0-logloss:0.70404
# [1]	validation_0-logloss:0.70053
# [2]	validation_0-logloss:0.69645
# [3]	validation_0-logloss:0.69317
# [4]	validation_0-logloss:0.68989
# [5]	validation_0-logloss:0.68685
# [6]	validation_0-logloss:0.68386
# [7]	validation_0-logloss:0.68071
# [8]	validation_0-logloss:0.67788
# [9]	validation_0-logloss:0.67519
# [10]	validation_0-logloss:0.67168
# [11]	validation_0-logloss:0.66888
# [12]	validation_0-logloss:0.66638
# [13]	validation_0-logloss:0.66408
# [14]	validation_0-logloss:0.66146
# [15]	validation_0-logloss:0.65892
# [16]	validation_0-logloss:0.65654
# [17]	validation_0-logloss:0.65412
# [18]	validation_0-logloss:0.65217
# [19]	validation_0-logloss:0.64944
# [0]	validation_0-logloss:0.70415
# [1]	validation_0-logloss:0.70088
# [2]	validation_0-logloss:0.69641
# [3]	validation_0-logloss:0.69262
# [4]	validation_0-logloss:0.68863
# [5]	validation_0-logloss:0.68520
# [6]	validation_0-logloss:0.68231
# [7]	validation_0-logloss:0.67930
# [8]	validation_0-logloss:0.67644
# [9]	validation_0-logloss:0.67347
# [10]	validation_0-logloss:0.67098
# [11]	validation_0-logloss:0.66819
# [12]	validation_0-logloss:0.66595
# [13]	validation_0-logloss:0.66378
# [14]	validation_0-logloss:0.66135
# [15]	validation_0-logloss:0.65876
# [16]	validation_0-logloss:0.65655
# [17]	validation_0-logloss:0.65448
# [18]	validation_0-logloss:0.65257
# [19]	validation_0-logloss:0.65080
# [0]	validation_0-logloss:0.70303
# [1]	validation_0-logloss:0.69969
# [2]	validation_0-logloss:0.69590
# [3]	validation_0-logloss:0.69264
# [4]	validation_0-logloss:0.68934
# [5]	validation_0-logloss:0.68669
# [6]	validation_0-logloss:0.68418
# [7]	validation_0-logloss:0.68044
# [8]	validation_0-logloss:0.67749
# [9]	validation_0-logloss:0.67481
# [10]	validation_0-logloss:0.67175
# [11]	validation_0-logloss:0.66883
# [12]	validation_0-logloss:0.66616
# [13]	validation_0-logloss:0.66376
# [14]	validation_0-logloss:0.66142
# [15]	validation_0-logloss:0.65930
# [16]	validation_0-logloss:0.65716
# [17]	validation_0-logloss:0.65505
# [18]	validation_0-logloss:0.65322
# [19]	validation_0-logloss:0.65102
# [0]	validation_0-logloss:0.70293
# [1]	validation_0-logloss:0.69911
# [2]	validation_0-logloss:0.69538
# [3]	validation_0-logloss:0.69160
# [4]	validation_0-logloss:0.68861
# [5]	validation_0-logloss:0.68523
# [6]	validation_0-logloss:0.68189
# [7]	validation_0-logloss:0.67860
# [8]	validation_0-logloss:0.67544
# [9]	validation_0-logloss:0.67248
# [10]	validation_0-logloss:0.66922
# [11]	validation_0-logloss:0.66616
# [12]	validation_0-logloss:0.66314
# [13]	validation_0-logloss:0.66076
# [14]	validation_0-logloss:0.65804
# [15]	validation_0-logloss:0.65559
# [16]	validation_0-logloss:0.65309
# [17]	validation_0-logloss:0.65038
# [18]	validation_0-logloss:0.64795
# [19]	validation_0-logloss:0.64543
# [0]	validation_0-logloss:0.69737
# [1]	validation_0-logloss:0.69601
# [2]	validation_0-logloss:0.69494
# [3]	validation_0-logloss:0.69370
# [4]	validation_0-logloss:0.69226
# [5]	validation_0-logloss:0.69111
# [6]	validation_0-logloss:0.68991
# [7]	validation_0-logloss:0.68884
# [8]	validation_0-logloss:0.68738
# [9]	validation_0-logloss:0.68589
# [10]	validation_0-logloss:0.68478
# [11]	validation_0-logloss:0.68357
# [12]	validation_0-logloss:0.68236
# [13]	validation_0-logloss:0.68101
# [14]	validation_0-logloss:0.67982
# [15]	validation_0-logloss:0.67899
# [16]	validation_0-logloss:0.67761
# [17]	validation_0-logloss:0.67655
# [18]	validation_0-logloss:0.67554
# [19]	validation_0-logloss:0.67469
# [0]	validation_0-logloss:0.69770
# [1]	validation_0-logloss:0.69637
# [2]	validation_0-logloss:0.69470
# [3]	validation_0-logloss:0.69293
# [4]	validation_0-logloss:0.69102
# [5]	validation_0-logloss:0.68966
# [6]	validation_0-logloss:0.68833
# [7]	validation_0-logloss:0.68693
# [8]	validation_0-logloss:0.68550
# [9]	validation_0-logloss:0.68405
# [10]	validation_0-logloss:0.68252
# [11]	validation_0-logloss:0.68115
# [12]	validation_0-logloss:0.67983
# [13]	validation_0-logloss:0.67850
# [14]	validation_0-logloss:0.67720
# [15]	validation_0-logloss:0.67579
# [16]	validation_0-logloss:0.67452
# [17]	validation_0-logloss:0.67324
# [18]	validation_0-logloss:0.67194
# [19]	validation_0-logloss:0.67087
# [0]	validation_0-logloss:0.69798
# [1]	validation_0-logloss:0.69667
# [2]	validation_0-logloss:0.69532
# [3]	validation_0-logloss:0.69387
# [4]	validation_0-logloss:0.69214
# [5]	validation_0-logloss:0.69084
# [6]	validation_0-logloss:0.68958
# [7]	validation_0-logloss:0.68857
# [8]	validation_0-logloss:0.68724
# [9]	validation_0-logloss:0.68572
# [10]	validation_0-logloss:0.68454
# [11]	validation_0-logloss:0.68332
# [12]	validation_0-logloss:0.68194
# [13]	validation_0-logloss:0.68079
# [14]	validation_0-logloss:0.67945
# [15]	validation_0-logloss:0.67809
# [16]	validation_0-logloss:0.67691
# [17]	validation_0-logloss:0.67596
# [18]	validation_0-logloss:0.67470
# [19]	validation_0-logloss:0.67367
# [0]	validation_0-logloss:0.69751
# [1]	validation_0-logloss:0.69600
# [2]	validation_0-logloss:0.69450
# [3]	validation_0-logloss:0.69296
# [4]	validation_0-logloss:0.69120
# [5]	validation_0-logloss:0.69002
# [6]	validation_0-logloss:0.68887
# [7]	validation_0-logloss:0.68769
# [8]	validation_0-logloss:0.68633
# [9]	validation_0-logloss:0.68495
# [10]	validation_0-logloss:0.68384
# [11]	validation_0-logloss:0.68252
# [12]	validation_0-logloss:0.68107
# [13]	validation_0-logloss:0.67983
# [14]	validation_0-logloss:0.67859
# [15]	validation_0-logloss:0.67789
# [16]	validation_0-logloss:0.67666
# [17]	validation_0-logloss:0.67563
# [18]	validation_0-logloss:0.67421
# [19]	validation_0-logloss:0.67312
# [0]	validation_0-logloss:0.69714
# [1]	validation_0-logloss:0.69548
# [2]	validation_0-logloss:0.69413
# [3]	validation_0-logloss:0.69267
# [4]	validation_0-logloss:0.69102
# [5]	validation_0-logloss:0.68941
# [6]	validation_0-logloss:0.68796
# [7]	validation_0-logloss:0.68650
# [8]	validation_0-logloss:0.68519
# [9]	validation_0-logloss:0.68374
# [10]	validation_0-logloss:0.68244
# [11]	validation_0-logloss:0.68102
# [12]	validation_0-logloss:0.67934
# [13]	validation_0-logloss:0.67795
# [14]	validation_0-logloss:0.67696
# [15]	validation_0-logloss:0.67576
# [16]	validation_0-logloss:0.67416
# [17]	validation_0-logloss:0.67297
# [18]	validation_0-logloss:0.67156
# [19]	validation_0-logloss:0.67031
# [0]	validation_0-logloss:0.70488
# [1]	validation_0-logloss:0.70068
# [2]	validation_0-logloss:0.69719
# [3]	validation_0-logloss:0.69385
# [4]	validation_0-logloss:0.68998
# [5]	validation_0-logloss:0.68689
# [6]	validation_0-logloss:0.68309
# [7]	validation_0-logloss:0.68034
# [8]	validation_0-logloss:0.67857
# [9]	validation_0-logloss:0.67663
# [10]	validation_0-logloss:0.67457
# [11]	validation_0-logloss:0.67152
# [12]	validation_0-logloss:0.66923
# [13]	validation_0-logloss:0.66690
# [14]	validation_0-logloss:0.66381
# [15]	validation_0-logloss:0.66227
# [16]	validation_0-logloss:0.65951
# [17]	validation_0-logloss:0.65728
# [18]	validation_0-logloss:0.65625
# [19]	validation_0-logloss:0.65456
# [20]	validation_0-logloss:0.65218
# [21]	validation_0-logloss:0.65106
# [22]	validation_0-logloss:0.64947
# [23]	validation_0-logloss:0.64807
# [24]	validation_0-logloss:0.64636
# [25]	validation_0-logloss:0.64513
# [26]	validation_0-logloss:0.64380
# [27]	validation_0-logloss:0.64271
# [28]	validation_0-logloss:0.64130
# [29]	validation_0-logloss:0.64056
# [0]	validation_0-logloss:0.70571
# [1]	validation_0-logloss:0.70160
# [2]	validation_0-logloss:0.69720
# [3]	validation_0-logloss:0.69345
# [4]	validation_0-logloss:0.68957
# [5]	validation_0-logloss:0.68606
# [6]	validation_0-logloss:0.68294
# [7]	validation_0-logloss:0.67955
# [8]	validation_0-logloss:0.67616
# [9]	validation_0-logloss:0.67309
# [10]	validation_0-logloss:0.66937
# [11]	validation_0-logloss:0.66653
# [12]	validation_0-logloss:0.66418
# [13]	validation_0-logloss:0.66196
# [14]	validation_0-logloss:0.65951
# [15]	validation_0-logloss:0.65678
# [16]	validation_0-logloss:0.65469
# [17]	validation_0-logloss:0.65202
# [18]	validation_0-logloss:0.65011
# [19]	validation_0-logloss:0.64796
# [20]	validation_0-logloss:0.64583
# [21]	validation_0-logloss:0.64412
# [22]	validation_0-logloss:0.64260
# [23]	validation_0-logloss:0.64055
# [24]	validation_0-logloss:0.63835
# [25]	validation_0-logloss:0.63646
# [26]	validation_0-logloss:0.63451
# [27]	validation_0-logloss:0.63318
# [28]	validation_0-logloss:0.63145
# [29]	validation_0-logloss:0.62968
# [0]	validation_0-logloss:0.70549
# [1]	validation_0-logloss:0.70088
# [2]	validation_0-logloss:0.69680
# [3]	validation_0-logloss:0.69257
# [4]	validation_0-logloss:0.68799
# [5]	validation_0-logloss:0.68455
# [6]	validation_0-logloss:0.68128
# [7]	validation_0-logloss:0.67778
# [8]	validation_0-logloss:0.67469
# [9]	validation_0-logloss:0.67178
# [10]	validation_0-logloss:0.66862
# [11]	validation_0-logloss:0.66588
# [12]	validation_0-logloss:0.66312
# [13]	validation_0-logloss:0.66018
# [14]	validation_0-logloss:0.65747
# [15]	validation_0-logloss:0.65490
# [16]	validation_0-logloss:0.65313
# [17]	validation_0-logloss:0.65056
# [18]	validation_0-logloss:0.64848
# [19]	validation_0-logloss:0.64697
# [20]	validation_0-logloss:0.64483
# [21]	validation_0-logloss:0.64256
# [22]	validation_0-logloss:0.64073
# [23]	validation_0-logloss:0.63865
# [24]	validation_0-logloss:0.63644
# [25]	validation_0-logloss:0.63439
# [26]	validation_0-logloss:0.63277
# [27]	validation_0-logloss:0.63115
# [28]	validation_0-logloss:0.62926
# [29]	validation_0-logloss:0.62778
# [0]	validation_0-logloss:0.70523
# [1]	validation_0-logloss:0.70119
# [2]	validation_0-logloss:0.69628
# [3]	validation_0-logloss:0.69266
# [4]	validation_0-logloss:0.68749
# [5]	validation_0-logloss:0.68471
# [6]	validation_0-logloss:0.68188
# [7]	validation_0-logloss:0.67912
# [8]	validation_0-logloss:0.67518
# [9]	validation_0-logloss:0.67203
# [10]	validation_0-logloss:0.66950
# [11]	validation_0-logloss:0.66700
# [12]	validation_0-logloss:0.66438
# [13]	validation_0-logloss:0.66209
# [14]	validation_0-logloss:0.66031
# [15]	validation_0-logloss:0.65798
# [16]	validation_0-logloss:0.65500
# [17]	validation_0-logloss:0.65271
# [18]	validation_0-logloss:0.65027
# [19]	validation_0-logloss:0.64883
# [20]	validation_0-logloss:0.64678
# [21]	validation_0-logloss:0.64507
# [22]	validation_0-logloss:0.64396
# [23]	validation_0-logloss:0.64215
# [24]	validation_0-logloss:0.63998
# [25]	validation_0-logloss:0.63729
# [26]	validation_0-logloss:0.63575
# [27]	validation_0-logloss:0.63366
# [28]	validation_0-logloss:0.63147
# [29]	validation_0-logloss:0.62928
# [0]	validation_0-logloss:0.70463
# [1]	validation_0-logloss:0.69951
# [2]	validation_0-logloss:0.69518
# [3]	validation_0-logloss:0.69123
# [4]	validation_0-logloss:0.68736
# [5]	validation_0-logloss:0.68367
# [6]	validation_0-logloss:0.67999
# [7]	validation_0-logloss:0.67578
# [8]	validation_0-logloss:0.67289
# [9]	validation_0-logloss:0.66992
# [10]	validation_0-logloss:0.66658
# [11]	validation_0-logloss:0.66352
# [12]	validation_0-logloss:0.66063
# [13]	validation_0-logloss:0.65852
# [14]	validation_0-logloss:0.65624
# [15]	validation_0-logloss:0.65332
# [16]	validation_0-logloss:0.65099
# [17]	validation_0-logloss:0.64797
# [18]	validation_0-logloss:0.64604
# [19]	validation_0-logloss:0.64360
# [20]	validation_0-logloss:0.64229
# [21]	validation_0-logloss:0.63964
# [22]	validation_0-logloss:0.63817
# [23]	validation_0-logloss:0.63620
# [24]	validation_0-logloss:0.63454
# [25]	validation_0-logloss:0.63287
# [26]	validation_0-logloss:0.63094
# [27]	validation_0-logloss:0.62888
# [28]	validation_0-logloss:0.62659
# [29]	validation_0-logloss:0.62459
# [0]	validation_0-logloss:0.69051
# [1]	validation_0-logloss:0.68799
# [2]	validation_0-logloss:0.68588
# [3]	validation_0-logloss:0.68393
# [4]	validation_0-logloss:0.68219
# [5]	validation_0-logloss:0.68074
# [6]	validation_0-logloss:0.67855
# [7]	validation_0-logloss:0.67683
# [8]	validation_0-logloss:0.67478
# [9]	validation_0-logloss:0.67343
# [10]	validation_0-logloss:0.67142
# [11]	validation_0-logloss:0.66942
# [12]	validation_0-logloss:0.66726
# [13]	validation_0-logloss:0.66569
# [14]	validation_0-logloss:0.66372
# [15]	validation_0-logloss:0.66221
# [16]	validation_0-logloss:0.66107
# [17]	validation_0-logloss:0.65947
# [18]	validation_0-logloss:0.65857
# [19]	validation_0-logloss:0.65756
# [20]	validation_0-logloss:0.65569
# [21]	validation_0-logloss:0.65397
# [22]	validation_0-logloss:0.65229
# [23]	validation_0-logloss:0.65128
# [24]	validation_0-logloss:0.64967
# [25]	validation_0-logloss:0.64829
# [26]	validation_0-logloss:0.64707
# [27]	validation_0-logloss:0.64576
# [28]	validation_0-logloss:0.64419
# [29]	validation_0-logloss:0.64323
# [0]	validation_0-logloss:0.69059
# [1]	validation_0-logloss:0.68794
# [2]	validation_0-logloss:0.68553
# [3]	validation_0-logloss:0.68344
# [4]	validation_0-logloss:0.68152
# [5]	validation_0-logloss:0.67926
# [6]	validation_0-logloss:0.67695
# [7]	validation_0-logloss:0.67452
# [8]	validation_0-logloss:0.67217
# [9]	validation_0-logloss:0.67010
# [10]	validation_0-logloss:0.66796
# [11]	validation_0-logloss:0.66651
# [12]	validation_0-logloss:0.66472
# [13]	validation_0-logloss:0.66281
# [14]	validation_0-logloss:0.66091
# [15]	validation_0-logloss:0.65905
# [16]	validation_0-logloss:0.65718
# [17]	validation_0-logloss:0.65537
# [18]	validation_0-logloss:0.65364
# [19]	validation_0-logloss:0.65160
# [20]	validation_0-logloss:0.64981
# [21]	validation_0-logloss:0.64858
# [22]	validation_0-logloss:0.64691
# [23]	validation_0-logloss:0.64568
# [24]	validation_0-logloss:0.64409
# [25]	validation_0-logloss:0.64302
# [26]	validation_0-logloss:0.64153
# [27]	validation_0-logloss:0.64003
# [28]	validation_0-logloss:0.63886
# [29]	validation_0-logloss:0.63730
# [0]	validation_0-logloss:0.69058
# [1]	validation_0-logloss:0.68842
# [2]	validation_0-logloss:0.68609
# [3]	validation_0-logloss:0.68369
# [4]	validation_0-logloss:0.68159
# [5]	validation_0-logloss:0.67919
# [6]	validation_0-logloss:0.67672
# [7]	validation_0-logloss:0.67421
# [8]	validation_0-logloss:0.67186
# [9]	validation_0-logloss:0.66942
# [10]	validation_0-logloss:0.66700
# [11]	validation_0-logloss:0.66502
# [12]	validation_0-logloss:0.66304
# [13]	validation_0-logloss:0.66085
# [14]	validation_0-logloss:0.65874
# [15]	validation_0-logloss:0.65670
# [16]	validation_0-logloss:0.65495
# [17]	validation_0-logloss:0.65325
# [18]	validation_0-logloss:0.65140
# [19]	validation_0-logloss:0.64968
# [20]	validation_0-logloss:0.64797
# [21]	validation_0-logloss:0.64644
# [22]	validation_0-logloss:0.64452
# [23]	validation_0-logloss:0.64284
# [24]	validation_0-logloss:0.64112
# [25]	validation_0-logloss:0.63938
# [26]	validation_0-logloss:0.63768
# [27]	validation_0-logloss:0.63626
# [28]	validation_0-logloss:0.63479
# [29]	validation_0-logloss:0.63314
# [0]	validation_0-logloss:0.69109
# [1]	validation_0-logloss:0.68802
# [2]	validation_0-logloss:0.68535
# [3]	validation_0-logloss:0.68278
# [4]	validation_0-logloss:0.68050
# [5]	validation_0-logloss:0.67866
# [6]	validation_0-logloss:0.67667
# [7]	validation_0-logloss:0.67473
# [8]	validation_0-logloss:0.67250
# [9]	validation_0-logloss:0.67001
# [10]	validation_0-logloss:0.66824
# [11]	validation_0-logloss:0.66618
# [12]	validation_0-logloss:0.66349
# [13]	validation_0-logloss:0.66177
# [14]	validation_0-logloss:0.66017
# [15]	validation_0-logloss:0.65824
# [16]	validation_0-logloss:0.65691
# [17]	validation_0-logloss:0.65544
# [18]	validation_0-logloss:0.65363
# [19]	validation_0-logloss:0.65212
# [20]	validation_0-logloss:0.65045
# [21]	validation_0-logloss:0.64918
# [22]	validation_0-logloss:0.64796
# [23]	validation_0-logloss:0.64657
# [24]	validation_0-logloss:0.64519
# [25]	validation_0-logloss:0.64389
# [26]	validation_0-logloss:0.64285
# [27]	validation_0-logloss:0.64171
# [28]	validation_0-logloss:0.63995
# [29]	validation_0-logloss:0.63816
# [0]	validation_0-logloss:0.69061
# [1]	validation_0-logloss:0.68773
# [2]	validation_0-logloss:0.68539
# [3]	validation_0-logloss:0.68303
# [4]	validation_0-logloss:0.68110
# [5]	validation_0-logloss:0.67873
# [6]	validation_0-logloss:0.67636
# [7]	validation_0-logloss:0.67367
# [8]	validation_0-logloss:0.67136
# [9]	validation_0-logloss:0.66947
# [10]	validation_0-logloss:0.66730
# [11]	validation_0-logloss:0.66541
# [12]	validation_0-logloss:0.66337
# [13]	validation_0-logloss:0.66147
# [14]	validation_0-logloss:0.65958
# [15]	validation_0-logloss:0.65755
# [16]	validation_0-logloss:0.65584
# [17]	validation_0-logloss:0.65386
# [18]	validation_0-logloss:0.65226
# [19]	validation_0-logloss:0.65064
# [20]	validation_0-logloss:0.64927
# [21]	validation_0-logloss:0.64738
# [22]	validation_0-logloss:0.64593
# [23]	validation_0-logloss:0.64427
# [24]	validation_0-logloss:0.64285
# [25]	validation_0-logloss:0.64161
# [26]	validation_0-logloss:0.64032
# [27]	validation_0-logloss:0.63885
# [28]	validation_0-logloss:0.63761
# [29]	validation_0-logloss:0.63583
# [0]	validation_0-logloss:0.69132
# [1]	validation_0-logloss:0.68806
# [2]	validation_0-logloss:0.68543
# [3]	validation_0-logloss:0.68298
# [4]	validation_0-logloss:0.68102
# [5]	validation_0-logloss:0.67822
# [6]	validation_0-logloss:0.67544
# [7]	validation_0-logloss:0.67367
# [8]	validation_0-logloss:0.67208
# [9]	validation_0-logloss:0.66963
# [10]	validation_0-logloss:0.66831
# [11]	validation_0-logloss:0.66572
# [12]	validation_0-logloss:0.66307
# [13]	validation_0-logloss:0.66124
# [14]	validation_0-logloss:0.65908
# [15]	validation_0-logloss:0.65791
# [16]	validation_0-logloss:0.65597
# [17]	validation_0-logloss:0.65372
# [18]	validation_0-logloss:0.65141
# [19]	validation_0-logloss:0.64912
# [0]	validation_0-logloss:0.69063
# [1]	validation_0-logloss:0.68745
# [2]	validation_0-logloss:0.68461
# [3]	validation_0-logloss:0.68179
# [4]	validation_0-logloss:0.67876
# [5]	validation_0-logloss:0.67592
# [6]	validation_0-logloss:0.67312
# [7]	validation_0-logloss:0.67031
# [8]	validation_0-logloss:0.66744
# [9]	validation_0-logloss:0.66464
# [10]	validation_0-logloss:0.66193
# [11]	validation_0-logloss:0.65944
# [12]	validation_0-logloss:0.65731
# [13]	validation_0-logloss:0.65510
# [14]	validation_0-logloss:0.65299
# [15]	validation_0-logloss:0.65072
# [16]	validation_0-logloss:0.64890
# [17]	validation_0-logloss:0.64659
# [18]	validation_0-logloss:0.64426
# [19]	validation_0-logloss:0.64182
# [0]	validation_0-logloss:0.69051
# [1]	validation_0-logloss:0.68732
# [2]	validation_0-logloss:0.68403
# [3]	validation_0-logloss:0.68125
# [4]	validation_0-logloss:0.67807
# [5]	validation_0-logloss:0.67497
# [6]	validation_0-logloss:0.67219
# [7]	validation_0-logloss:0.66935
# [8]	validation_0-logloss:0.66700
# [9]	validation_0-logloss:0.66474
# [10]	validation_0-logloss:0.66231
# [11]	validation_0-logloss:0.65981
# [12]	validation_0-logloss:0.65715
# [13]	validation_0-logloss:0.65478
# [14]	validation_0-logloss:0.65228
# [15]	validation_0-logloss:0.64970
# [16]	validation_0-logloss:0.64816
# [17]	validation_0-logloss:0.64611
# [18]	validation_0-logloss:0.64438
# [19]	validation_0-logloss:0.64252
# [0]	validation_0-logloss:0.69140
# [1]	validation_0-logloss:0.68868
# [2]	validation_0-logloss:0.68560
# [3]	validation_0-logloss:0.68256
# [4]	validation_0-logloss:0.67906
# [5]	validation_0-logloss:0.67686
# [6]	validation_0-logloss:0.67492
# [7]	validation_0-logloss:0.67245
# [8]	validation_0-logloss:0.66900
# [9]	validation_0-logloss:0.66681
# [10]	validation_0-logloss:0.66479
# [11]	validation_0-logloss:0.66235
# [12]	validation_0-logloss:0.65984
# [13]	validation_0-logloss:0.65721
# [14]	validation_0-logloss:0.65535
# [15]	validation_0-logloss:0.65324
# [16]	validation_0-logloss:0.65162
# [17]	validation_0-logloss:0.64961
# [18]	validation_0-logloss:0.64716
# [19]	validation_0-logloss:0.64569
# [0]	validation_0-logloss:0.69086
# [1]	validation_0-logloss:0.68710
# [2]	validation_0-logloss:0.68396
# [3]	validation_0-logloss:0.68080
# [4]	validation_0-logloss:0.67792
# [5]	validation_0-logloss:0.67516
# [6]	validation_0-logloss:0.67224
# [7]	validation_0-logloss:0.66907
# [8]	validation_0-logloss:0.66684
# [9]	validation_0-logloss:0.66462
# [10]	validation_0-logloss:0.66195
# [11]	validation_0-logloss:0.65924
# [12]	validation_0-logloss:0.65675
# [13]	validation_0-logloss:0.65482
# [14]	validation_0-logloss:0.65277
# [15]	validation_0-logloss:0.65030
# [16]	validation_0-logloss:0.64832
# [17]	validation_0-logloss:0.64626
# [18]	validation_0-logloss:0.64359
# [19]	validation_0-logloss:0.64107
# [0]	validation_0-logloss:0.69707
# [1]	validation_0-logloss:0.69527
# [2]	validation_0-logloss:0.69390
# [3]	validation_0-logloss:0.69243
# [4]	validation_0-logloss:0.69073
# [5]	validation_0-logloss:0.68931
# [6]	validation_0-logloss:0.68770
# [7]	validation_0-logloss:0.68628
# [8]	validation_0-logloss:0.68439
# [9]	validation_0-logloss:0.68294
# [10]	validation_0-logloss:0.68162
# [11]	validation_0-logloss:0.68020
# [12]	validation_0-logloss:0.67862
# [13]	validation_0-logloss:0.67688
# [14]	validation_0-logloss:0.67554
# [15]	validation_0-logloss:0.67436
# [16]	validation_0-logloss:0.67287
# [17]	validation_0-logloss:0.67141
# [18]	validation_0-logloss:0.67002
# [19]	validation_0-logloss:0.66869
# [0]	validation_0-logloss:0.69732
# [1]	validation_0-logloss:0.69551
# [2]	validation_0-logloss:0.69330
# [3]	validation_0-logloss:0.69124
# [4]	validation_0-logloss:0.68918
# [5]	validation_0-logloss:0.68739
# [6]	validation_0-logloss:0.68575
# [7]	validation_0-logloss:0.68408
# [8]	validation_0-logloss:0.68218
# [9]	validation_0-logloss:0.68048
# [10]	validation_0-logloss:0.67832
# [11]	validation_0-logloss:0.67668
# [12]	validation_0-logloss:0.67529
# [13]	validation_0-logloss:0.67356
# [14]	validation_0-logloss:0.67200
# [15]	validation_0-logloss:0.67047
# [16]	validation_0-logloss:0.66894
# [17]	validation_0-logloss:0.66744
# [18]	validation_0-logloss:0.66588
# [19]	validation_0-logloss:0.66432
# [0]	validation_0-logloss:0.69720
# [1]	validation_0-logloss:0.69552
# [2]	validation_0-logloss:0.69366
# [3]	validation_0-logloss:0.69185
# [4]	validation_0-logloss:0.68966
# [5]	validation_0-logloss:0.68768
# [6]	validation_0-logloss:0.68624
# [7]	validation_0-logloss:0.68459
# [8]	validation_0-logloss:0.68270
# [9]	validation_0-logloss:0.68097
# [10]	validation_0-logloss:0.67900
# [11]	validation_0-logloss:0.67763
# [12]	validation_0-logloss:0.67587
# [13]	validation_0-logloss:0.67458
# [14]	validation_0-logloss:0.67307
# [15]	validation_0-logloss:0.67168
# [16]	validation_0-logloss:0.67008
# [17]	validation_0-logloss:0.66878
# [18]	validation_0-logloss:0.66731
# [19]	validation_0-logloss:0.66584
# [0]	validation_0-logloss:0.69695
# [1]	validation_0-logloss:0.69552
# [2]	validation_0-logloss:0.69359
# [3]	validation_0-logloss:0.69164
# [4]	validation_0-logloss:0.68972
# [5]	validation_0-logloss:0.68811
# [6]	validation_0-logloss:0.68649
# [7]	validation_0-logloss:0.68489
# [8]	validation_0-logloss:0.68326
# [9]	validation_0-logloss:0.68156
# [10]	validation_0-logloss:0.67991
# [11]	validation_0-logloss:0.67842
# [12]	validation_0-logloss:0.67652
# [13]	validation_0-logloss:0.67478
# [14]	validation_0-logloss:0.67326
# [15]	validation_0-logloss:0.67220
# [16]	validation_0-logloss:0.67068
# [17]	validation_0-logloss:0.66919
# [18]	validation_0-logloss:0.66760
# [19]	validation_0-logloss:0.66627
# [0]	validation_0-logloss:0.69664
# [1]	validation_0-logloss:0.69452
# [2]	validation_0-logloss:0.69267
# [3]	validation_0-logloss:0.69072
# [4]	validation_0-logloss:0.68872
# [5]	validation_0-logloss:0.68681
# [6]	validation_0-logloss:0.68533
# [7]	validation_0-logloss:0.68333
# [8]	validation_0-logloss:0.68157
# [9]	validation_0-logloss:0.67988
# [10]	validation_0-logloss:0.67802
# [11]	validation_0-logloss:0.67620
# [12]	validation_0-logloss:0.67418
# [13]	validation_0-logloss:0.67272
# [14]	validation_0-logloss:0.67145
# [15]	validation_0-logloss:0.66982
# [16]	validation_0-logloss:0.66816
# [17]	validation_0-logloss:0.66660
# [18]	validation_0-logloss:0.66476
# [19]	validation_0-logloss:0.66303
# [0]	validation_0-logloss:0.70696
# [1]	validation_0-logloss:0.70485
# [2]	validation_0-logloss:0.70307
# [3]	validation_0-logloss:0.70128
# [4]	validation_0-logloss:0.69924
# [5]	validation_0-logloss:0.69755
# [6]	validation_0-logloss:0.69558
# [7]	validation_0-logloss:0.69405
# [8]	validation_0-logloss:0.69228
# [9]	validation_0-logloss:0.69107
# [0]	validation_0-logloss:0.70744
# [1]	validation_0-logloss:0.70524
# [2]	validation_0-logloss:0.70297
# [3]	validation_0-logloss:0.70104
# [4]	validation_0-logloss:0.69892
# [5]	validation_0-logloss:0.69708
# [6]	validation_0-logloss:0.69520
# [7]	validation_0-logloss:0.69305
# [8]	validation_0-logloss:0.69107
# [9]	validation_0-logloss:0.68914
# [0]	validation_0-logloss:0.70760
# [1]	validation_0-logloss:0.70546
# [2]	validation_0-logloss:0.70339
# [3]	validation_0-logloss:0.70120
# [4]	validation_0-logloss:0.69883
# [5]	validation_0-logloss:0.69678
# [6]	validation_0-logloss:0.69473
# [7]	validation_0-logloss:0.69248
# [8]	validation_0-logloss:0.69056
# [9]	validation_0-logloss:0.68885
# [0]	validation_0-logloss:0.70649
# [1]	validation_0-logloss:0.70430
# [2]	validation_0-logloss:0.70197
# [3]	validation_0-logloss:0.69998
# [4]	validation_0-logloss:0.69826
# [5]	validation_0-logloss:0.69666
# [6]	validation_0-logloss:0.69507
# [7]	validation_0-logloss:0.69340
# [8]	validation_0-logloss:0.69176
# [9]	validation_0-logloss:0.68984
# [0]	validation_0-logloss:0.70641
# [1]	validation_0-logloss:0.70372
# [2]	validation_0-logloss:0.70144
# [3]	validation_0-logloss:0.69935
# [4]	validation_0-logloss:0.69733
# [5]	validation_0-logloss:0.69527
# [6]	validation_0-logloss:0.69310
# [7]	validation_0-logloss:0.69076
# [8]	validation_0-logloss:0.68869
# [9]	validation_0-logloss:0.68707
# [0]	validation_0-logloss:0.68966
# [1]	validation_0-logloss:0.68295
# [2]	validation_0-logloss:0.67730
# [3]	validation_0-logloss:0.67200
# [4]	validation_0-logloss:0.66725
# [5]	validation_0-logloss:0.66420
# [6]	validation_0-logloss:0.65908
# [7]	validation_0-logloss:0.65593
# [8]	validation_0-logloss:0.65350
# [9]	validation_0-logloss:0.65141
# [10]	validation_0-logloss:0.64730
# [11]	validation_0-logloss:0.64335
# [12]	validation_0-logloss:0.63911
# [13]	validation_0-logloss:0.63638
# [14]	validation_0-logloss:0.63284
# [15]	validation_0-logloss:0.63087
# [16]	validation_0-logloss:0.62692
# [17]	validation_0-logloss:0.62407
# [18]	validation_0-logloss:0.62130
# [19]	validation_0-logloss:0.61939
# [20]	validation_0-logloss:0.61584
# [21]	validation_0-logloss:0.61257
# [22]	validation_0-logloss:0.61045
# [23]	validation_0-logloss:0.60931
# [24]	validation_0-logloss:0.60674
# [25]	validation_0-logloss:0.60487
# [26]	validation_0-logloss:0.60351
# [27]	validation_0-logloss:0.60256
# [28]	validation_0-logloss:0.60128
# [29]	validation_0-logloss:0.60057
# [0]	validation_0-logloss:0.68961
# [1]	validation_0-logloss:0.68273
# [2]	validation_0-logloss:0.67599
# [3]	validation_0-logloss:0.67013
# [4]	validation_0-logloss:0.66426
# [5]	validation_0-logloss:0.65937
# [6]	validation_0-logloss:0.65410
# [7]	validation_0-logloss:0.64845
# [8]	validation_0-logloss:0.64406
# [9]	validation_0-logloss:0.63925
# [10]	validation_0-logloss:0.63487
# [11]	validation_0-logloss:0.63229
# [12]	validation_0-logloss:0.62802
# [13]	validation_0-logloss:0.62420
# [14]	validation_0-logloss:0.62062
# [15]	validation_0-logloss:0.61790
# [16]	validation_0-logloss:0.61364
# [17]	validation_0-logloss:0.61000
# [18]	validation_0-logloss:0.60789
# [19]	validation_0-logloss:0.60465
# [20]	validation_0-logloss:0.60171
# [21]	validation_0-logloss:0.59996
# [22]	validation_0-logloss:0.59715
# [23]	validation_0-logloss:0.59467
# [24]	validation_0-logloss:0.59185
# [25]	validation_0-logloss:0.59034
# [26]	validation_0-logloss:0.58773
# [27]	validation_0-logloss:0.58605
# [28]	validation_0-logloss:0.58338
# [29]	validation_0-logloss:0.58128
# [0]	validation_0-logloss:0.69002
# [1]	validation_0-logloss:0.68327
# [2]	validation_0-logloss:0.67692
# [3]	validation_0-logloss:0.67064
# [4]	validation_0-logloss:0.66445
# [5]	validation_0-logloss:0.65983
# [6]	validation_0-logloss:0.65463
# [7]	validation_0-logloss:0.64931
# [8]	validation_0-logloss:0.64566
# [9]	validation_0-logloss:0.64076
# [10]	validation_0-logloss:0.63638
# [11]	validation_0-logloss:0.63316
# [12]	validation_0-logloss:0.62889
# [13]	validation_0-logloss:0.62458
# [14]	validation_0-logloss:0.62065
# [15]	validation_0-logloss:0.61706
# [16]	validation_0-logloss:0.61476
# [17]	validation_0-logloss:0.61219
# [18]	validation_0-logloss:0.60931
# [19]	validation_0-logloss:0.60735
# [20]	validation_0-logloss:0.60387
# [21]	validation_0-logloss:0.60160
# [22]	validation_0-logloss:0.59926
# [23]	validation_0-logloss:0.59687
# [24]	validation_0-logloss:0.59537
# [25]	validation_0-logloss:0.59289
# [26]	validation_0-logloss:0.59080
# [27]	validation_0-logloss:0.58878
# [28]	validation_0-logloss:0.58624
# [29]	validation_0-logloss:0.58449
# [0]	validation_0-logloss:0.69044
# [1]	validation_0-logloss:0.68404
# [2]	validation_0-logloss:0.67708
# [3]	validation_0-logloss:0.67092
# [4]	validation_0-logloss:0.66615
# [5]	validation_0-logloss:0.66161
# [6]	validation_0-logloss:0.65726
# [7]	validation_0-logloss:0.65303
# [8]	validation_0-logloss:0.64641
# [9]	validation_0-logloss:0.64195
# [10]	validation_0-logloss:0.63856
# [11]	validation_0-logloss:0.63441
# [12]	validation_0-logloss:0.62933
# [13]	validation_0-logloss:0.62476
# [14]	validation_0-logloss:0.62084
# [15]	validation_0-logloss:0.61828
# [16]	validation_0-logloss:0.61470
# [17]	validation_0-logloss:0.61204
# [18]	validation_0-logloss:0.60920
# [19]	validation_0-logloss:0.60723
# [20]	validation_0-logloss:0.60479
# [21]	validation_0-logloss:0.60167
# [22]	validation_0-logloss:0.59950
# [23]	validation_0-logloss:0.59736
# [24]	validation_0-logloss:0.59512
# [25]	validation_0-logloss:0.59203
# [26]	validation_0-logloss:0.59003
# [27]	validation_0-logloss:0.58728
# [28]	validation_0-logloss:0.58518
# [29]	validation_0-logloss:0.58302
# [0]	validation_0-logloss:0.68906
# [1]	validation_0-logloss:0.68040
# [2]	validation_0-logloss:0.67354
# [3]	validation_0-logloss:0.66736
# [4]	validation_0-logloss:0.66188
# [5]	validation_0-logloss:0.65652
# [6]	validation_0-logloss:0.65085
# [7]	validation_0-logloss:0.64459
# [8]	validation_0-logloss:0.64075
# [9]	validation_0-logloss:0.63578
# ...
# [1]	validation_0-logloss:0.69885
# [2]	validation_0-logloss:0.69652
# [3]	validation_0-logloss:0.69401
# [4]	validation_0-logloss:0.69114
# [5]	validation_0-logloss:0.68892
# [6]	validation_0-logloss:0.68644
# [7]	validation_0-logloss:0.68471
# [8]	validation_0-logloss:0.68305
# [9]	validation_0-logloss:0.68124
# [10]	validation_0-logloss:0.67961
# [11]	validation_0-logloss:0.67729
# [12]	validation_0-logloss:0.67551
# [13]	validation_0-logloss:0.67369
# [14]	validation_0-logloss:0.67198
# [15]	validation_0-logloss:0.67063
# [16]	validation_0-logloss:0.66904
# [17]	validation_0-logloss:0.66699
# [18]	validation_0-logloss:0.66532
# [19]	validation_0-logloss:0.66333
# [20]	validation_0-logloss:0.66131
# [21]	validation_0-logloss:0.66044
# [22]	validation_0-logloss:0.65937
# [23]	validation_0-logloss:0.65803
# [24]	validation_0-logloss:0.65661
# [25]	validation_0-logloss:0.65572
# [26]	validation_0-logloss:0.65436
# [27]	validation_0-logloss:0.65331
# [28]	validation_0-logloss:0.65153
# [29]	validation_0-logloss:0.65049
# [0]	validation_0-logloss:0.70245
# [1]	validation_0-logloss:0.69977
# [2]	validation_0-logloss:0.69667
# [3]	validation_0-logloss:0.69387
# [4]	validation_0-logloss:0.69125
# [5]	validation_0-logloss:0.68865
# [6]	validation_0-logloss:0.68616
# [7]	validation_0-logloss:0.68393
# [8]	validation_0-logloss:0.68174
# [9]	validation_0-logloss:0.67918
# [10]	validation_0-logloss:0.67631
# [11]	validation_0-logloss:0.67396
# [12]	validation_0-logloss:0.67227
# [13]	validation_0-logloss:0.67007
# [14]	validation_0-logloss:0.66776
# [15]	validation_0-logloss:0.66534
# [16]	validation_0-logloss:0.66319
# [17]	validation_0-logloss:0.66106
# [18]	validation_0-logloss:0.65953
# [19]	validation_0-logloss:0.65737
# [20]	validation_0-logloss:0.65541
# [21]	validation_0-logloss:0.65370
# [22]	validation_0-logloss:0.65230
# [23]	validation_0-logloss:0.65044
# [24]	validation_0-logloss:0.64857
# [25]	validation_0-logloss:0.64727
# [26]	validation_0-logloss:0.64591
# [27]	validation_0-logloss:0.64443
# [28]	validation_0-logloss:0.64318
# [29]	validation_0-logloss:0.64144
# [0]	validation_0-logloss:0.70217
# [1]	validation_0-logloss:0.69903
# [2]	validation_0-logloss:0.69622
# [3]	validation_0-logloss:0.69344
# [4]	validation_0-logloss:0.69022
# [5]	validation_0-logloss:0.68726
# [6]	validation_0-logloss:0.68475
# [7]	validation_0-logloss:0.68246
# [8]	validation_0-logloss:0.68018
# [9]	validation_0-logloss:0.67755
# [10]	validation_0-logloss:0.67549
# [11]	validation_0-logloss:0.67324
# [12]	validation_0-logloss:0.67116
# [13]	validation_0-logloss:0.66879
# [14]	validation_0-logloss:0.66642
# [15]	validation_0-logloss:0.66426
# [16]	validation_0-logloss:0.66279
# [17]	validation_0-logloss:0.66095
# [18]	validation_0-logloss:0.65945
# [19]	validation_0-logloss:0.65781
# [20]	validation_0-logloss:0.65585
# [21]	validation_0-logloss:0.65398
# [22]	validation_0-logloss:0.65252
# [23]	validation_0-logloss:0.65078
# [24]	validation_0-logloss:0.64866
# [25]	validation_0-logloss:0.64659
# [26]	validation_0-logloss:0.64533
# [27]	validation_0-logloss:0.64393
# [28]	validation_0-logloss:0.64222
# [29]	validation_0-logloss:0.64050
# [0]	validation_0-logloss:0.70181
# [1]	validation_0-logloss:0.69946
# [2]	validation_0-logloss:0.69625
# [3]	validation_0-logloss:0.69309
# [4]	validation_0-logloss:0.68956
# [5]	validation_0-logloss:0.68754
# [6]	validation_0-logloss:0.68545
# [7]	validation_0-logloss:0.68333
# [8]	validation_0-logloss:0.68006
# [9]	validation_0-logloss:0.67774
# [10]	validation_0-logloss:0.67582
# [11]	validation_0-logloss:0.67364
# [12]	validation_0-logloss:0.67147
# [13]	validation_0-logloss:0.66925
# [14]	validation_0-logloss:0.66757
# [15]	validation_0-logloss:0.66561
# [16]	validation_0-logloss:0.66420
# [17]	validation_0-logloss:0.66253
# [18]	validation_0-logloss:0.66086
# [19]	validation_0-logloss:0.65951
# [20]	validation_0-logloss:0.65796
# [21]	validation_0-logloss:0.65627
# [22]	validation_0-logloss:0.65488
# [23]	validation_0-logloss:0.65332
# [24]	validation_0-logloss:0.65199
# [25]	validation_0-logloss:0.64980
# [26]	validation_0-logloss:0.64760
# [27]	validation_0-logloss:0.64628
# [28]	validation_0-logloss:0.64406
# [29]	validation_0-logloss:0.64210
# [0]	validation_0-logloss:0.70152
# [1]	validation_0-logloss:0.69839
# [2]	validation_0-logloss:0.69541
# [3]	validation_0-logloss:0.69239
# [4]	validation_0-logloss:0.68962
# [5]	validation_0-logloss:0.68701
# [6]	validation_0-logloss:0.68485
# [7]	validation_0-logloss:0.68192
# [8]	validation_0-logloss:0.67919
# [9]	validation_0-logloss:0.67711
# [10]	validation_0-logloss:0.67492
# [11]	validation_0-logloss:0.67247
# [12]	validation_0-logloss:0.66995
# [13]	validation_0-logloss:0.66818
# [14]	validation_0-logloss:0.66638
# [15]	validation_0-logloss:0.66414
# [16]	validation_0-logloss:0.66150
# [17]	validation_0-logloss:0.65972
# [18]	validation_0-logloss:0.65722
# [19]	validation_0-logloss:0.65531
# [20]	validation_0-logloss:0.65374
# [21]	validation_0-logloss:0.65132
# [22]	validation_0-logloss:0.64978
# [23]	validation_0-logloss:0.64809
# [24]	validation_0-logloss:0.64661
# [25]	validation_0-logloss:0.64480
# [26]	validation_0-logloss:0.64337
# [27]	validation_0-logloss:0.64177
# [28]	validation_0-logloss:0.64030
# [29]	validation_0-logloss:0.63840
# [0]	validation_0-logloss:0.69176
# [1]	validation_0-logloss:0.68862
# [2]	validation_0-logloss:0.68612
# [3]	validation_0-logloss:0.68370
# [4]	validation_0-logloss:0.68084
# [5]	validation_0-logloss:0.67860
# [6]	validation_0-logloss:0.67602
# [7]	validation_0-logloss:0.67446
# [8]	validation_0-logloss:0.67283
# [9]	validation_0-logloss:0.67116
# [10]	validation_0-logloss:0.66941
# [11]	validation_0-logloss:0.66698
# [12]	validation_0-logloss:0.66512
# [13]	validation_0-logloss:0.66338
# [14]	validation_0-logloss:0.66169
# [15]	validation_0-logloss:0.66053
# [16]	validation_0-logloss:0.65892
# [17]	validation_0-logloss:0.65689
# [18]	validation_0-logloss:0.65526
# [19]	validation_0-logloss:0.65322
# [20]	validation_0-logloss:0.65131
# [21]	validation_0-logloss:0.65033
# [22]	validation_0-logloss:0.64891
# [23]	validation_0-logloss:0.64744
# [24]	validation_0-logloss:0.64576
# [25]	validation_0-logloss:0.64496
# [26]	validation_0-logloss:0.64365
# [27]	validation_0-logloss:0.64253
# [28]	validation_0-logloss:0.64080
# [29]	validation_0-logloss:0.63995
# [0]	validation_0-logloss:0.69160
# [1]	validation_0-logloss:0.68863
# [2]	validation_0-logloss:0.68559
# [3]	validation_0-logloss:0.68286
# [4]	validation_0-logloss:0.68038
# [5]	validation_0-logloss:0.67753
# [6]	validation_0-logloss:0.67493
# [7]	validation_0-logloss:0.67237
# [8]	validation_0-logloss:0.66986
# [9]	validation_0-logloss:0.66750
# [10]	validation_0-logloss:0.66498
# [11]	validation_0-logloss:0.66267
# [12]	validation_0-logloss:0.66093
# [13]	validation_0-logloss:0.65864
# [14]	validation_0-logloss:0.65656
# [15]	validation_0-logloss:0.65442
# [16]	validation_0-logloss:0.65285
# [17]	validation_0-logloss:0.65075
# [18]	validation_0-logloss:0.64923
# [19]	validation_0-logloss:0.64683
# [20]	validation_0-logloss:0.64511
# [21]	validation_0-logloss:0.64326
# [22]	validation_0-logloss:0.64178
# [23]	validation_0-logloss:0.63990
# [24]	validation_0-logloss:0.63815
# [25]	validation_0-logloss:0.63713
# [26]	validation_0-logloss:0.63578
# [27]	validation_0-logloss:0.63433
# [28]	validation_0-logloss:0.63315
# [29]	validation_0-logloss:0.63134
# [0]	validation_0-logloss:0.69151
# [1]	validation_0-logloss:0.68834
# [2]	validation_0-logloss:0.68572
# [3]	validation_0-logloss:0.68316
# [4]	validation_0-logloss:0.68017
# [5]	validation_0-logloss:0.67718
# [6]	validation_0-logloss:0.67458
# [7]	validation_0-logloss:0.67225
# [8]	validation_0-logloss:0.66963
# [9]	validation_0-logloss:0.66695
# [10]	validation_0-logloss:0.66495
# [11]	validation_0-logloss:0.66275
# [12]	validation_0-logloss:0.66064
# [13]	validation_0-logloss:0.65835
# [14]	validation_0-logloss:0.65601
# [15]	validation_0-logloss:0.65356
# [16]	validation_0-logloss:0.65217
# [17]	validation_0-logloss:0.65045
# [18]	validation_0-logloss:0.64877
# [19]	validation_0-logloss:0.64684
# [20]	validation_0-logloss:0.64509
# [21]	validation_0-logloss:0.64324
# [22]	validation_0-logloss:0.64128
# [23]	validation_0-logloss:0.63956
# [24]	validation_0-logloss:0.63760
# [25]	validation_0-logloss:0.63579
# [26]	validation_0-logloss:0.63440
# [27]	validation_0-logloss:0.63307
# [28]	validation_0-logloss:0.63153
# [29]	validation_0-logloss:0.62987
# [0]	validation_0-logloss:0.69245
# [1]	validation_0-logloss:0.69011
# [2]	validation_0-logloss:0.68707
# [3]	validation_0-logloss:0.68393
# [4]	validation_0-logloss:0.68066
# [5]	validation_0-logloss:0.67870
# [6]	validation_0-logloss:0.67705
# [7]	validation_0-logloss:0.67491
# [8]	validation_0-logloss:0.67156
# [9]	validation_0-logloss:0.66912
# [10]	validation_0-logloss:0.66716
# [11]	validation_0-logloss:0.66499
# [12]	validation_0-logloss:0.66255
# [13]	validation_0-logloss:0.66020
# [14]	validation_0-logloss:0.65830
# [15]	validation_0-logloss:0.65648
# [16]	validation_0-logloss:0.65506
# [17]	validation_0-logloss:0.65329
# [18]	validation_0-logloss:0.65102
# [19]	validation_0-logloss:0.64970
# [20]	validation_0-logloss:0.64821
# [21]	validation_0-logloss:0.64660
# [22]	validation_0-logloss:0.64522
# [23]	validation_0-logloss:0.64377
# [24]	validation_0-logloss:0.64230
# [25]	validation_0-logloss:0.64026
# [26]	validation_0-logloss:0.63834
# [27]	validation_0-logloss:0.63722
# [28]	validation_0-logloss:0.63545
# [29]	validation_0-logloss:0.63399
# [0]	validation_0-logloss:0.69192
# [1]	validation_0-logloss:0.68858
# [2]	validation_0-logloss:0.68566
# [3]	validation_0-logloss:0.68271
# [4]	validation_0-logloss:0.67994
# [5]	validation_0-logloss:0.67736
# [6]	validation_0-logloss:0.67515
# [7]	validation_0-logloss:0.67223
# [8]	validation_0-logloss:0.66962
# [9]	validation_0-logloss:0.66753
# [10]	validation_0-logloss:0.66550
# [11]	validation_0-logloss:0.66286
# [12]	validation_0-logloss:0.66043
# [13]	validation_0-logloss:0.65877
# [14]	validation_0-logloss:0.65698
# [15]	validation_0-logloss:0.65482
# [16]	validation_0-logloss:0.65302
# [17]	validation_0-logloss:0.65132
# [18]	validation_0-logloss:0.64871
# [19]	validation_0-logloss:0.64657
# [20]	validation_0-logloss:0.64516
# [21]	validation_0-logloss:0.64277
# [22]	validation_0-logloss:0.64122
# [23]	validation_0-logloss:0.63947
# [24]	validation_0-logloss:0.63811
# [25]	validation_0-logloss:0.63655
# [26]	validation_0-logloss:0.63534
# [27]	validation_0-logloss:0.63386
# [28]	validation_0-logloss:0.63259
# [29]	validation_0-logloss:0.63088
# [0]	validation_0-logloss:0.72292
# [1]	validation_0-logloss:0.72058
# [2]	validation_0-logloss:0.71928
# [3]	validation_0-logloss:0.71736
# [4]	validation_0-logloss:0.71509
# [5]	validation_0-logloss:0.71318
# [6]	validation_0-logloss:0.71130
# [7]	validation_0-logloss:0.70943
# [8]	validation_0-logloss:0.70808
# [9]	validation_0-logloss:0.70715
# [10]	validation_0-logloss:0.70518
# [11]	validation_0-logloss:0.70310
# [12]	validation_0-logloss:0.70126
# [13]	validation_0-logloss:0.69978
# [14]	validation_0-logloss:0.69851
# [15]	validation_0-logloss:0.69708
# [16]	validation_0-logloss:0.69619
# [17]	validation_0-logloss:0.69470
# [18]	validation_0-logloss:0.69380
# [19]	validation_0-logloss:0.69224
# [20]	validation_0-logloss:0.69080
# [21]	validation_0-logloss:0.68905
# [22]	validation_0-logloss:0.68745
# [23]	validation_0-logloss:0.68637
# [24]	validation_0-logloss:0.68489
# [25]	validation_0-logloss:0.68368
# [26]	validation_0-logloss:0.68269
# [27]	validation_0-logloss:0.68151
# [28]	validation_0-logloss:0.68032
# [29]	validation_0-logloss:0.67947
# [0]	validation_0-logloss:0.72222
# [1]	validation_0-logloss:0.71980
# [2]	validation_0-logloss:0.71770
# [3]	validation_0-logloss:0.71573
# [4]	validation_0-logloss:0.71352
# [5]	validation_0-logloss:0.71168
# [6]	validation_0-logloss:0.70955
# [7]	validation_0-logloss:0.70735
# [8]	validation_0-logloss:0.70527
# [9]	validation_0-logloss:0.70360
# [10]	validation_0-logloss:0.70206
# [11]	validation_0-logloss:0.70012
# [12]	validation_0-logloss:0.69873
# [13]	validation_0-logloss:0.69706
# [14]	validation_0-logloss:0.69564
# [15]	validation_0-logloss:0.69408
# [16]	validation_0-logloss:0.69276
# [17]	validation_0-logloss:0.69141
# [18]	validation_0-logloss:0.68995
# [19]	validation_0-logloss:0.68813
# [20]	validation_0-logloss:0.68656
# [21]	validation_0-logloss:0.68494
# [22]	validation_0-logloss:0.68351
# [23]	validation_0-logloss:0.68273
# [24]	validation_0-logloss:0.68173
# [25]	validation_0-logloss:0.68055
# [26]	validation_0-logloss:0.67944
# [27]	validation_0-logloss:0.67802
# [28]	validation_0-logloss:0.67717
# [29]	validation_0-logloss:0.67570
# [0]	validation_0-logloss:0.72229
# [1]	validation_0-logloss:0.72017
# [2]	validation_0-logloss:0.71841
# [3]	validation_0-logloss:0.71650
# [4]	validation_0-logloss:0.71421
# [5]	validation_0-logloss:0.71207
# [6]	validation_0-logloss:0.71014
# [7]	validation_0-logloss:0.70839
# [8]	validation_0-logloss:0.70616
# [9]	validation_0-logloss:0.70409
# [10]	validation_0-logloss:0.70231
# [11]	validation_0-logloss:0.70076
# [12]	validation_0-logloss:0.69901
# [13]	validation_0-logloss:0.69710
# [14]	validation_0-logloss:0.69544
# [15]	validation_0-logloss:0.69369
# [16]	validation_0-logloss:0.69261
# [17]	validation_0-logloss:0.69144
# [18]	validation_0-logloss:0.68978
# [19]	validation_0-logloss:0.68757
# [20]	validation_0-logloss:0.68609
# [21]	validation_0-logloss:0.68456
# [22]	validation_0-logloss:0.68282
# [23]	validation_0-logloss:0.68112
# [24]	validation_0-logloss:0.67975
# [25]	validation_0-logloss:0.67848
# [26]	validation_0-logloss:0.67710
# [27]	validation_0-logloss:0.67611
# [28]	validation_0-logloss:0.67508
# [29]	validation_0-logloss:0.67359
# [0]	validation_0-logloss:0.72412
# [1]	validation_0-logloss:0.72168
# [2]	validation_0-logloss:0.71967
# [3]	validation_0-logloss:0.71776
# [4]	validation_0-logloss:0.71614
# [5]	validation_0-logloss:0.71471
# [6]	validation_0-logloss:0.71313
# [7]	validation_0-logloss:0.71105
# [8]	validation_0-logloss:0.70910
# [9]	validation_0-logloss:0.70768
# [10]	validation_0-logloss:0.70620
# [11]	validation_0-logloss:0.70415
# [12]	validation_0-logloss:0.70173
# [13]	validation_0-logloss:0.70018
# [14]	validation_0-logloss:0.69875
# [15]	validation_0-logloss:0.69744
# [16]	validation_0-logloss:0.69640
# [17]	validation_0-logloss:0.69521
# [18]	validation_0-logloss:0.69351
# [19]	validation_0-logloss:0.69223
# [20]	validation_0-logloss:0.69080
# [21]	validation_0-logloss:0.68963
# [22]	validation_0-logloss:0.68852
# [23]	validation_0-logloss:0.68746
# [24]	validation_0-logloss:0.68616
# [25]	validation_0-logloss:0.68439
# [26]	validation_0-logloss:0.68340
# [27]	validation_0-logloss:0.68189
# [28]	validation_0-logloss:0.68068
# [29]	validation_0-logloss:0.67913
# [0]	validation_0-logloss:0.72379
# [1]	validation_0-logloss:0.72177
# [2]	validation_0-logloss:0.71975
# [3]	validation_0-logloss:0.71760
# [4]	validation_0-logloss:0.71546
# [5]	validation_0-logloss:0.71348
# [6]	validation_0-logloss:0.71189
# [7]	validation_0-logloss:0.70967
# [8]	validation_0-logloss:0.70809
# [9]	validation_0-logloss:0.70628
# [10]	validation_0-logloss:0.70466
# [11]	validation_0-logloss:0.70255
# [12]	validation_0-logloss:0.70074
# [13]	validation_0-logloss:0.69958
# [14]	validation_0-logloss:0.69810
# [15]	validation_0-logloss:0.69664
# [16]	validation_0-logloss:0.69534
# [17]	validation_0-logloss:0.69396
# [18]	validation_0-logloss:0.69256
# [19]	validation_0-logloss:0.69116
# [20]	validation_0-logloss:0.68989
# [21]	validation_0-logloss:0.68810
# [22]	validation_0-logloss:0.68690
# [23]	validation_0-logloss:0.68555
# [24]	validation_0-logloss:0.68432
# [25]	validation_0-logloss:0.68293
# [26]	validation_0-logloss:0.68213
# [27]	validation_0-logloss:0.68119
# [28]	validation_0-logloss:0.68016
# [29]	validation_0-logloss:0.67881
# 100%|██████████| 35/35 [08:43<00:00, 14.96s/trial, best loss: -0.7447793672587415]
# Processing key: alpha, val: 17.62206383516034
# Processing key: colsample_bytree, val: 0.3611259083197948
# Processing key: gamma, val: 0.8569327117554759
# Processing key: lambda, val: 25.754070671202925
# Processing key: learning_rate, val: 0.02735709861424748
# Processing key: max_depth, val: 0
# Processing key: min_child_weight, val: 20.0
# Processing key: n_estimators, val: 2
# Processing key: scale_pos_weight, val: 1.3602083631835196
# Processing key: subsample, val: 0.5030785821721243
# {'alpha': 17.62206383516034, 'colsample_bytree': 0.3611259083197948, 'gamma': 0.8569327117554759, 'lambda': 25.754070671202925, 'learning_rate': 0.02735709861424748, 'max_depth': 1, 'min_child_weight': 20.0, 'n_estimators': 30, 'scale_pos_weight': 1.3602083631835196, 'subsample': 0.5030785821721243}

# %%
# Merge default and best params
xgb_optimized_params = {**xgb_default_params, **xgb_best_params}
print(xgb_optimized_params)

# Train the model using the optimized parameters
xgb = XGBClassifier(**xgb_optimized_params)
xgb.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(xgb, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(xgb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(xgb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'n_jobs': -1, 'alpha': 17.62206383516034, 'colsample_bytree': 0.3611259083197948, 'gamma': 0.8569327117554759, 'lambda': 25.754070671202925, 'learning_rate': 0.02735709861424748, 'max_depth': 1, 'min_child_weight': 20.0, 'n_estimators': 30, 'scale_pos_weight': 1.3602083631835196, 'subsample': 0.5030785821721243}
# Training Data Evaluation:
# {'Accuracy': 0.68, 'Precision': 0.62, 'Recall': 0.93, 'F1': 0.75}
#
# Validation Data Evaluation:
# {'Accuracy': 0.73, 'Precision': 0.72, 'Recall': 0.93, 'F1': 0.81}
#
# Test Data Evaluation:
# {'Accuracy': 0.66, 'Precision': 0.6, 'Recall': 0.97, 'F1': 0.74}

# %%
# Import necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.metrics import Metric, Precision, Recall

class F1Score(Metric):
    def __init__(self, name="f1_score", **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
        p = self.precision.result()
        r = self.recall.result()
        # Compute F1 Score
        self.f1.assign(2 * ((p * r) / (p + r + K.epsilon())))

    def result(self):
        return self.f1

    def reset_state(self):
        self.f1.assign(0.)
        self.precision.reset_state()
        self.recall.reset_state()


def optimize_hyperparams_mlp(space, X_train, y_train, X_val, y_val, enable_early_stopping=True, max_evals=25, random_state=72):

    def objective(params):
        try:
            # Build the model
            model = Sequential()
            model.add(Dense(params['hidden_layers'][0],
                            activation='relu',
                            input_dim=X_train.shape[1]))

            model.add(Dropout(params['dropout']))
            for units in params['hidden_layers'][1:]:
                model.add(Dense(units, activation='relu'))
                model.add(Dropout(params['dropout']))
            model.add(Dense(1, activation='sigmoid'))  # for binary classification

            if params['optimizer'] == 'adam':
                opt = Adam(learning_rate=params['learning_rate'])
            else:
                opt = SGD(learning_rate=params['learning_rate'])

            model.compile(optimizer=opt, loss='binary_crossentropy',
                          metrics=['accuracy', Precision(), Recall(), F1Score()])

            # Set early stopping
            if enable_early_stopping:
                callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
            else:
                callbacks = None

            # Train the model
            model.fit(X_train, y_train, epochs=35,
                      batch_size=int(params['batch_size']),
                      verbose=0, validation_data=(X_val, y_val),
                      callbacks=callbacks)

            # Evaluate the model
            _, accuracy, precision, recall, f1_val = model.evaluate(X_val, y_val, verbose=0)

            return -f1_val  # we want to maximize accuracy, hence the negative sign

        except Exception as e:
            print(f"Exception encountered: {e}")
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest,
                max_evals=max_evals, trials=trials)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
from hyperopt import hp
from hyperopt import Trials, fmin, tpe

# Define the space
mlp_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2),
    'batch_size': hp.choice('batch_size', [32, 64, 128, 256]),
    'hidden_layers': hp.choice('hidden_layers', [
        [16],
        [32],
        [64],
        [128],
        [16, 16],
        [32, 32],
        [64, 64],
        [128, 128],
        [128, 64],
        [64, 32],
        [32, 16],
        [128, 64, 32, 16],
        [128, 64, 32]
    ]),
    'optimizer': hp.choice('optimizer', ['adam', 'sgd']),
    'dropout': hp.uniform('dropout', 0, 0.5)
}

# Use the function
mlp_best_params = optimize_hyperparams_mlp(space=mlp_hyperparam_space,
                                           X_train=X_train_smote,
                                           y_train=y_train_smote,
                                           X_val=X_val, y_val=y_val,
                                           enable_early_stopping=True,
                                           max_evals=35)
print(mlp_best_params)
# Out:
# 100%|██████████| 35/35 [03:11<00:00,  5.48s/trial, best loss: -0.797385573387146]
# Processing key: batch_size, val: 2
# Processing key: dropout, val: 0.28713133139640845
# Processing key: hidden_layers, val: 9
# Processing key: learning_rate, val: 0.007921511632168036
# Processing key: optimizer, val: 0
# {'batch_size': 128, 'dropout': 0.28713133139640845, 'hidden_layers': [64, 32], 'learning_rate': 0.007921511632168036, 'optimizer': 'adam'}

# %%
# Evaluate the fitted pipeline
def evaluate_mlp(model, X, y):
    # Evaluate on given X
    _, accuracy, precision, recall, f1 = model.evaluate(X, y)

    # Return the values in a dictionary
    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD

model = Sequential()

hidden_layers = mlp_best_params['hidden_layers']

print(hidden_layers)
for units in hidden_layers:
    model.add(Dense(units, activation='relu'))
    model.add(Dropout(mlp_best_params['dropout']))


# Output layer
model.add(Dense(1, activation='sigmoid'))

# Determine optimizer based on the optimized parameters
if mlp_best_params['optimizer'] == 'adam':
    optimizer = Adam(learning_rate=mlp_best_params['learning_rate'])
elif mlp_best_params['optimizer'] == 'sgd':
    optimizer = SGD(learning_rate=mlp_best_params['learning_rate'])

callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall(), F1Score()])
model.fit(X_train_smote, y_train_smote,
          validation_data=(X_val, y_val),
          epochs=mlp_best_params.get('epochs', 40),
          batch_size=mlp_best_params['batch_size'],
          callbacks=callbacks)
# Out:
# [64, 32]
# Epoch 1/40
# 15/15 [==============================] - 3s 37ms/step - loss: 0.8677 - accuracy: 0.5184 - precision_78: 0.5181 - recall_78: 0.5268 - f1_score: 0.5224 - val_loss: 0.7005 - val_accuracy: 0.3904 - val_precision_78: 0.0000e+00 - val_recall_78: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 2/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.7099 - accuracy: 0.5068 - precision_78: 0.5077 - recall_78: 0.4470 - f1_score: 0.4754 - val_loss: 0.6950 - val_accuracy: 0.3904 - val_precision_78: 0.0000e+00 - val_recall_78: 0.0000e+00 - val_f1_score: 0.0000e+00
# Epoch 3/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6928 - accuracy: 0.5268 - precision_78: 0.5311 - recall_78: 0.4565 - f1_score: 0.4910 - val_loss: 0.6906 - val_accuracy: 0.6096 - val_precision_78: 0.6096 - val_recall_78: 1.0000 - val_f1_score: 0.7575
# Epoch 4/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6921 - accuracy: 0.5331 - precision_78: 0.5267 - recall_78: 0.6516 - f1_score: 0.5826 - val_loss: 0.6925 - val_accuracy: 0.4538 - val_precision_78: 0.8511 - val_recall_78: 0.1262 - val_f1_score: 0.2198
# Epoch 5/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6908 - accuracy: 0.5346 - precision_78: 0.5372 - recall_78: 0.4995 - f1_score: 0.5177 - val_loss: 0.6866 - val_accuracy: 0.6865 - val_precision_78: 0.6851 - val_recall_78: 0.8991 - val_f1_score: 0.7776
# Epoch 6/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6840 - accuracy: 0.5645 - precision_78: 0.5571 - recall_78: 0.6296 - f1_score: 0.5911 - val_loss: 0.6759 - val_accuracy: 0.6596 - val_precision_78: 0.8500 - val_recall_78: 0.5363 - val_f1_score: 0.6576
# Epoch 7/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6615 - accuracy: 0.6028 - precision_78: 0.6054 - recall_78: 0.5908 - f1_score: 0.5980 - val_loss: 0.6256 - val_accuracy: 0.7096 - val_precision_78: 0.6886 - val_recall_78: 0.9558 - val_f1_score: 0.8005
# Epoch 8/40
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6627 - accuracy: 0.5923 - precision_78: 0.5853 - recall_78: 0.6338 - f1_score: 0.6086 - val_loss: 0.6552 - val_accuracy: 0.6385 - val_precision_78: 0.9161 - val_recall_78: 0.4479 - val_f1_score: 0.6017
# Epoch 9/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6224 - accuracy: 0.6689 - precision_78: 0.6667 - recall_78: 0.6758 - f1_score: 0.6712 - val_loss: 0.6140 - val_accuracy: 0.7096 - val_precision_78: 0.8843 - val_recall_78: 0.6025 - val_f1_score: 0.7167
# Epoch 10/40
# 15/15 [==============================] - 0s 26ms/step - loss: 0.6372 - accuracy: 0.6563 - precision_78: 0.6345 - recall_78: 0.7377 - f1_score: 0.6822 - val_loss: 0.5760 - val_accuracy: 0.7135 - val_precision_78: 0.7819 - val_recall_78: 0.7350 - val_f1_score: 0.7577
# Epoch 11/40
# 15/15 [==============================] - 0s 26ms/step - loss: 0.6121 - accuracy: 0.6810 - precision_78: 0.6720 - recall_78: 0.7072 - f1_score: 0.6892 - val_loss: 0.5736 - val_accuracy: 0.7135 - val_precision_78: 0.8443 - val_recall_78: 0.6498 - val_f1_score: 0.7344
# Epoch 12/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6071 - accuracy: 0.6616 - precision_78: 0.6461 - recall_78: 0.7146 - f1_score: 0.6786 - val_loss: 0.5740 - val_accuracy: 0.7135 - val_precision_78: 0.8717 - val_recall_78: 0.6215 - val_f1_score: 0.7256
# Epoch 13/40
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6033 - accuracy: 0.6527 - precision_78: 0.6234 - recall_78: 0.7712 - f1_score: 0.6895 - val_loss: 0.6186 - val_accuracy: 0.6731 - val_precision_78: 0.9016 - val_recall_78: 0.5205 - val_f1_score: 0.6600
# Epoch 14/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5960 - accuracy: 0.6611 - precision_78: 0.6574 - recall_78: 0.6726 - f1_score: 0.6649 - val_loss: 0.5437 - val_accuracy: 0.7135 - val_precision_78: 0.8206 - val_recall_78: 0.6782 - val_f1_score: 0.7427
# Epoch 15/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5970 - accuracy: 0.6527 - precision_78: 0.6136 - recall_78: 0.8248 - f1_score: 0.7037 - val_loss: 0.5295 - val_accuracy: 0.7365 - val_precision_78: 0.7500 - val_recall_78: 0.8517 - val_f1_score: 0.7976
# Epoch 16/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6275 - accuracy: 0.6259 - precision_78: 0.6095 - recall_78: 0.7009 - f1_score: 0.6520 - val_loss: 0.5708 - val_accuracy: 0.7038 - val_precision_78: 0.8300 - val_recall_78: 0.6467 - val_f1_score: 0.7270
# Epoch 17/40
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6167 - accuracy: 0.6511 - precision_78: 0.6851 - recall_78: 0.5593 - f1_score: 0.6158 - val_loss: 0.5264 - val_accuracy: 0.7135 - val_precision_78: 0.7609 - val_recall_78: 0.7729 - val_f1_score: 0.7668
# Epoch 18/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6233 - accuracy: 0.6322 - precision_78: 0.7121 - recall_78: 0.4439 - f1_score: 0.5469 - val_loss: 0.5759 - val_accuracy: 0.7019 - val_precision_78: 0.8491 - val_recall_78: 0.6215 - val_f1_score: 0.7177
# Epoch 19/40
# 15/15 [==============================] - 0s 10ms/step - loss: 0.6054 - accuracy: 0.6537 - precision_78: 0.7170 - recall_78: 0.5079 - f1_score: 0.5946 - val_loss: 0.5362 - val_accuracy: 0.7404 - val_precision_78: 0.7407 - val_recall_78: 0.8833 - val_f1_score: 0.8058
# Epoch 20/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6029 - accuracy: 0.6495 - precision_78: 0.7162 - recall_78: 0.4953 - f1_score: 0.5856 - val_loss: 0.5526 - val_accuracy: 0.7173 - val_precision_78: 0.8320 - val_recall_78: 0.6719 - val_f1_score: 0.7435
# Epoch 21/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6011 - accuracy: 0.6501 - precision_78: 0.7200 - recall_78: 0.4911 - f1_score: 0.5839 - val_loss: 0.5371 - val_accuracy: 0.7250 - val_precision_78: 0.8199 - val_recall_78: 0.7035 - val_f1_score: 0.7572
# Epoch 22/40
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6037 - accuracy: 0.6411 - precision_78: 0.7307 - recall_78: 0.4470 - f1_score: 0.5547 - val_loss: 0.5409 - val_accuracy: 0.7096 - val_precision_78: 0.8144 - val_recall_78: 0.6782 - val_f1_score: 0.7401

# %%
# Evaluate the trained model
train_results = {}
train_results = evaluate_mlp(model, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

validation_results = evaluate_mlp(model, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

test_results = evaluate_mlp(model, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# 60/60 [==============================] - 0s 6ms/step - loss: 0.5477 - accuracy: 0.7219 - precision_78: 0.7248 - recall_78: 0.7156 - f1_score: 0.7202
# Training Data Evaluation:
# {'Accuracy': 0.721930742263794, 'Precision': 0.724760890007019, 'Recall': 0.715634822845459, 'F1': 0.7201688885688782}
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5409 - accuracy: 0.7096 - precision_78: 0.8144 - recall_78: 0.6782 - f1_score: 0.7401
#
# Validation Data Evaluation:
# {'Accuracy': 0.7096154093742371, 'Precision': 0.814393937587738, 'Recall': 0.6782334446907043, 'F1': 0.7401032447814941}
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5649 - accuracy: 0.7067 - precision_78: 0.7039 - recall_78: 0.7133 - f1_score: 0.7086
#
# Test Data Evaluation:
# {'Accuracy': 0.7066666483879089, 'Precision': 0.7039473652839661, 'Recall': 0.7133333086967468, 'F1': 0.7086092233657837}
