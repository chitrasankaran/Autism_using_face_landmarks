# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ## Configure Project Path and other paths

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
proj_path = '/content/drive/MyDrive/Magnimind/Face_detection/MP'
os.chdir(proj_path)

# %%
train_csv_path = os.path.join(proj_path, 'train_3D.csv')
test_csv_path = os.path.join(proj_path, 'test_3D.csv')

# %% [markdown]
# ## Read data from csv to pandas dataframe

# %%
train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        839  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        825  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        817  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...        845  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        844  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.511593      0.709910     -0.040127      0.517181      0.670308
# 1      0.566339      0.733220     -0.065258      0.575596      0.677747
# 2      0.437217      0.744490     -0.077209      0.426740      0.685478
# 3      0.533727      0.797597     -0.053682      0.549781      0.762331
# 4      0.524054      0.774706     -0.052582      0.505436      0.710976
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.168715      0.515403  ...       -0.057532        0.587559
# 1     -0.127426      0.568713  ...        0.001300        0.609449
# 2     -0.165941      0.433244  ...       -0.018598        0.488665
# 3     -0.169223      0.540980  ...       -0.035548        0.601406
# 4     -0.152662      0.512779  ...       -0.039194        0.528307
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.500262       -0.077599        0.768636        0.474503
# 1        0.556148       -0.015839        0.738344        0.541875
# 2        0.551752       -0.038808        0.656447        0.535078
# 3        0.623819       -0.057016        0.766676        0.603243
# 4        0.568924       -0.058087        0.683886        0.525732
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0       -0.021161        0.784336        0.468965       -0.021392
# 1        0.039996        0.751471        0.531839        0.042270
# 2        0.003090        0.674554        0.525373        0.003349
# 3        0.013871        0.782729        0.596054        0.015662
# 4       -0.016595        0.697740        0.517121       -0.017281
#
# [5 rows x 1407 columns]

# %%
test_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        100  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        108  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        106  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...          1  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        103  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# 0      0.727391      0.710138     -0.117875      0.753489      0.581854
# 1      0.457443      0.710929     -0.091133      0.437796      0.633989
# 2      0.452099      0.779923     -0.042830      0.453784      0.726497
# 3      0.457504      0.754957     -0.085740      0.470419      0.687706
# 4      0.362426      0.740446     -0.046425      0.366750      0.668341
#
#    landmark_1_z  landmark_2_x  ...  landmark_464_z  landmark_465_x  \
# 0     -0.193980      0.723864  ...        0.048919        0.737665
# 1     -0.193647      0.445459  ...       -0.020685        0.482040
# 2     -0.181251      0.455887  ...       -0.063696        0.546055
# 3     -0.211908      0.467041  ...       -0.034361        0.565713
# 4     -0.156865      0.372543  ...       -0.048113        0.491366
#
#    landmark_465_y  landmark_465_z  landmark_466_x  landmark_466_y  \
# 0        0.421433        0.016144        0.890724        0.401811
# 1        0.471925       -0.044690        0.660659        0.437236
# 2        0.521134       -0.084867        0.749610        0.499630
# 3        0.535771       -0.059295        0.783299        0.529403
# 4        0.545638       -0.066218        0.686309        0.559731
#
#    landmark_466_z  landmark_467_x  landmark_467_y  landmark_467_z
# 0        0.169311        0.903891        0.394724        0.177334
# 1        0.013672        0.679693        0.424461        0.015152
# 2       -0.035831        0.771000        0.490222       -0.036383
# 3        0.008190        0.804902        0.522787        0.009052
# 4       -0.032427        0.705237        0.556214       -0.034047
#
# [5 rows x 1407 columns]

# %%
train_df['label'].value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %%
test_df['label'].value_counts()
# Out:
# Autistic        150
# Non_Autistic    150
# Name: label, dtype: int64

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_0_z, landmark_1_x, landmark_1_y, landmark_1_z, landmark_2_x, landmark_2_y, landmark_2_z, landmark_3_x, landmark_3_y, landmark_3_z, landmark_4_x, landmark_4_y, landmark_4_z, landmark_5_x, landmark_5_y, landmark_5_z, landmark_6_x, landmark_6_y, landmark_6_z, landmark_7_x, landmark_7_y, landmark_7_z, landmark_8_x, landmark_8_y, landmark_8_z, landmark_9_x, landmark_9_y, landmark_9_z, landmark_10_x, landmark_10_y, landmark_10_z, landmark_11_x, landmark_11_y, landmark_11_z, landmark_12_x, landmark_12_y, landmark_12_z, landmark_13_x, landmark_13_y, landmark_13_z, landmark_14_x, landmark_14_y, landmark_14_z, landmark_15_x, landmark_15_y, landmark_15_z, landmark_16_x, landmark_16_y, landmark_16_z, landmark_17_x, landmark_17_y, landmark_17_z, landmark_18_x, landmark_18_y, landmark_18_z, landmark_19_x, landmark_19_y, landmark_19_z, landmark_20_x, landmark_20_y, landmark_20_z, landmark_21_x, landmark_21_y, landmark_21_z, landmark_22_x, landmark_22_y, landmark_22_z, landmark_23_x, landmark_23_y, landmark_23_z, landmark_24_x, landmark_24_y, landmark_24_z, landmark_25_x, landmark_25_y, landmark_25_z, landmark_26_x, landmark_26_y, landmark_26_z, landmark_27_x, landmark_27_y, landmark_27_z, landmark_28_x, landmark_28_y, landmark_28_z, landmark_29_x, landmark_29_y, landmark_29_z, landmark_30_x, landmark_30_y, landmark_30_z, landmark_31_x, landmark_31_y, landmark_31_z, landmark_32_x, ...]
# Index: []
#
# [0 rows x 1407 columns]

# %% [markdown]
# ## Setting input features and output features

# %%
X = train_df['img_path']
y = train_df['label']

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
#y = y.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, stratify=y, shuffle=True, random_state=72)

# %%
X_test = test_df['img_path']
y_test = test_df['label']
#y_test = y_test.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
# Initializing random_state
random_state = 72
seed = 72

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import os
import random
from PIL import Image
from skimage import io, filters
from scipy import ndimage
import tensorflow as tf
from keras.applications.vgg19 import VGG19, preprocess_input
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

# %%
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Input shape required by VGG19
IMAGE_WIDTH=512
IMAGE_HEIGHT=512
IMAGE_CHANNELS=3
INP_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
IMAGE_SIZE=(IMAGE_HEIGHT, IMAGE_WIDTH)
BATCH_SIZE = 64

# %%
# Load the VGG19 model without the top classification layers
vgg_model = VGG19(weights='imagenet', include_top=False, input_shape=INP_SHAPE)

# Freeze the layers of VGG19 model to not train them during the fine-tuning
for layer in vgg_model.layers:
    layer.trainable = False

# Create a new top model to put on top of the VGG19
x = vgg_model.output
x = Flatten()(x)  # Flatten the output of the conv layers

x = Dense(128)(x)
x = Activation('relu')(x)
x = Dropout(0.7)(x)

# Add a final output layer for binary classification with a sigmoid activation
predictions = Dense(1, activation='sigmoid')(x)

# This is the new model we will train
model = Model(inputs=vgg_model.input, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 512, 512, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 512, 512, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 256, 256, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 256, 256, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 256, 256, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 128, 128, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 128, 128, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_conv4 (Conv2D)       (None, 128, 128, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 64, 64, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36801857 (140.39 MB)
# Trainable params: 16777473 (64.00 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
vggmodel_weights_filepath = 'vggmodel_best_debug_2.hdf5'
if os.path.exists(vggmodel_weights_filepath):
    model.load_weights(vggmodel_weights_filepath)

# %%
from keras.optimizers import Adam
# Set a custom learning rate
learning_rate = 0.0001

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=learning_rate),
              loss="binary_crossentropy",
              metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall'),
                       ])

# %%
callbacks = []

# Saving checkpoints
checkpoint = ModelCheckpoint(vggmodel_weights_filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='min')
callbacks.append(checkpoint)

# Define early_stopping.
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=8,
                               verbose=1,
                               restore_best_weights=True)
callbacks.append(early_stopping)

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=5)
callbacks.append(reduce_lr)

# %%
#set a seed
seed = 72
np.random.seed(seed)

# %%
# Concatenate X_train and y_train
train_df = pd.concat([X_train, y_train], axis=1)
# Concatenate X_val and y_val
val_df = pd.concat([X_val, y_val], axis=1)
# Concatenate X_test and y_test
test_df = pd.concat([X_test, y_test], axis=1)

# %%
# Data augmentation and preprocessing
def apply_data_augmentation(df, batch_size=32):

    datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                 rotation_range=15,
                                 brightness_range=[0.6, 1.0],
                                 horizontal_flip=True)

    image_generator = datagen.flow_from_dataframe(dataframe=df,
                                                  x_col='img_path',
                                                  y_col='label',
                                                  seed=seed,
                                                  # all images will be resized to configured target size,
                                                  target_size=IMAGE_SIZE,
                                                  batch_size=batch_size, # Default 32 images from this label
                                                  #interpolation='bicubic',
                                                  class_mode=None, # Setting this to None as we are doing class-wise augmentation.
                                                  )

    return image_generator

# %%
# Filter autistic class images.
autistic_df = train_df[train_df['label'] == 'Autistic']
non_autistic_df = train_df[train_df['label'] == 'Non_Autistic']

# %%
autistic_train_generator = apply_data_augmentation(autistic_df, batch_size=BATCH_SIZE//2)
non_autistic_train_generator = apply_data_augmentation(non_autistic_df, batch_size=BATCH_SIZE//2)
# Out:
# Found 1079 validated image filenames.
# Found 689 validated image filenames.

# %%
def visualize_batch(image_generator, labels_included=False,
                    num_rows=4, num_cols=8,
                    bgr_to_rgb=False, reverse_preprocess=False):

    if labels_included:
        images, labels = next(image_generator)
    else:
        images = next(image_generator)

    if reverse_preprocess:
        # The mean values for VGG16 trained on ImageNet data
        mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)

        # The preprocess_input for VGG16 subtracts the mean of each channel.
        # Add the mean to their corresponding channels
        images += mean.reshape((1, 1, 1, 3))


    if bgr_to_rgb: # VGG16 preprocess_input changes RGB images to BGR images.
        images = images[..., ::-1]  # Convert BGR to RGB

    # Initialize a grid for the images
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
    axes = axes.flatten()

    for i in range(num_rows * num_cols):
        # Check if the index is within the batch size
        if i < images.shape[0]:
            img = images[i]
            # Clip and convert to uint8
            img = np.clip(img, 0, 255).astype('uint8')

            if labels_included:
                label = "Autistic" if labels[i] == 1 else "Non_Autistic"
                axes[i].set_title(f'Label: {label}')

            axes[i].imshow(img)
            axes[i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
# Visualizing the autistic images in BGR format
visualize_batch(autistic_train_generator)

# %%
visualize_batch(non_autistic_train_generator)

# %%
def combined_generator(autistic_generator, non_autistic_generator):
    while True:
        # Get a batch of images from the autistic_generator
        autistic_batch_x = next(autistic_generator)
        autistic_generator_filenames = autistic_generator.filenames

        # Get the batch size
        autistic_batch_size = autistic_batch_x.shape[0]
        # Autistic image labels are 1
        autistic_batch_y = np.ones((autistic_batch_size, 1))


        # Get a batch of images from the non-autistic generator
        non_autistic_batch_x = next(non_autistic_generator)
        non_autistic_generator_filenames = non_autistic_generator.filenames

        # Get the batch size
        non_autistic_batch_size = non_autistic_batch_x.shape[0]
        # Non-autistic image labels are 0
        non_autistic_batch_y = np.zeros((non_autistic_batch_size, 1))

        # Combine the batches
        batch_x = np.vstack((autistic_batch_x, non_autistic_batch_x))
        batch_y = np.vstack((autistic_batch_y, non_autistic_batch_y))
        batch_filenames = autistic_generator_filenames + non_autistic_generator_filenames

        # Shuffle the combined batch to avoid sequence of autistic and non-autistic images.
        # Total batch size should be 64
        indices = np.random.permutation(batch_x.shape[0])
        batch_x = batch_x[indices]
        batch_y = batch_y[indices]
        batch_filenames = [batch_filenames[i] for i in indices]

        yield batch_x, batch_y

# Combine the two generators
train_generator = combined_generator(autistic_train_generator,
                                     non_autistic_train_generator)

# %%
visualize_batch(train_generator,
                labels_included=True,
                num_rows=8,
                num_cols=8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
label_names = ['Non_Autistic', 'Autistic']

# %%
# preprocess_input from VGG
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_generator = val_datagen.flow_from_dataframe(dataframe=val_df,
                                                x_col='img_path',
                                                y_col='label',
                                                seed=seed,
                                                # all images will be resized to configured target size,
                                                target_size=IMAGE_SIZE,
                                                batch_size=BATCH_SIZE,
                                                classes=label_names,
                                                class_mode='binary',
                                                )
# Out:
# Found 312 validated image filenames belonging to 2 classes.

# %%
# preprocess_input from VGG
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_generator = test_datagen.flow_from_dataframe(dataframe=test_df,
                                                  x_col='img_path',
                                                  y_col='label',
                                                  seed=seed,
                                                  # all images will be resized to configured target size,
                                                  target_size=IMAGE_SIZE,
                                                  batch_size=BATCH_SIZE,
                                                  class_mode='binary',
                                                  classes=label_names,
                                                  shuffle=False
                                                )
# Out:
# Found 300 validated image filenames belonging to 2 classes.

# %%
label_names
# Out:
# ['Non_Autistic', 'Autistic']

# %%
y_train.value_counts()
# Out:
# Autistic        1079
# Non_Autistic     689
# Name: label, dtype: int64

# %%
from sklearn.utils import class_weight

# Compute class weight
weights = class_weight.compute_class_weight('balanced', classes=label_names, y=y_train)

class_weight_dict = {i: weight for i, weight in enumerate(weights)}
class_weight_dict
# Out:
# {0: 1.2830188679245282, 1: 0.8192771084337349}

# %%
history = model.fit(train_generator,
                    steps_per_epoch=BATCH_SIZE,
                    epochs=100,
                    callbacks=callbacks,
                    class_weight=class_weight_dict,
                    validation_data=val_generator,
                    validation_steps=len(val_generator))
# Out:
# Epoch 1/100
# 64/64 [==============================] - ETA: 0s - loss: 1.0997 - accuracy: 0.6400 - precision: 0.7317 - recall: 0.4522
# Epoch 1: val_loss improved from inf to 0.49483, saving model to vggmodel_best_debug_2.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 64/64 [==============================] - 1176s 18s/step - loss: 1.0997 - accuracy: 0.6400 - precision: 0.7317 - recall: 0.4522 - val_loss: 0.4948 - val_accuracy: 0.7500 - val_precision: 0.9380 - val_recall: 0.6335 - lr: 1.0000e-04
# Epoch 2/100
# 64/64 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7596 - precision: 0.8118 - recall: 0.6778
# Epoch 2: val_loss improved from 0.49483 to 0.45676, saving model to vggmodel_best_debug_2.hdf5
# 64/64 [==============================] - 359s 6s/step - loss: 0.4700 - accuracy: 0.7596 - precision: 0.8118 - recall: 0.6778 - val_loss: 0.4568 - val_accuracy: 0.8173 - val_precision: 0.9295 - val_recall: 0.7592 - lr: 1.0000e-04
# Epoch 3/100
# 64/64 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 0.8051 - precision: 0.8403 - recall: 0.7567
# Epoch 3: val_loss improved from 0.45676 to 0.41911, saving model to vggmodel_best_debug_2.hdf5
# 64/64 [==============================] - 367s 6s/step - loss: 0.4138 - accuracy: 0.8051 - precision: 0.8403 - recall: 0.7567 - val_loss: 0.4191 - val_accuracy: 0.8173 - val_precision: 0.9351 - val_recall: 0.7539 - lr: 1.0000e-04
# Epoch 4/100
# 64/64 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.8433 - precision: 0.8836 - recall: 0.7931
# Epoch 4: val_loss improved from 0.41911 to 0.40591, saving model to vggmodel_best_debug_2.hdf5
# 64/64 [==============================] - 359s 6s/step - loss: 0.3422 - accuracy: 0.8433 - precision: 0.8836 - recall: 0.7931 - val_loss: 0.4059 - val_accuracy: 0.8237 - val_precision: 0.9250 - val_recall: 0.7749 - lr: 1.0000e-04
# Epoch 5/100
# 64/64 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8636 - precision: 0.8874 - recall: 0.8350
# Epoch 5: val_loss improved from 0.40591 to 0.38059, saving model to vggmodel_best_debug_2.hdf5
# 64/64 [==============================] - 372s 6s/step - loss: 0.3161 - accuracy: 0.8636 - precision: 0.8874 - recall: 0.8350 - val_loss: 0.3806 - val_accuracy: 0.8558 - val_precision: 0.9398 - val_recall: 0.8168 - lr: 1.0000e-04
# Epoch 6/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.8849 - precision: 0.9028 - recall: 0.8645
# Epoch 6: val_loss did not improve from 0.38059
# 64/64 [==============================] - 368s 6s/step - loss: 0.2788 - accuracy: 0.8849 - precision: 0.9028 - recall: 0.8645 - val_loss: 0.4389 - val_accuracy: 0.8269 - val_precision: 0.9363 - val_recall: 0.7696 - lr: 1.0000e-04
# Epoch 7/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2587 - accuracy: 0.8854 - precision: 0.9071 - recall: 0.8606
# Epoch 7: val_loss did not improve from 0.38059
# 64/64 [==============================] - 366s 6s/step - loss: 0.2587 - accuracy: 0.8854 - precision: 0.9071 - recall: 0.8606 - val_loss: 0.4236 - val_accuracy: 0.8365 - val_precision: 0.9430 - val_recall: 0.7801 - lr: 1.0000e-04
# Epoch 8/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9050 - precision: 0.9174 - recall: 0.8916
# Epoch 8: val_loss improved from 0.38059 to 0.31003, saving model to vggmodel_best_debug_2.hdf5
# 64/64 [==============================] - 362s 6s/step - loss: 0.2345 - accuracy: 0.9050 - precision: 0.9174 - recall: 0.8916 - val_loss: 0.3100 - val_accuracy: 0.8558 - val_precision: 0.8925 - val_recall: 0.8691 - lr: 1.0000e-04
# Epoch 9/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2060 - accuracy: 0.9159 - precision: 0.9320 - recall: 0.8985
# Epoch 9: val_loss did not improve from 0.31003
# 64/64 [==============================] - 343s 5s/step - loss: 0.2060 - accuracy: 0.9159 - precision: 0.9320 - recall: 0.8985 - val_loss: 0.3986 - val_accuracy: 0.8462 - val_precision: 0.9231 - val_recall: 0.8168 - lr: 1.0000e-04
# Epoch 10/100
# 64/64 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9149 - precision: 0.9257 - recall: 0.9039
# Epoch 10: val_loss did not improve from 0.31003
# 64/64 [==============================] - 374s 6s/step - loss: 0.2088 - accuracy: 0.9149 - precision: 0.9257 - recall: 0.9039 - val_loss: 0.4107 - val_accuracy: 0.8526 - val_precision: 0.9096 - val_recall: 0.8429 - lr: 1.0000e-04
# Epoch 11/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9224 - precision: 0.9312 - recall: 0.9133
# Epoch 11: val_loss did not improve from 0.31003
# 64/64 [==============================] - 353s 6s/step - loss: 0.1777 - accuracy: 0.9224 - precision: 0.9312 - recall: 0.9133 - val_loss: 0.4326 - val_accuracy: 0.8654 - val_precision: 0.9306 - val_recall: 0.8429 - lr: 1.0000e-04
# Epoch 12/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9301 - precision: 0.9414 - recall: 0.9182
# Epoch 12: val_loss did not improve from 0.31003
# 64/64 [==============================] - 355s 6s/step - loss: 0.1634 - accuracy: 0.9301 - precision: 0.9414 - recall: 0.9182 - val_loss: 0.3714 - val_accuracy: 0.8782 - val_precision: 0.9180 - val_recall: 0.8796 - lr: 1.0000e-04
# Epoch 13/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1770 - accuracy: 0.9323 - precision: 0.9416 - recall: 0.9222
# Epoch 13: val_loss did not improve from 0.31003
# 64/64 [==============================] - 361s 6s/step - loss: 0.1770 - accuracy: 0.9323 - precision: 0.9416 - recall: 0.9222 - val_loss: 0.4385 - val_accuracy: 0.8654 - val_precision: 0.9257 - val_recall: 0.8482 - lr: 1.0000e-04
# Epoch 14/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9407 - precision: 0.9520 - recall: 0.9291
# Epoch 14: val_loss did not improve from 0.31003
# 64/64 [==============================] - 358s 6s/step - loss: 0.1403 - accuracy: 0.9407 - precision: 0.9520 - recall: 0.9291 - val_loss: 0.4164 - val_accuracy: 0.8718 - val_precision: 0.9218 - val_recall: 0.8639 - lr: 1.0000e-05
# Epoch 15/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9405 - precision: 0.9488 - recall: 0.9320
# Epoch 15: val_loss did not improve from 0.31003
# 64/64 [==============================] - 358s 6s/step - loss: 0.1376 - accuracy: 0.9405 - precision: 0.9488 - recall: 0.9320 - val_loss: 0.4220 - val_accuracy: 0.8686 - val_precision: 0.9167 - val_recall: 0.8639 - lr: 1.0000e-05
# Epoch 16/100
# 64/64 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9420 - precision: 0.9490 - recall: 0.9350
# Epoch 16: val_loss did not improve from 0.31003
# Restoring model weights from the end of the best epoch: 8.
# 64/64 [==============================] - 369s 6s/step - loss: 0.1313 - accuracy: 0.9420 - precision: 0.9490 - recall: 0.9350 - val_loss: 0.4074 - val_accuracy: 0.8782 - val_precision: 0.9180 - val_recall: 0.8796 - lr: 1.0000e-05
# Epoch 16: early stopping

# %%
model.load_weights("vggmodel_best_debug_2.hdf5")

# %%
# Plot the loss curve
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the accuracy curve
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot the precision curve
plt.plot(history.history['precision'], label='Training Precision')
plt.plot(history.history['val_precision'], label='Validation Precision')
plt.title('Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# Plot the recall curve
plt.plot(history.history['recall'], label='Training Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
# Evaluate model on train data
train_eval_results = model.evaluate(train_generator, steps=BATCH_SIZE)
print(f'Accuracy: {train_eval_results[1]}')
precision = train_eval_results[2]
recall = train_eval_results[3]
print(f'Precision: {precision}')
print(f'Recall: {recall}')
f1_score = 2 * (precision * recall) / (precision + recall)

print(f'F1-score: {f1_score}')
# Out:
# 64/64 [==============================] - 353s 6s/step - loss: 0.1210 - accuracy: 0.9752 - precision: 0.9830 - recall: 0.9675
# Accuracy: 0.975204586982727
# Precision: 0.9829829931259155
# Recall: 0.9674876928329468
# F1-score: 0.9751737926231767

# %%
# Evaluate model on val data
val_eval_results = model.evaluate(val_generator)
print(f'Accuracy: {val_eval_results[1]}')
precision = val_eval_results[2]
recall = val_eval_results[3]
print(f'Precision: {precision}')
print(f'Recall: {recall}')
f1_score = 2 * (precision * recall) / (precision + recall)

print(f'F1-score: {f1_score}')
# Out:
# 5/5 [==============================] - 9s 2s/step - loss: 0.3100 - accuracy: 0.8558 - precision: 0.8925 - recall: 0.8691
# Accuracy: 0.8557692170143127
# Precision: 0.8924731016159058
# Recall: 0.8691099286079407
# F1-score: 0.880636586890081

# %%
# Evaluate model on test data
test_eval_results = model.evaluate(test_generator)
print(f'Accuracy: {test_eval_results[1]}')
precision = test_eval_results[2]
recall = test_eval_results[3]
print(f'Precision: {precision}')
print(f'Recall: {recall}')
f1_score = 2 * (precision * recall) / (precision + recall)

print(f'F1-score: {f1_score}')
# Out:
# 5/5 [==============================] - 96s 23s/step - loss: 0.4916 - accuracy: 0.8200 - precision: 0.7759 - recall: 0.9000
# Accuracy: 0.8199999928474426
# Precision: 0.7758620977401733
# Recall: 0.8999999761581421
# F1-score: 0.8333333397107842

# %%
# Predict labels for the images in train_generator
train_predicted_probs = model.predict(train_generator, steps=BATCH_SIZE)
train_predicted_labels = (train_predicted_probs > 0.5).astype("int32") # Assuming you have a binary classification problem

# Create a dataframe using img_path and predicted labels
train_predicted_df = pd.DataFrame({
    'img_path': train_generator.filenames,
    'predicted_probs': train_predicted_probs.reshape(-1),
    'predicted_label': train_predicted_labels.reshape(-1)
})

# Merge with train_df
merged_train_df = pd.merge(train_df, train_predicted_df, on='img_path', how='left')
merged_train_df.to_csv('train_results.csv')
# Out:
# 49/64 [=====================>........] - ETA: 1:23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-b82a759b13b4> in <cell line: 2>()
#       1 # Predict labels for the images in train_generator
# ----> 2 train_predicted_probs = model.predict(train_generator, steps=BATCH_SIZE)
#       3 train_predicted_labels = (train_predicted_probs > 0.5).astype("int32") # Assuming you have a binary classification problem
#       4
#       5 # Create a dataframe using img_path and predicted labels
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2627             for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2628                 with data_handler.catch_stop_iteration():
# -> 2629                     for step in data_handler.steps():
#    2630                         callbacks.on_predict_batch_begin(step)
#    2631                         tmp_batch_outputs = self.predict_function(iterator)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in steps(self)
#    1409             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410                 break
# -> 1411             original_spe = self._steps_per_execution.numpy().item()
#    1412             can_run_full_execution = (
#    1413                 original_spe == 1
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     685   def numpy(self):
#     686     if context.executing_eagerly():
# --> 687       return self.read_value().numpy()
#     688     raise NotImplementedError(
#     689         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     394     """
#     395     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 396     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     397     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     398
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     360   def _numpy(self):
#     361     try:
# --> 362       return self._numpy_internal()
#     363     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     364       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# Predict labels for the images in val_generator
val_predicted_probs = model.predict(val_generator)
val_predicted_labels = (val_predicted_probs > 0.5).astype("int32") # Assuming you have a binary classification problem

# Create a dataframe using img_path and predicted labels
val_predicted_df = pd.DataFrame({
    'img_path': val_generator.filenames,
    'predicted_probs': val_predicted_probs.reshape(-1),
    'predicted_label': val_predicted_labels.reshape(-1)
})

# Merge with val_df
merged_val_df = pd.merge(val_df, val_predicted_df, on='img_path', how='left')
merged_val_df.to_csv('val_results.csv')
# Out:
# 5/5 [==============================] - 12s 2s/step

# %%
# Predict labels for the images in test_generator
test_predicted_probs = model.predict(test_generator)
test_predicted_labels = (test_predicted_probs > 0.5).astype("int32") # Assuming you have a binary classification problem

# Create a dataframe using img_path and predicted labels
test_predicted_df = pd.DataFrame({
    'img_path': test_generator.filenames,
    'predicted_probs': test_predicted_probs.reshape(-1),
    'predicted_label': test_predicted_labels.reshape(-1)
})

# Merge with test_df
merged_test_df = pd.merge(test_df, test_predicted_df, on='img_path', how='left')
merged_test_df.to_csv('test_results.csv')
# Out:
# 5/5 [==============================] - 9s 2s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Prediction on test set
predictions = model.predict(test_generator)
predictions = predictions.flatten()  # Convert predictions to 1D array if necessary

# Apply 0.5 threshold
predictions_binary = np.where(predictions > 0.68, 1, 0)

# True Labels
# Ensure test_generator labels are in the same order as predictions
true_labels = test_generator.classes

# Compute Confusion Matrix
conf_matrix = confusion_matrix(true_labels, predictions_binary)

# Extract individual elements
TN, FP, FN, TP = conf_matrix.ravel()

# Create a new confusion matrix with labels
conf_matrix_labelled = np.array([[f"TN\n{TN}", f"FP\n{FP}"], [f"FN\n{FN}", f"TP\n{TP}"]])

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
ax = sns.heatmap(conf_matrix, annot=conf_matrix_labelled, fmt='', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
ax.set_xticklabels(['Negative', 'Positive'])
ax.set_yticklabels(['Negative', 'Positive'])
plt.show()
# Out:
# 5/5 [==============================] - 8s 2s/step

# %%
from sklearn.metrics import classification_report

# Class names
class_names = ['Non_Autistic', 'Autistic']

# Generate classification report
report = classification_report(true_labels, predictions_binary, target_names=class_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# Non_Autistic       0.83      0.80      0.82       150
#     Autistic       0.81      0.84      0.82       150
#
#     accuracy                           0.82       300
#    macro avg       0.82      0.82      0.82       300
# weighted avg       0.82      0.82      0.82       300
