# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
from google.colab import drive

# %% [markdown]
# ## Configure Project Path and other paths

# %%
import numpy as np
rstate = np.random.default_rng(seed=72)

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
proj_path = '/content/drive/MyDrive/Magnimind/Face_detection/MP'
os.chdir(proj_path)

# %%
train_csv_path = os.path.join(proj_path, 'train_2D.csv')
test_csv_path = os.path.join(proj_path, 'test_2D.csv')

# %% [markdown]
# ## Read data from csv to pandas dataframe

# %%
train_df = pd.read_csv(train_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        839  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        825  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        817  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...        845  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        844  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_1_x  landmark_1_y  landmark_2_x  \
# 0      0.511593      0.709910      0.517181      0.670308      0.515403
# 1      0.566339      0.733220      0.575596      0.677747      0.568713
# 2      0.437217      0.744490      0.426740      0.685478      0.433244
# 3      0.533727      0.797597      0.549781      0.762331      0.540980
# 4      0.524054      0.774706      0.505436      0.710976      0.512779
#
#    landmark_2_y  landmark_3_x  ...  landmark_463_x  landmark_463_y  \
# 0      0.679123      0.500272  ...        0.614458        0.486299
# 1      0.697361      0.553947  ...        0.628819        0.549039
# 2      0.704711      0.405189  ...        0.517382        0.542334
# 3      0.772093      0.528068  ...        0.624055        0.614141
# 4      0.727149      0.466017  ...        0.550516        0.553379
#
#    landmark_464_x  landmark_464_y  landmark_465_x  landmark_465_y  \
# 0        0.597307        0.492995        0.587559        0.500262
# 1        0.615948        0.553194        0.609449        0.556148
# 2        0.499661        0.547696        0.488665        0.551752
# 3        0.608973        0.618901        0.601406        0.623819
# 4        0.536100        0.562195        0.528307        0.568924
#
#    landmark_466_x  landmark_466_y  landmark_467_x  landmark_467_y
# 0        0.768636        0.474503        0.784336        0.468965
# 1        0.738344        0.541875        0.751471        0.531839
# 2        0.656447        0.535078        0.674554        0.525373
# 3        0.766676        0.603243        0.782729        0.596054
# 4        0.683886        0.525732        0.697740        0.517121
#
# [5 rows x 939 columns]

# %%
test_df.head()
# Out:
#                                             img_path  image_num     label  \
# 0  /content/drive/MyDrive/Magnimind/Face_detectio...        100  Autistic
# 1  /content/drive/MyDrive/Magnimind/Face_detectio...        108  Autistic
# 2  /content/drive/MyDrive/Magnimind/Face_detectio...        106  Autistic
# 3  /content/drive/MyDrive/Magnimind/Face_detectio...          1  Autistic
# 4  /content/drive/MyDrive/Magnimind/Face_detectio...        103  Autistic
#
#    landmark_0_x  landmark_0_y  landmark_1_x  landmark_1_y  landmark_2_x  \
# 0      0.727391      0.710138      0.753489      0.581854      0.723864
# 1      0.457443      0.710929      0.437796      0.633989      0.445459
# 2      0.452099      0.779923      0.453784      0.726497      0.455887
# 3      0.457504      0.754957      0.470419      0.687706      0.467041
# 4      0.362426      0.740446      0.366750      0.668341      0.372543
#
#    landmark_2_y  landmark_3_x  ...  landmark_463_x  landmark_463_y  \
# 0      0.624057      0.699572  ...        0.749237        0.411756
# 1      0.658974      0.401915  ...        0.509359        0.460005
# 2      0.738631      0.441661  ...        0.577733        0.505678
# 3      0.708499      0.457171  ...        0.599581        0.529724
# 4      0.689162      0.377194  ...        0.525101        0.542058
#
#    landmark_464_x  landmark_464_y  landmark_465_x  landmark_465_y  \
# 0        0.737767        0.418196        0.737665        0.421433
# 1        0.492417        0.466946        0.482040        0.471925
# 2        0.558054        0.512911        0.546055        0.521134
# 3        0.578473        0.532598        0.565713        0.535771
# 4        0.504449        0.543285        0.491366        0.545638
#
#    landmark_466_x  landmark_466_y  landmark_467_x  landmark_467_y
# 0        0.890724        0.401811        0.903891        0.394724
# 1        0.660659        0.437236        0.679693        0.424461
# 2        0.749610        0.499630        0.771000        0.490222
# 3        0.783299        0.529403        0.804902        0.522787
# 4        0.686309        0.559731        0.705237        0.556214
#
# [5 rows x 939 columns]

# %%
train_df['label'].value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_1_x, landmark_1_y, landmark_2_x, landmark_2_y, landmark_3_x, landmark_3_y, landmark_4_x, landmark_4_y, landmark_5_x, landmark_5_y, landmark_6_x, landmark_6_y, landmark_7_x, landmark_7_y, landmark_8_x, landmark_8_y, landmark_9_x, landmark_9_y, landmark_10_x, landmark_10_y, landmark_11_x, landmark_11_y, landmark_12_x, landmark_12_y, landmark_13_x, landmark_13_y, landmark_14_x, landmark_14_y, landmark_15_x, landmark_15_y, landmark_16_x, landmark_16_y, landmark_17_x, landmark_17_y, landmark_18_x, landmark_18_y, landmark_19_x, landmark_19_y, landmark_20_x, landmark_20_y, landmark_21_x, landmark_21_y, landmark_22_x, landmark_22_y, landmark_23_x, landmark_23_y, landmark_24_x, landmark_24_y, landmark_25_x, landmark_25_y, landmark_26_x, landmark_26_y, landmark_27_x, landmark_27_y, landmark_28_x, landmark_28_y, landmark_29_x, landmark_29_y, landmark_30_x, landmark_30_y, landmark_31_x, landmark_31_y, landmark_32_x, landmark_32_y, landmark_33_x, landmark_33_y, landmark_34_x, landmark_34_y, landmark_35_x, landmark_35_y, landmark_36_x, landmark_36_y, landmark_37_x, landmark_37_y, landmark_38_x, landmark_38_y, landmark_39_x, landmark_39_y, landmark_40_x, landmark_40_y, landmark_41_x, landmark_41_y, landmark_42_x, landmark_42_y, landmark_43_x, landmark_43_y, landmark_44_x, landmark_44_y, landmark_45_x, landmark_45_y, landmark_46_x, landmark_46_y, landmark_47_x, landmark_47_y, landmark_48_x, ...]
# Index: []
#
# [0 rows x 939 columns]

# %%
test_df['label'].value_counts()
# Out:
# Autistic        150
# Non_Autistic    150
# Name: label, dtype: int64

# %%
test_df[test_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [img_path, image_num, label, landmark_0_x, landmark_0_y, landmark_1_x, landmark_1_y, landmark_2_x, landmark_2_y, landmark_3_x, landmark_3_y, landmark_4_x, landmark_4_y, landmark_5_x, landmark_5_y, landmark_6_x, landmark_6_y, landmark_7_x, landmark_7_y, landmark_8_x, landmark_8_y, landmark_9_x, landmark_9_y, landmark_10_x, landmark_10_y, landmark_11_x, landmark_11_y, landmark_12_x, landmark_12_y, landmark_13_x, landmark_13_y, landmark_14_x, landmark_14_y, landmark_15_x, landmark_15_y, landmark_16_x, landmark_16_y, landmark_17_x, landmark_17_y, landmark_18_x, landmark_18_y, landmark_19_x, landmark_19_y, landmark_20_x, landmark_20_y, landmark_21_x, landmark_21_y, landmark_22_x, landmark_22_y, landmark_23_x, landmark_23_y, landmark_24_x, landmark_24_y, landmark_25_x, landmark_25_y, landmark_26_x, landmark_26_y, landmark_27_x, landmark_27_y, landmark_28_x, landmark_28_y, landmark_29_x, landmark_29_y, landmark_30_x, landmark_30_y, landmark_31_x, landmark_31_y, landmark_32_x, landmark_32_y, landmark_33_x, landmark_33_y, landmark_34_x, landmark_34_y, landmark_35_x, landmark_35_y, landmark_36_x, landmark_36_y, landmark_37_x, landmark_37_y, landmark_38_x, landmark_38_y, landmark_39_x, landmark_39_y, landmark_40_x, landmark_40_y, landmark_41_x, landmark_41_y, landmark_42_x, landmark_42_y, landmark_43_x, landmark_43_y, landmark_44_x, landmark_44_y, landmark_45_x, landmark_45_y, landmark_46_x, landmark_46_y, landmark_47_x, landmark_47_y, landmark_48_x, ...]
# Index: []
#
# [0 rows x 939 columns]

# %% [markdown]
# ## Setting input features and output features

# %%
X = train_df.drop(columns=['img_path', 'image_num', 'label'])
y = train_df['label']

# %%
y.value_counts()
# Out:
# Autistic        1270
# Non_Autistic     810
# Name: label, dtype: int64

# %%
y = y.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
y.value_counts()
# Out:
# 1    1270
# 0     810
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, shuffle=True, random_state=72)

# %%
X_test = test_df.drop(columns=['img_path', 'image_num', 'label'])
y_test = test_df['label']
y_test = y_test.map({'Autistic': 1, 'Non_Autistic': 0})

# %%
X_train.shape
# Out:
# (1560, 936)

# %%
X_val.shape
# Out:
# (520, 936)

# %%
X_test.shape
# Out:
# (300, 936)

# %% [markdown]
# ## SMOTE

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=72)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# 0    953
# 1    953
# Name: label, dtype: int64

# %%
y_val.value_counts()
# Out:
# 1    317
# 0    203
# Name: label, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    150
# 0    150
# Name: label, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import precision_recall_curve
import numpy as np
from sklearn.pipeline import Pipeline
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import hyperopt

# %%
# Initializing random_state
random_state = 72

# %%
from hyperopt.pyll.base import Apply

def hyperopt_indices_to_values(space, best):
    best_params = {}

    for key, val in best.items():
        print(f"Processing key: {key}, val: {val}")  # Debugging line
        #print(f"Type of space[key]: {type(space[key])}")  # Additional Debugging line
        #print(f"Name attribute of space[key] (if exists): {getattr(space[key], 'name', 'No name attribute')}")  # Additional Debugging line

        if key == 'penalty_solver':
            # Extract penalty and solver values directly from the tuple
            penalty, solver = space[key].pos_args[int(val) + 1].pos_args
            best_params['penalty'] = penalty.obj
            best_params['solver'] = solver.obj

        elif isinstance(space[key], Apply) and space[key].name == 'switch':
            # This means the parameter is defined using hp.choice
            selected_item = space[key].pos_args[val + 1]
            if key == 'hidden_layers':
                try:
                    # Attempt to unpack it as if it was a list
                    best_params[key] = [item.obj for item in selected_item.pos_args]
                except AttributeError:
                    # If there's an error, revert back to previous handling
                    best_params[key] = getattr(selected_item, 'obj', selected_item)

            else:
                # Handle the scenario where 'selected_item' might not have 'obj'
                best_params[key] = getattr(selected_item, 'obj', selected_item)

        else:
            # Otherwise, directly assign the value
            best_params[key] = val

    return best_params

# %%
def optimize_hyperparams(model_class, default_params, space,
                         X_train, y_train, enable_early_stopping=False,
                         max_evals=20, random_state=72):

        # Convert numpy arrays to pandas DataFrame or Series
    if isinstance(X_train, np.ndarray):
        X_train = pd.DataFrame(X_train)
    if isinstance(y_train, np.ndarray):
        y_train = pd.Series(y_train)

    def objective(params):
        try:
            # If 'penalty_solver' is in params, get mapped 'penalty' and 'solver' params
            if 'penalty_solver' in params:
                params['penalty'], params['solver'] = params.pop('penalty_solver')

            # If the penalty is not 'elasticnet', remove the l1_ratio parameter
            if params.get('penalty') != 'elasticnet':
                params.pop('l1_ratio', None)


            all_params = {**default_params, **params}
            m = model_class(**all_params)

            cv_folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

            if enable_early_stopping:
                # Set early_stopping_rounds
                m.set_params(early_stopping_rounds=3, eval_metric="logloss")
                scores = []

                for train_index, test_index in cv_folds.split(X_train, y_train):
                    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[test_index]
                    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[test_index]

                    eval_set = [(X_val_fold, y_val_fold)]
                    m.fit(X_train_fold, y_train_fold,
                          eval_set=eval_set, verbose=True)

                    predictions = m.predict(X_val_fold)
                    score = f1_score(y_val_fold, predictions)
                    scores.append(score)

                return -np.mean(scores) # since we want to maximize F1 score

            else:
                loss = -cross_val_score(m, X_train, y_train, cv=cv_folds, scoring='f1').mean()
                return loss

        except Exception as e:
            print(f"Exception encountered: {e}")
            # Handle any other exception that arises during model training or evaluation
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=max_evals,
                trials=trials, rstate=rstate)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
# Evaluate the fitted pipeline
def evaluate(model, X, y):
    # Predict on given X
    y_pred = model.predict(X)

    # Calculate below evaluation metrics
    accuracy = round(accuracy_score(y, y_pred), 2)
    precision = round(precision_score(y, y_pred), 2)
    recall = round(recall_score(y, y_pred), 2)
    f1 = round(f1_score(y, y_pred), 2)

    # Return the values in a dictionary

    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
default_params = {
    'random_state': random_state,
    'max_iter': 3000,
}

lr_hyperparam_space = {
    # Combine penalty and solver
    'penalty_solver': hp.choice('penalty_solver', [
        ('l1', 'liblinear'),
        ('l2', 'liblinear'),
    ]),

    # Regularization strength
    'C': hp.loguniform('C', np.log(0.0001), np.log(10)),
}

# Using the function
best_params = optimize_hyperparams(LogisticRegression,
                                   default_params,
                                   lr_hyperparam_space,
                                   X_train_smote, y_train_smote,
                                   max_evals=25)
print(best_params)
# Out:
# 100%|██████████| 25/25 [02:27<00:00,  5.89s/trial, best loss: -0.7585691366214891]
# Processing key: C, val: 8.509540372207411
# Processing key: penalty_solver, val: 1
# {'C': 8.509540372207411, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
optimized_params = {**default_params, **best_params}
print(optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
lr = LogisticRegression(**optimized_params)
lr.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(lr, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(lr, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(lr, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'max_iter': 3000, 'C': 8.509540372207411, 'penalty': 'l2', 'solver': 'liblinear'}
# Training Data Evaluation:
# {'Accuracy': 0.77, 'Precision': 0.77, 'Recall': 0.77, 'F1': 0.77}
#
# Validation Data Evaluation:
# {'Accuracy': 0.78, 'Precision': 0.86, 'Recall': 0.77, 'F1': 0.81}
#
# Test Data Evaluation:
# {'Accuracy': 0.76, 'Precision': 0.74, 'Recall': 0.81, 'F1': 0.77}

# %%
rf_default_params = {
    'random_state': random_state,
    'class_weight': 'balanced',
    'n_jobs': -1,
}

rf_hyperparam_space = {
    'n_estimators': hp.choice('n_estimators', list(range(30, 70, 5))),
    'max_depth': hp.choice('max_depth', list(range(2, 5))),  # Excluding None to prevent unlimited depth
    'min_samples_split': hp.uniform('min_samples_split', 0.05, 0.2),  # Increasing the lower bound to avoid tiny splits
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.01, 0.1),  # Increasing the lower bound to ensure larger leaves
    'max_features': hp.choice('max_features', [0.4, 0.5, 0.6, 'sqrt', 'log2']),  # Focusing on fewer feature options
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'bootstrap': hp.choice('bootstrap', [True]),
    'oob_score': hp.choice('oob_score', [True, False])
}

# Using the function
rf_best_params = optimize_hyperparams(RandomForestClassifier,
                                      rf_default_params,
                                      rf_hyperparam_space,
                                      X_train_smote, y_train_smote,
                                      max_evals=25)
print(rf_best_params)
# Out:
# 100%|██████████| 25/25 [06:41<00:00, 16.06s/trial, best loss: -0.7290730033940471]
# Processing key: bootstrap, val: 0
# Processing key: criterion, val: 1
# Processing key: max_depth, val: 2
# Processing key: max_features, val: 3
# Processing key: min_samples_leaf, val: 0.06708070264826843
# Processing key: min_samples_split, val: 0.12315517405596627
# Processing key: n_estimators, val: 7
# Processing key: oob_score, val: 0
# {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 0.06708070264826843, 'min_samples_split': 0.12315517405596627, 'n_estimators': 65, 'oob_score': True}

# %%
rf_optimized_params = {**rf_default_params, **rf_best_params}
print(rf_optimized_params)

# Train the model using the parameters obtained from hyperparam tuning
rf = RandomForestClassifier(**rf_optimized_params)
rf.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(rf, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(rf, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(rf, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'class_weight': 'balanced', 'n_jobs': -1, 'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 0.06708070264826843, 'min_samples_split': 0.12315517405596627, 'n_estimators': 65, 'oob_score': True}
# Training Data Evaluation:
# {'Accuracy': 0.74, 'Precision': 0.72, 'Recall': 0.78, 'F1': 0.75}
#
# Validation Data Evaluation:
# {'Accuracy': 0.73, 'Precision': 0.79, 'Recall': 0.77, 'F1': 0.78}
#
# Test Data Evaluation:
# {'Accuracy': 0.71, 'Precision': 0.67, 'Recall': 0.82, 'F1': 0.74}

# %%
adb_default_params = {
    'random_state': random_state,
}

adb_hyperparam_space = {
    # AdaBoost hyperparameters
    # Number of weak learners to train
    'n_estimators': hp.choice('n_estimators', list(range(30, 70, 5))),
    # Helps to shrink the contribution of each classifier
    'learning_rate': hp.loguniform('learning_rate', -7, 0), # Log uniform distribution between 1e-7 and 1
}

# Using the function
adb_best_params = optimize_hyperparams(AdaBoostClassifier,
                                       adb_default_params,
                                       adb_hyperparam_space,
                                       X_train_smote, y_train_smote,
                                       max_evals=35)
print(adb_best_params)
# Out:
# 100%|██████████| 35/35 [31:55<00:00, 54.72s/trial, best loss: -0.7433640199528669]
# Processing key: learning_rate, val: 0.34569492989391976
# Processing key: n_estimators, val: 5
# {'learning_rate': 0.34569492989391976, 'n_estimators': 55}

# %%
# Merge default and best params
adb_optimized_params = {**adb_default_params, **adb_best_params}
print(adb_optimized_params)

# Train the model using the optimized parameters
adb = AdaBoostClassifier(**adb_optimized_params)
adb.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(adb, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(adb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(adb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'learning_rate': 0.34569492989391976, 'n_estimators': 55}
# Training Data Evaluation:
# {'Accuracy': 0.79, 'Precision': 0.78, 'Recall': 0.8, 'F1': 0.79}
#
# Validation Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.8, 'Recall': 0.79, 'F1': 0.79}
#
# Test Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.72, 'Recall': 0.83, 'F1': 0.77}

# %%
# Merge default and best params
adb_optimized_params = {**adb_default_params, **adb_best_params}
print(adb_optimized_params)

# Train the model using the optimized parameters
adb = AdaBoostClassifier(**adb_optimized_params)
adb.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(adb, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(adb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(adb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'learning_rate': 0.3881274762752531, 'n_estimators': 65}
# Training Data Evaluation:
# {'Accuracy': 0.8, 'Precision': 0.8, 'Recall': 0.81, 'F1': 0.81}
#
# Validation Data Evaluation:
# {'Accuracy': 0.75, 'Precision': 0.8, 'Recall': 0.78, 'F1': 0.79}
#
# Test Data Evaluation:
# {'Accuracy': 0.73, 'Precision': 0.7, 'Recall': 0.83, 'F1': 0.76}

# %%
xgb_default_params = {
    'random_state': random_state,
    'n_jobs': -1,
}

# Hyperparams for XGB
xgb_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -3),  # remain the same
    'n_estimators': hp.choice('n_estimators', [10, 20, 30, 40]),  # even more reduced choices
    'max_depth': hp.choice('max_depth', [1, 2]),  # remain the same
    'min_child_weight': hp.quniform('min_child_weight', 16, 20, 1),  # remain the same
    'gamma': hp.uniform('gamma', 0.7, 1),  # remain the same
    'colsample_bytree': hp.uniform('colsample_bytree', 0.2, 0.5),  # remain the same
    'alpha': hp.loguniform('alpha', 0, 4),  # more aggressive L1 regularization
    'lambda': hp.loguniform('lambda', 0, 4),  # more aggressive L2 regularization
    'subsample': hp.uniform('subsample', 0.3, 0.7),  # remain the same
    'scale_pos_weight': hp.uniform('scale_pos_weight', 0.5, 1.5)  # reducing the influence of positive class
}


# Using the function
xgb_best_params = optimize_hyperparams(XGBClassifier,
                                       xgb_default_params,
                                       xgb_hyperparam_space,
                                       X_train_smote, y_train_smote,
                                       enable_early_stopping=True,
                                       max_evals=35)
print(xgb_best_params)
# Out:
# [0]	validation_0-logloss:0.69026
# [1]	validation_0-logloss:0.68649
# [2]	validation_0-logloss:0.68323
# [3]	validation_0-logloss:0.67991
# [4]	validation_0-logloss:0.67628
# [5]	validation_0-logloss:0.67277
# [6]	validation_0-logloss:0.66924
# [7]	validation_0-logloss:0.66664
# [8]	validation_0-logloss:0.66354
# [9]	validation_0-logloss:0.66077
# [10]	validation_0-logloss:0.65764
# [11]	validation_0-logloss:0.65477
# [12]	validation_0-logloss:0.65215
# [13]	validation_0-logloss:0.64931
# [14]	validation_0-logloss:0.64682
# [15]	validation_0-logloss:0.64417
# [16]	validation_0-logloss:0.64147
# [17]	validation_0-logloss:0.63892
# [18]	validation_0-logloss:0.63647
# [19]	validation_0-logloss:0.63422
# [20]	validation_0-logloss:0.63194
# [21]	validation_0-logloss:0.62952
# [22]	validation_0-logloss:0.62734
# [23]	validation_0-logloss:0.62529
# [24]	validation_0-logloss:0.62316
# [25]	validation_0-logloss:0.62133
# [26]	validation_0-logloss:0.61956
# [27]	validation_0-logloss:0.61730
# [28]	validation_0-logloss:0.61526
# [29]	validation_0-logloss:0.61407
# [30]	validation_0-logloss:0.61242
# [31]	validation_0-logloss:0.61062
# [32]	validation_0-logloss:0.60854
# [33]	validation_0-logloss:0.60714
# [34]	validation_0-logloss:0.60528
# [35]	validation_0-logloss:0.60382
# [36]	validation_0-logloss:0.60214
# [37]	validation_0-logloss:0.60056
# [38]	validation_0-logloss:0.59877
# [39]	validation_0-logloss:0.59752
# [0]	validation_0-logloss:0.69015
# [1]	validation_0-logloss:0.68630
# [2]	validation_0-logloss:0.68289
# [3]	validation_0-logloss:0.67959
# [4]	validation_0-logloss:0.67627
# [5]	validation_0-logloss:0.67275
# [6]	validation_0-logloss:0.66922
# [7]	validation_0-logloss:0.66633
# [8]	validation_0-logloss:0.66295
# [9]	validation_0-logloss:0.66014
# [10]	validation_0-logloss:0.65687
# [11]	validation_0-logloss:0.65415
# [12]	validation_0-logloss:0.65175
# [13]	validation_0-logloss:0.64910
# [14]	validation_0-logloss:0.64600
# [15]	validation_0-logloss:0.64343
# [16]	validation_0-logloss:0.64094
# [17]	validation_0-logloss:0.63859
# [18]	validation_0-logloss:0.63627
# [19]	validation_0-logloss:0.63334
# [20]	validation_0-logloss:0.63106
# [21]	validation_0-logloss:0.62873
# [22]	validation_0-logloss:0.62654
# [23]	validation_0-logloss:0.62422
# [24]	validation_0-logloss:0.62217
# [25]	validation_0-logloss:0.62038
# [26]	validation_0-logloss:0.61863
# [27]	validation_0-logloss:0.61688
# [28]	validation_0-logloss:0.61542
# [29]	validation_0-logloss:0.61364
# [30]	validation_0-logloss:0.61221
# [31]	validation_0-logloss:0.61056
# [32]	validation_0-logloss:0.60897
# [33]	validation_0-logloss:0.60745
# [34]	validation_0-logloss:0.60573
# [35]	validation_0-logloss:0.60449
# [36]	validation_0-logloss:0.60281
# [37]	validation_0-logloss:0.60093
# [38]	validation_0-logloss:0.59963
# [39]	validation_0-logloss:0.59772
# [0]	validation_0-logloss:0.69019
# [1]	validation_0-logloss:0.68665
# [2]	validation_0-logloss:0.68278
# [3]	validation_0-logloss:0.67962
# [4]	validation_0-logloss:0.67548
# [5]	validation_0-logloss:0.67200
# [6]	validation_0-logloss:0.66903
# [7]	validation_0-logloss:0.66623
# [8]	validation_0-logloss:0.66320
# [9]	validation_0-logloss:0.65978
# [10]	validation_0-logloss:0.65728
# [11]	validation_0-logloss:0.65451
# [12]	validation_0-logloss:0.65147
# [13]	validation_0-logloss:0.64904
# [14]	validation_0-logloss:0.64640
# [15]	validation_0-logloss:0.64379
# [16]	validation_0-logloss:0.64129
# [17]	validation_0-logloss:0.63887
# [18]	validation_0-logloss:0.63658
# [19]	validation_0-logloss:0.63390
# [20]	validation_0-logloss:0.63142
# [21]	validation_0-logloss:0.62947
# [22]	validation_0-logloss:0.62758
# [23]	validation_0-logloss:0.62544
# [24]	validation_0-logloss:0.62363
# [25]	validation_0-logloss:0.62171
# [26]	validation_0-logloss:0.61942
# [27]	validation_0-logloss:0.61772
# [28]	validation_0-logloss:0.61600
# [29]	validation_0-logloss:0.61439
# [30]	validation_0-logloss:0.61256
# [31]	validation_0-logloss:0.61088
# [32]	validation_0-logloss:0.60933
# [33]	validation_0-logloss:0.60759
# [34]	validation_0-logloss:0.60622
# [35]	validation_0-logloss:0.60432
# [36]	validation_0-logloss:0.60277
# [37]	validation_0-logloss:0.60107
# [38]	validation_0-logloss:0.59970
# [39]	validation_0-logloss:0.59817
# [0]	validation_0-logloss:0.69043
# [1]	validation_0-logloss:0.68701
# [2]	validation_0-logloss:0.68369
# [3]	validation_0-logloss:0.68014
# [4]	validation_0-logloss:0.67660
# [5]	validation_0-logloss:0.67333
# [6]	validation_0-logloss:0.67083
# [7]	validation_0-logloss:0.66785
# [8]	validation_0-logloss:0.66454
# [9]	validation_0-logloss:0.66135
# [10]	validation_0-logloss:0.65846
# [11]	validation_0-logloss:0.65590
# [12]	validation_0-logloss:0.65339
# [13]	validation_0-logloss:0.65115
# [14]	validation_0-logloss:0.64890
# [15]	validation_0-logloss:0.64688
# [16]	validation_0-logloss:0.64435
# [17]	validation_0-logloss:0.64219
# [18]	validation_0-logloss:0.64012
# [19]	validation_0-logloss:0.63768
# [20]	validation_0-logloss:0.63545
# [21]	validation_0-logloss:0.63320
# [22]	validation_0-logloss:0.63145
# [23]	validation_0-logloss:0.62927
# [24]	validation_0-logloss:0.62718
# [25]	validation_0-logloss:0.62458
# [26]	validation_0-logloss:0.62269
# [27]	validation_0-logloss:0.62106
# [28]	validation_0-logloss:0.61942
# [29]	validation_0-logloss:0.61755
# [30]	validation_0-logloss:0.61591
# [31]	validation_0-logloss:0.61424
# [32]	validation_0-logloss:0.61280
# [33]	validation_0-logloss:0.61112
# [34]	validation_0-logloss:0.60923
# [35]	validation_0-logloss:0.60767
# [36]	validation_0-logloss:0.60653
# [37]	validation_0-logloss:0.60510
# [38]	validation_0-logloss:0.60388
# [39]	validation_0-logloss:0.60262
# [0]	validation_0-logloss:0.68980
# [1]	validation_0-logloss:0.68598
# [2]	validation_0-logloss:0.68210
# [3]	validation_0-logloss:0.67816
# [4]	validation_0-logloss:0.67491
# [5]	validation_0-logloss:0.67134
# [6]	validation_0-logloss:0.66799
# [7]	validation_0-logloss:0.66415
# [8]	validation_0-logloss:0.66116
# [9]	validation_0-logloss:0.65792
# [10]	validation_0-logloss:0.65466
# [11]	validation_0-logloss:0.65141
# [12]	validation_0-logloss:0.64862
# [13]	validation_0-logloss:0.64625
# [14]	validation_0-logloss:0.64364
# [15]	validation_0-logloss:0.64095
# [16]	validation_0-logloss:0.63870
# [17]	validation_0-logloss:0.63596
# [18]	validation_0-logloss:0.63301
# [19]	validation_0-logloss:0.63043
# [20]	validation_0-logloss:0.62787
# [21]	validation_0-logloss:0.62504
# [22]	validation_0-logloss:0.62300
# [23]	validation_0-logloss:0.62068
# [24]	validation_0-logloss:0.61834
# [25]	validation_0-logloss:0.61619
# [26]	validation_0-logloss:0.61414
# [27]	validation_0-logloss:0.61202
# [28]	validation_0-logloss:0.61006
# [29]	validation_0-logloss:0.60789
# [30]	validation_0-logloss:0.60569
# [31]	validation_0-logloss:0.60352
# [32]	validation_0-logloss:0.60156
# [33]	validation_0-logloss:0.59995
# [34]	validation_0-logloss:0.59829
# [35]	validation_0-logloss:0.59703
# [36]	validation_0-logloss:0.59541
# [37]	validation_0-logloss:0.59400
# [38]	validation_0-logloss:0.59206
# [39]	validation_0-logloss:0.59028
# [0]	validation_0-logloss:0.68772
# [1]	validation_0-logloss:0.68224
# [2]	validation_0-logloss:0.67777
# [3]	validation_0-logloss:0.67360
# [4]	validation_0-logloss:0.66909
# [5]	validation_0-logloss:0.66436
# [6]	validation_0-logloss:0.66045
# [7]	validation_0-logloss:0.65659
# [8]	validation_0-logloss:0.65192
# [9]	validation_0-logloss:0.64834
# [0]	validation_0-logloss:0.68775
# [1]	validation_0-logloss:0.68211
# [2]	validation_0-logloss:0.67711
# [3]	validation_0-logloss:0.67268
# [4]	validation_0-logloss:0.66815
# [5]	validation_0-logloss:0.66348
# [6]	validation_0-logloss:0.65929
# [7]	validation_0-logloss:0.65514
# [8]	validation_0-logloss:0.65076
# [9]	validation_0-logloss:0.64686
# [0]	validation_0-logloss:0.68750
# [1]	validation_0-logloss:0.68198
# [2]	validation_0-logloss:0.67649
# [3]	validation_0-logloss:0.67233
# [4]	validation_0-logloss:0.66794
# [5]	validation_0-logloss:0.66296
# [6]	validation_0-logloss:0.65971
# [7]	validation_0-logloss:0.65599
# [8]	validation_0-logloss:0.65237
# [9]	validation_0-logloss:0.64842
# [0]	validation_0-logloss:0.68764
# [1]	validation_0-logloss:0.68257
# [2]	validation_0-logloss:0.67701
# [3]	validation_0-logloss:0.67234
# [4]	validation_0-logloss:0.66740
# [5]	validation_0-logloss:0.66325
# [6]	validation_0-logloss:0.65993
# [7]	validation_0-logloss:0.65585
# [8]	validation_0-logloss:0.65115
# [9]	validation_0-logloss:0.64752
# [0]	validation_0-logloss:0.68649
# [1]	validation_0-logloss:0.68086
# [2]	validation_0-logloss:0.67528
# [3]	validation_0-logloss:0.67081
# [4]	validation_0-logloss:0.66647
# [5]	validation_0-logloss:0.66151
# [6]	validation_0-logloss:0.65694
# [7]	validation_0-logloss:0.65190
# [8]	validation_0-logloss:0.64777
# [9]	validation_0-logloss:0.64319
# [0]	validation_0-logloss:0.69645
# [1]	validation_0-logloss:0.69464
# [2]	validation_0-logloss:0.69311
# [3]	validation_0-logloss:0.69161
# [4]	validation_0-logloss:0.68984
# [5]	validation_0-logloss:0.68804
# [6]	validation_0-logloss:0.68627
# [7]	validation_0-logloss:0.68489
# [8]	validation_0-logloss:0.68307
# [9]	validation_0-logloss:0.68192
# [10]	validation_0-logloss:0.68038
# [11]	validation_0-logloss:0.67907
# [12]	validation_0-logloss:0.67745
# [13]	validation_0-logloss:0.67592
# [14]	validation_0-logloss:0.67436
# [15]	validation_0-logloss:0.67307
# [16]	validation_0-logloss:0.67161
# [17]	validation_0-logloss:0.67007
# [18]	validation_0-logloss:0.66857
# [19]	validation_0-logloss:0.66738
# [20]	validation_0-logloss:0.66611
# [21]	validation_0-logloss:0.66467
# [22]	validation_0-logloss:0.66339
# [23]	validation_0-logloss:0.66220
# [24]	validation_0-logloss:0.66096
# [25]	validation_0-logloss:0.65971
# [26]	validation_0-logloss:0.65851
# [27]	validation_0-logloss:0.65727
# [28]	validation_0-logloss:0.65599
# [29]	validation_0-logloss:0.65501
# [30]	validation_0-logloss:0.65414
# [31]	validation_0-logloss:0.65291
# [32]	validation_0-logloss:0.65158
# [33]	validation_0-logloss:0.65019
# [34]	validation_0-logloss:0.64897
# [35]	validation_0-logloss:0.64792
# [36]	validation_0-logloss:0.64681
# [37]	validation_0-logloss:0.64561
# [38]	validation_0-logloss:0.64437
# [39]	validation_0-logloss:0.64331
# [0]	validation_0-logloss:0.69712
# [1]	validation_0-logloss:0.69543
# [2]	validation_0-logloss:0.69356
# [3]	validation_0-logloss:0.69192
# [4]	validation_0-logloss:0.69039
# [5]	validation_0-logloss:0.68857
# [6]	validation_0-logloss:0.68684
# [7]	validation_0-logloss:0.68493
# [8]	validation_0-logloss:0.68328
# [9]	validation_0-logloss:0.68171
# [10]	validation_0-logloss:0.67996
# [11]	validation_0-logloss:0.67821
# [12]	validation_0-logloss:0.67699
# [13]	validation_0-logloss:0.67551
# [14]	validation_0-logloss:0.67401
# [15]	validation_0-logloss:0.67268
# [16]	validation_0-logloss:0.67108
# [17]	validation_0-logloss:0.66970
# [18]	validation_0-logloss:0.66856
# [19]	validation_0-logloss:0.66703
# [20]	validation_0-logloss:0.66558
# [21]	validation_0-logloss:0.66442
# [22]	validation_0-logloss:0.66315
# [23]	validation_0-logloss:0.66169
# [24]	validation_0-logloss:0.66020
# [25]	validation_0-logloss:0.65909
# [26]	validation_0-logloss:0.65771
# [27]	validation_0-logloss:0.65659
# [28]	validation_0-logloss:0.65566
# [29]	validation_0-logloss:0.65422
# [30]	validation_0-logloss:0.65308
# [31]	validation_0-logloss:0.65194
# [32]	validation_0-logloss:0.65080
# [33]	validation_0-logloss:0.64957
# [34]	validation_0-logloss:0.64837
# [35]	validation_0-logloss:0.64754
# [36]	validation_0-logloss:0.64641
# [37]	validation_0-logloss:0.64533
# [38]	validation_0-logloss:0.64407
# [39]	validation_0-logloss:0.64311
# [0]	validation_0-logloss:0.69682
# [1]	validation_0-logloss:0.69496
# [2]	validation_0-logloss:0.69300
# [3]	validation_0-logloss:0.69113
# [4]	validation_0-logloss:0.68921
# [5]	validation_0-logloss:0.68728
# [6]	validation_0-logloss:0.68548
# [7]	validation_0-logloss:0.68399
# [8]	validation_0-logloss:0.68232
# [9]	validation_0-logloss:0.68073
# [10]	validation_0-logloss:0.67927
# [11]	validation_0-logloss:0.67765
# [12]	validation_0-logloss:0.67618
# [13]	validation_0-logloss:0.67477
# [14]	validation_0-logloss:0.67328
# [15]	validation_0-logloss:0.67185
# [16]	validation_0-logloss:0.67046
# [17]	validation_0-logloss:0.66914
# [18]	validation_0-logloss:0.66776
# [19]	validation_0-logloss:0.66625
# [20]	validation_0-logloss:0.66474
# [21]	validation_0-logloss:0.66342
# [22]	validation_0-logloss:0.66244
# [23]	validation_0-logloss:0.66116
# [24]	validation_0-logloss:0.65986
# [25]	validation_0-logloss:0.65854
# [26]	validation_0-logloss:0.65728
# [27]	validation_0-logloss:0.65604
# [28]	validation_0-logloss:0.65500
# [29]	validation_0-logloss:0.65365
# [30]	validation_0-logloss:0.65246
# [31]	validation_0-logloss:0.65130
# [32]	validation_0-logloss:0.65041
# [33]	validation_0-logloss:0.64917
# [34]	validation_0-logloss:0.64798
# [35]	validation_0-logloss:0.64664
# [36]	validation_0-logloss:0.64562
# [37]	validation_0-logloss:0.64428
# [38]	validation_0-logloss:0.64321
# [39]	validation_0-logloss:0.64215
# [0]	validation_0-logloss:0.69661
# [1]	validation_0-logloss:0.69503
# [2]	validation_0-logloss:0.69265
# [3]	validation_0-logloss:0.69071
# [4]	validation_0-logloss:0.68932
# [5]	validation_0-logloss:0.68802
# [6]	validation_0-logloss:0.68682
# [7]	validation_0-logloss:0.68533
# [8]	validation_0-logloss:0.68335
# [9]	validation_0-logloss:0.68130
# [10]	validation_0-logloss:0.68001
# [11]	validation_0-logloss:0.67868
# [12]	validation_0-logloss:0.67741
# [13]	validation_0-logloss:0.67622
# [14]	validation_0-logloss:0.67497
# [15]	validation_0-logloss:0.67390
# [16]	validation_0-logloss:0.67274
# [17]	validation_0-logloss:0.67145
# [18]	validation_0-logloss:0.67027
# [19]	validation_0-logloss:0.66910
# [20]	validation_0-logloss:0.66815
# [21]	validation_0-logloss:0.66715
# [22]	validation_0-logloss:0.66621
# [23]	validation_0-logloss:0.66454
# [24]	validation_0-logloss:0.66354
# [25]	validation_0-logloss:0.66155
# [26]	validation_0-logloss:0.66054
# [27]	validation_0-logloss:0.65901
# [28]	validation_0-logloss:0.65798
# [29]	validation_0-logloss:0.65633
# [30]	validation_0-logloss:0.65504
# [31]	validation_0-logloss:0.65357
# [32]	validation_0-logloss:0.65269
# [33]	validation_0-logloss:0.65115
# [34]	validation_0-logloss:0.64962
# [35]	validation_0-logloss:0.64845
# [36]	validation_0-logloss:0.64770
# [37]	validation_0-logloss:0.64692
# [38]	validation_0-logloss:0.64614
# [39]	validation_0-logloss:0.64479
# [0]	validation_0-logloss:0.69588
# [1]	validation_0-logloss:0.69373
# [2]	validation_0-logloss:0.69190
# [3]	validation_0-logloss:0.68997
# [4]	validation_0-logloss:0.68845
# [5]	validation_0-logloss:0.68669
# [6]	validation_0-logloss:0.68517
# [7]	validation_0-logloss:0.68323
# [8]	validation_0-logloss:0.68178
# [9]	validation_0-logloss:0.67998
# [10]	validation_0-logloss:0.67837
# [11]	validation_0-logloss:0.67666
# [12]	validation_0-logloss:0.67507
# [13]	validation_0-logloss:0.67367
# [14]	validation_0-logloss:0.67228
# [15]	validation_0-logloss:0.67106
# [16]	validation_0-logloss:0.66968
# [17]	validation_0-logloss:0.66830
# [18]	validation_0-logloss:0.66649
# [19]	validation_0-logloss:0.66517
# [20]	validation_0-logloss:0.66394
# [21]	validation_0-logloss:0.66225
# [22]	validation_0-logloss:0.66101
# [23]	validation_0-logloss:0.65949
# [24]	validation_0-logloss:0.65794
# [25]	validation_0-logloss:0.65666
# [26]	validation_0-logloss:0.65528
# [27]	validation_0-logloss:0.65382
# [28]	validation_0-logloss:0.65265
# [29]	validation_0-logloss:0.65118
# [30]	validation_0-logloss:0.65017
# [31]	validation_0-logloss:0.64908
# [32]	validation_0-logloss:0.64795
# [33]	validation_0-logloss:0.64685
# [34]	validation_0-logloss:0.64579
# [35]	validation_0-logloss:0.64490
# [36]	validation_0-logloss:0.64357
# [37]	validation_0-logloss:0.64243
# [38]	validation_0-logloss:0.64114
# [39]	validation_0-logloss:0.63981
# [0]	validation_0-logloss:0.74611
# [1]	validation_0-logloss:0.74611
# [2]	validation_0-logloss:0.74611
# [0]	validation_0-logloss:0.74506
# [1]	validation_0-logloss:0.74506
# [2]	validation_0-logloss:0.74506
# [3]	validation_0-logloss:0.74506
# [0]	validation_0-logloss:0.74506
# [1]	validation_0-logloss:0.74506
# [2]	validation_0-logloss:0.74506
# [3]	validation_0-logloss:0.74506
# [0]	validation_0-logloss:0.74716
# [1]	validation_0-logloss:0.74716
# [2]	validation_0-logloss:0.74716
# [3]	validation_0-logloss:0.74716
# [0]	validation_0-logloss:0.74716
# [1]	validation_0-logloss:0.74716
# [2]	validation_0-logloss:0.74716
# [0]	validation_0-logloss:0.69098
# [1]	validation_0-logloss:0.68836
# [2]	validation_0-logloss:0.68579
# [3]	validation_0-logloss:0.68382
# [4]	validation_0-logloss:0.68133
# [5]	validation_0-logloss:0.67863
# [6]	validation_0-logloss:0.67626
# [7]	validation_0-logloss:0.67470
# [8]	validation_0-logloss:0.67225
# [9]	validation_0-logloss:0.67010
# [10]	validation_0-logloss:0.66839
# [11]	validation_0-logloss:0.66666
# [12]	validation_0-logloss:0.66521
# [13]	validation_0-logloss:0.66330
# [14]	validation_0-logloss:0.66145
# [15]	validation_0-logloss:0.65985
# [16]	validation_0-logloss:0.65780
# [17]	validation_0-logloss:0.65596
# [18]	validation_0-logloss:0.65429
# [19]	validation_0-logloss:0.65268
# [20]	validation_0-logloss:0.65145
# [21]	validation_0-logloss:0.64960
# [22]	validation_0-logloss:0.64797
# [23]	validation_0-logloss:0.64667
# [24]	validation_0-logloss:0.64566
# [25]	validation_0-logloss:0.64420
# [26]	validation_0-logloss:0.64283
# [27]	validation_0-logloss:0.64147
# [28]	validation_0-logloss:0.63998
# [29]	validation_0-logloss:0.63893
# [30]	validation_0-logloss:0.63797
# [31]	validation_0-logloss:0.63659
# [32]	validation_0-logloss:0.63508
# [33]	validation_0-logloss:0.63415
# [34]	validation_0-logloss:0.63277
# [35]	validation_0-logloss:0.63160
# [36]	validation_0-logloss:0.63080
# [37]	validation_0-logloss:0.62941
# [38]	validation_0-logloss:0.62802
# [39]	validation_0-logloss:0.62681
# [0]	validation_0-logloss:0.69105
# [1]	validation_0-logloss:0.68860
# [2]	validation_0-logloss:0.68599
# [3]	validation_0-logloss:0.68401
# [4]	validation_0-logloss:0.68146
# [5]	validation_0-logloss:0.67902
# [6]	validation_0-logloss:0.67653
# [7]	validation_0-logloss:0.67430
# [8]	validation_0-logloss:0.67216
# [9]	validation_0-logloss:0.67011
# [10]	validation_0-logloss:0.66800
# [11]	validation_0-logloss:0.66580
# [12]	validation_0-logloss:0.66397
# [13]	validation_0-logloss:0.66209
# [14]	validation_0-logloss:0.66026
# [15]	validation_0-logloss:0.65859
# [16]	validation_0-logloss:0.65701
# [17]	validation_0-logloss:0.65511
# [18]	validation_0-logloss:0.65374
# [19]	validation_0-logloss:0.65183
# [20]	validation_0-logloss:0.65059
# [21]	validation_0-logloss:0.64915
# [22]	validation_0-logloss:0.64757
# [23]	validation_0-logloss:0.64582
# [24]	validation_0-logloss:0.64416
# [25]	validation_0-logloss:0.64291
# [26]	validation_0-logloss:0.64145
# [27]	validation_0-logloss:0.63999
# [28]	validation_0-logloss:0.63863
# [29]	validation_0-logloss:0.63704
# [30]	validation_0-logloss:0.63601
# [31]	validation_0-logloss:0.63475
# [32]	validation_0-logloss:0.63357
# [33]	validation_0-logloss:0.63232
# [34]	validation_0-logloss:0.63119
# [35]	validation_0-logloss:0.63058
# [36]	validation_0-logloss:0.62931
# [37]	validation_0-logloss:0.62826
# [38]	validation_0-logloss:0.62682
# [39]	validation_0-logloss:0.62541
# [0]	validation_0-logloss:0.69074
# [1]	validation_0-logloss:0.68825
# [2]	validation_0-logloss:0.68575
# [3]	validation_0-logloss:0.68330
# [4]	validation_0-logloss:0.68064
# [5]	validation_0-logloss:0.67820
# [6]	validation_0-logloss:0.67577
# [7]	validation_0-logloss:0.67373
# [8]	validation_0-logloss:0.67140
# [9]	validation_0-logloss:0.66914
# [10]	validation_0-logloss:0.66726
# [11]	validation_0-logloss:0.66525
# [12]	validation_0-logloss:0.66332
# [13]	validation_0-logloss:0.66154
# [14]	validation_0-logloss:0.65961
# [15]	validation_0-logloss:0.65820
# [16]	validation_0-logloss:0.65657
# [17]	validation_0-logloss:0.65482
# [18]	validation_0-logloss:0.65296
# [19]	validation_0-logloss:0.65087
# [20]	validation_0-logloss:0.64942
# [21]	validation_0-logloss:0.64763
# [22]	validation_0-logloss:0.64639
# [23]	validation_0-logloss:0.64489
# [24]	validation_0-logloss:0.64320
# [25]	validation_0-logloss:0.64143
# [26]	validation_0-logloss:0.63953
# [27]	validation_0-logloss:0.63806
# [28]	validation_0-logloss:0.63669
# [29]	validation_0-logloss:0.63513
# [30]	validation_0-logloss:0.63400
# [31]	validation_0-logloss:0.63255
# [32]	validation_0-logloss:0.63133
# [33]	validation_0-logloss:0.62982
# [34]	validation_0-logloss:0.62867
# [35]	validation_0-logloss:0.62718
# [36]	validation_0-logloss:0.62593
# [37]	validation_0-logloss:0.62453
# [38]	validation_0-logloss:0.62334
# [39]	validation_0-logloss:0.62221
# [0]	validation_0-logloss:0.69142
# [1]	validation_0-logloss:0.68864
# [2]	validation_0-logloss:0.68584
# [3]	validation_0-logloss:0.68355
# [4]	validation_0-logloss:0.68162
# [5]	validation_0-logloss:0.67976
# [6]	validation_0-logloss:0.67807
# [7]	validation_0-logloss:0.67549
# [8]	validation_0-logloss:0.67293
# [9]	validation_0-logloss:0.67133
# [10]	validation_0-logloss:0.66968
# [11]	validation_0-logloss:0.66797
# [12]	validation_0-logloss:0.66546
# [13]	validation_0-logloss:0.66403
# [14]	validation_0-logloss:0.66263
# [15]	validation_0-logloss:0.66134
# [16]	validation_0-logloss:0.65901
# [17]	validation_0-logloss:0.65778
# [18]	validation_0-logloss:0.65658
# [19]	validation_0-logloss:0.65514
# [20]	validation_0-logloss:0.65375
# [21]	validation_0-logloss:0.65245
# [22]	validation_0-logloss:0.65113
# [23]	validation_0-logloss:0.65009
# [24]	validation_0-logloss:0.64893
# [25]	validation_0-logloss:0.64705
# [26]	validation_0-logloss:0.64590
# [27]	validation_0-logloss:0.64411
# [28]	validation_0-logloss:0.64237
# [29]	validation_0-logloss:0.64054
# [30]	validation_0-logloss:0.63887
# [31]	validation_0-logloss:0.63727
# [32]	validation_0-logloss:0.63579
# [33]	validation_0-logloss:0.63421
# [34]	validation_0-logloss:0.63240
# [35]	validation_0-logloss:0.63146
# [36]	validation_0-logloss:0.63057
# [37]	validation_0-logloss:0.62969
# [38]	validation_0-logloss:0.62878
# [39]	validation_0-logloss:0.62734
# [0]	validation_0-logloss:0.69124
# [1]	validation_0-logloss:0.68834
# [2]	validation_0-logloss:0.68585
# [3]	validation_0-logloss:0.68352
# [4]	validation_0-logloss:0.68144
# [5]	validation_0-logloss:0.67903
# [6]	validation_0-logloss:0.67672
# [7]	validation_0-logloss:0.67417
# [8]	validation_0-logloss:0.67221
# [9]	validation_0-logloss:0.66977
# [10]	validation_0-logloss:0.66777
# [11]	validation_0-logloss:0.66540
# [12]	validation_0-logloss:0.66343
# [13]	validation_0-logloss:0.66163
# [14]	validation_0-logloss:0.65994
# [15]	validation_0-logloss:0.65842
# [16]	validation_0-logloss:0.65680
# [17]	validation_0-logloss:0.65528
# [18]	validation_0-logloss:0.65301
# [19]	validation_0-logloss:0.65146
# [20]	validation_0-logloss:0.65017
# [21]	validation_0-logloss:0.64802
# [22]	validation_0-logloss:0.64662
# [23]	validation_0-logloss:0.64532
# [24]	validation_0-logloss:0.64382
# [25]	validation_0-logloss:0.64263
# [26]	validation_0-logloss:0.64108
# [27]	validation_0-logloss:0.63936
# [28]	validation_0-logloss:0.63752
# [29]	validation_0-logloss:0.63603
# [30]	validation_0-logloss:0.63478
# [31]	validation_0-logloss:0.63353
# [32]	validation_0-logloss:0.63199
# [33]	validation_0-logloss:0.63087
# [34]	validation_0-logloss:0.62980
# [35]	validation_0-logloss:0.62848
# [36]	validation_0-logloss:0.62756
# [37]	validation_0-logloss:0.62642
# [38]	validation_0-logloss:0.62532
# [39]	validation_0-logloss:0.62383
# [0]	validation_0-logloss:0.69453
# [1]	validation_0-logloss:0.69289
# [2]	validation_0-logloss:0.69160
# [3]	validation_0-logloss:0.69006
# [4]	validation_0-logloss:0.68835
# [5]	validation_0-logloss:0.68687
# [6]	validation_0-logloss:0.68533
# [7]	validation_0-logloss:0.68368
# [8]	validation_0-logloss:0.68202
# [9]	validation_0-logloss:0.68042
# [10]	validation_0-logloss:0.67898
# [11]	validation_0-logloss:0.67730
# [12]	validation_0-logloss:0.67594
# [13]	validation_0-logloss:0.67446
# [14]	validation_0-logloss:0.67303
# [15]	validation_0-logloss:0.67165
# [16]	validation_0-logloss:0.67028
# [17]	validation_0-logloss:0.66872
# [18]	validation_0-logloss:0.66739
# [19]	validation_0-logloss:0.66603
# [20]	validation_0-logloss:0.66471
# [21]	validation_0-logloss:0.66312
# [22]	validation_0-logloss:0.66190
# [23]	validation_0-logloss:0.66072
# [24]	validation_0-logloss:0.65941
# [25]	validation_0-logloss:0.65820
# [26]	validation_0-logloss:0.65709
# [27]	validation_0-logloss:0.65591
# [28]	validation_0-logloss:0.65456
# [29]	validation_0-logloss:0.65335
# [30]	validation_0-logloss:0.65208
# [31]	validation_0-logloss:0.65100
# [32]	validation_0-logloss:0.64983
# [33]	validation_0-logloss:0.64860
# [34]	validation_0-logloss:0.64751
# [35]	validation_0-logloss:0.64653
# [36]	validation_0-logloss:0.64554
# [37]	validation_0-logloss:0.64461
# [38]	validation_0-logloss:0.64341
# [39]	validation_0-logloss:0.64224
# [0]	validation_0-logloss:0.69433
# [1]	validation_0-logloss:0.69261
# [2]	validation_0-logloss:0.69115
# [3]	validation_0-logloss:0.68949
# [4]	validation_0-logloss:0.68807
# [5]	validation_0-logloss:0.68654
# [6]	validation_0-logloss:0.68494
# [7]	validation_0-logloss:0.68345
# [8]	validation_0-logloss:0.68202
# [9]	validation_0-logloss:0.68048
# [10]	validation_0-logloss:0.67907
# [11]	validation_0-logloss:0.67773
# [12]	validation_0-logloss:0.67614
# [13]	validation_0-logloss:0.67465
# [14]	validation_0-logloss:0.67329
# [15]	validation_0-logloss:0.67207
# [16]	validation_0-logloss:0.67053
# [17]	validation_0-logloss:0.66934
# [18]	validation_0-logloss:0.66780
# [19]	validation_0-logloss:0.66631
# [20]	validation_0-logloss:0.66496
# [21]	validation_0-logloss:0.66374
# [22]	validation_0-logloss:0.66231
# [23]	validation_0-logloss:0.66112
# [24]	validation_0-logloss:0.65979
# [25]	validation_0-logloss:0.65867
# [26]	validation_0-logloss:0.65749
# [27]	validation_0-logloss:0.65625
# [28]	validation_0-logloss:0.65517
# [29]	validation_0-logloss:0.65399
# [30]	validation_0-logloss:0.65287
# [31]	validation_0-logloss:0.65200
# [32]	validation_0-logloss:0.65088
# [33]	validation_0-logloss:0.64979
# [34]	validation_0-logloss:0.64874
# [35]	validation_0-logloss:0.64765
# [36]	validation_0-logloss:0.64651
# [37]	validation_0-logloss:0.64539
# [38]	validation_0-logloss:0.64441
# [39]	validation_0-logloss:0.64320
# [0]	validation_0-logloss:0.69421
# [1]	validation_0-logloss:0.69264
# [2]	validation_0-logloss:0.69099
# [3]	validation_0-logloss:0.68953
# [4]	validation_0-logloss:0.68794
# [5]	validation_0-logloss:0.68654
# [6]	validation_0-logloss:0.68519
# [7]	validation_0-logloss:0.68386
# [8]	validation_0-logloss:0.68227
# [9]	validation_0-logloss:0.68073
# [10]	validation_0-logloss:0.67954
# [11]	validation_0-logloss:0.67817
# [12]	validation_0-logloss:0.67667
# [13]	validation_0-logloss:0.67529
# [14]	validation_0-logloss:0.67377
# [15]	validation_0-logloss:0.67241
# [16]	validation_0-logloss:0.67105
# [17]	validation_0-logloss:0.66971
# [18]	validation_0-logloss:0.66846
# [19]	validation_0-logloss:0.66702
# [20]	validation_0-logloss:0.66560
# [21]	validation_0-logloss:0.66439
# [22]	validation_0-logloss:0.66326
# [23]	validation_0-logloss:0.66196
# [24]	validation_0-logloss:0.66066
# [25]	validation_0-logloss:0.65938
# [26]	validation_0-logloss:0.65818
# [27]	validation_0-logloss:0.65722
# [28]	validation_0-logloss:0.65610
# [29]	validation_0-logloss:0.65488
# [30]	validation_0-logloss:0.65378
# [31]	validation_0-logloss:0.65253
# [32]	validation_0-logloss:0.65145
# [33]	validation_0-logloss:0.65018
# [34]	validation_0-logloss:0.64915
# [35]	validation_0-logloss:0.64808
# [36]	validation_0-logloss:0.64686
# [37]	validation_0-logloss:0.64577
# [38]	validation_0-logloss:0.64476
# [39]	validation_0-logloss:0.64379
# [0]	validation_0-logloss:0.69468
# [1]	validation_0-logloss:0.69305
# [2]	validation_0-logloss:0.69166
# [3]	validation_0-logloss:0.69013
# [4]	validation_0-logloss:0.68846
# [5]	validation_0-logloss:0.68689
# [6]	validation_0-logloss:0.68541
# [7]	validation_0-logloss:0.68389
# [8]	validation_0-logloss:0.68239
# [9]	validation_0-logloss:0.68118
# [10]	validation_0-logloss:0.67972
# [11]	validation_0-logloss:0.67823
# [12]	validation_0-logloss:0.67673
# [13]	validation_0-logloss:0.67535
# [14]	validation_0-logloss:0.67397
# [15]	validation_0-logloss:0.67271
# [16]	validation_0-logloss:0.67132
# [17]	validation_0-logloss:0.67010
# [18]	validation_0-logloss:0.66887
# [19]	validation_0-logloss:0.66759
# [20]	validation_0-logloss:0.66642
# [21]	validation_0-logloss:0.66510
# [22]	validation_0-logloss:0.66393
# [23]	validation_0-logloss:0.66271
# [24]	validation_0-logloss:0.66158
# [25]	validation_0-logloss:0.66034
# [26]	validation_0-logloss:0.65923
# [27]	validation_0-logloss:0.65813
# [28]	validation_0-logloss:0.65693
# [29]	validation_0-logloss:0.65567
# [30]	validation_0-logloss:0.65457
# [31]	validation_0-logloss:0.65347
# [32]	validation_0-logloss:0.65244
# [33]	validation_0-logloss:0.65129
# [34]	validation_0-logloss:0.65007
# [35]	validation_0-logloss:0.64913
# [36]	validation_0-logloss:0.64810
# [37]	validation_0-logloss:0.64702
# [38]	validation_0-logloss:0.64602
# [39]	validation_0-logloss:0.64504
# [0]	validation_0-logloss:0.69473
# [1]	validation_0-logloss:0.69306
# [2]	validation_0-logloss:0.69131
# [3]	validation_0-logloss:0.68970
# [4]	validation_0-logloss:0.68818
# [5]	validation_0-logloss:0.68656
# [6]	validation_0-logloss:0.68483
# [7]	validation_0-logloss:0.68323
# [8]	validation_0-logloss:0.68173
# [9]	validation_0-logloss:0.68019
# [10]	validation_0-logloss:0.67867
# [11]	validation_0-logloss:0.67711
# [12]	validation_0-logloss:0.67558
# [13]	validation_0-logloss:0.67421
# [14]	validation_0-logloss:0.67271
# [15]	validation_0-logloss:0.67146
# [16]	validation_0-logloss:0.67001
# [17]	validation_0-logloss:0.66854
# [18]	validation_0-logloss:0.66701
# [19]	validation_0-logloss:0.66563
# [20]	validation_0-logloss:0.66414
# [21]	validation_0-logloss:0.66286
# [22]	validation_0-logloss:0.66177
# [23]	validation_0-logloss:0.66046
# [24]	validation_0-logloss:0.65906
# [25]	validation_0-logloss:0.65786
# [26]	validation_0-logloss:0.65666
# [27]	validation_0-logloss:0.65532
# [28]	validation_0-logloss:0.65410
# [29]	validation_0-logloss:0.65286
# [30]	validation_0-logloss:0.65151
# [31]	validation_0-logloss:0.65016
# [32]	validation_0-logloss:0.64887
# [33]	validation_0-logloss:0.64774
# [34]	validation_0-logloss:0.64657
# [35]	validation_0-logloss:0.64564
# [36]	validation_0-logloss:0.64443
# [37]	validation_0-logloss:0.64332
# [38]	validation_0-logloss:0.64216
# [39]	validation_0-logloss:0.64117
# [0]	validation_0-logloss:0.69156
# [1]	validation_0-logloss:0.69020
# [2]	validation_0-logloss:0.68899
# [3]	validation_0-logloss:0.68737
# [4]	validation_0-logloss:0.68568
# [5]	validation_0-logloss:0.68445
# [6]	validation_0-logloss:0.68296
# [7]	validation_0-logloss:0.68199
# [8]	validation_0-logloss:0.68035
# [9]	validation_0-logloss:0.67905
# [10]	validation_0-logloss:0.67783
# [11]	validation_0-logloss:0.67654
# [12]	validation_0-logloss:0.67529
# [13]	validation_0-logloss:0.67375
# [14]	validation_0-logloss:0.67248
# [15]	validation_0-logloss:0.67140
# [16]	validation_0-logloss:0.67013
# [17]	validation_0-logloss:0.66888
# [18]	validation_0-logloss:0.66753
# [19]	validation_0-logloss:0.66652
# [20]	validation_0-logloss:0.66543
# [21]	validation_0-logloss:0.66413
# [22]	validation_0-logloss:0.66293
# [23]	validation_0-logloss:0.66188
# [24]	validation_0-logloss:0.66072
# [25]	validation_0-logloss:0.65985
# [26]	validation_0-logloss:0.65868
# [27]	validation_0-logloss:0.65782
# [28]	validation_0-logloss:0.65646
# [29]	validation_0-logloss:0.65554
# [30]	validation_0-logloss:0.65464
# [31]	validation_0-logloss:0.65366
# [32]	validation_0-logloss:0.65284
# [33]	validation_0-logloss:0.65196
# [34]	validation_0-logloss:0.65108
# [35]	validation_0-logloss:0.65016
# [36]	validation_0-logloss:0.64952
# [37]	validation_0-logloss:0.64869
# [38]	validation_0-logloss:0.64747
# [39]	validation_0-logloss:0.64653
# [0]	validation_0-logloss:0.69157
# [1]	validation_0-logloss:0.69023
# [2]	validation_0-logloss:0.68852
# [3]	validation_0-logloss:0.68699
# [4]	validation_0-logloss:0.68542
# [5]	validation_0-logloss:0.68391
# [6]	validation_0-logloss:0.68264
# [7]	validation_0-logloss:0.68112
# [8]	validation_0-logloss:0.67972
# [9]	validation_0-logloss:0.67833
# [10]	validation_0-logloss:0.67702
# [11]	validation_0-logloss:0.67560
# [12]	validation_0-logloss:0.67458
# [13]	validation_0-logloss:0.67302
# [14]	validation_0-logloss:0.67167
# [15]	validation_0-logloss:0.67062
# [16]	validation_0-logloss:0.66939
# [17]	validation_0-logloss:0.66830
# [18]	validation_0-logloss:0.66714
# [19]	validation_0-logloss:0.66574
# [20]	validation_0-logloss:0.66460
# [21]	validation_0-logloss:0.66350
# [22]	validation_0-logloss:0.66239
# [23]	validation_0-logloss:0.66127
# [24]	validation_0-logloss:0.66016
# [25]	validation_0-logloss:0.65907
# [26]	validation_0-logloss:0.65829
# [27]	validation_0-logloss:0.65728
# [28]	validation_0-logloss:0.65657
# [29]	validation_0-logloss:0.65530
# [30]	validation_0-logloss:0.65437
# [31]	validation_0-logloss:0.65333
# [32]	validation_0-logloss:0.65232
# [33]	validation_0-logloss:0.65132
# [34]	validation_0-logloss:0.64994
# [35]	validation_0-logloss:0.64914
# [36]	validation_0-logloss:0.64824
# [37]	validation_0-logloss:0.64727
# [38]	validation_0-logloss:0.64626
# [39]	validation_0-logloss:0.64521
# [0]	validation_0-logloss:0.69180
# [1]	validation_0-logloss:0.69029
# [2]	validation_0-logloss:0.68897
# [3]	validation_0-logloss:0.68763
# [4]	validation_0-logloss:0.68552
# [5]	validation_0-logloss:0.68400
# [6]	validation_0-logloss:0.68265
# [7]	validation_0-logloss:0.68157
# [8]	validation_0-logloss:0.67995
# [9]	validation_0-logloss:0.67850
# [10]	validation_0-logloss:0.67723
# [11]	validation_0-logloss:0.67619
# [12]	validation_0-logloss:0.67501
# [13]	validation_0-logloss:0.67396
# [14]	validation_0-logloss:0.67237
# [15]	validation_0-logloss:0.67124
# [16]	validation_0-logloss:0.67010
# [17]	validation_0-logloss:0.66891
# [18]	validation_0-logloss:0.66779
# [19]	validation_0-logloss:0.66639
# [20]	validation_0-logloss:0.66533
# [21]	validation_0-logloss:0.66411
# [22]	validation_0-logloss:0.66322
# [23]	validation_0-logloss:0.66227
# [24]	validation_0-logloss:0.66115
# [25]	validation_0-logloss:0.66026
# [26]	validation_0-logloss:0.65939
# [27]	validation_0-logloss:0.65865
# [28]	validation_0-logloss:0.65784
# [29]	validation_0-logloss:0.65672
# [30]	validation_0-logloss:0.65561
# [31]	validation_0-logloss:0.65465
# [32]	validation_0-logloss:0.65344
# [33]	validation_0-logloss:0.65239
# [34]	validation_0-logloss:0.65148
# [35]	validation_0-logloss:0.65070
# [36]	validation_0-logloss:0.64977
# [37]	validation_0-logloss:0.64870
# [38]	validation_0-logloss:0.64771
# [39]	validation_0-logloss:0.64698
# [0]	validation_0-logloss:0.69197
# [1]	validation_0-logloss:0.69060
# [2]	validation_0-logloss:0.68916
# [3]	validation_0-logloss:0.68774
# [4]	validation_0-logloss:0.68620
# [5]	validation_0-logloss:0.68521
# [6]	validation_0-logloss:0.68387
# [7]	validation_0-logloss:0.68250
# [8]	validation_0-logloss:0.68110
# [9]	validation_0-logloss:0.67954
# [10]	validation_0-logloss:0.67841
# [11]	validation_0-logloss:0.67715
# [12]	validation_0-logloss:0.67609
# [13]	validation_0-logloss:0.67483
# [14]	validation_0-logloss:0.67352
# [15]	validation_0-logloss:0.67273
# [16]	validation_0-logloss:0.67161
# [17]	validation_0-logloss:0.67041
# [18]	validation_0-logloss:0.66930
# [19]	validation_0-logloss:0.66815
# [20]	validation_0-logloss:0.66702
# [21]	validation_0-logloss:0.66586
# [22]	validation_0-logloss:0.66466
# [23]	validation_0-logloss:0.66374
# [24]	validation_0-logloss:0.66237
# [25]	validation_0-logloss:0.66142
# [26]	validation_0-logloss:0.66050
# [27]	validation_0-logloss:0.65969
# [28]	validation_0-logloss:0.65840
# [29]	validation_0-logloss:0.65734
# [30]	validation_0-logloss:0.65622
# [31]	validation_0-logloss:0.65511
# [32]	validation_0-logloss:0.65415
# [33]	validation_0-logloss:0.65322
# [34]	validation_0-logloss:0.65209
# [35]	validation_0-logloss:0.65124
# [36]	validation_0-logloss:0.65041
# [37]	validation_0-logloss:0.64944
# [38]	validation_0-logloss:0.64863
# [39]	validation_0-logloss:0.64783
# [0]	validation_0-logloss:0.69163
# [1]	validation_0-logloss:0.69001
# [2]	validation_0-logloss:0.68860
# [3]	validation_0-logloss:0.68712
# [4]	validation_0-logloss:0.68545
# [5]	validation_0-logloss:0.68403
# [6]	validation_0-logloss:0.68274
# [7]	validation_0-logloss:0.68131
# [8]	validation_0-logloss:0.68005
# [9]	validation_0-logloss:0.67861
# [10]	validation_0-logloss:0.67712
# [11]	validation_0-logloss:0.67566
# [12]	validation_0-logloss:0.67402
# [13]	validation_0-logloss:0.67281
# [14]	validation_0-logloss:0.67166
# [15]	validation_0-logloss:0.67052
# [16]	validation_0-logloss:0.66924
# [17]	validation_0-logloss:0.66799
# [18]	validation_0-logloss:0.66645
# [19]	validation_0-logloss:0.66534
# [20]	validation_0-logloss:0.66422
# [21]	validation_0-logloss:0.66282
# [22]	validation_0-logloss:0.66156
# [23]	validation_0-logloss:0.66065
# [24]	validation_0-logloss:0.65941
# [25]	validation_0-logloss:0.65857
# [26]	validation_0-logloss:0.65753
# [27]	validation_0-logloss:0.65643
# [28]	validation_0-logloss:0.65516
# [29]	validation_0-logloss:0.65407
# [30]	validation_0-logloss:0.65293
# [31]	validation_0-logloss:0.65142
# [32]	validation_0-logloss:0.65030
# [33]	validation_0-logloss:0.64934
# [34]	validation_0-logloss:0.64851
# [35]	validation_0-logloss:0.64751
# [36]	validation_0-logloss:0.64661
# [37]	validation_0-logloss:0.64546
# [38]	validation_0-logloss:0.64463
# [39]	validation_0-logloss:0.64365
# [0]	validation_0-logloss:0.69460
# [1]	validation_0-logloss:0.69265
# [2]	validation_0-logloss:0.69125
# [3]	validation_0-logloss:0.68981
# [4]	validation_0-logloss:0.68810
# [5]	validation_0-logloss:0.68660
# [6]	validation_0-logloss:0.68504
# [7]	validation_0-logloss:0.68394
# [8]	validation_0-logloss:0.68207
# [9]	validation_0-logloss:0.68101
# [10]	validation_0-logloss:0.67952
# [11]	validation_0-logloss:0.67787
# [12]	validation_0-logloss:0.67632
# [13]	validation_0-logloss:0.67497
# [14]	validation_0-logloss:0.67375
# [15]	validation_0-logloss:0.67252
# [16]	validation_0-logloss:0.67089
# [17]	validation_0-logloss:0.66947
# [18]	validation_0-logloss:0.66816
# [19]	validation_0-logloss:0.66693
# [20]	validation_0-logloss:0.66567
# [21]	validation_0-logloss:0.66469
# [22]	validation_0-logloss:0.66342
# [23]	validation_0-logloss:0.66246
# [24]	validation_0-logloss:0.66110
# [25]	validation_0-logloss:0.66000
# [26]	validation_0-logloss:0.65853
# [27]	validation_0-logloss:0.65733
# [28]	validation_0-logloss:0.65614
# [29]	validation_0-logloss:0.65522
# [30]	validation_0-logloss:0.65437
# [31]	validation_0-logloss:0.65300
# [32]	validation_0-logloss:0.65189
# [33]	validation_0-logloss:0.65075
# [34]	validation_0-logloss:0.65005
# [35]	validation_0-logloss:0.64889
# [36]	validation_0-logloss:0.64819
# [37]	validation_0-logloss:0.64713
# [38]	validation_0-logloss:0.64588
# [39]	validation_0-logloss:0.64463
# [0]	validation_0-logloss:0.69469
# [1]	validation_0-logloss:0.69324
# [2]	validation_0-logloss:0.69142
# [3]	validation_0-logloss:0.69001
# [4]	validation_0-logloss:0.68841
# [5]	validation_0-logloss:0.68657
# [6]	validation_0-logloss:0.68484
# [7]	validation_0-logloss:0.68334
# [8]	validation_0-logloss:0.68175
# [9]	validation_0-logloss:0.68029
# [10]	validation_0-logloss:0.67883
# [11]	validation_0-logloss:0.67709
# [12]	validation_0-logloss:0.67600
# [13]	validation_0-logloss:0.67452
# [14]	validation_0-logloss:0.67317
# [15]	validation_0-logloss:0.67198
# [16]	validation_0-logloss:0.67066
# [17]	validation_0-logloss:0.66937
# [18]	validation_0-logloss:0.66818
# [19]	validation_0-logloss:0.66659
# [20]	validation_0-logloss:0.66569
# [21]	validation_0-logloss:0.66434
# [22]	validation_0-logloss:0.66315
# [23]	validation_0-logloss:0.66189
# [24]	validation_0-logloss:0.66079
# [25]	validation_0-logloss:0.65977
# [26]	validation_0-logloss:0.65880
# [27]	validation_0-logloss:0.65745
# [28]	validation_0-logloss:0.65649
# [29]	validation_0-logloss:0.65533
# [30]	validation_0-logloss:0.65442
# [31]	validation_0-logloss:0.65334
# [32]	validation_0-logloss:0.65219
# [33]	validation_0-logloss:0.65114
# [34]	validation_0-logloss:0.65021
# [35]	validation_0-logloss:0.64935
# [36]	validation_0-logloss:0.64842
# [37]	validation_0-logloss:0.64743
# [38]	validation_0-logloss:0.64615
# [39]	validation_0-logloss:0.64505
# [0]	validation_0-logloss:0.69467
# [1]	validation_0-logloss:0.69292
# [2]	validation_0-logloss:0.69123
# [3]	validation_0-logloss:0.68951
# [4]	validation_0-logloss:0.68774
# [5]	validation_0-logloss:0.68580
# [6]	validation_0-logloss:0.68414
# [7]	validation_0-logloss:0.68275
# [8]	validation_0-logloss:0.68095
# [9]	validation_0-logloss:0.67935
# [10]	validation_0-logloss:0.67794
# [11]	validation_0-logloss:0.67653
# [12]	validation_0-logloss:0.67506
# [13]	validation_0-logloss:0.67373
# [14]	validation_0-logloss:0.67194
# [15]	validation_0-logloss:0.67082
# [16]	validation_0-logloss:0.66957
# [17]	validation_0-logloss:0.66813
# [18]	validation_0-logloss:0.66666
# [19]	validation_0-logloss:0.66546
# [20]	validation_0-logloss:0.66420
# [21]	validation_0-logloss:0.66290
# [22]	validation_0-logloss:0.66190
# [23]	validation_0-logloss:0.66060
# [24]	validation_0-logloss:0.65934
# [25]	validation_0-logloss:0.65845
# [26]	validation_0-logloss:0.65730
# [27]	validation_0-logloss:0.65627
# [28]	validation_0-logloss:0.65517
# [29]	validation_0-logloss:0.65420
# [30]	validation_0-logloss:0.65306
# [31]	validation_0-logloss:0.65195
# [32]	validation_0-logloss:0.65098
# [33]	validation_0-logloss:0.64964
# [34]	validation_0-logloss:0.64861
# [35]	validation_0-logloss:0.64732
# [36]	validation_0-logloss:0.64606
# [37]	validation_0-logloss:0.64486
# [38]	validation_0-logloss:0.64380
# [39]	validation_0-logloss:0.64274
# [0]	validation_0-logloss:0.69545
# [1]	validation_0-logloss:0.69416
# [2]	validation_0-logloss:0.69223
# [3]	validation_0-logloss:0.69055
# [4]	validation_0-logloss:0.68865
# [5]	validation_0-logloss:0.68737
# [6]	validation_0-logloss:0.68560
# [7]	validation_0-logloss:0.68439
# [8]	validation_0-logloss:0.68314
# [9]	validation_0-logloss:0.68115
# [10]	validation_0-logloss:0.67969
# [11]	validation_0-logloss:0.67844
# [12]	validation_0-logloss:0.67658
# [13]	validation_0-logloss:0.67528
# [14]	validation_0-logloss:0.67409
# [15]	validation_0-logloss:0.67307
# [16]	validation_0-logloss:0.67191
# [17]	validation_0-logloss:0.67074
# [18]	validation_0-logloss:0.66960
# [19]	validation_0-logloss:0.66867
# [20]	validation_0-logloss:0.66744
# [21]	validation_0-logloss:0.66639
# [22]	validation_0-logloss:0.66537
# [23]	validation_0-logloss:0.66433
# [24]	validation_0-logloss:0.66318
# [25]	validation_0-logloss:0.66210
# [26]	validation_0-logloss:0.66115
# [27]	validation_0-logloss:0.66033
# [28]	validation_0-logloss:0.65953
# [29]	validation_0-logloss:0.65794
# [30]	validation_0-logloss:0.65716
# [31]	validation_0-logloss:0.65582
# [32]	validation_0-logloss:0.65465
# [33]	validation_0-logloss:0.65349
# [34]	validation_0-logloss:0.65198
# [35]	validation_0-logloss:0.65073
# [36]	validation_0-logloss:0.64996
# [37]	validation_0-logloss:0.64915
# [38]	validation_0-logloss:0.64836
# [39]	validation_0-logloss:0.64729
# [0]	validation_0-logloss:0.69522
# [1]	validation_0-logloss:0.69322
# [2]	validation_0-logloss:0.69160
# [3]	validation_0-logloss:0.69015
# [4]	validation_0-logloss:0.68863
# [5]	validation_0-logloss:0.68701
# [6]	validation_0-logloss:0.68541
# [7]	validation_0-logloss:0.68388
# [8]	validation_0-logloss:0.68245
# [9]	validation_0-logloss:0.68074
# [10]	validation_0-logloss:0.67907
# [11]	validation_0-logloss:0.67746
# [12]	validation_0-logloss:0.67593
# [13]	validation_0-logloss:0.67472
# [14]	validation_0-logloss:0.67368
# [15]	validation_0-logloss:0.67258
# [16]	validation_0-logloss:0.67116
# [17]	validation_0-logloss:0.67006
# [18]	validation_0-logloss:0.66821
# [19]	validation_0-logloss:0.66695
# [20]	validation_0-logloss:0.66580
# [21]	validation_0-logloss:0.66419
# [22]	validation_0-logloss:0.66310
# [23]	validation_0-logloss:0.66196
# [24]	validation_0-logloss:0.66042
# [25]	validation_0-logloss:0.65957
# [26]	validation_0-logloss:0.65842
# [27]	validation_0-logloss:0.65695
# [28]	validation_0-logloss:0.65588
# [29]	validation_0-logloss:0.65495
# [30]	validation_0-logloss:0.65377
# [31]	validation_0-logloss:0.65253
# [32]	validation_0-logloss:0.65160
# [33]	validation_0-logloss:0.65065
# [34]	validation_0-logloss:0.64963
# [35]	validation_0-logloss:0.64884
# [36]	validation_0-logloss:0.64806
# [37]	validation_0-logloss:0.64695
# [38]	validation_0-logloss:0.64551
# [39]	validation_0-logloss:0.64457
# [0]	validation_0-logloss:0.70461
# [1]	validation_0-logloss:0.69913
# [2]	validation_0-logloss:0.69495
# [3]	validation_0-logloss:0.69071
# [4]	validation_0-logloss:0.68658
# [5]	validation_0-logloss:0.68202
# [6]	validation_0-logloss:0.67841
# [7]	validation_0-logloss:0.67492
# [8]	validation_0-logloss:0.67125
# [9]	validation_0-logloss:0.66887
# [0]	validation_0-logloss:0.70497
# [1]	validation_0-logloss:0.70046
# [2]	validation_0-logloss:0.69546
# [3]	validation_0-logloss:0.69111
# [4]	validation_0-logloss:0.68699
# [5]	validation_0-logloss:0.68261
# [6]	validation_0-logloss:0.67937
# [7]	validation_0-logloss:0.67607
# [8]	validation_0-logloss:0.67228
# [9]	validation_0-logloss:0.66905
# [0]	validation_0-logloss:0.70382
# [1]	validation_0-logloss:0.69868
# [2]	validation_0-logloss:0.69404
# [3]	validation_0-logloss:0.69032
# [4]	validation_0-logloss:0.68592
# [5]	validation_0-logloss:0.68130
# [6]	validation_0-logloss:0.67817
# [7]	validation_0-logloss:0.67499
# [8]	validation_0-logloss:0.67064
# [9]	validation_0-logloss:0.66668
# [0]	validation_0-logloss:0.70584
# [1]	validation_0-logloss:0.70131
# [2]	validation_0-logloss:0.69682
# [3]	validation_0-logloss:0.69253
# [4]	validation_0-logloss:0.68863
# [5]	validation_0-logloss:0.68507
# [6]	validation_0-logloss:0.68196
# [7]	validation_0-logloss:0.67805
# [8]	validation_0-logloss:0.67434
# [9]	validation_0-logloss:0.67158
# [0]	validation_0-logloss:0.70506
# [1]	validation_0-logloss:0.69995
# [2]	validation_0-logloss:0.69479
# [3]	validation_0-logloss:0.69055
# [4]	validation_0-logloss:0.68626
# [5]	validation_0-logloss:0.68210
# [6]	validation_0-logloss:0.67745
# [7]	validation_0-logloss:0.67390
# [8]	validation_0-logloss:0.67009
# [9]	validation_0-logloss:0.66634
# [0]	validation_0-logloss:0.70920
# [1]	validation_0-logloss:0.70629
# [2]	validation_0-logloss:0.70399
# [3]	validation_0-logloss:0.70142
# [4]	validation_0-logloss:0.69882
# [5]	validation_0-logloss:0.69600
# [6]	validation_0-logloss:0.69337
# [7]	validation_0-logloss:0.69163
# [8]	validation_0-logloss:0.68893
# [9]	validation_0-logloss:0.68663
# [0]	validation_0-logloss:0.70983
# [1]	validation_0-logloss:0.70710
# [2]	validation_0-logloss:0.70406
# [3]	validation_0-logloss:0.70171
# [4]	validation_0-logloss:0.69891
# [5]	validation_0-logloss:0.69599
# [6]	validation_0-logloss:0.69346
# [7]	validation_0-logloss:0.69095
# [8]	validation_0-logloss:0.68827
# [9]	validation_0-logloss:0.68579
# [0]	validation_0-logloss:0.70975
# [1]	validation_0-logloss:0.70680
# [2]	validation_0-logloss:0.70407
# [3]	validation_0-logloss:0.70172
# [4]	validation_0-logloss:0.69820
# [5]	validation_0-logloss:0.69526
# [6]	validation_0-logloss:0.69294
# [7]	validation_0-logloss:0.69084
# [8]	validation_0-logloss:0.68850
# [9]	validation_0-logloss:0.68597
# [0]	validation_0-logloss:0.70859
# [1]	validation_0-logloss:0.70594
# [2]	validation_0-logloss:0.70294
# [3]	validation_0-logloss:0.70005
# [4]	validation_0-logloss:0.69691
# [5]	validation_0-logloss:0.69437
# [6]	validation_0-logloss:0.69180
# [7]	validation_0-logloss:0.68938
# [8]	validation_0-logloss:0.68663
# [9]	validation_0-logloss:0.68454
# [0]	validation_0-logloss:0.70776
# [1]	validation_0-logloss:0.70492
# [2]	validation_0-logloss:0.70180
# [3]	validation_0-logloss:0.69887
# [4]	validation_0-logloss:0.69606
# [5]	validation_0-logloss:0.69307
# [6]	validation_0-logloss:0.69027
# [7]	validation_0-logloss:0.68737
# [8]	validation_0-logloss:0.68494
# [9]	validation_0-logloss:0.68221
# [0]	validation_0-logloss:0.69240
# [1]	validation_0-logloss:0.69152
# [2]	validation_0-logloss:0.69068
# [3]	validation_0-logloss:0.68984
# [4]	validation_0-logloss:0.68890
# [5]	validation_0-logloss:0.68807
# [6]	validation_0-logloss:0.68717
# [7]	validation_0-logloss:0.68621
# [8]	validation_0-logloss:0.68521
# [9]	validation_0-logloss:0.68438
# [10]	validation_0-logloss:0.68347
# [11]	validation_0-logloss:0.68263
# [12]	validation_0-logloss:0.68183
# [13]	validation_0-logloss:0.68094
# [14]	validation_0-logloss:0.68011
# [15]	validation_0-logloss:0.67922
# [16]	validation_0-logloss:0.67834
# [17]	validation_0-logloss:0.67745
# [18]	validation_0-logloss:0.67666
# [19]	validation_0-logloss:0.67579
# [20]	validation_0-logloss:0.67501
# [21]	validation_0-logloss:0.67417
# [22]	validation_0-logloss:0.67340
# [23]	validation_0-logloss:0.67263
# [24]	validation_0-logloss:0.67185
# [25]	validation_0-logloss:0.67115
# [26]	validation_0-logloss:0.67041
# [27]	validation_0-logloss:0.66965
# [28]	validation_0-logloss:0.66882
# [29]	validation_0-logloss:0.66812
# [0]	validation_0-logloss:0.69235
# [1]	validation_0-logloss:0.69138
# [2]	validation_0-logloss:0.69046
# [3]	validation_0-logloss:0.68969
# [4]	validation_0-logloss:0.68885
# [5]	validation_0-logloss:0.68795
# [6]	validation_0-logloss:0.68701
# [7]	validation_0-logloss:0.68606
# [8]	validation_0-logloss:0.68527
# [9]	validation_0-logloss:0.68437
# [10]	validation_0-logloss:0.68339
# [11]	validation_0-logloss:0.68249
# [12]	validation_0-logloss:0.68173
# [13]	validation_0-logloss:0.68086
# [14]	validation_0-logloss:0.68005
# [15]	validation_0-logloss:0.67925
# [16]	validation_0-logloss:0.67844
# [17]	validation_0-logloss:0.67761
# [18]	validation_0-logloss:0.67686
# [19]	validation_0-logloss:0.67596
# [20]	validation_0-logloss:0.67517
# [21]	validation_0-logloss:0.67444
# [22]	validation_0-logloss:0.67358
# [23]	validation_0-logloss:0.67280
# [24]	validation_0-logloss:0.67202
# [25]	validation_0-logloss:0.67136
# [26]	validation_0-logloss:0.67059
# [27]	validation_0-logloss:0.66993
# ...
# [9]	validation_0-logloss:0.64860
# [10]	validation_0-logloss:0.64523
# [11]	validation_0-logloss:0.64192
# [12]	validation_0-logloss:0.63869
# [13]	validation_0-logloss:0.63579
# [14]	validation_0-logloss:0.63227
# [15]	validation_0-logloss:0.62993
# [16]	validation_0-logloss:0.62740
# [17]	validation_0-logloss:0.62401
# [18]	validation_0-logloss:0.62132
# [19]	validation_0-logloss:0.61922
# [0]	validation_0-logloss:0.69447
# [1]	validation_0-logloss:0.68924
# [2]	validation_0-logloss:0.68206
# [3]	validation_0-logloss:0.67696
# [4]	validation_0-logloss:0.67067
# [5]	validation_0-logloss:0.66616
# [6]	validation_0-logloss:0.66240
# [7]	validation_0-logloss:0.65871
# [8]	validation_0-logloss:0.65341
# [9]	validation_0-logloss:0.65051
# [10]	validation_0-logloss:0.64772
# [11]	validation_0-logloss:0.64509
# [12]	validation_0-logloss:0.64304
# [13]	validation_0-logloss:0.63907
# [14]	validation_0-logloss:0.63671
# [15]	validation_0-logloss:0.63476
# [16]	validation_0-logloss:0.63260
# [17]	validation_0-logloss:0.63005
# [18]	validation_0-logloss:0.62680
# [19]	validation_0-logloss:0.62499
# [0]	validation_0-logloss:0.69346
# [1]	validation_0-logloss:0.68626
# [2]	validation_0-logloss:0.68222
# [3]	validation_0-logloss:0.67773
# [4]	validation_0-logloss:0.67274
# [5]	validation_0-logloss:0.66836
# [6]	validation_0-logloss:0.66259
# [7]	validation_0-logloss:0.65748
# [8]	validation_0-logloss:0.65340
# [9]	validation_0-logloss:0.64864
# [10]	validation_0-logloss:0.64477
# [11]	validation_0-logloss:0.64092
# [12]	validation_0-logloss:0.63695
# [13]	validation_0-logloss:0.63426
# [14]	validation_0-logloss:0.63160
# [15]	validation_0-logloss:0.62877
# [16]	validation_0-logloss:0.62468
# [17]	validation_0-logloss:0.62256
# [18]	validation_0-logloss:0.61872
# [19]	validation_0-logloss:0.61657
# [0]	validation_0-logloss:0.69804
# [1]	validation_0-logloss:0.69383
# [2]	validation_0-logloss:0.69015
# [3]	validation_0-logloss:0.68694
# [4]	validation_0-logloss:0.68312
# [5]	validation_0-logloss:0.67973
# [6]	validation_0-logloss:0.67641
# [7]	validation_0-logloss:0.67432
# [8]	validation_0-logloss:0.67049
# [9]	validation_0-logloss:0.66848
# [0]	validation_0-logloss:0.69968
# [1]	validation_0-logloss:0.69576
# [2]	validation_0-logloss:0.69169
# [3]	validation_0-logloss:0.68811
# [4]	validation_0-logloss:0.68395
# [5]	validation_0-logloss:0.68017
# [6]	validation_0-logloss:0.67667
# [7]	validation_0-logloss:0.67345
# [8]	validation_0-logloss:0.67062
# [9]	validation_0-logloss:0.66798
# [0]	validation_0-logloss:0.69885
# [1]	validation_0-logloss:0.69452
# [2]	validation_0-logloss:0.69022
# [3]	validation_0-logloss:0.68618
# [4]	validation_0-logloss:0.68214
# [5]	validation_0-logloss:0.67766
# [6]	validation_0-logloss:0.67414
# [7]	validation_0-logloss:0.67178
# [8]	validation_0-logloss:0.66866
# [9]	validation_0-logloss:0.66560
# [0]	validation_0-logloss:0.69902
# [1]	validation_0-logloss:0.69543
# [2]	validation_0-logloss:0.69027
# [3]	validation_0-logloss:0.68620
# [4]	validation_0-logloss:0.68139
# [5]	validation_0-logloss:0.67863
# [6]	validation_0-logloss:0.67576
# [7]	validation_0-logloss:0.67294
# [8]	validation_0-logloss:0.66869
# [9]	validation_0-logloss:0.66636
# [0]	validation_0-logloss:0.69735
# [1]	validation_0-logloss:0.69258
# [2]	validation_0-logloss:0.68868
# [3]	validation_0-logloss:0.68533
# [4]	validation_0-logloss:0.68205
# [5]	validation_0-logloss:0.67866
# [6]	validation_0-logloss:0.67478
# [7]	validation_0-logloss:0.67114
# [8]	validation_0-logloss:0.66828
# [9]	validation_0-logloss:0.66474
# [0]	validation_0-logloss:0.70630
# [1]	validation_0-logloss:0.70125
# [2]	validation_0-logloss:0.69647
# [3]	validation_0-logloss:0.69167
# [4]	validation_0-logloss:0.68692
# [5]	validation_0-logloss:0.68253
# [6]	validation_0-logloss:0.67852
# [7]	validation_0-logloss:0.67566
# [8]	validation_0-logloss:0.67139
# [9]	validation_0-logloss:0.66755
# [10]	validation_0-logloss:0.66383
# [11]	validation_0-logloss:0.66052
# [12]	validation_0-logloss:0.65839
# [13]	validation_0-logloss:0.65492
# [14]	validation_0-logloss:0.65124
# [15]	validation_0-logloss:0.64852
# [16]	validation_0-logloss:0.64526
# [17]	validation_0-logloss:0.64205
# [18]	validation_0-logloss:0.63943
# [19]	validation_0-logloss:0.63732
# [0]	validation_0-logloss:0.70831
# [1]	validation_0-logloss:0.70331
# [2]	validation_0-logloss:0.69809
# [3]	validation_0-logloss:0.69254
# [4]	validation_0-logloss:0.68844
# [5]	validation_0-logloss:0.68362
# [6]	validation_0-logloss:0.67948
# [7]	validation_0-logloss:0.67539
# [8]	validation_0-logloss:0.67219
# [9]	validation_0-logloss:0.66853
# [10]	validation_0-logloss:0.66426
# [11]	validation_0-logloss:0.66060
# [12]	validation_0-logloss:0.65833
# [13]	validation_0-logloss:0.65518
# [14]	validation_0-logloss:0.65210
# [15]	validation_0-logloss:0.64968
# [16]	validation_0-logloss:0.64666
# [17]	validation_0-logloss:0.64364
# [18]	validation_0-logloss:0.64170
# [19]	validation_0-logloss:0.63902
# [0]	validation_0-logloss:0.70797
# [1]	validation_0-logloss:0.70297
# [2]	validation_0-logloss:0.69744
# [3]	validation_0-logloss:0.69218
# [4]	validation_0-logloss:0.68693
# [5]	validation_0-logloss:0.68235
# [6]	validation_0-logloss:0.67779
# [7]	validation_0-logloss:0.67364
# [8]	validation_0-logloss:0.66995
# [9]	validation_0-logloss:0.66626
# [10]	validation_0-logloss:0.66292
# [11]	validation_0-logloss:0.66001
# [12]	validation_0-logloss:0.65696
# [13]	validation_0-logloss:0.65408
# [14]	validation_0-logloss:0.65066
# [15]	validation_0-logloss:0.64849
# [16]	validation_0-logloss:0.64629
# [17]	validation_0-logloss:0.64343
# [18]	validation_0-logloss:0.64160
# [19]	validation_0-logloss:0.63964
# [0]	validation_0-logloss:0.70618
# [1]	validation_0-logloss:0.70116
# [2]	validation_0-logloss:0.69507
# [3]	validation_0-logloss:0.69131
# [4]	validation_0-logloss:0.68762
# [5]	validation_0-logloss:0.68405
# [6]	validation_0-logloss:0.67877
# [7]	validation_0-logloss:0.67424
# [8]	validation_0-logloss:0.66946
# [9]	validation_0-logloss:0.66665
# [10]	validation_0-logloss:0.66360
# [11]	validation_0-logloss:0.66089
# [12]	validation_0-logloss:0.65700
# [13]	validation_0-logloss:0.65471
# [14]	validation_0-logloss:0.65216
# [15]	validation_0-logloss:0.65026
# [16]	validation_0-logloss:0.64623
# [17]	validation_0-logloss:0.64384
# [18]	validation_0-logloss:0.64210
# [19]	validation_0-logloss:0.64027
# [0]	validation_0-logloss:0.70670
# [1]	validation_0-logloss:0.69983
# [2]	validation_0-logloss:0.69484
# [3]	validation_0-logloss:0.68922
# [4]	validation_0-logloss:0.68509
# [5]	validation_0-logloss:0.68036
# [6]	validation_0-logloss:0.67519
# [7]	validation_0-logloss:0.67131
# [8]	validation_0-logloss:0.66713
# [9]	validation_0-logloss:0.66283
# [10]	validation_0-logloss:0.65814
# [11]	validation_0-logloss:0.65464
# [12]	validation_0-logloss:0.65138
# [13]	validation_0-logloss:0.64862
# [14]	validation_0-logloss:0.64589
# [15]	validation_0-logloss:0.64286
# [16]	validation_0-logloss:0.63910
# [17]	validation_0-logloss:0.63653
# [18]	validation_0-logloss:0.63305
# [19]	validation_0-logloss:0.62994
# [0]	validation_0-logloss:0.70506
# [1]	validation_0-logloss:0.69993
# [2]	validation_0-logloss:0.69516
# [3]	validation_0-logloss:0.69028
# [4]	validation_0-logloss:0.68566
# [5]	validation_0-logloss:0.68072
# [6]	validation_0-logloss:0.67635
# [7]	validation_0-logloss:0.67377
# [8]	validation_0-logloss:0.66954
# [9]	validation_0-logloss:0.66655
# [10]	validation_0-logloss:0.66288
# [11]	validation_0-logloss:0.65947
# [12]	validation_0-logloss:0.65634
# [13]	validation_0-logloss:0.65288
# [14]	validation_0-logloss:0.64930
# [15]	validation_0-logloss:0.64647
# [16]	validation_0-logloss:0.64363
# [17]	validation_0-logloss:0.64049
# [18]	validation_0-logloss:0.63761
# [19]	validation_0-logloss:0.63529
# [0]	validation_0-logloss:0.70676
# [1]	validation_0-logloss:0.70196
# [2]	validation_0-logloss:0.69669
# [3]	validation_0-logloss:0.69169
# [4]	validation_0-logloss:0.68669
# [5]	validation_0-logloss:0.68162
# [6]	validation_0-logloss:0.67738
# [7]	validation_0-logloss:0.67384
# [8]	validation_0-logloss:0.67011
# [9]	validation_0-logloss:0.66629
# [10]	validation_0-logloss:0.66189
# [11]	validation_0-logloss:0.65804
# [12]	validation_0-logloss:0.65576
# [13]	validation_0-logloss:0.65280
# [14]	validation_0-logloss:0.64976
# [15]	validation_0-logloss:0.64740
# [16]	validation_0-logloss:0.64428
# [17]	validation_0-logloss:0.64164
# [18]	validation_0-logloss:0.63971
# [19]	validation_0-logloss:0.63706
# [0]	validation_0-logloss:0.70573
# [1]	validation_0-logloss:0.70021
# [2]	validation_0-logloss:0.69460
# [3]	validation_0-logloss:0.68953
# [4]	validation_0-logloss:0.68454
# [5]	validation_0-logloss:0.67921
# [6]	validation_0-logloss:0.67489
# [7]	validation_0-logloss:0.67170
# [8]	validation_0-logloss:0.66869
# [9]	validation_0-logloss:0.66478
# [10]	validation_0-logloss:0.66202
# [11]	validation_0-logloss:0.65832
# [12]	validation_0-logloss:0.65514
# [13]	validation_0-logloss:0.65225
# [14]	validation_0-logloss:0.64946
# [15]	validation_0-logloss:0.64712
# [16]	validation_0-logloss:0.64467
# [17]	validation_0-logloss:0.64207
# [18]	validation_0-logloss:0.64030
# [19]	validation_0-logloss:0.63909
# [0]	validation_0-logloss:0.70597
# [1]	validation_0-logloss:0.70090
# [2]	validation_0-logloss:0.69396
# [3]	validation_0-logloss:0.68913
# [4]	validation_0-logloss:0.68488
# [5]	validation_0-logloss:0.68098
# [6]	validation_0-logloss:0.67733
# [7]	validation_0-logloss:0.67225
# [8]	validation_0-logloss:0.66753
# [9]	validation_0-logloss:0.66434
# [10]	validation_0-logloss:0.66155
# [11]	validation_0-logloss:0.65874
# [12]	validation_0-logloss:0.65631
# [13]	validation_0-logloss:0.65407
# [14]	validation_0-logloss:0.65193
# [15]	validation_0-logloss:0.65009
# [16]	validation_0-logloss:0.64711
# [17]	validation_0-logloss:0.64343
# [18]	validation_0-logloss:0.64171
# [19]	validation_0-logloss:0.63987
# [0]	validation_0-logloss:0.70381
# [1]	validation_0-logloss:0.69715
# [2]	validation_0-logloss:0.69191
# [3]	validation_0-logloss:0.68700
# [4]	validation_0-logloss:0.68300
# [5]	validation_0-logloss:0.67840
# [6]	validation_0-logloss:0.67302
# [7]	validation_0-logloss:0.66800
# [8]	validation_0-logloss:0.66459
# [9]	validation_0-logloss:0.66053
# [10]	validation_0-logloss:0.65591
# [11]	validation_0-logloss:0.65218
# [12]	validation_0-logloss:0.64885
# [13]	validation_0-logloss:0.64592
# [14]	validation_0-logloss:0.64319
# [15]	validation_0-logloss:0.64027
# [16]	validation_0-logloss:0.63664
# [17]	validation_0-logloss:0.63409
# [18]	validation_0-logloss:0.63064
# [19]	validation_0-logloss:0.62849
# [0]	validation_0-logloss:0.70270
# [1]	validation_0-logloss:0.69676
# [2]	validation_0-logloss:0.69152
# [3]	validation_0-logloss:0.68639
# [4]	validation_0-logloss:0.68100
# [5]	validation_0-logloss:0.67597
# [6]	validation_0-logloss:0.67094
# [7]	validation_0-logloss:0.66790
# [8]	validation_0-logloss:0.66317
# [9]	validation_0-logloss:0.65887
# [10]	validation_0-logloss:0.65515
# [11]	validation_0-logloss:0.65183
# [12]	validation_0-logloss:0.64967
# [13]	validation_0-logloss:0.64606
# [14]	validation_0-logloss:0.64220
# [15]	validation_0-logloss:0.63903
# [16]	validation_0-logloss:0.63609
# [17]	validation_0-logloss:0.63252
# [18]	validation_0-logloss:0.63028
# [19]	validation_0-logloss:0.62765
# [20]	validation_0-logloss:0.62546
# [21]	validation_0-logloss:0.62295
# [22]	validation_0-logloss:0.62094
# [23]	validation_0-logloss:0.61937
# [24]	validation_0-logloss:0.61736
# [25]	validation_0-logloss:0.61531
# [26]	validation_0-logloss:0.61368
# [27]	validation_0-logloss:0.61230
# [28]	validation_0-logloss:0.61027
# [29]	validation_0-logloss:0.60890
# [0]	validation_0-logloss:0.70478
# [1]	validation_0-logloss:0.69900
# [2]	validation_0-logloss:0.69280
# [3]	validation_0-logloss:0.68706
# [4]	validation_0-logloss:0.68233
# [5]	validation_0-logloss:0.67701
# [6]	validation_0-logloss:0.67223
# [7]	validation_0-logloss:0.66755
# [8]	validation_0-logloss:0.66358
# [9]	validation_0-logloss:0.65976
# [10]	validation_0-logloss:0.65499
# [11]	validation_0-logloss:0.65097
# [12]	validation_0-logloss:0.64859
# [13]	validation_0-logloss:0.64537
# [14]	validation_0-logloss:0.64211
# [15]	validation_0-logloss:0.63919
# [16]	validation_0-logloss:0.63596
# [17]	validation_0-logloss:0.63274
# [18]	validation_0-logloss:0.63078
# [19]	validation_0-logloss:0.62835
# [20]	validation_0-logloss:0.62561
# [21]	validation_0-logloss:0.62308
# [22]	validation_0-logloss:0.62066
# [23]	validation_0-logloss:0.61849
# [24]	validation_0-logloss:0.61594
# [25]	validation_0-logloss:0.61426
# [26]	validation_0-logloss:0.61220
# [27]	validation_0-logloss:0.61087
# [28]	validation_0-logloss:0.60863
# [29]	validation_0-logloss:0.60677
# [0]	validation_0-logloss:0.70370
# [1]	validation_0-logloss:0.69788
# [2]	validation_0-logloss:0.69129
# [3]	validation_0-logloss:0.68536
# [4]	validation_0-logloss:0.67940
# [5]	validation_0-logloss:0.67440
# [6]	validation_0-logloss:0.66970
# [7]	validation_0-logloss:0.66516
# [8]	validation_0-logloss:0.66091
# [9]	validation_0-logloss:0.65701
# [10]	validation_0-logloss:0.65322
# [11]	validation_0-logloss:0.64958
# [12]	validation_0-logloss:0.64652
# [13]	validation_0-logloss:0.64355
# [14]	validation_0-logloss:0.64046
# [15]	validation_0-logloss:0.63811
# [16]	validation_0-logloss:0.63477
# [17]	validation_0-logloss:0.63217
# [18]	validation_0-logloss:0.62936
# [19]	validation_0-logloss:0.62751
# [20]	validation_0-logloss:0.62433
# [21]	validation_0-logloss:0.62183
# [22]	validation_0-logloss:0.62047
# [23]	validation_0-logloss:0.61857
# [24]	validation_0-logloss:0.61579
# [25]	validation_0-logloss:0.61330
# [26]	validation_0-logloss:0.61178
# [27]	validation_0-logloss:0.60936
# [28]	validation_0-logloss:0.60653
# [29]	validation_0-logloss:0.60451
# [0]	validation_0-logloss:0.70402
# [1]	validation_0-logloss:0.69871
# [2]	validation_0-logloss:0.69138
# [3]	validation_0-logloss:0.68570
# [4]	validation_0-logloss:0.67880
# [5]	validation_0-logloss:0.67473
# [6]	validation_0-logloss:0.67130
# [7]	validation_0-logloss:0.66760
# [8]	validation_0-logloss:0.66239
# [9]	validation_0-logloss:0.65919
# [10]	validation_0-logloss:0.65577
# [11]	validation_0-logloss:0.65290
# [12]	validation_0-logloss:0.64853
# [13]	validation_0-logloss:0.64605
# [14]	validation_0-logloss:0.64354
# [15]	validation_0-logloss:0.64162
# [16]	validation_0-logloss:0.63708
# [17]	validation_0-logloss:0.63462
# [18]	validation_0-logloss:0.63269
# [19]	validation_0-logloss:0.63096
# [20]	validation_0-logloss:0.62911
# [21]	validation_0-logloss:0.62748
# [22]	validation_0-logloss:0.62542
# [23]	validation_0-logloss:0.62417
# [24]	validation_0-logloss:0.62299
# [25]	validation_0-logloss:0.61977
# [26]	validation_0-logloss:0.61824
# [27]	validation_0-logloss:0.61524
# [28]	validation_0-logloss:0.61230
# [29]	validation_0-logloss:0.61077
# [0]	validation_0-logloss:0.70321
# [1]	validation_0-logloss:0.69586
# [2]	validation_0-logloss:0.69008
# [3]	validation_0-logloss:0.68474
# [4]	validation_0-logloss:0.68007
# [5]	validation_0-logloss:0.67491
# [6]	validation_0-logloss:0.66933
# [7]	validation_0-logloss:0.66367
# [8]	validation_0-logloss:0.65997
# [9]	validation_0-logloss:0.65560
# [10]	validation_0-logloss:0.65054
# [11]	validation_0-logloss:0.64670
# [12]	validation_0-logloss:0.64326
# [13]	validation_0-logloss:0.64044
# [14]	validation_0-logloss:0.63773
# [15]	validation_0-logloss:0.63432
# [16]	validation_0-logloss:0.63032
# [17]	validation_0-logloss:0.62772
# [18]	validation_0-logloss:0.62410
# [19]	validation_0-logloss:0.62099
# [20]	validation_0-logloss:0.61801
# [21]	validation_0-logloss:0.61462
# [22]	validation_0-logloss:0.61281
# [23]	validation_0-logloss:0.61007
# [24]	validation_0-logloss:0.60764
# [25]	validation_0-logloss:0.60529
# [26]	validation_0-logloss:0.60320
# [27]	validation_0-logloss:0.60107
# [28]	validation_0-logloss:0.59931
# [29]	validation_0-logloss:0.59689
# 100%|██████████| 35/35 [06:59<00:00, 12.00s/trial, best loss: -0.740811671983822]
# Processing key: alpha, val: 8.451196193049118
# Processing key: colsample_bytree, val: 0.40583474275638326
# Processing key: gamma, val: 0.7853747610053212
# Processing key: lambda, val: 8.385862116716124
# Processing key: learning_rate, val: 0.036573898272578106
# Processing key: max_depth, val: 0
# Processing key: min_child_weight, val: 19.0
# Processing key: n_estimators, val: 1
# Processing key: scale_pos_weight, val: 1.4939495145255228
# Processing key: subsample, val: 0.47921170817104575
# {'alpha': 8.451196193049118, 'colsample_bytree': 0.40583474275638326, 'gamma': 0.7853747610053212, 'lambda': 8.385862116716124, 'learning_rate': 0.036573898272578106, 'max_depth': 1, 'min_child_weight': 19.0, 'n_estimators': 20, 'scale_pos_weight': 1.4939495145255228, 'subsample': 0.47921170817104575}

# %%
# Merge default and best params
xgb_optimized_params = {**xgb_default_params, **xgb_best_params}
print(xgb_optimized_params)

# Train the model using the optimized parameters
xgb = XGBClassifier(**xgb_optimized_params)
xgb.fit(X_train_smote, y_train_smote)

# Evaluate on the training data
train_results = evaluate(xgb, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

# Evaluate on the validation data
validation_results = evaluate(xgb, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

# Evaluate on the test data
test_results = evaluate(xgb, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# {'random_state': 72, 'n_jobs': -1, 'alpha': 8.451196193049118, 'colsample_bytree': 0.40583474275638326, 'gamma': 0.7853747610053212, 'lambda': 8.385862116716124, 'learning_rate': 0.036573898272578106, 'max_depth': 1, 'min_child_weight': 19.0, 'n_estimators': 20, 'scale_pos_weight': 1.4939495145255228, 'subsample': 0.47921170817104575}
# Training Data Evaluation:
# {'Accuracy': 0.67, 'Precision': 0.6, 'Recall': 0.96, 'F1': 0.74}
#
# Validation Data Evaluation:
# {'Accuracy': 0.72, 'Precision': 0.7, 'Recall': 0.94, 'F1': 0.8}
#
# Test Data Evaluation:
# {'Accuracy': 0.65, 'Precision': 0.59, 'Recall': 0.97, 'F1': 0.74}

# %%
# Import necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.metrics import Metric, Precision, Recall

class F1Score(Metric):
    def __init__(self, name="f1_score", **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.f1 = self.add_weight(name="f1", initializer="zeros")
        self.precision = Precision()
        self.recall = Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)
        p = self.precision.result()
        r = self.recall.result()
        # Compute F1 Score
        self.f1.assign(2 * ((p * r) / (p + r + K.epsilon())))

    def result(self):
        return self.f1

    def reset_state(self):
        self.f1.assign(0.)
        self.precision.reset_state()
        self.recall.reset_state()


def optimize_hyperparams_mlp(space, X_train, y_train, X_val, y_val, enable_early_stopping=True, max_evals=25, random_state=72):

    def objective(params):
        try:
            # Build the model
            model = Sequential()
            model.add(Dense(params['hidden_layers'][0],
                            activation='relu',
                            input_dim=X_train.shape[1]))

            model.add(Dropout(params['dropout']))
            for units in params['hidden_layers'][1:]:
                model.add(Dense(units, activation='relu'))
                model.add(Dropout(params['dropout']))
            model.add(Dense(1, activation='sigmoid'))  # for binary classification

            if params['optimizer'] == 'adam':
                opt = Adam(learning_rate=params['learning_rate'])
            else:
                opt = SGD(learning_rate=params['learning_rate'])

            model.compile(optimizer=opt, loss='binary_crossentropy',
                          metrics=['accuracy', Precision(), Recall(), F1Score()])

            # Set early stopping
            if enable_early_stopping:
                callbacks = [EarlyStopping(monitor='val_loss', patience=5)]
            else:
                callbacks = None

            # Train the model
            model.fit(X_train, y_train, epochs=35,
                      batch_size=int(params['batch_size']),
                      verbose=0, validation_data=(X_val, y_val),
                      callbacks=callbacks)

            # Evaluate the model
            _, accuracy, precision, recall, f1_val = model.evaluate(X_val, y_val, verbose=0)

            return -f1_val  # we want to maximize accuracy, hence the negative sign

        except Exception as e:
            print(f"Exception encountered: {e}")
            return float('inf')

    trials = Trials()
    best = fmin(fn=objective, space=space, algo=tpe.suggest,
                max_evals=max_evals, trials=trials)
    best_params = hyperopt_indices_to_values(space, best)

    return best_params

# %%
from hyperopt import hp
from hyperopt import Trials, fmin, tpe

# Define the space
mlp_hyperparam_space = {
    'learning_rate': hp.loguniform('learning_rate', -5, -2),
    'batch_size': hp.choice('batch_size', [32, 64, 128, 256]),
    'hidden_layers': hp.choice('hidden_layers', [
        [16],
        [32],
        [64],
        [128],
        [16, 16],
        [32, 32],
        [64, 64],
        [128, 128],
        [128, 64],
        [64, 32],
        [32, 16],
        [128, 64, 32, 16],
        [128, 64, 32]
    ]),
    'optimizer': hp.choice('optimizer', ['adam', 'sgd']),
    'dropout': hp.uniform('dropout', 0, 0.5)
}

# Use the function
mlp_best_params = optimize_hyperparams_mlp(space=mlp_hyperparam_space,
                                           X_train=X_train_smote,
                                           y_train=y_train_smote,
                                           X_val=X_val, y_val=y_val,
                                           enable_early_stopping=True,
                                           max_evals=45)
print(mlp_best_params)
# Out:
# 100%|██████████| 45/45 [03:37<00:00,  4.83s/trial, best loss: -0.7924016118049622]
# Processing key: batch_size, val: 2
# Processing key: dropout, val: 0.41388664008035836
# Processing key: hidden_layers, val: 5
# Processing key: learning_rate, val: 0.007614747013552635
# Processing key: optimizer, val: 1
# {'batch_size': 128, 'dropout': 0.41388664008035836, 'hidden_layers': [32, 32], 'learning_rate': 0.007614747013552635, 'optimizer': 'sgd'}

# %%
# Evaluate the fitted pipeline
def evaluate_mlp(model, X, y):
    # Evaluate on given X
    _, accuracy, precision, recall, f1 = model.evaluate(X, y)

    # Return the values in a dictionary
    return {"Accuracy": accuracy, "Precision": precision, "Recall": recall, 'F1': f1}

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD

model = Sequential()

hidden_layers = mlp_best_params['hidden_layers']

print(hidden_layers)
for units in hidden_layers:
    model.add(Dense(units, activation='relu'))
    model.add(Dropout(mlp_best_params['dropout']))


# Output layer
model.add(Dense(1, activation='sigmoid'))

# Determine optimizer based on the optimized parameters
if mlp_best_params['optimizer'] == 'adam':
    optimizer = Adam(learning_rate=mlp_best_params['learning_rate'])
elif mlp_best_params['optimizer'] == 'sgd':
    optimizer = SGD(learning_rate=mlp_best_params['learning_rate'])

callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', Precision(), Recall(), F1Score()])
model.fit(X_train_smote, y_train_smote,
          validation_data=(X_val, y_val),
          epochs=mlp_best_params.get('epochs', 40),
          batch_size=mlp_best_params['batch_size'],
          callbacks=callbacks)
# Out:
# [32, 32]
# Epoch 1/40
# 15/15 [==============================] - 1s 31ms/step - loss: 0.7251 - accuracy: 0.5047 - precision_162: 0.5036 - recall_162: 0.6621 - f1_score: 0.5721 - val_loss: 0.6926 - val_accuracy: 0.5115 - val_precision_162: 0.6933 - val_recall_162: 0.3565 - val_f1_score: 0.4708
# Epoch 2/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.7014 - accuracy: 0.4916 - precision_162: 0.4919 - recall_162: 0.5089 - f1_score: 0.5003 - val_loss: 0.6887 - val_accuracy: 0.6269 - val_precision_162: 0.6732 - val_recall_162: 0.7539 - val_f1_score: 0.7113
# Epoch 3/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.7005 - accuracy: 0.5016 - precision_162: 0.5014 - recall_162: 0.5771 - f1_score: 0.5366 - val_loss: 0.6888 - val_accuracy: 0.6269 - val_precision_162: 0.7236 - val_recall_162: 0.6278 - val_f1_score: 0.6723
# Epoch 4/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6957 - accuracy: 0.5052 - precision_162: 0.5042 - recall_162: 0.6296 - f1_score: 0.5600 - val_loss: 0.6843 - val_accuracy: 0.6442 - val_precision_162: 0.6658 - val_recall_162: 0.8360 - val_f1_score: 0.7413
# Epoch 5/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5147 - precision_162: 0.5118 - recall_162: 0.6359 - f1_score: 0.5672 - val_loss: 0.6921 - val_accuracy: 0.4885 - val_precision_162: 0.7429 - val_recall_162: 0.2461 - val_f1_score: 0.3697
# Epoch 6/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6922 - accuracy: 0.5110 - precision_162: 0.5101 - recall_162: 0.5582 - f1_score: 0.5331 - val_loss: 0.6908 - val_accuracy: 0.5000 - val_precision_162: 0.7522 - val_recall_162: 0.2681 - val_f1_score: 0.3953
# Epoch 7/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6902 - accuracy: 0.5325 - precision_162: 0.5337 - recall_162: 0.5152 - f1_score: 0.5243 - val_loss: 0.6891 - val_accuracy: 0.5769 - val_precision_162: 0.7771 - val_recall_162: 0.4290 - val_f1_score: 0.5528
# Epoch 8/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6918 - accuracy: 0.5147 - precision_162: 0.5128 - recall_162: 0.5897 - f1_score: 0.5486 - val_loss: 0.6894 - val_accuracy: 0.5615 - val_precision_162: 0.7834 - val_recall_162: 0.3880 - val_f1_score: 0.5190
# Epoch 9/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.6875 - accuracy: 0.5404 - precision_162: 0.5412 - recall_162: 0.5310 - f1_score: 0.5360 - val_loss: 0.6865 - val_accuracy: 0.6692 - val_precision_162: 0.7757 - val_recall_162: 0.6435 - val_f1_score: 0.7034

# %%
# Evaluate the trained model
train_results = {}
train_results = evaluate_mlp(model, X_train_smote, y_train_smote)
print("Training Data Evaluation:")
print(train_results)

validation_results = evaluate_mlp(model, X_val, y_val)
print("\nValidation Data Evaluation:")
print(validation_results)

test_results = evaluate_mlp(model, X_test, y_test)
print("\nTest Data Evaluation:")
print(test_results)
# Out:
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.6495 - precision_162: 0.6607 - recall_162: 0.6149 - f1_score: 0.6370
# Training Data Evaluation:
# {'Accuracy': 0.6495277881622314, 'Precision': 0.6606538891792297, 'Recall': 0.6149002909660339, 'F1': 0.6369564533233643}
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.6692 - precision_162: 0.7757 - recall_162: 0.6435 - f1_score: 0.7034
#
# Validation Data Evaluation:
# {'Accuracy': 0.6692307591438293, 'Precision': 0.7756654024124146, 'Recall': 0.6435331106185913, 'F1': 0.7034482359886169}
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.6300 - precision_162: 0.6275 - recall_162: 0.6400 - f1_score: 0.6337
#
# Test Data Evaluation:
# {'Accuracy': 0.6299999952316284, 'Precision': 0.6274510025978088, 'Recall': 0.6399999856948853, 'F1': 0.6336632966995239}
